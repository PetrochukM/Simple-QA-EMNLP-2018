# %% [markdown]
# # Subject Recognition Data
#
# The goal of this notebook is to create data for subject recognition tagging. For every token in a question, we tag it with a I for inside subject or O for outside subject.

# %%
import sys
sys.path.insert(0, '../../')
import pandas as pd
from tqdm import tqdm_notebook
import scripts.utils.import_notebook
from scripts.utils.connect import get_connection 

tqdm_notebook().pandas()

connection = get_connection()
cursor = connection.cursor()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
from scripts.utils.simple_qa import load_simple_qa 

# Destination Filename
DEST_TRAIN = './../../data/subject_recognition/train.txt'
DEST_DEV = './../../data/subject_recognition/dev.txt'

df_dev, = load_simple_qa(dev=True)
print('Dev:')
display(df_dev[:5])
df_train, = load_simple_qa(train=True)
print('Train:')
display(df_train[:5])
# Out:
# Dev:
#    subject                      relation   object  \
# 0   0f3xg_  symbols/namesake/named_after   0cqt90
# 1   07f3jg  people/person/place_of_birth    0565d
# 2  031j8nn          music/release/region    07ssc
# 3  0c1cyhd            film/director/film  0wxsz5y
# 4  0fvhc0g          music/release/region    0345h
#
#                                             question
# 0  Who was the trump ocean club international hot...
# 1                       where was sasha vujačić born
# 2   What is a region that dead combo was released in
# 3  What is a film directed by wiebke von carolsfeld?
# 4  what country was music for stock exchange  rel...
# Train:
#    subject                        relation   object  \
# 0  04whkz5      book/written_work/subjects   01cj3p
# 1  0tp2p24     music/release_track/release  0sjc7c1
# 2  04j0t75               film/film/country    07ssc
# 3    0ftqr  music/producer/tracks_produced   0p600l
# 4  036p007         music/release/producers   0677ng
#
#                                             question
# 0                           what is the book e about
# 1  to what release does the release track cardiac...
# 2            what country was the film the debt from
# 3            what songs have nobuo uematsu produced?
# 4                          Who produced eve-olution?

# %% [markdown]
# ## Step 1 - Link Question to Subject Name

# %%
import importlib
from functools import partial
edit_distance_link_alias = importlib.import_module(
                "scripts.Simple QA Numbers.HYPOTHESIS - Question Refers to Multiple Subjects").edit_distance_link_alias
normalize = importlib.import_module(
                "scripts.Simple QA Numbers.HYPOTHESIS - Subject Name not in Question").normalize

# Create a column with the subject_name linked per example
df_dev['subject_name'] = df_dev.progress_apply(partial(edit_distance_link_alias, cursor, normalize), axis=1)
print('Dev Linked', sum(df_dev.subject_name.notnull()), 'examples')
display(df_dev[:5])
df_train['subject_name'] = df_train.progress_apply(partial(edit_distance_link_alias, cursor, normalize), axis=1)
print('Train Linked', sum(df_train.subject_name.notnull()), 'examples')
display(df_train[:5])
# Out:
# importing Jupyter notebook from ../../scripts/Simple QA Numbers/HYPOTHESIS - Question Refers to Multiple Subjects.ipynb
# importing Jupyter notebook from ../../scripts/Simple QA Numbers/HYPOTHESIS - Subject Name not in Question.ipynb
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# Dev Linked 10648 examples
#    subject                      relation   object  \
# 0   0f3xg_  symbols/namesake/named_after   0cqt90
# 1   07f3jg  people/person/place_of_birth    0565d
# 2  031j8nn          music/release/region    07ssc
# 3  0c1cyhd            film/director/film  0wxsz5y
# 4  0fvhc0g          music/release/region    0345h
#
#                                             question  \
# 0  Who was the trump ocean club international hot...
# 1                       where was sasha vujačić born
# 2   What is a region that dead combo was released in
# 3  What is a film directed by wiebke von carolsfeld?
# 4  what country was music for stock exchange  rel...
#
#                                      subject_name
# 0  trump ocean club international hotel and tower
# 1                                   sasha vujacic
# 2                                      dead combo
# 3                           wiebke von carolsfeld
# 4                        music for stock exchange
# HBox(children=(IntProgress(value=0, max=75910), HTML(value='')))
# Train Linked 74520 examples
#    subject                        relation   object  \
# 0  04whkz5      book/written_work/subjects   01cj3p
# 1  0tp2p24     music/release_track/release  0sjc7c1
# 2  04j0t75               film/film/country    07ssc
# 3    0ftqr  music/producer/tracks_produced   0p600l
# 4  036p007         music/release/producers   0677ng
#
#                                             question    subject_name
# 0                           what is the book e about               e
# 1  to what release does the release track cardiac...  cardiac arrest
# 2            what country was the film the debt from        the debt
# 3            what songs have nobuo uematsu produced?   nobuo uematsu
# 4                          Who produced eve-olution?     eve-olution

# %% [markdown]
# ## Step 2 - Determine the Span of the Subject Name
#
# During the first step, we determined the subject name that best fits the question. We now need to determine the span of the subject name inside the question

# %%
import importlib
import re

# Otherwise, importing this notebook the strip_accents wont be picked up as a definition
def strip_accents(*args, **kwargs):
    return importlib.import_module(
                "scripts.Simple QA Numbers.HYPOTHESIS - Subject Name not in Question"
    ).strip_accents(*args, **kwargs)

def preprocess(s):
    """
    Preprocess before tagging with IO.
    """
    # Represent characters in ASCII
    s = strip_accents(s)
    s = s.strip()
    s = s.lower()
    # Normalize quatations
    s = s.replace('“', '"').replace('”', '"').replace('’', "'").replace('‘', "'")
    # Substitue multiple spaces with one
    s = re.sub('\s+', ' ', s)
    return s

def normalize_abbreviations(s):
    # Only remove punctuation from words with punctuation
    if sum([c.isalnum() for c in s]) > 0 and s.count('.') > 0:
        s = s.replace('.', '')
    return s

normalize_abbreviations('A.C.D.C.')
# Out:
# 'ACDC'

# %%
import spacy

NLP = spacy.load('en_core_web_sm')
    
def spacy_tokenize(s):
    doc = NLP(s, disable=['parser', 'tagger', 'ner'])
    return [w.text for w in doc]

# %%
import math
from numpy import nan
from scripts.utils.edit_distance import edit_token_distance

def find_subject_name_span(row):
    if not isinstance(row['subject_name'], str):
        return row
    
    # Get the start character and end character that best match
    question_tokens = spacy_tokenize(preprocess(row['question']))
    question_tokens_no_abbreviations = tuple([normalize_abbreviations(t) for t in question_tokens])
    best_token_distance = math.inf
    best_start_index = None
    best_end_index = None
    best_subject_name_tokens = None

    # NOTE: Try multiple tokenization techiniques to line up the subject name with question
    for tokenize in [lambda s: s.split(), spacy_tokenize]:
        subject_name_tokens = tokenize(preprocess(row['subject_name']))
        subject_name_tokens = tuple([normalize_abbreviations(t) for t in subject_name_tokens])
        token_distance, start_index, end_index = edit_token_distance(subject_name_tokens,
                                                                     question_tokens_no_abbreviations)
            
        assert start_index <= end_index
        if token_distance < best_token_distance:
            best_token_distance = token_distance
            best_start_index = start_index
            best_end_index = end_index
            best_subject_name_tokens = subject_name_tokens
            
    # Edge case
    # Include the closing parentheses if one was opened
    if best_end_index < len(question_tokens) and question_tokens[best_end_index] == ')':
        best_end_index += 1
        
    row['start_index'] = best_start_index
    row['end_index'] = best_end_index
    row['subject_name_tokens'] = best_subject_name_tokens
    row['question_tokens'] = question_tokens
    return row
    

df_dev = df_dev.progress_apply(find_subject_name_span, axis=1)
display(df_dev[:5])
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
#    end_index   object                                           question  \
# 0       10.0   0cqt90  Who was the trump ocean club international hot...
# 1        4.0    0565d                       where was sasha vujačić born
# 2        7.0    07ssc   What is a region that dead combo was released in
# 3        9.0  0wxsz5y  What is a film directed by wiebke von carolsfeld?
# 4        7.0    0345h  what country was music for stock exchange  rel...
#
#                                      question_tokens  \
# 0  [who, was, the, trump, ocean, club, internatio...
# 1                 [where, was, sasha, vujacic, born]
# 2  [what, is, a, region, that, dead, combo, was, ...
# 3  [what, is, a, film, directed, by, wiebke, von,...
# 4  [what, country, was, music, for, stock, exchan...
#
#                        relation  start_index  subject  \
# 0  symbols/namesake/named_after          3.0   0f3xg_
# 1  people/person/place_of_birth          2.0   07f3jg
# 2          music/release/region          5.0  031j8nn
# 3            film/director/film          6.0  0c1cyhd
# 4          music/release/region          3.0  0fvhc0g
#
#                                      subject_name  \
# 0  trump ocean club international hotel and tower
# 1                                   sasha vujacic
# 2                                      dead combo
# 3                           wiebke von carolsfeld
# 4                        music for stock exchange
#
#                                  subject_name_tokens
# 0  (trump, ocean, club, international, hotel, and...
# 1                                   (sasha, vujacic)
# 2                                      (dead, combo)
# 3                          (wiebke, von, carolsfeld)
# 4                      (music, for, stock, exchange)

# %% [markdown]
# ## Analysis - Worst Spans
#
# Empirical analysis of the worst question tokens to subject name tokens link.

# %%
from Levenshtein import distance
from scripts.utils.table import format_pipe_table

print_data = []

for index, row in tqdm_notebook(df_dev.iterrows(), total=df_dev.shape[0]):  
    if not isinstance(row['subject_name'], str):
        continue

    # Print the worst fit subject_name's just in case
    tagged_subject_name = row['question_tokens'][int(row['start_index']):int(row['end_index'])]
    tagged_subject_name = ' '.join([normalize_abbreviations(t) for t in tagged_subject_name])
    edit_distance = distance(tagged_subject_name, ' '.join(row['subject_name_tokens']))
    max_length = max(len(' '.join(row['subject_name_tokens'])), len(tagged_subject_name))
    normalized_edit_distance = (max_length - edit_distance) / max_length
    print_data.append({
        'Predicted Subject Name': tagged_subject_name,
        'Original Subject Name': row['subject_name'],
        'Normalized Edit Distance': normalized_edit_distance,
        'Question Tokens': row['question_tokens'],
    })

exact_match = [d for d in print_data if d['Normalized Edit Distance'] == 1.0]
not_matched = [d for d in print_data if d['Normalized Edit Distance'] != 1.0]
print('Exact Match: %f [%d of %d]' % (len(exact_match) / len(print_data), len(exact_match), len(print_data)))
print('Not Matched:\n')
print(format_pipe_table(not_matched))
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# Exact Match: 0.976991 [10403 of 10648]
# Not Matched:
#
# | Index | Normalized Edit Distance | Original Subject Name | Predicted Subject Name | Question Tokens |
# | --- | --- | --- | --- | --- |
# | 0 | 0.9655172413793104 | roman-parthian war of 58–63 | roman – parthian war of 58–63 | ['what', 'entity', 'was', 'involved', 'in', 'the', 'roman', '–', 'parthian', 'war', 'of', '58–63'] |
# | 1 | 0.8333333333333334 | mecca | meccas | ['what', 'is', 'the', 'name', 'for', 'meccas', 'canonical', 'version'] |
# | 2 | 0.9310344827586207 | assassin's creed: revelations | assassins creed : revelations | ['what', 'kind', 'of', 'game', 'is', 'assassins', 'creed', ':', 'revelations'] |
# | 3 | 0.9285714285714286 | lim, hyung joo | lim hyung joo | ['what', 'kind', 'of', 'music', 'does', 'lim', 'hyung', 'joo', 'do'] |
# | 4 | 0.9444444444444444 | this pud's for you | this puds for you | ['what', 'is', 'the', 'series', 'where', 'the', 'episode', 'this', 'puds', 'for', 'you', 'comes', 'from'] |
# | 5 | 0.6666666666666666 | t-town | town | ['what', 'newspaper', 'circulates', 'in', 'the', 'town', 'of', 'kearny'] |
# | 6 | 0.9259259259259259 | who want's to live forever? | who wants to live forever | ['who', 'is', 'the', 'producer', 'of', 'who', 'wants', 'to', 'live', 'forever'] |
# | 7 | 0.9166666666666666 | paranoia: 1.0 | paranoia 10 | ['which', 'language', 'is', 'paranoia', '1.0', 'filmed', 'in', '?'] |
# | 8 | 0.8571428571428571 | ¡three amigos! | three amigos | ['who', 'did', 'the', 'music', 'for', 'three', 'amigos'] |
# | 9 | 0.9545454545454546 | mexican-american war | mexican – american war | ['who', 'was', 'involved', 'in', 'mexican', '–', 'american', 'war'] |
# | 10 | 0.9722222222222222 | the best of daniel o'donnell on film | the best of daniel odonnell on film | ['what', 'kind', 'of', 'music', 'is', 'the', 'film', 'the', 'best', 'of', 'daniel', 'odonnell', 'on', 'film', 'about', '?'] |
# | 11 | 0.9333333333333333 | philip pullman | phillip pullman | ['what', 'works', 'written', 'by', 'phillip', 'pullman', '?'] |
# | 12 | 0.975 | harry potter and the philosopher's stone | harry potter and the philosophers stone | ['what', 'genre', 'is', 'harry', 'potter', 'and', 'the', 'philosophers', 'stone'] |
# | 13 | 0.95 | .977 the '80s channel | 977 the 80s channel | ['which', 'soul', 'artist', 'is', 'featured', 'on', 'the', '.977', 'the', '80s', 'channel'] |
# | 14 | 0.9166666666666666 | kim hee-chul | kim heechul | ['which', 'city', 'is', 'kim', 'heechul', 'from'] |
# | 15 | 0.9772727272727273 | intégrale, volume 2: the guitar don't lie | integrale , volume 2 : the guitar do nt lie | ['what', "'s", 'a', 'song', 'released', 'on', 'integrale', ',', 'volume', '2', ':', 'the', 'guitar', 'do', 'nt', 'lie'] |
# | 16 | 0.9615384615384616 | bill & ted's bogus journey | bill & teds bogus journey | ['what', 'foreign', 'language', 'is', 'an', 'option', 'for', 'the', 'film', 'bill', '&', 'teds', 'bogus', 'journey'] |
# | 17 | 0.8846153846153846 | single-player video game | single - player mode game | ['what', 'is', 'a', 'single', '-', 'player', 'mode', 'game', '?'] |
# | 18 | 0.9473684210526315 | eve's beach fantasy | eves beach fantasy | ['what', 'language', 'is', 'spoken', 'in', 'eves', 'beach', 'fantasy'] |
# | 19 | 0.9473684210526315 | live in denmark '72 | live in denmark 72 | ['what', 'are', 'songs', 'of', 'the', 'live', 'in', 'denmark', '72', 'album'] |
# | 20 | 0.9230769230769231 | bonnie's kids | bonnies kids | ['what', 'is', 'the', 'genre', 'of', 'the', 'film', 'bonnies', 'kids', '?'] |
# | 21 | 0.9166666666666666 | men's badminton, singles | mens badminton , singles | ['what', 'olympic', 'games', 'was', 'mens', 'badminton', ',', 'singles', 'apart', 'of'] |
# | 22 | 0.8571428571428571 | germans | german | ['who', 'is', 'german', '?'] |
# | 23 | 0.9444444444444444 | action-adventure | action / adventure | ['what', 'is', 'an', 'action', '/', 'adventure', 'netflix', 'title'] |
# | 24 | 0.9 | love's labour's lost | loves labours lost | ['who', 'produced', 'the', 'film', 'loves', 'labours', 'lost'] |
# | 25 | 0.9565217391304348 | rogers-o'daniel house | rogers - odaniel house | ['what', 'county', 'is', 'rogers', '-', 'odaniel', 'house', 'apart', 'of'] |
# | 26 | 0.9285714285714286 | curtis pulley | curtis pulleys | ['what', 's', 'curtis', 'pulleys', 'profession'] |
# | 27 | 0.9743589743589743 | manos hajidakis - eidolo ston kathrefti | manos hajidakis : eidolo ston kathrefti | ['what', 'country', 'is', 'manos', 'hajidakis', ':', 'eidolo', 'ston', 'kathrefti', 'from'] |
# | 28 | 0.9 | supernews! | supernews | ['what', 'genre', 'of', 'program', 'is', 'supernews'] |
# | 29 | 0.9375 | showgirls 2: penny's from heaven | showgirls 2 : pennys from heaven | ['what', 'language', 'is', 'showgirls', '2', ':', 'pennys', 'from', 'heaven', 'in', '?'] |
# | 30 | 0.9230769230769231 | pop rock 80's | pop rock 80s | ['what', 'artists', 'broadcast', "'s", 'pop', 'rock', '80s', 'music'] |
# | 31 | 0.7777777777777778 | macedonia | macedon | ['what', 'invasions', 'happened', 'in', 'macedon'] |
# | 32 | 0.9565217391304348 | mockingbird don't sing | mockingbird do nt sing | ['what', 'kind', 'of', 'film', 'is', 'mockingbird', 'do', 'nt', 'sing'] |
# | 33 | 0.9285714285714286 | zalman shazar | zalman shazars | ['what', 'is', 'zalman', 'shazars', 'area', 'of', 'activism'] |
# | 34 | 0.9696969696969697 | atomic - the very best of blondie | atomic : the very best of blondie | ['what', 'type', 'of', 'release', 'is', 'atomic', ':', 'the', 'very', 'best', 'of', 'blondie', '?'] |
# | 35 | 0.8333333333333334 | album | albums | ['what', 'albums', 'were', 'released', 'in', '2000', '?'] |
# | 36 | 0.9 | zeke's pad | zekes pad | ['is', 'zekes', 'pad', 'an', 'action', ',', 'romance', ',', 'or', 'comedy', 'tv', 'program'] |
# | 37 | 0.9565217391304348 | raffi's christmas album | raffis christmas album | ['what', 'kind', 'of', 'album', 'is', 'raffis', 'christmas', 'album'] |
# | 38 | 0.8928571428571429 | u.s. office of war information | office of war information | ['which', 'film', 'did', 'the', 'office', 'of', 'war', 'information', 'help', 'produce'] |
# | 39 | 0.967741935483871 | phillipa lord: she's the shit | phillipa lord : she s the shit | ['which', 'country', 'released', 'phillipa', 'lord', ':', 'she', 's', 'the', 'shit'] |
# | 40 | 0.875 | pillows & prayers: cherry red 1982–1983 | pillows & prayers : cherry red 1982 | ['what', 'is', 'the', 'name', 'of', 'the', 'track', 'list', 'for', 'the', 'release', 'pillows', '&', 'prayers', ':', 'cherry', 'red', '1982', '-', '1983', '?'] |
# | 41 | 0.9375 | wichita [kansas | wichita , kansas | ['who', 'was', 'born', 'in', 'wichita', ',', 'kansas'] |
# | 42 | 0.8636363636363636 | victoria, australia | victoria ( australia ) | ['which', 'places', 'are', 'located', 'in', 'victoria', '(', 'australia', ')', '?'] |
# | 43 | 0.8666666666666667 | eat, pray, love | eat pray love | ['who', 'composed', 'the', 'music', 'for', 'eat', 'pray', 'love'] |
# | 44 | 0.8888888888888888 | lost (12\" inch version) | lost ( 12 inch version ) | ['what', 's', 'the', 'canonical', 'version', 'of', 'lost', '(', '12', 'inch', 'version', ')'] |
# | 45 | 0.8 | “you don’t dream in cryo. ....” | " you do n't dream in cryo " | ['what', 'artist', 'recorded', '"', 'you', 'do', "n't", 'dream', 'in', 'cryo', '"', '?'] |
# | 46 | 0.8 | drums | drum | ['which', 'musician', 'plays', 'the', 'drum', 'kit'] |
# | 47 | 0.75 | the crystal city | crystal city | ['what', 'genre', 'is', 'crystal', 'city'] |
# | 48 | 0.9130434782608695 | william e. mcanulty jr. | william e mcanulty , jr | ['what', 'is', 'william', 'e.', 'mcanulty', ',', 'jr', '.', "'s", 'gender'] |
# | 49 | 0.8571428571428571 | somalis | somali | ['who', "'s", 'somebody', 'that', 'identifies', 'with', 'the', 'somali', 'people'] |
# | 50 | 0.975 | san jose state spartans men's basketball | san jose state spartans mens basketball | ['which', 'sport', 'does', 'the', 'san', 'jose', 'state', 'spartans', 'mens', 'basketball', 'team', 'play'] |
# | 51 | 0.9375 | don't look down | do nt look down | ['what', 'is', 'do', 'nt', 'look', 'down', '?'] |
# | 52 | 0.9705882352941176 | now that's what i call music! 28 | now that s what i call music ! 28 | ['where', 'was', 'now', 'that', 's', 'what', 'i', 'call', 'music', '!', '28', 'released', '?'] |
# | 53 | 0.9523809523809523 | cosimo iii de' medici | cosimo iii de medici | ['which', 'family', 'is', 'cosimo', 'iii', 'de', 'medici', 'from'] |
# | 54 | 0.8 | drums | drum | ['who', 'played', 'the', 'drum', 'in', 'the', 'los', 'angeles', 'rock', 'quintet', 'rooney'] |
# | 55 | 0.75 | atb* | atb | ['what', "'s", 'a', 'remix', 'made', 'by', 'atb'] |
# | 56 | 0.9411764705882353 | timothy treadwell | timothy treadwall | ['what', 'gender', 'is', 'timothy', 'treadwall', '?'] |
# | 57 | 0.8571428571428571 | hawai`i | hawaii | ['name', 'a', 'volcano', 'located', 'in', 'hawaii'] |
# | 58 | 0.9473684210526315 | i'll be missing you | ill be missing you | ['what', 'is', 'the', 'name', 'of', 'the', 'artist', 'that', 'recorded', 'ill', 'be', 'missing', 'you'] |
# | 59 | 0.9565217391304348 | 20 classics of the '80s | 20 classics of the 80s | ['which', 'country', 'was', 'the', 'album', '20', 'classics', 'of', 'the', '80s', 'released', 'in', '?'] |
# | 60 | 0.9130434782608695 | happy birthday, lola! | happy birthday , lola | ['what', 'language', 'is', 'happy', 'birthday', ',', 'lola', 'in', '?'] |
# | 61 | 0.9411764705882353 | flannery o'connor | flannery oconnor | ['what', 'condition', 'did', 'flannery', 'oconnor', 'have'] |
# | 62 | 0.9428571428571428 | b'nai b'rith district grand lodge 1 | bnai brith district grand lodge 1 | ['what', 'state', 'is', 'bnai', 'brith', 'district', 'grand', 'lodge', '1', 'in'] |
# | 63 | 0.9259259259259259 | ahmed mubarak al-mahaijri | ahmed mubarak al mahaijri | ['what', 'is', 'the', 'birth', 'location', 'of', 'ahmed', 'mubarak', 'al', 'mahaijri', '?'] |
# | 64 | 0.9166666666666666 | mary o'grady | mary ogrady | ['mary', 'ogrady', 'was', 'born', 'in', 'what', 'country', '?'] |
# | 65 | 0.9473684210526315 | symphony no. 1 including \"blumine\ | symphony no . 1 including \\"blumine\\ | ['who', 'released', 'the', 'album', 'symphony', 'no', '.', '1', 'including', '\\\\"blumine\\\\', '"'] |
# | 66 | 0.9333333333333333 | half-a-mill | half - a - mil | ['what', 'was', 'half', '-', 'a', '-', 'mil', "'s", 'cause', 'of', 'death', '?'] |
# | 67 | 0.9333333333333333 | red cloud's war | red clouds war | ['what', 'was', 'involved', 'in', 'the', 'red', 'clouds', 'war', '?'] |
# | 68 | 0.9615384615384616 | it takes diff'rent strokes | it takes diffrent strokes | ['what', 'musician', 'recorded', 'the', 'track', 'it', 'takes', 'diffrent', 'strokes'] |
# | 69 | 0.9285714285714286 | fleetwood mack | fleetwood mac | ['where', 'play', 'fleetwood', 'mac', "'s", 'music'] |
# | 70 | 0.9523809523809523 | you can't hurry love | you ca nt hurry love | ['where', 'was', 'you', 'ca', 'nt', 'hurry', 'love', 'filmed', 'in', '?'] |
# | 71 | 0.975 | star wars: episode i - battle for naboo | star wars : episode i : battle for naboo | ['who', 'was', 'the', 'publisher', 'that', 'released', 'star', 'wars', ':', 'episode', 'i', ':', 'battle', 'for', 'naboo'] |
# | 72 | 0.9473684210526315 | mithun chakraborty | mithun chakrabortys | ['what', 'are', 'the', 'names', 'of', 'mithun', 'chakrabortys', 'children'] |
# | 73 | 0.9411764705882353 | the cryin' shames | the cryin shames | ['where', 'is', 'the', 'cryin', 'shames', 'from'] |
# | 74 | 0.9375 | barack obama, sr. | barack obama sr | ['what', 's', 'barack', 'obama', 'sr', '.', "'s", 'ethnicity'] |
# | 75 | 0.9166666666666666 | mick o'brien | mick obrien | ['what', 'gender', 'is', 'mick', 'obrien', '?'] |
# | 76 | 0.7272727272727273 | multiplayer video game | multiplayer game | ['what', 'is', 'a', 'multiplayer', 'game', '?'] |
# | 77 | 0.84 | daniel \"2dark\" richards | daniel 2dark richards | ['what', 'genre', 'does', 'daniel', '2dark', 'richards', 'produce', '?'] |
# | 78 | 0.9285714285714286 | kracker jack'd | kracker jackd | ['which', 'language', 'is', 'spoken', 'in', 'kracker', 'jackd'] |
# | 79 | 0.9583333333333334 | it's the way you love me | its the way you love me | ['which', 'female', 'artist', 'sang', 'its', 'the', 'way', 'you', 'love', 'me'] |
# | 80 | 0.8333333333333334 | album | albums | ['what', 'are', 'albums', '?'] |
# | 81 | 0.8333333333333334 | st. peter's church | st . peters church | ['what', 'is', 'st', '.', 'peters', 'church'] |
# | 82 | 0.9487179487179487 | gunnar \"the ghost pilot\" andersson | gunnar \\"the ghost pilot\\ " andersson | ['what', 'caused', 'gunnar', '\\\\"the', 'ghost', 'pilot\\\\', '"', 'andersson', "'s", 'death'] |
# | 83 | 0.8 | 'snaz | snaz | ['what', 'format', 'was', 'snaz', 'released', 'in'] |
# | 84 | 0.9310344827586207 | stompin' at the savoy: live | stompin at the savoy : live | ['where', 'was', 'stompin', 'at', 'the', 'savoy', ':', 'live', 'released', '?'] |
# | 85 | 0.8333333333333334 | get in the ring | get in the ring?\\ | ['what', 'is', 'the', 'release', 'typ', 'eof', 'the', 'album', 'get', 'in', 'the', 'ring?\\\\'] |
# | 86 | 0.9487179487179487 | screwed: al goldstein's kingdom of porn | screwed : al goldsteins kingdom of porn | ['what', 'is', 'the', 'type', 'of', 'release', 'of', 'screwed', ':', 'al', 'goldsteins', 'kingdom', 'of', 'porn', '?'] |
# | 87 | 0.9090909090909091 | no baggage? | no baggage | ['what', 'was', 'the', 'album', 'no', 'baggage', "'s", 'genre'] |
# | 88 | 0.8 | new american soldier | american soldier | ['what', 'is', 'the', 'language', 'spoken', 'in', 'the', 'filmnew', 'american', 'soldier', '?'] |
# | 89 | 0.9411764705882353 | james a. michener | james a micheners | ['what', 'is', 'james', 'a.', 'micheners', 'ethnicity'] |
# | 90 | 0.8148148148148148 | single-player video game | single - player horror game | ['what', "'s", 'the', 'name', 'of', 'a', 'single', '-', 'player', 'horror', 'game'] |
# | 91 | 0.8461538461538461 | david dodge | david f dodge | ['which', 'bay', 'area', 'city', 'was', 'david', 'f.', 'dodge', 'born', 'in'] |
# | 92 | 0.9230769230769231 | ann holbrook | anna holbrook | ['what', 'country', 'is', 'anna', 'holbrook', 'from'] |
# | 93 | 0.8 | unix® | unix | ['what', 'language', 'is', 'used', 'in', 'the', 'software', 'unix'] |
# | 94 | 0.9583333333333334 | peter's point plantation | peters point plantation | ['what', 'is', 'peters', 'point', 'plantation', "'s", 'architectural', 'style'] |
# | 95 | 0.9090909090909091 | chet's speech, part ii | chets speech , part ii | ['who', 'sings', 'chets', 'speech', ',', 'part', 'ii'] |
# | 96 | 0.95 | you're not a number | you re not a number | ['who', 'was', 'the', 'composer', 'for', 'you', 're', 'not', 'a', 'number'] |
# | 97 | 0.9473684210526315 | heaton's crossroads | heatons crossroads | ['which', 'war', 'did', 'the', 'heatons', 'crossroads', 'take', 'place'] |
# | 98 | 0.975 | what's the flavor ? : the black mixtape | what s the flavor ? : the black mixtape | ['what', "'s", 'a', 'track', 'featured', 'on', 'what', 's', 'the', 'flavor', '?', ':', 'the', 'black', 'mixtape'] |
# | 99 | 0.967741935483871 | clemson tigers men's basketball | clemson tigers mens basketball | ['what', 'conference', 'do', 'the', 'clemson', 'tigers', 'mens', 'basketball', 'play', 'in'] |
# | 100 | 0.9523809523809523 | roman-parthian wars | roman – parthian wars | ['who', 'is', 'an', 'entity', 'that', 'was', 'involved', 'in', 'roman', '–', 'parthian', 'wars'] |
# | 101 | 0.8666666666666667 | pablo longueira | pablo longueria | ['name', 'the', 'profession', 'of', 'pablo', 'longueria', '.'] |
# | 102 | 0.9090909090909091 | peter ford | peter fords | ['what', 'is', 'the', 'name', 'of', 'peter', 'fords', 'parent'] |
# | 103 | 0.9473684210526315 | uncle jasper's will | uncle jaspers will | ['who', 'produced', 'uncle', 'jaspers', 'will'] |
# | 104 | 0.7777777777777778 | topical medication | topical medicine | ['name', 'a', 'topical', 'medicine'] |
# | 105 | 0.9230769230769231 | french movies | french movie | ['what', 'is', 'the', 'name', 'of', 'a', 'woman', 'that', 'is', 'also', 'the', 'title', 'of', 'a', 'netflix', 'french', 'movie', '?'] |
# | 106 | 0.9761904761904762 | wallace and gromit's cracking contraptions | wallace and gromits cracking contraptions | ['what', 'kind', 'of', 'film', 'is', 'wallace', 'and', 'gromits', 'cracking', 'contraptions', '?'] |
# | 107 | 0.8 | nicol | nico | ['what', 'is', 'the', 'name', 'of', 'one', 'of', 'nico', "'s", 'songs'] |
# | 108 | 0.7272727272727273 | multiplayer video game | multiplayer game | ['what', "'s", 'a', 'text', 'based', 'multiplayer', 'game'] |
# | 109 | 0.8333333333333334 | album | albums | ['which', 'albums', 'were', 'released', 'by', 'deep', 'purple', '?'] |
# | 110 | 0.8095238095238095 | sign \"o\" the times | sign ' o ' the times | ['what', 'kind', 'of', 'album', 'is', 'sign', "'", 'o', "'", 'the', 'times'] |
# | 111 | 0.9655172413793104 | dimillo's floating restaurant | dimillos floating restaurant | ['what', 'state', 'is', 'dimillos', 'floating', 'restaurant', 'in', '?'] |
# | 112 | 0.8 | drums | drum | ['which', 'instrumentalists', 'play', 'the', 'drum', 'kit', '?'] |
# | 113 | 0.9565217391304348 | ich wär' so gern wie du | ich war so gern wie du | ['who', 'recorded', 'ich', 'war', 'so', 'gern', 'wie', 'du'] |
# | 114 | 0.9583333333333334 | battle of drewry's bluff | battle of drewrys bluff | ['what', 'campaign', 'was', 'the', 'battle', 'of', 'drewrys', 'bluff', 'a', 'part', 'of'] |
# | 115 | 0.9583333333333334 | rockin' with judy jetson | rockin with judy jetson | ['who', 's', 'the', 'producer', 'of', 'the', 'film', 'rockin', 'with', 'judy', 'jetson'] |
# | 116 | 0.96875 | there are things you don't know | there are things you do nt know | ['what', 'language', 'is', 'there', 'are', 'things', 'you', 'do', 'nt', 'know', 'shot', 'in'] |
# | 117 | 0.9583333333333334 | britain's next top model | britains next top model | ['what', 'kind', 'of', 'show', 'is', 'britains', 'next', 'top', 'model', '?'] |
# | 118 | 0.7222222222222222 | ready.. set.. zoom! | ready , set , zoom | ['who', 'was', 'the', 'director', 'of', 'the', 'film', 'ready', ',', 'set', ',', 'zoom', '!'] |
# | 119 | 0.8571428571428571 | peanut | peanuts | ['what', 'indonesian', 'food', 'contains', 'chilis', 'and', 'peanuts', '?'] |
# | 120 | 0.9565217391304348 | the godfather's revenge | the godfathers revenge | ['what', 'is', 'the', 'genre', 'for', 'the', 'book', 'the', 'godfathers', 'revenge'] |
# | 121 | 0.875 | 80's box | 80s box | ['in', 'what', 'region', 'did', '80s', 'box', 'release'] |
# | 122 | 0.9487179487179487 | the national parks: america's best idea | the national parks : americas best idea | ['who', 'produced', 'the', 'film', 'the', 'national', 'parks', ':', 'americas', 'best', 'idea'] |
# | 123 | 0.96 | it doesn't really matter | it does nt really matter | ['which', '1990s', 'singer', 'wrote', 'the', 'lyrics', 'for', 'it', 'does', 'nt', 'really', 'matter', '?'] |
# | 124 | 0.7058823529411765 | texas a&m university school of law | university school of law | ['where', 'is', 'texas', 'wesleyan', 'university', 'school', 'of', 'law', 'located', '?'] |
# | 125 | 0.9655172413793104 | roman-parthian war of 58–63 | roman – parthian war of 58–63 | ['where', 'was', 'the', 'roman', '–', 'parthian', 'war', 'of', '58–63', 'located'] |
# | 126 | 0.9230769230769231 | dynamite cop! | dynamite cop | ['what', 'is', 'the', 'computer', 'video', 'game', 'genre', 'of', 'dynamite', 'cop'] |
# | 127 | 0.972972972972973 | alabama crimson tide men's basketball | alabama crimson tide mens basketball | ['what', 'division', 'is', 'alabama', 'crimson', 'tide', 'mens', 'basketball', '?'] |
# | 128 | 0.6666666666666666 | ac\\dc | acdc | ['which', 'label', 'company', 'is', 'acdc', 'signed', 'to'] |
# | 129 | 0.8571428571428571 | bretons | breton | ['name', 'one', 'of', 'the', 'breton', 'people'] |
# | 130 | 0.9259259259259259 | fido's summer fun, volume 2 | fidos summer fun , volume 2 | ['what', "'s", 'a', 'track', 'listed', 'on', 'fidos', 'summer', 'fun', ',', 'volume', '2'] |
# | 131 | 0.8571428571428571 | live at \"sweet basil\", volume 2 | live at sweet basil , volume 2 | ['what', 'is', 'the', 'release', 'type', 'of', 'live', 'at', 'sweet', 'basil', ',', 'volume', '2'] |
# | 132 | 0.9615384615384616 | sid meier's alpha centauri | sid meiers alpha centauri | ['what', 'is', 'the', 'name', 'of', 'the', 'game', 'that', 'has', 'a', 'version', 'titled', 'sid', 'meiers', 'alpha', 'centauri'] |
# | 133 | 0.9354838709677419 | a sides win: singles 1992-2005 | a sides win : singles 1992–2005 | ['what', 'type', 'of', 'content', 'album', 'is', 'a', 'sides', 'win', ':', 'singles', '1992–2005', '?'] |
# | 134 | 0.7777777777777778 | blackhawk band | blackhawk ( band ) | ['what', 'is', 'the', 'album', 'of', 'blackhawk', '(', 'band', ')'] |
# | 135 | 0.9545454545454546 | kleines, dickes müller | kleines dickes muller | ['what', 'country', 'is', 'kleines', 'dickes', 'muller', 'from', '?'] |
# | 136 | 0.9655172413793104 | mona - the carnivorous circus | mona – the carnivorous circus | ['what', 'genre', 'does', 'the', 'album', 'mona', '–', 'the', 'carnivorous', 'circus', 'belong', 'to'] |
# | 137 | 0.9285714285714286 | acorna's world | acornas world | ['who', 'wrote', 'acornas', 'world', '?'] |
# | 138 | 0.8620689655172413 | salvatore \"the boss\" maroni | salvatore the boss maroni | ['what', 'gender', 'is', 'salvatore', 'the', 'boss', 'maroni', '?'] |
# | 139 | 0.9230769230769231 | quartet live! | quartet live | ['who', 'is', 'the', 'artist', 'of', 'the', 'album', 'quartet', 'live'] |
# | 140 | 0.9444444444444444 | tabu \"thick n' sassy\" magazine | tabu \\"thick n ' sassy\\ " magazine | ['what', 'does', 'tabu', '\\\\"thick', 'n', "'", 'sassy\\\\', '"', 'magazine', 'write', 'about'] |
# | 141 | 0.926829268292683 | disney's kim possible 2: drakken's demise | disneys kim possible 2 : drakkens demise | ['what', 'is', 'a', 'gameplay', 'mode', 'supported', 'on', 'disneys', 'kim', 'possible', '2', ':', 'drakkens', 'demise', '?'] |
# | 142 | 0.8888888888888888 | greco–punic wars | greek – punic wars | ['where', 'did', 'greek', '–', 'punic', 'wars', 'take', 'place', '?'] |
# | 143 | 0.875 | d'scover | dscover | ['what', 'rock', 'genre', 'does', 'dscover', 'fall', 'under'] |
# | 144 | 0.7142857142857143 | maurice merleau­ponty | maurice merleau | ['who', 'did', 'maurice', 'merleau', '-', 'ponty', 'help', 'to', 'influence'] |
# | 145 | 0.9090909090909091 | beat 'em up | beat em up | ['what', 'is', 'the', 'name', 'of', 'a', 'video', 'game', 'of', 'the', 'beat', 'em', 'up', 'collection'] |
# | 146 | 0.96 | richard scarry's busytown | richard scarrys busytown | ['what', 'is', 'a', 'gameplay', 'mode', 'featured', 'on', 'richard', 'scarrys', 'busytown'] |
# | 147 | 0.9166666666666666 | shoot 'em up | shoot em up | ['where', 'was', 'the', 'movie', 'shoot', 'em', 'up', 'shot'] |
# | 148 | 0.9230769230769231 | minor planets | minor planet | ['what', 'is', 'a', 'main', '-', 'belt', 'minor', 'planet', 'discovered', 'in', '1999', '?'] |
# | 149 | 0.9333333333333333 | that's my mama | that s my mama | ['that', 's', 'my', 'mama', 'is', 'labeled', 'under', 'what', 'netflix', 'genre', 'title', '?'] |
# | 150 | 0.8461538461538461 | foghat (rock 'n' roll) | foghat ( rock n roll ) | ['what', 'type', 'of', 'music', 'is', 'foghat', '(', 'rock', 'n', 'roll', ')', '?'] |
# | 151 | 0.9090909090909091 | indie film | indie films | ['what', 'are', 'indie', 'films', '?'] |
# | 152 | 0.8928571428571429 | st. peter's episcopal church | st . peters episcopal church | ['what', 'state', 'and', 'city', 'is', 'st', '.', 'peters', 'episcopal', 'church', 'located', 'in', '?'] |
# | 153 | 0.9 | ĭn’terview | interview | ['what', 'kind', 'of', 'music', 'is', 'the', 'interview', 'album'] |
# | 154 | 0.972972972972973 | can't get blue monday out of my head | ca nt get blue monday out of my head | ['which', 'song', 'was', 'part', 'of', 'ca', 'nt', 'get', 'blue', 'monday', 'out', 'of', 'my', 'head'] |
# | 155 | 0.9642857142857143 | the wonderful wizard of ha's | the wonderful wizard of has | ['what', 'film', 'series', 'is', 'the', 'wonderful', 'wizard', 'of', 'has', 'from', '?'] |
# | 156 | 0.9285714285714286 | solid gold '68 | solid gold 68 | ['what', 'genre', 'was', 'the', 'musical', 'album', 'solid', 'gold', '68', '.'] |
# | 157 | 0.9166666666666666 | cartel, 1882 | cartel 1882 | ['which', 'country', 'is', 'cartel', '1882', 'filmed', 'in', '?'] |
# | 158 | 0.7241379310344828 | godbout v longueuil (city of) | godbout v longueuil case | ['what', 'court', 'handled', 'the', 'godbout', 'v.', 'longueuil', 'case', '?'] |
# | 159 | 0.9444444444444444 | action-adventure | action / adventure | ['what', 'is', 'a', 'action', '/', 'adventure', 'film'] |
# | 160 | 0.9166666666666666 | death eaters | death eater | ['which', 'is', 'the', 'name', 'of', 'a', 'death', 'eater', 'in', 'harry', 'potter', '?'] |
# | 161 | 0.9615384615384616 | pretend you don't see her | pretend you do nt see her | ['what', 'netflix', 'genre', 'was', 'the', 'title', 'pretend', 'you', 'do', 'nt', 'see', 'her'] |
# | 162 | 0.8636363636363636 | victoria, australia | victoria ( australia ) | ['what', 'secondary', 'college', 'is', 'located', 'in', 'victoria', '(', 'australia', ')'] |
# | 163 | 0.9473684210526315 | thursday's children | thursdays children | ['who', 'directed', 'thursdays', 'children'] |
# | 164 | 0.9 | defenseman | defenceman | ['what', 'player', 'is', 'a', 'defenceman', '(', 'ice', 'hockey', ')'] |
# | 165 | 0.9411764705882353 | can't get enough | ca nt get enough | ['which', 'artist', 'sang', 'the', 'song', 'ca', 'nt', 'get', 'enough'] |
# | 166 | 0.875 | cruisin' | cruisin | ['what', "'s", 'the', 'original', 'version', 'of', 'cruisin'] |
# | 167 | 0.8666666666666667 | elliot eisner | elliot w eisner | ['which', 'city', 'was', 'elliot', 'w.', 'eisner', 'born'] |
# | 168 | 0.9375 | love's boomerang | loves boomerang | ['what', 'is', 'the', 'genre', 'associated', 'with', 'loves', 'boomerang'] |
# | 169 | 0.9767441860465116 | a connecticut yankee in king arthur's court | a connecticut yankee in king arthurs court | ['where', 'published', 'a', 'connecticut', 'yankee', 'in', 'king', 'arthurs', 'court'] |
# | 170 | 0.9166666666666666 | kevin walsh | kevin walshs | ['what', 'is', 'kevin', 'walshs', 'nationality'] |
# | 171 | 0.9473684210526315 | emmanuel college: st. paul's campus | emmanuel college : st . pauls campus | ['this', 'color', 'is', 'one', 'of', 'three', 'that', 'represent', 'emmanuel', 'college', ':', 'st', '.', 'pauls', 'campus', '.'] |
# | 172 | 0.9333333333333333 | timothy's quest | timothys quest | ['what', 'type', 'of', 'film', 'is', 'timothys', 'quest', '?'] |
# | 173 | 0.8620689655172413 | the return of 'allo 'allo! | the return of allo allo ! | ['what', 'kind', 'of', 'tv', 'show', 'is', 'the', 'return', 'of', 'allo', 'allo', '!'] |
# | 174 | 0.8461538461538461 | alvin \"youngblood\" hart | alvin ' youngblood ' hart | ['what', 'is', 'the', 'nationality', 'of', 'alvin', "'", 'youngblood', "'", 'hart', '?'] |
# | 175 | 0.95 | strategy video game | strategy video games | ['what', 'are', 'some', 'strategy', 'video', 'games'] |
# | 176 | 0.9666666666666667 | double easy - the u.s. singles | double easy : the us . singles | ['what', 'format', 'was', 'double', 'easy', ':', 'the', 'u.s', '.', 'singles', 'released', 'in', '?'] |
# | 177 | 0.8260869565217391 | william \"bull\" nelson | william bull nelson | ['what', 'caused', 'william', 'bull', 'nelson', "'s", 'death'] |
# | 178 | 0.9285714285714286 | hilo, hawai'i | hilo , hawaii | ['what', 'is', 'the', 'postal', 'code', 'in', 'hilo', ',', 'hawaii'] |
# | 179 | 0.9090909090909091 | 'little' jimmy dickens | little jimmy dickens | ['where', 'is', 'little', 'jimmy', 'dickens', 'from', '?'] |
# | 180 | 0.7857142857142857 | first battle of james island | battle of james island | ['name', 'a', 'soldier', 'involved', 'in', 'the', 'battle', 'of', 'james', 'island', '.'] |
# | 181 | 0.9411764705882353 | swingin' with bud | swingin with bud | ['what', 'kinds', 'of', 'music', 'is', 'swingin', 'with', 'bud'] |
# | 182 | 0.9230769230769231 | sandry's book | sandrys book | ['what', 'kind', 'of', 'book', 'is', 'sandrys', 'book'] |
# | 183 | 0.7777777777777778 | dr. c.h.u.d. | dr . chud | ['does', 'dr', '.', 'chud', 'play', 'the', 'drum', 'kit', 'or', 'guitar'] |
# | 184 | 0.8823529411764706 | millard s drexler | millard drexler | ['what', 'organization', 'did', 'millard', 'drexler', 'found'] |
# | 185 | 0.9473684210526315 | guy's grocery games | guys grocery games | ['what', 'type', 'of', 'show', 'is', 'guys', 'grocery', 'games', '?'] |
# | 186 | 0.9166666666666666 | megan cheng | megan chengs | ['what', 's', 'megan', 'chengs', 'ethnicity'] |
# | 187 | 0.9375 | soumodip sarkar | soumodip sarkars | ['what', 'is', 'soumodip', 'sarkars', 'place', 'of', 'birth'] |
# | 188 | 0.9523809523809523 | durban girls' college | durban girls college | ['what', 'kind', 'of', 'school', 'is', 'durban', 'girls', 'college', '?'] |
# | 189 | 0.9375 | beretta's island | berettas island | ['what', 'type', 'of', 'film', 'is', 'berettas', 'island'] |
# | 190 | 0.8666666666666667 | kim, jin-man | kim jin - man | ['which', 'country', 'is', 'kim', 'jin', '-', 'man', 'from'] |
# | 191 | 0.9444444444444444 | what's this?!! | what s this ? ! ! | ['who', 'is', 'the', 'lyricist', 'for', 'the', 'composition', 'what', 's', 'this', '?', '!', '!'] |
# | 192 | 0.875 | cruisin' | cruisin | ['what', 'release', 'is', 'cruisin', 'on', '?'] |
# | 193 | 0.9545454545454546 | prince george's county | prince georges county | ['what', 'is', 'in', 'prince', 'georges', 'county'] |
# | 194 | 0.9629629629629629 | improvized explosive device | improvised explosive device | ['what', 'is', 'a', 'type', 'of', 'disaster', 'from', 'a', 'improvised', 'explosive', 'device', '?'] |
# | 195 | 0.9285714285714286 | when it's over | when its over | ['what', 'film', 'genre', 'is', 'when', 'its', 'over'] |
# | 196 | 0.9375 | who's an expert | who s an expert | ['what', 'is', 'the', 'subject', 'of', 'who', 's', 'an', 'expert', '?'] |
# | 197 | 0.9629629629629629 | you can't take it with you | you ca nt take it with you | ['who', 'created', 'the', 'story', 'for', 'the', 'film', 'you', 'ca', 'nt', 'take', 'it', 'with', 'you'] |
# | 198 | 0.8571428571428571 | dory funk jr. | dory funk , jr | ['where', 'was', 'dory', 'funk', ',', 'jr', '.', 'born', '?'] |
# | 199 | 0.96 | blue's clues kindergarten | blues clues kindergarten | ['who', 'published', 'the', 'game', 'blues', 'clues', 'kindergarten'] |
# | 200 | 0.9285714285714286 | mount grant, south georgia | mount grant in south georgia | ['what', 'country', 'is', 'mount', 'grant', 'in', 'south', 'georgia', 'located', '?'] |
# | 201 | 0.9545454545454546 | battle of hudson's bay | battle of hudsons bay | ['where', 'did', 'the', 'battle', 'of', 'hudsons', 'bay', 'take', 'place'] |
# | 202 | 0.8333333333333334 | album | albums | ['what', 'albums', 'did', 'willie', 'nelson', 'release', '?'] |
# | 203 | 0.7894736842105263 | the regatta mystery | regatta mystery | ['what', 'theme', 'is', 'in', 'the', 'piece', 'regatta', 'mystery'] |
# | 204 | 0.8333333333333334 | album | albums | ['which', 'albums', 'were', 'released', 'by', 'the', 'century', 'media', 'label', '?'] |
# | 205 | 0.9767441860465116 | hms pinafore: i’m called little buttercup | hms pinafore : i m called little buttercup | ['who', 'is', 'the', 'artist', 'that', 'recorded', 'hms', 'pinafore', ':', 'i', 'm', 'called', 'little', 'buttercup', '?'] |
# | 206 | 0.9565217391304348 | álvaro d'ataide da gama | alvaro dataide da gama | ['what', 'is', 'alvaro', 'dataide', 'da', 'gama'] |
# | 207 | 0.9705882352941176 | chara the best: baby baby baby xxx | chara the best baby baby baby xxx | ['what', 'type', 'of', 'music', 'did', 'chara', 'the', 'best', 'baby', 'baby', 'baby', 'xxx', 'play', '?'] |
# | 208 | 0.9655172413793104 | santa claus is comin' to town | santa claus is comin to town | ['what', 'is', 'a', 'song', 'on', 'the', 'recording', 'santa', 'claus', 'is', 'comin', 'to', 'town'] |
# | 209 | 0.9090909090909091 | coup d'etat | coup detat | ['what', 'format', 'was', 'coup', 'detat', 'released', 'in'] |
# | 210 | 0.9428571428571428 | don't tell me (what love can do) | do n't tell me 9what love can do ) | ['who', 'composed', '"', 'do', "n't", 'tell', 'me', '9what', 'love', 'can', 'do', ')', '"', '?'] |
# | 211 | 0.8666666666666667 | raymond a. meier | raymond meier | ['which', 'city', 'was', 'raymond', 'meier', 'born', 'in'] |
# | 212 | 0.9375 | edwina armstrong | edwina armstron | ['who', 'is', 'edwina', 'armstron', "'s", 'parent', '?'] |
# | 213 | 0.9565217391304348 | the emperor's new cloak | the emperors new cloak | ['who', 'wrote', 'the', 'emperors', 'new', 'cloak'] |
# | 214 | 0.9444444444444444 | men's pommel horse | mens pommel horse | ['what', 'olympic', 'games', 'featured', 'mens', 'pommel', 'horse'] |
# | 215 | 0.9473684210526315 | parkinson's disease | parkinsons disease | ['which', 'american', 'judge', 'died', 'due', 'to', 'parkinsons', 'disease'] |
# | 216 | 0.9166666666666666 | d'atra hicks | datra hicks | ['where', 'in', 'manhattan', 'was', 'datra', 'hicks', "'s", 'birthplace', '?'] |
# | 217 | 0.9705882352941176 | the best of martin denny's exotica | the best of martin dennys exotica | ['what', 'kind', 'of', 'album', 'the', 'best', 'of', 'martin', 'dennys', 'exotica'] |
# | 218 | 0.9565217391304348 | the girl from tomorrow part ii: tomorrow's end | the girl from tomorrow part ii : tomorrows end | ['what', 'language', 'is', 'the', 'girl', 'from', 'tomorrow', 'part', 'ii', ':', 'tomorrows', 'end', 'in', '?'] |
# | 219 | 0.9130434782608695 | john d. rockefeller jr. | john d rockefeller , jr | ['who', 'is', 'john', 'd.', 'rockefeller', ',', 'jr', '.', 'named', 'after'] |
# | 220 | 0.9166666666666666 | woody's gone | woodys gone | ['who', 'recorded', 'woodys', 'gone'] |
# | 221 | 0.9333333333333333 | st barnabas' church, chester | st barnabas church , chester | ['where', 'is', 'st', 'barnabas', 'church', ',', 'chester', 'located', '?'] |
# | 222 | 0.9166666666666666 | yann songo'o | yann songoo | ['what', 'is', 'the', 'nation', 'to', 'which', 'yann', 'songoo', 'belongs'] |
# | 223 | 0.7894736842105263 | luxembourg city | luxembourg ( city ) | ['what', 'is', 'an', 'attraction', 'is', 'luxembourg', '(', 'city', ')'] |
# | 224 | 0.8 | drums | drum | ['who', 'uses', 'a', 'drum', 'kit', '?'] |
# | 225 | 0.7777777777777778 | ian kamau | is kamau | ['which', 'city', 'is', 'kamau', 'from'] |
# | 226 | 0.8333333333333334 | bikash malla | bikash malal | ['what', 'is', 'bikash', 'malal', "'s", 'nationality', '?'] |
# | 227 | 0.96 | classics: the early years | classics the early years | ['who', 'released', 'the', 'album', 'classics', 'the', 'early', 'years'] |
# | 228 | 0.9459459459459459 | all the stuff (and more!) volume 2 | all the stuff ( and more ) , volume 2 | ['what', 'type', 'of', 'album', 'was', 'all', 'the', 'stuff', '(', 'and', 'more', ')', ',', 'volume', '2'] |
# | 229 | 0.9166666666666666 | brian o'shea | brian oshea | ['brian', 'oshea', 'performs', 'what', 'type', 'of', 'martial', 'art'] |
# | 230 | 0.9285714285714286 | willie \"the lion\" smith | willie \\"the lion\\ " smith | ['what', 's', 'the', 'genre', 'of', 'music', 'that', 'the', 'artist', 'willie', '\\\\"the', 'lion\\\\', '"', 'smith', 'makes'] |
# | 231 | 0.9 | pakistanis | pakistani | ['who', 'is', 'a', 'bollywood', 'actor', 'who', 'belongs', 'to', 'pakistani', 'people'] |
# | 232 | 0.84 | alvin \"youngblood\" hart | alvin youngblood hart | ['what', 'radio', 'station', 'plays', 'music', 'from', 'alvin', 'youngblood', 'hart', '?'] |
# | 233 | 0.9722222222222222 | npr: wait wait... don't tell me! | npr : wait wait ... do nt tell me ! | ['who', 'produces', 'npr', ':', 'wait', 'wait', '...', 'do', 'nt', 'tell', 'me', '!', 'podcast'] |
# | 234 | 0.5714285714285714 | aqua??? | aqua | ['what', 'kind', 'of', 'music', 'does', 'aqua', '(', 'band', ')', 'play'] |
# | 235 | 0.95 | william wilson \"buffalo bill\" quinn | william wilson \\"buffalo bill\\ " quinn | ['where', 'did', 'william', 'wilson', '\\\\"buffalo', 'bill\\\\', '"', 'quinn', 'die'] |
# | 236 | 0.8823529411764706 | lee, hyung-min | lee hyung - min | ['what', 'is', 'the', 'gender', 'of', 'lee', 'hyung', '-', 'min', '?'] |
# | 237 | 0.9583333333333334 | online news association | online news associations | ['what', 'is', 'online', 'news', 'associations', 'sector'] |
# | 238 | 0.9230769230769231 | jim beggarly | jim beggarlys | ['what', 's', 'jim', 'beggarlys', 'gender'] |
# | 239 | 0.9285714285714286 | roy nicholson | roy nicholsons | ['what', 'is', 'roy', 'nicholsons', 'profession'] |
# | 240 | 0.5714285714285714 | aqua??? | aqua | ['what', 'kind', 'of', 'artist', 'is', 'aqua', '(', 'band', ')', '?'] |
# | 241 | 0.9090909090909091 | piranha 3dd | piranha dd | ['what', 'company', 'produced', 'piranha', 'dd'] |
# | 242 | 0.9375 | regan gascoigne | regan gascoignes | ['who', 'is', 'regan', 'gascoignes', 'parent'] |
# | 243 | 0.8 | st. catharine's | st . catharines | ['what', "'s", 'a', 'lake', 'that', 'can', 'be', 'visited', 'near', 'st', '.', 'catharines'] |
# | 244 | 0.9615384615384616 | german wire-haired pointer | german wirehaired pointer | ['what', 'kind', 'of', 'personality', 'do', 'german', 'wirehaired', 'pointer', 'have', '?'] |

# %% [markdown]
# ### Discussion
#
# #### Numbers:
#
# Exact Match: 0.976991 [10403 of 10648]
#
# We find that most of the time, we are able to determine exactly the span in the question that refers to the linked subject name.
#
# #### Error Bucket:
#
# **Discussion:**
#
# We are able to determine the correct span 98% of time that there is not an exact match; therefore, we approximate that overall 10643/10648 (0.9995%). This makes sense due to the fact that subject name was only linked if it had a high similarity with the question.
#
# **Buckets:**
# - (49 / 50) Correct: The span correctly locations the subject name in the question.
# - (1 / 50) Other: The alias is incorrect; therefore, the span is incorrect.
#
# | Index | Bucket | Normalized Edit Distance | Original Subject Name | Predicted Subject Name | Question Tokens |
# | --- | --- | --- | --- | --- | --- |
# | 0 | Correct | 0.9655172413793104 | roman-parthian war of 58–63 | roman – parthian war of 58–63 | ['what', 'entity', 'was', 'involved', 'in', 'the', 'roman', '–', 'parthian', 'war', 'of', '58–63'] |
# | 1 | Correct | 0.8333333333333334 | mecca | meccas | ['what', 'is', 'the', 'name', 'for', 'meccas', 'canonical', 'version'] |
# | 2 | Correct | 0.9310344827586207 | assassin's creed: revelations | assassins creed : revelations | ['what', 'kind', 'of', 'game', 'is', 'assassins', 'creed', ':', 'revelations'] |
# | 3 | Correct | 0.9285714285714286 | lim, hyung joo | lim hyung joo | ['what', 'kind', 'of', 'music', 'does', 'lim', 'hyung', 'joo', 'do'] |
# | 4 | Correct | 0.9444444444444444 | this pud's for you | this puds for you | ['what', 'is', 'the', 'series', 'where', 'the', 'episode', 'this', 'puds', 'for', 'you', 'comes', 'from'] |
# | 5 | Other | 0.6666666666666666 | t-town | town | ['what', 'newspaper', 'circulates', 'in', 'the', 'town', 'of', 'kearny'] |
# | 6 | Correct | 0.9259259259259259 | who want's to live forever? | who wants to live forever | ['who', 'is', 'the', 'producer', 'of', 'who', 'wants', 'to', 'live', 'forever'] |
# | 7 | Correct | 0.9166666666666666 | paranoia: 1.0 | paranoia 10 | ['which', 'language', 'is', 'paranoia', '1.0', 'filmed', 'in', '?'] |
# | 8 | Correct | 0.8571428571428571 | ¡three amigos! | three amigos | ['who', 'did', 'the', 'music', 'for', 'three', 'amigos'] |
# | 9 | Correct  | 0.9545454545454546 | mexican-american war | mexican – american war | ['who', 'was', 'involved', 'in', 'mexican', '–', 'american', 'war'] |
# | 10 | Correct | 0.9722222222222222 | the best of daniel o'donnell on film | the best of daniel odonnell on film | ['what', 'kind', 'of', 'music', 'is', 'the', 'film', 'the', 'best', 'of', 'daniel', 'odonnell', 'on', 'film', 'about', '?'] |
# | 11 | Correct | 0.9333333333333333 | philip pullman | phillip pullman | ['what', 'works', 'written', 'by', 'phillip', 'pullman', '?'] |
# | 12 | Correct | 0.975 | harry potter and the philosopher's stone | harry potter and the philosophers stone | ['what', 'genre', 'is', 'harry', 'potter', 'and', 'the', 'philosophers', 'stone'] |
# | 13 | Correct | 0.95 | .977 the '80s channel | 977 the 80s channel | ['which', 'soul', 'artist', 'is', 'featured', 'on', 'the', '.977', 'the', '80s', 'channel'] |
# | 14 | Correct | 0.9166666666666666 | kim hee-chul | kim heechul | ['which', 'city', 'is', 'kim', 'heechul', 'from'] |
# | 15 | Correct | 0.9772727272727273 | intégrale, volume 2: the guitar don't lie | integrale , volume 2 : the guitar do nt lie | ['what', "'s", 'a', 'song', 'released', 'on', 'integrale', ',', 'volume', '2', ':', 'the', 'guitar', 'do', 'nt', 'lie'] |
# | 16 | Correct | 0.9615384615384616 | bill & ted's bogus journey | bill & teds bogus journey | ['what', 'foreign', 'language', 'is', 'an', 'option', 'for', 'the', 'film', 'bill', '&', 'teds', 'bogus', 'journey'] |
# | 17 | Correct | 0.8846153846153846 | single-player video game | single - player mode game | ['what', 'is', 'a', 'single', '-', 'player', 'mode', 'game', '?'] |
# | 18 | Correct | 0.9473684210526315 | eve's beach fantasy | eves beach fantasy | ['what', 'language', 'is', 'spoken', 'in', 'eves', 'beach', 'fantasy'] |
# | 19 | Correct | 0.9473684210526315 | live in denmark '72 | live in denmark 72 | ['what', 'are', 'songs', 'of', 'the', 'live', 'in', 'denmark', '72', 'album'] |
# | 20 | Correct | 0.9230769230769231 | bonnie's kids | bonnies kids | ['what', 'is', 'the', 'genre', 'of', 'the', 'film', 'bonnies', 'kids', '?'] |
# | 21 | Correct | 0.9166666666666666 | men's badminton, singles | mens badminton , singles | ['what', 'olympic', 'games', 'was', 'mens', 'badminton', ',', 'singles', 'apart', 'of'] |
# | 22 | Correct | 0.8571428571428571 | germans | german | ['who', 'is', 'german', '?'] |
# | 23 | Correct | 0.9444444444444444 | action-adventure | action / adventure | ['what', 'is', 'an', 'action', '/', 'adventure', 'netflix', 'title'] |
# | 24 | Correct | 0.9 | love's labour's lost | loves labours lost | ['who', 'produced', 'the', 'film', 'loves', 'labours', 'lost'] |
# | 25 | Correct | 0.9565217391304348 | rogers-o'daniel house | rogers - odaniel house | ['what', 'county', 'is', 'rogers', '-', 'odaniel', 'house', 'apart', 'of'] |
# | 26 | Correct | 0.9285714285714286 | curtis pulley | curtis pulleys | ['what', 's', 'curtis', 'pulleys', 'profession'] |
# | 27 | Correct | 0.9743589743589743 | manos hajidakis - eidolo ston kathrefti | manos hajidakis : eidolo ston kathrefti | ['what', 'country', 'is', 'manos', 'hajidakis', ':', 'eidolo', 'ston', 'kathrefti', 'from'] |
# | 28 | Correct | 0.9 | supernews! | supernews | ['what', 'genre', 'of', 'program', 'is', 'supernews'] |
# | 29 | Correct | 0.9375 | showgirls 2: penny's from heaven | showgirls 2 : pennys from heaven | ['what', 'language', 'is', 'showgirls', '2', ':', 'pennys', 'from', 'heaven', 'in', '?'] |
# | 30 | Correct | 0.9230769230769231 | pop rock 80's | pop rock 80s | ['what', 'artists', 'broadcast', "'s", 'pop', 'rock', '80s', 'music'] |
# | 31 | Correct | 0.7777777777777778 | macedonia | macedon | ['what', 'invasions', 'happened', 'in', 'macedon'] |
# | 32 | Correct | 0.9565217391304348 | mockingbird don't sing | mockingbird do nt sing | ['what', 'kind', 'of', 'film', 'is', 'mockingbird', 'do', 'nt', 'sing'] |
# | 33 | Correct | 0.9285714285714286 | zalman shazar | zalman shazars | ['what', 'is', 'zalman', 'shazars', 'area', 'of', 'activism'] |
# | 34 | Correct | 0.9696969696969697 | atomic - the very best of blondie | atomic : the very best of blondie | ['what', 'type', 'of', 'release', 'is', 'atomic', ':', 'the', 'very', 'best', 'of', 'blondie', '?'] |
# | 35 | Correct | 0.8333333333333334 | album | albums | ['what', 'albums', 'were', 'released', 'in', '2000', '?'] |
# | 36 | Correct | 0.9 | zeke's pad | zekes pad | ['is', 'zekes', 'pad', 'an', 'action', ',', 'romance', ',', 'or', 'comedy', 'tv', 'program'] |
# | 37 | Correct | 0.9565217391304348 | raffi's christmas album | raffis christmas album | ['what', 'kind', 'of', 'album', 'is', 'raffis', 'christmas', 'album'] |
# | 38 | Correct | 0.8928571428571429 | u.s. office of war information | office of war information | ['which', 'film', 'did', 'the', 'office', 'of', 'war', 'information', 'help', 'produce'] |
# | 39 | Correct | 0.967741935483871 | phillipa lord: she's the shit | phillipa lord : she s the shit | ['which', 'country', 'released', 'phillipa', 'lord', ':', 'she', 's', 'the', 'shit'] |
# | 40 | Correct | 0.875 | pillows & prayers: cherry red 1982–1983 | pillows & prayers : cherry red 1982 | ['what', 'is', 'the', 'name', 'of', 'the', 'track', 'list', 'for', 'the', 'release', 'pillows', '&', 'prayers', ':', 'cherry', 'red', '1982', '-', '1983', '?'] |
# | 41 | Correct | 0.9375 | wichita [kansas | wichita , kansas | ['who', 'was', 'born', 'in', 'wichita', ',', 'kansas'] |
# | 42 | Correct | 0.8636363636363636 | victoria, australia | victoria ( australia ) | ['which', 'places', 'are', 'located', 'in', 'victoria', '(', 'australia', ')', '?'] |
# | 43 | Correct | 0.8666666666666667 | eat, pray, love | eat pray love | ['who', 'composed', 'the', 'music', 'for', 'eat', 'pray', 'love'] |
# | 44 | Correct | 0.8888888888888888 | lost (12\" inch version) | lost ( 12 inch version ) | ['what', 's', 'the', 'canonical', 'version', 'of', 'lost', '(', '12', 'inch', 'version', ')'] |
# | 45 | Correct | 0.8 | “you don’t dream in cryo. ....” | " you do n't dream in cryo " | ['what', 'artist', 'recorded', '"', 'you', 'do', "n't", 'dream', 'in', 'cryo', '"', '?'] |
# | 46 | Correct | 0.8 | drums | drum | ['which', 'musician', 'plays', 'the', 'drum', 'kit'] |
# | 47 | Correct | 0.75 | the crystal city | crystal city | ['what', 'genre', 'is', 'crystal', 'city'] |
# | 48 | Correct | 0.9130434782608695 | william e. mcanulty jr. | william e mcanulty , jr | ['what', 'is', 'william', 'e.', 'mcanulty', ',', 'jr', '.', "'s", 'gender'] |
# | 49 | Correct | 0.8571428571428571 | somalis | somali | ['who', "'s", 'somebody', 'that', 'identifies', 'with', 'the', 'somali', 'people'] |

# %% [markdown]
# ## Step 2 - Continued

# %%
df_train = df_train.progress_apply(find_subject_name_span, axis=1)
display(df_train[:5])
# Out:
# HBox(children=(IntProgress(value=0, max=75910), HTML(value='')))
#    end_index   object                                           question  \
# 0        5.0   01cj3p                           what is the book e about
# 1        9.0  0sjc7c1  to what release does the release track cardiac...
# 2        7.0    07ssc            what country was the film the debt from
# 3        5.0   0p600l            what songs have nobuo uematsu produced?
# 4        5.0   0677ng                          Who produced eve-olution?
#
#                                      question_tokens  \
# 0                    [what, is, the, book, e, about]
# 1  [to, what, release, does, the, release, track,...
# 2   [what, country, was, the, film, the, debt, from]
# 3   [what, songs, have, nobuo, uematsu, produced, ?]
# 4                [who, produced, eve, -, olution, ?]
#
#                          relation  start_index  subject    subject_name  \
# 0      book/written_work/subjects          4.0  04whkz5               e
# 1     music/release_track/release          7.0  0tp2p24  cardiac arrest
# 2               film/film/country          5.0  04j0t75        the debt
# 3  music/producer/tracks_produced          3.0    0ftqr   nobuo uematsu
# 4         music/release/producers          2.0  036p007     eve-olution
#
#   subject_name_tokens
# 0                (e,)
# 1   (cardiac, arrest)
# 2         (the, debt)
# 3    (nobuo, uematsu)
# 4   (eve, -, olution)

# %% [markdown]
# ## Step 3 - Format Examples

# %%
from tqdm import tqdm_notebook


def get_formatted_examples(df):
    examples = []
    for index, row in tqdm_notebook(df.iterrows(), total=df.shape[0]):
        if not isinstance(row['subject_name'], str):
            continue

        ret =  ''
        for i, token in enumerate(row['question_tokens']):
            ret += token
            if i >= row['start_index'] and i < row['end_index']:
                ret += '/I '
            else:
                ret += '/O ' # IO – Inside Outside tagging schema
        examples.append(ret.strip())
    return examples

train_examples = get_formatted_examples(df_train)
print('Train:')
print(train_examples[:5])
dev_examples = get_formatted_examples(df_dev)
print('Dev:')
print(dev_examples[:5])
# Out:
# HBox(children=(IntProgress(value=0, max=75910), HTML(value='')))
# Train:
# ['what/O is/O the/O book/O e/I about/O', 'to/O what/O release/O does/O the/O release/O track/O cardiac/I arrest/I come/O from/O', 'what/O country/O was/O the/O film/O the/I debt/I from/O', 'what/O songs/O have/O nobuo/I uematsu/I produced/O ?/O', 'who/O produced/O eve/I -/I olution/I ?/O']
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# Dev:
# ['who/O was/O the/O trump/I ocean/I club/I international/I hotel/I and/I tower/I named/O after/O', 'where/O was/O sasha/I vujacic/I born/O', 'what/O is/O a/O region/O that/O dead/I combo/I was/O released/O in/O', 'what/O is/O a/O film/O directed/O by/O wiebke/I von/I carolsfeld/I ?/O', 'what/O country/O was/O music/I for/I stock/I exchange/I released/O in/O']

# %% [markdown]
# ## Step 4 - Write

# %%
file_ = open(DEST_TRAIN, 'w')
file_.write('\n'.join(train_examples))

file_ = open(DEST_DEV, 'w')
file_.write('\n'.join(dev_examples))
# Out:
# 633151
