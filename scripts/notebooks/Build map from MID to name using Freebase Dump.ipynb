# %% [markdown]
# # Build map from MID to name using Freebase Dump
#
# Parse freebase-rdf-latest to mid_to_name. Script takes 1 hour to run on a 2016 Macbook. The code is setup to play a sound when it finishes.
#
# Download http://commondatastorage.googleapis.com/freebase-public/rdf/freebase-rdf-latest.gz before hand!

# %%
import logging
import time
import os
import subprocess

from functools import partial

mid_url = '<http://rdf.freebase.com/ns/m.'
name_attribute = '<http://rdf.freebase.com/ns/type.object.name>'
estimated_number_of_lines_to_read = 3129197591  # Used for progress
start = time.time()
end = time.time()
total_lines_read = 0
total_lines_wrote = 0
slimmed_file_path = '/Users/petrochuk/data/simple_qa/source/freebase_dump/mid_to_name_1.tsv'
slimmed_file = open(slimmed_file_path, 'w')
dump_path = '/Users/petrochuk/data/simple_qa/source/freebase_dump/freebase-rdf-latest.gz'

def iterate_gzip_fast(file_name, visitor):
    """ Reading GZIP fast
    https://stackoverflow.com/questions/36559626/python-vs-perl-performance-reading-a-gzipped-file
    Args:
        file_name (str): gziped file to read
        visitor (func): func to call on every line of gzip read
    """
    gzip = subprocess.Popen(
        ['gzip', '-cdfq', file_name], stdout=subprocess.PIPE)
    for line in gzip.stdout:
        visitor(line)
    gzip.wait()

def sound_alarm():
    """ Sounds an alarm when your code finishes!
    https://stackoverflow.com/questions/16573051/python-sound-alarm-when-code-finishes
    """
    os.system('say "Finished!"')

def write_row(file_, split):
    """ Write row to slimmed file like "01001t69\tAfter the Morning"
    Notes:
        Removes language tag
        Removes mid_url
    Args:
        split (list): line split \t in freebase-rdf-latest.gz like
        [<http://rdf.freebase.com/ns/m.011d7vyl>,<http://rdf.freebase.com/ns/type.object.name>,
        "H.M.K. Smith"@en,.]
        file_ (file): file to write line too after parsing
    """
    line_to_write = split[0].replace(mid_url, "").replace(">", "")
    line_to_write += "\t"
    line_to_write += split[2].replace('"@en', "")[1:]
    line_to_write += "\n"
    file_.write(line_to_write)


def read_line(file_, line):
    """ Reads lines that defined english MID names and writes them to file_.
    Args:
        line (str): line in freebase-rdf-latest.gz
        file_ (file): file to write line too after parsing
    """
    global end
    global start
    global total_lines_read
    global total_lines_wrote

    split = line.decode('utf-8').split("\t")
    is_english_name_attribute_triple = (split[1] == name_attribute and mid_url in split[0] and
                                        "@en" in split[2])
    if is_english_name_attribute_triple:
        write_row(slimmed_file, split)
        if total_lines_wrote % 1000 == 0:
            print('Slim Lines: %d - Done: %.2f%% - %.1fm Elapsed' % (total_lines_wrote,
                        (total_lines_read / float(estimated_number_of_lines_to_read)) * 100.0,
                        (time.time() - start) / 60.0))
        total_lines_wrote += 1
    total_lines_read += 1

iterate_gzip_fast(dump_path, partial(read_line, slimmed_file))
sound_alarm()
# Out:
# Slim Lines: 0 - Done: 0.22% - 0.2m Elapsed
# Slim Lines: 1000 - Done: 0.22% - 0.2m Elapsed
# Slim Lines: 2000 - Done: 0.22% - 0.2m Elapsed
# Slim Lines: 3000 - Done: 0.22% - 0.2m Elapsed
# Slim Lines: 4000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 5000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 6000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 7000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 8000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 9000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 10000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 11000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 12000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 13000 - Done: 0.23% - 0.2m Elapsed
# Slim Lines: 14000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 15000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 16000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 17000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 18000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 19000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 20000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 21000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 22000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 23000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 24000 - Done: 0.24% - 0.2m Elapsed
# Slim Lines: 25000 - Done: 0.25% - 0.2m Elapsed
# Slim Lines: 26000 - Done: 0.25% - 0.2m Elapsed
# Slim Lines: 27000 - Done: 0.25% - 0.2m Elapsed
# Slim Lines: 28000 - Done: 0.25% - 0.2m Elapsed
# Slim Lines: 29000 - Done: 0.25% - 0.2m Elapsed
# Slim Lines: 30000 - Done: 0.25% - 0.2m Elapsed
# Slim Lines: 31000 - Done: 0.25% - 0.2m Elapsed
# Slim Lines: 32000 - Done: 0.26% - 0.2m Elapsed
# Slim Lines: 33000 - Done: 0.26% - 0.2m Elapsed
# Slim Lines: 34000 - Done: 0.26% - 0.2m Elapsed
# Slim Lines: 35000 - Done: 0.26% - 0.2m Elapsed
# Slim Lines: 36000 - Done: 0.26% - 0.2m Elapsed
# Slim Lines: 37000 - Done: 0.26% - 0.2m Elapsed
# Slim Lines: 38000 - Done: 0.26% - 0.2m Elapsed
# Slim Lines: 39000 - Done: 0.27% - 0.2m Elapsed
# Slim Lines: 40000 - Done: 0.27% - 0.2m Elapsed
# Slim Lines: 41000 - Done: 0.27% - 0.2m Elapsed
# Slim Lines: 42000 - Done: 0.27% - 0.2m Elapsed
# Slim Lines: 43000 - Done: 0.28% - 0.2m Elapsed
# Slim Lines: 44000 - Done: 0.28% - 0.2m Elapsed
# Slim Lines: 45000 - Done: 0.28% - 0.2m Elapsed
# Slim Lines: 46000 - Done: 0.28% - 0.2m Elapsed
# Slim Lines: 47000 - Done: 0.28% - 0.2m Elapsed
# Slim Lines: 48000 - Done: 0.28% - 0.2m Elapsed
# Slim Lines: 49000 - Done: 0.29% - 0.2m Elapsed
# Slim Lines: 50000 - Done: 0.29% - 0.2m Elapsed
# Slim Lines: 51000 - Done: 0.29% - 0.2m Elapsed
# Slim Lines: 52000 - Done: 0.29% - 0.2m Elapsed
# Slim Lines: 53000 - Done: 0.29% - 0.2m Elapsed
# Slim Lines: 54000 - Done: 0.29% - 0.2m Elapsed
# Slim Lines: 55000 - Done: 0.30% - 0.2m Elapsed
# Slim Lines: 56000 - Done: 0.30% - 0.2m Elapsed
# Slim Lines: 57000 - Done: 0.30% - 0.2m Elapsed
# Slim Lines: 58000 - Done: 0.30% - 0.2m Elapsed
# Slim Lines: 59000 - Done: 0.30% - 0.2m Elapsed
# Slim Lines: 60000 - Done: 0.30% - 0.2m Elapsed
# Slim Lines: 61000 - Done: 0.30% - 0.2m Elapsed
# Slim Lines: 62000 - Done: 0.30% - 0.2m Elapsed
# Slim Lines: 63000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 64000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 65000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 66000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 67000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 68000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 69000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 70000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 71000 - Done: 0.31% - 0.2m Elapsed
# Slim Lines: 72000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 73000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 74000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 75000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 76000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 77000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 78000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 79000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 80000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 81000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 82000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 83000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 84000 - Done: 0.32% - 0.2m Elapsed
# Slim Lines: 85000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 86000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 87000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 88000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 89000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 90000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 91000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 92000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 93000 - Done: 0.33% - 0.2m Elapsed
# Slim Lines: 94000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 95000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 96000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 97000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 98000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 99000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 100000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 101000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 102000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 103000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 104000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 105000 - Done: 0.34% - 0.2m Elapsed
# Slim Lines: 106000 - Done: 0.35% - 0.3m Elapsed
# Slim Lines: 107000 - Done: 0.35% - 0.3m Elapsed
# Slim Lines: 108000 - Done: 0.35% - 0.3m Elapsed
# Slim Lines: 109000 - Done: 0.35% - 0.3m Elapsed
# Slim Lines: 110000 - Done: 0.35% - 0.3m Elapsed
# Slim Lines: 111000 - Done: 0.35% - 0.3m Elapsed
# Slim Lines: 112000 - Done: 0.35% - 0.3m Elapsed
# Slim Lines: 113000 - Done: 0.35% - 0.3m Elapsed
# Slim Lines: 114000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 115000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 116000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 117000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 118000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 119000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 120000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 121000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 122000 - Done: 0.36% - 0.3m Elapsed
# Slim Lines: 123000 - Done: 0.37% - 0.3m Elapsed
# Slim Lines: 124000 - Done: 0.37% - 0.3m Elapsed
# Slim Lines: 125000 - Done: 0.37% - 0.3m Elapsed
# Slim Lines: 126000 - Done: 0.37% - 0.3m Elapsed
# Slim Lines: 127000 - Done: 0.37% - 0.3m Elapsed
# Slim Lines: 128000 - Done: 0.37% - 0.3m Elapsed
# Slim Lines: 129000 - Done: 0.37% - 0.3m Elapsed
# Slim Lines: 130000 - Done: 0.37% - 0.3m Elapsed
# Slim Lines: 131000 - Done: 0.38% - 0.3m Elapsed
# Slim Lines: 132000 - Done: 0.38% - 0.3m Elapsed
# Slim Lines: 133000 - Done: 0.38% - 0.3m Elapsed
# Slim Lines: 134000 - Done: 0.38% - 0.3m Elapsed
# Slim Lines: 135000 - Done: 0.38% - 0.3m Elapsed
# Slim Lines: 136000 - Done: 0.38% - 0.3m Elapsed
# Slim Lines: 137000 - Done: 0.38% - 0.3m Elapsed
# Slim Lines: 138000 - Done: 0.38% - 0.3m Elapsed
# Slim Lines: 139000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 140000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 141000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 142000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 143000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 144000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 145000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 146000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 147000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 148000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 149000 - Done: 0.39% - 0.3m Elapsed
# Slim Lines: 150000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 151000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 152000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 153000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 154000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 155000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 156000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 157000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 158000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 159000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 160000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 161000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 162000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 163000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 164000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 165000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 166000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 167000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 168000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 169000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 170000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 171000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 172000 - Done: 0.40% - 0.3m Elapsed
# Slim Lines: 173000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 174000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 175000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 176000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 177000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 178000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 179000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 180000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 181000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 182000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 183000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 184000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 185000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 186000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 187000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 188000 - Done: 0.41% - 0.3m Elapsed
# Slim Lines: 189000 - Done: 0.42% - 0.3m Elapsed
# Slim Lines: 190000 - Done: 0.42% - 0.3m Elapsed
# Slim Lines: 191000 - Done: 0.42% - 0.3m Elapsed
# Slim Lines: 192000 - Done: 0.42% - 0.3m Elapsed
# Slim Lines: 193000 - Done: 0.42% - 0.3m Elapsed
# Slim Lines: 194000 - Done: 0.42% - 0.3m Elapsed
# Slim Lines: 195000 - Done: 0.42% - 0.3m Elapsed
# Slim Lines: 196000 - Done: 0.42% - 0.3m Elapsed
# Slim Lines: 197000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 198000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 199000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 200000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 201000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 202000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 203000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 204000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 205000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 206000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 207000 - Done: 0.43% - 0.3m Elapsed
# Slim Lines: 208000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 209000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 210000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 211000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 212000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 213000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 214000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 215000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 216000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 217000 - Done: 0.44% - 0.3m Elapsed
# Slim Lines: 218000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 219000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 220000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 221000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 222000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 223000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 224000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 225000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 226000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 227000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 228000 - Done: 0.45% - 0.3m Elapsed
# Slim Lines: 229000 - Done: 0.46% - 0.3m Elapsed
# Slim Lines: 230000 - Done: 0.46% - 0.3m Elapsed
# Slim Lines: 231000 - Done: 0.46% - 0.3m Elapsed
# Slim Lines: 232000 - Done: 0.46% - 0.3m Elapsed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f783594c4f5f> in <module>()
#      78     total_lines_read += 1
#      79
# ---> 80 iterate_gzip_fast(dump_path, partial(read_line, slimmed_file))
#      81 sound_alarm()
#
# <ipython-input-8-f783594c4f5f> in iterate_gzip_fast(file_name, visitor)
#      16         ['gzip', '-cdfq', file_name], stdout=subprocess.PIPE)
#      17     for line in gzip.stdout:
# ---> 18         visitor(line)
#      19     gzip.wait()
#      20
#
# <ipython-input-8-f783594c4f5f> in read_line(file_, line)
#      55
#      56
# ---> 57 def read_line(file_, line):
#      58     """ Reads lines that defined english MID names and writes them to file_.
#      59     Args:
#
# KeyboardInterrupt:
