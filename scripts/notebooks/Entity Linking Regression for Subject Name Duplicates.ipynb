# %%
import os
import psycopg2
import psycopg2.extras

# Load .env file
pass_ = {}
for line in open('../../.pass'):
    split = line.strip().split('=')
    pass_[split[0]] = split[1]

# Connect    
connection = psycopg2.connect(dbname=pass_['DB_NAME'],
                              port=pass_['DB_PORT'],
                              user=pass_['DB_USER'],
                              host=pass_['DB_HOST'],
                              password=pass_['DB_PASS'])
cursor = connection.cursor()

# %%
simple_qa = {
    'train': '../../data/SimpleQuestions_v2/annotated_fb_data_train.txt',
    'dev': '../../data/SimpleQuestions_v2/annotated_fb_data_valid.txt',
    'test': '../../data/SimpleQuestions_v2/annotated_fb_data_test.txt',
}

# %%
RELATION_CLASSIFIER = '../../results/0626.11-05_08:38:02.relation_classifier/11m_05d_08h_45m_57s.pt'

import math
import pprint
import re
import unicodedata

from lib.checkpoint import Checkpoint

    
def remove_accents(text):
    # https://stackoverflow.com/questions/517923/what-is-the-best-way-to-remove-accents-in-a-python-unicode-string
    nkfd_form = unicodedata.normalize('NFKD', text)
    return u"".join([c for c in nkfd_form if not unicodedata.combining(c)])

def preprocess(s):
    s = s.replace("'s", '')
    s = remove_accents(s)
    s = s.split()
    s = [re.sub('^\W+', '', w) for w in s]  # Strip prefix none alphanumeric
    s = [re.sub('\W+$', '', w) for w in s]  # Strip leading none alphanumeric
    s = [w.strip().lower() for w in s]
    s = [w for w in s if len(w) != 0] # Remove Empty
    return ' '.join(s)

relation_classifier_predict = Checkpoint(checkpoint_path=RELATION_CLASSIFIER).predict

def get_relation(question, top_k=3):
    """ 
    Given a question return the predicate in the question using `RELATION_CLASSIFIER` model.
    
    Args:
        question (str)
    Returns:
        list of predicates and their confidence
    """
    question = preprocess(question)
    predicted = list(relation_classifier_predict(question, top_k=top_k))
    if top_k == 1:
            predicted[1] = sum(predicted[1]) / len(predicted[1]) 
            return [predicted]
    return [(class_, sum(confidence) / len(confidence)) for class_, confidence in predicted]

# To test this cell
print(get_relation('Where was Obama born?', 1))

# %%
from IPython.display import display
import pandas as pd
from sklearn.utils import shuffle

names = ['subject', 'relation', 'object', 'question']
df_train = pd.read_table(simple_qa['train'], header=None, names=names)
df_dev = pd.read_table(simple_qa['dev'], header=None, names=names)
df_train = shuffle(df_train, random_state=123)
df_dev = shuffle(df_dev, random_state=123)
display(df_train)
# Out:
#                           subject  \
# 67691  www.freebase.com/m/0fqd80r
# 60980   www.freebase.com/m/01v7rw
# 44045  www.freebase.com/m/03fl5vh
# 35944   www.freebase.com/m/05sq1b
# 44254  www.freebase.com/m/03yzs66
# 68214   www.freebase.com/m/057vc_
# 618     www.freebase.com/m/0q8552
# 52003  www.freebase.com/m/09gdbzs
# 56512  www.freebase.com/m/02v_gfg
# 47413  www.freebase.com/m/0ch8kqd
# 20522  www.freebase.com/m/01j7wjb
# 61538  www.freebase.com/m/01lxs3p
# 32222  www.freebase.com/m/01nb_hd
# 36861  www.freebase.com/m/04f5csb
# 62062   www.freebase.com/m/06101p
# 48174    www.freebase.com/m/0fydw
# 43937   www.freebase.com/m/02vypx
# 48711  www.freebase.com/m/047sqg2
# 73513  www.freebase.com/m/0v4z20d
# 75410    www.freebase.com/m/03v1s
# 65371  www.freebase.com/m/04d3f4k
# 46659   www.freebase.com/m/09wqw4
# 11699  www.freebase.com/m/0dp9ymv
# 23952     www.freebase.com/m/0zc6
# 26058   www.freebase.com/m/026__5
# 56047  www.freebase.com/m/05h2t1t
# 2666   www.freebase.com/m/0qscjrj
# 40978  www.freebase.com/m/0h5m3vz
# 3241   www.freebase.com/m/048wncx
# 37254  www.freebase.com/m/02pn4h0
# ...                           ...
# 3252    www.freebase.com/m/04y338
# 8028   www.freebase.com/m/04w8xd7
# 2428    www.freebase.com/m/0chgzm
# 4195     www.freebase.com/m/0np9r
# 23728   www.freebase.com/m/063m08
# 6648    www.freebase.com/m/08k5nt
# 30255   www.freebase.com/m/048rtv
# 72020  www.freebase.com/m/05ynpsg
# 26626   www.freebase.com/m/0swgrj
# 45507  www.freebase.com/m/02623n7
# 73521   www.freebase.com/m/0cc2_7
# 14944   www.freebase.com/m/0bxcm7
# 68861  www.freebase.com/m/02w43l2
# 35662   www.freebase.com/m/06lyyt
# 17747    www.freebase.com/m/0343_
# 65647  www.freebase.com/m/0drtpyh
# 33710    www.freebase.com/m/0jtdp
# 71200   www.freebase.com/m/0b68vs
# 23166  www.freebase.com/m/03t06j6
# 55409  www.freebase.com/m/027856d
# 65632  www.freebase.com/m/026h5p5
# 22241    www.freebase.com/m/04f_d
# 46203   www.freebase.com/m/0190zy
# 73299   www.freebase.com/m/05fjdb
# 15377   www.freebase.com/m/0b2nbh
# 63206   www.freebase.com/m/086n11
# 61404    www.freebase.com/m/01vvy
# 17730    www.freebase.com/m/04n32
# 28030  www.freebase.com/m/04xdr00
# 15725   www.freebase.com/m/0clj86
#
#                                                 relation  \
# 67691                www.freebase.com/music/artist/genre
# 60980        www.freebase.com/book/written_work/subjects
# 44045               www.freebase.com/music/release/track
# 35944        www.freebase.com/common/topic/notable_types
# 44254          www.freebase.com/music/release/track_list
# 68214  www.freebase.com/military/military_person/part...
# 618              www.freebase.com/music/recording/tracks
# 52003  www.freebase.com/travel/tourist_attraction/nea...
# 56512          www.freebase.com/people/person/profession
# 47413  www.freebase.com/fictional_universe/fictional_...
# 20522    www.freebase.com/music/album/album_content_type
# 61538                www.freebase.com/music/artist/genre
# 32222                www.freebase.com/music/album/artist
# 36861     www.freebase.com/location/location/containedby
# 62062                  www.freebase.com/film/writer/film
# 48174  www.freebase.com/location/location/people_born...
# 43937              www.freebase.com/people/person/gender
# 48711                www.freebase.com/music/album/artist
# 73513      www.freebase.com/people/person/place_of_birth
# 75410        www.freebase.com/location/location/contains
# 65371          www.freebase.com/music/release/track_list
# 46659  www.freebase.com/music/group_member/instrument...
# 11699              www.freebase.com/music/recording/song
# 23952  www.freebase.com/location/location/nearby_airp...
# 26058      www.freebase.com/people/person/place_of_birth
# 56047                www.freebase.com/music/artist/genre
# 2666               www.freebase.com/people/person/gender
# 40978                www.freebase.com/film/film/language
# 3241      www.freebase.com/location/location/containedby
# 37254                www.freebase.com/film/film/language
# ...                                                  ...
# 3252                    www.freebase.com/film/film/genre
# 8028                    www.freebase.com/book/book/genre
# 2428   www.freebase.com/location/location/people_born...
# 4195   www.freebase.com/people/profession/people_with...
# 23728  www.freebase.com/medicine/notable_person_with_...
# 6648   www.freebase.com/people/deceased_person/place_...
# 30255     www.freebase.com/location/location/containedby
# 72020                www.freebase.com/music/artist/track
# 26626          www.freebase.com/music/recording/releases
# 45507  www.freebase.com/base/culturalevent/event/enti...
# 73521              www.freebase.com/people/person/gender
# 14944        www.freebase.com/common/topic/notable_types
# 68861  www.freebase.com/people/deceased_person/place_...
# 35662  www.freebase.com/religion/religious_leadership...
# 17747  www.freebase.com/location/location/people_born...
# 65647          www.freebase.com/music/recording/releases
# 33710  www.freebase.com/film/film_genre/films_in_this...
# 71200               www.freebase.com/music/artist/origin
# 23166  www.freebase.com/common/image/appears_in_topic...
# 55409  www.freebase.com/education/educational_institu...
# 65632  www.freebase.com/computer/software/languages_used
# 22241  www.freebase.com/location/location/people_born...
# 46203                www.freebase.com/music/genre/albums
# 73299         www.freebase.com/dining/restaurant/cuisine
# 15377    www.freebase.com/geography/island/body_of_water
# 63206         www.freebase.com/computer/software/license
# 61404                www.freebase.com/music/artist/track
# 17730                www.freebase.com/music/artist/album
# 28030        www.freebase.com/book/written_work/subjects
# 15725  www.freebase.com/education/educational_institu...
#
#                            object  \
# 67691   www.freebase.com/m/01kcty
# 60980    www.freebase.com/m/07dg1
# 44045   www.freebase.com/m/0x7w6c
# 35944  www.freebase.com/m/01xpjyz
# 44254  www.freebase.com/m/0n2nvvl
# 68214    www.freebase.com/m/0kbcg
# 618    www.freebase.com/m/0kzl7vw
# 52003    www.freebase.com/m/0g7yx
# 56512  www.freebase.com/m/02h665k
# 47413    www.freebase.com/m/03bpv
# 20522   www.freebase.com/m/06vw6v
# 61538    www.freebase.com/m/0m0jc
# 32222   www.freebase.com/m/01w57m
# 36861    www.freebase.com/m/0ls2v
# 62062  www.freebase.com/m/0g_tr3w
# 48174  www.freebase.com/m/0bwk6k4
# 43937   www.freebase.com/m/05zppz
# 48711  www.freebase.com/m/01w9jh4
# 73513    www.freebase.com/m/081m_
# 75410    www.freebase.com/m/0sm5_
# 65371  www.freebase.com/m/0m7y0rw
# 46659    www.freebase.com/m/07y_7
# 11699   www.freebase.com/m/05chtg
# 23952   www.freebase.com/m/0959z8
# 26058    www.freebase.com/m/0_d20
# 56047   www.freebase.com/m/011j5x
# 2666    www.freebase.com/m/05zppz
# 40978  www.freebase.com/m/02h40lc
# 3241    www.freebase.com/m/09c7w0
# 37254  www.freebase.com/m/02h40lc
# ...                           ...
# 3252    www.freebase.com/m/01585b
# 8028     www.freebase.com/m/02xlf
# 2428    www.freebase.com/m/0bg32v
# 4195   www.freebase.com/m/0qjcz3d
# 23728   www.freebase.com/m/0d19y2
# 6648     www.freebase.com/m/0nbzp
# 30255     www.freebase.com/m/0h7x
# 72020  www.freebase.com/m/018f56b
# 26626  www.freebase.com/m/037syqb
# 45507   www.freebase.com/m/02771q
# 73521   www.freebase.com/m/05zppz
# 14944  www.freebase.com/m/01xrvrv
# 68861    www.freebase.com/m/0fvvz
# 35662   www.freebase.com/m/02vxy_
# 17747   www.freebase.com/m/0cv5_8
# 65647  www.freebase.com/m/03fq0ks
# 33710  www.freebase.com/m/0j66q35
# 71200    www.freebase.com/m/034cm
# 23166   www.freebase.com/m/02kvhy
# 55409  www.freebase.com/m/025tjcb
# 65632  www.freebase.com/m/07sbkfb
# 22241   www.freebase.com/m/0k38l7
# 46203  www.freebase.com/m/01j98t2
# 73299    www.freebase.com/m/02z3r
# 15377    www.freebase.com/m/0g3nc
# 63206    www.freebase.com/m/067xd
# 61404  www.freebase.com/m/01b9f51
# 17730  www.freebase.com/m/01j1qbb
# 28030   www.freebase.com/m/0dg3n1
# 15725    www.freebase.com/m/0m4mb
#
#                                                 question
# 67691     what type of musician is bruna cara considered
# 60980        what is the book troilus and cressida about
# 44045            what is a single on the release busted
# 35944           what is the duluth international airport
# 44254  what song is on the release welcome to haiti: ...
# 68214     Which conflict did john gibbon participate in?
# 618    What track is featured in the recording of cha...
# 52003    what travel destination is quattro fontane near
# 56512                 What was Toby Wright's profession?
# 47413      what kind of entity is the character atropos
# 20522            What type of album is Five Leaves Left?
# 61538  would beady belle be considered electronica or...
# 32222    Which artist made le portrait de petit cossette
# 36861            where is moczadła, lipno county located
# 62062                   what towns are in lasalle county
# 48174               Name someone who was born in antwerp
# 43937                           what sex is charles bass
# 48711  which artist recorded the rza—instrumental exp...
# 73513                      where was marcin tyszka born?
# 75410              What is the name of a city in indiana
# 65371  which song is part of easy tempo, volume 6: a ...
# 46659       What's an instrument that lilihaydn can play
# 11699  which song is based on a recording of santa cl...
# 23952                      What airport is near alicante
# 26058     what are the track listings on sherlock holmes
# 56047       is dial m for murder! post-punk or classical
# 2666                          what gender is joel malone
# 40978     what language is the film the martini shot in?
# 3241                                    where is norris
# 37254                     what language is tap roots in?
# ...                                                  ...
# 3252                     What type of film is wrong turn
# 8028                 what kind of book is after midnight
# 2428            who is a soccer player born in melbourne
# 4195                           Name a famous voice actor
# 23728      what chronic condition does alan wiggins have
# 6648                eleanor hallowell abbott died where?
# 30255                     What country is au located in?
# 72020      What's a song that giuseppe sinopoli composed
# 26626               what release is the song poison from
# 45507  what party was involved in the siberian interv...
# 73521                     what is the gender of dj pooh?
# 14944                                      What is jmol?
# 68861              Where did edward white robertson die?
# 35662   to what religious group does rosses point belong
# 17747                 who is a person born in gothenburg
# 65647                     What was the release of viola?
# 33710                what is a type of documentary film?
# 71200  what is the origin of the artist corinne baile...
# 23166  in what topic gallery did the image salicin-pe...
# 55409  what type of school is john paul ii catholic h...
# 65632          Which language does open esb software use
# 22241  Name a male who was born in kansas city, missouri
# 46203                         what is a worldbeat album?
# 73299  What type of food does french laundry restaura...
# 15377       What body of water is around Rishiri Island?
# 63206                 Who licensed the software evernote
# 61404  What is a a track that was recorded by claude ...
# 17730               What's an album from louis armstrong
# 28030  what is the literary subject of the work south...
# 15725  what type of educational institution is clayfi...
#
# [75910 rows x 4 columns]

# %%
def preprocess(row):
    row['subject'] = row['subject'].strip().replace('www.freebase.com/m/', '')
    row['object'] = row['object'].strip().replace('www.freebase.com/m/', '')
    question = row['question'].strip()
    row['question'] = ' '.join(tokenize(question.lower()))
    row['relation'] = row['relation'].strip().replace('www.freebase.com/', '')
    return row

df_train = df_train.apply(preprocess, axis=1)
df_dev = df_dev.apply(preprocess, axis=1)
df_train
# Out:
#        subject                                           relation   object  \
# 67691  0fqd80r                                 music/artist/genre   01kcty
# 60980   01v7rw                         book/written_work/subjects    07dg1
# 44045  03fl5vh                                music/release/track   0x7w6c
# 35944   05sq1b                         common/topic/notable_types  01xpjyz
# 44254  03yzs66                           music/release/track_list  0n2nvvl
# 68214   057vc_  military/military_person/participated_in_confl...    0kbcg
# 618     0q8552                             music/recording/tracks  0kzl7vw
# 52003  09gdbzs  travel/tourist_attraction/near_travel_destination    0g7yx
# 56512  02v_gfg                           people/person/profession  02h665k
# 47413  0ch8kqd        fictional_universe/fictional_character/rank    03bpv
# 20522  01j7wjb                     music/album/album_content_type   06vw6v
# 61538  01lxs3p                                 music/artist/genre    0m0jc
# 32222  01nb_hd                                 music/album/artist   01w57m
# 36861  04f5csb                      location/location/containedby    0ls2v
# 62062   06101p                                   film/writer/film  0g_tr3w
# 48174    0fydw                 location/location/people_born_here  0bwk6k4
# 43937   02vypx                               people/person/gender   05zppz
# 48711  047sqg2                                 music/album/artist  01w9jh4
# 73513  0v4z20d                       people/person/place_of_birth    081m_
# 75410    03v1s                         location/location/contains    0sm5_
# 65371  04d3f4k                           music/release/track_list  0m7y0rw
# 46659   09wqw4              music/group_member/instruments_played    07y_7
# 11699  0dp9ymv                               music/recording/song   05chtg
# 23952     0zc6                  location/location/nearby_airports   0959z8
# 26058   026__5                       people/person/place_of_birth    0_d20
# 56047  05h2t1t                                 music/artist/genre   011j5x
# 2666   0qscjrj                               people/person/gender   05zppz
# 40978  0h5m3vz                                 film/film/language  02h40lc
# 3241   048wncx                      location/location/containedby   09c7w0
# 37254  02pn4h0                                 film/film/language  02h40lc
# ...        ...                                                ...      ...
# 3252    04y338                                    film/film/genre   01585b
# 8028   04w8xd7                                    book/book/genre    02xlf
# 2428    0chgzm                 location/location/people_born_here   0bg32v
# 4195     0np9r      people/profession/people_with_this_profession  0qjcz3d
# 23728   063m08  medicine/notable_person_with_medical_condition...   0d19y2
# 6648    08k5nt              people/deceased_person/place_of_death    0nbzp
# 30255   048rtv                      location/location/containedby     0h7x
# 72020  05ynpsg                                 music/artist/track  018f56b
# 26626   0swgrj                           music/recording/releases  037syqb
# 45507  02623n7           base/culturalevent/event/entity_involved   02771q
# 73521   0cc2_7                               people/person/gender   05zppz
# 14944   0bxcm7                         common/topic/notable_types  01xrvrv
# 68861  02w43l2              people/deceased_person/place_of_death    0fvvz
# 35662   06lyyt  religion/religious_leadership_jurisdiction/org...   02vxy_
# 17747    0343_                 location/location/people_born_here   0cv5_8
# 65647  0drtpyh                           music/recording/releases  03fq0ks
# 33710    0jtdp                film/film_genre/films_in_this_genre  0j66q35
# 71200   0b68vs                                music/artist/origin    034cm
# 23166  03t06j6              common/image/appears_in_topic_gallery   02kvhy
# 55409  027856d      education/educational_institution/school_type  025tjcb
# 65632  026h5p5                   computer/software/languages_used  07sbkfb
# 22241    04f_d                 location/location/people_born_here   0k38l7
# 46203   0190zy                                 music/genre/albums  01j98t2
# 73299   05fjdb                          dining/restaurant/cuisine    02z3r
# 15377   0b2nbh                     geography/island/body_of_water    0g3nc
# 63206   086n11                          computer/software/license    067xd
# 61404    01vvy                                 music/artist/track  01b9f51
# 17730    04n32                                 music/artist/album  01j1qbb
# 28030  04xdr00                         book/written_work/subjects   0dg3n1
# 15725   0clj86      education/educational_institution/school_type    0m4mb
#
#                                                 question
# 67691     what type of musician is bruna cara considered
# 60980        what is the book troilus and cressida about
# 44045             what is a single on the release busted
# 35944           what is the duluth international airport
# 44254  what song is on the release welcome to haiti :...
# 68214    which conflict did john gibbon participate in ?
# 618    what track is featured in the recording of cha...
# 52003    what travel destination is quattro fontane near
# 56512               what was toby wright 's profession ?
# 47413       what kind of entity is the character atropos
# 20522           what type of album is five leaves left ?
# 61538  would beady belle be considered electronica or...
# 32222    which artist made le portrait de petit cossette
# 36861           where is moczadła , lipno county located
# 62062                   what towns are in lasalle county
# 48174               name someone who was born in antwerp
# 43937                           what sex is charles bass
# 48711  which artist recorded the rza—instrumental exp...
# 73513                     where was marcin tyszka born ?
# 75410              what is the name of a city in indiana
# 65371  which song is part of easy tempo , volume 6 : ...
# 46659      what 's an instrument that lilihaydn can play
# 11699  which song is based on a recording of santa cl...
# 23952                      what airport is near alicante
# 26058     what are the track listings on sherlock holmes
# 56047      is dial m for murder ! post-punk or classical
# 2666                          what gender is joel malone
# 40978    what language is the film the martini shot in ?
# 3241                                     where is norris
# 37254                    what language is tap roots in ?
# ...                                                  ...
# 3252                     what type of film is wrong turn
# 8028                 what kind of book is after midnight
# 2428            who is a soccer player born in melbourne
# 4195                           name a famous voice actor
# 23728      what chronic condition does alan wiggins have
# 6648               eleanor hallowell abbott died where ?
# 30255                    what country is au located in ?
# 72020     what 's a song that giuseppe sinopoli composed
# 26626               what release is the song poison from
# 45507  what party was involved in the siberian interv...
# 73521                    what is the gender of dj pooh ?
# 14944                                     what is jmol ?
# 68861             where did edward white robertson die ?
# 35662   to what religious group does rosses point belong
# 17747                 who is a person born in gothenburg
# 65647                    what was the release of viola ?
# 33710               what is a type of documentary film ?
# 71200  what is the origin of the artist corinne baile...
# 23166  in what topic gallery did the image salicin-pe...
# 55409  what type of school is john paul ii catholic h...
# 65632          which language does open esb software use
# 22241  name a male who was born in kansas city , miss...
# 46203                        what is a worldbeat album ?
# 73299  what type of food does french laundry restaura...
# 15377      what body of water is around rishiri island ?
# 63206                 who licensed the software evernote
# 61404  what is a a track that was recorded by claude ...
# 17730              what 's an album from louis armstrong
# 28030  what is the literary subject of the work south...
# 15725  what type of educational institution is clayfi...
#
# [75910 rows x 4 columns]

# %%
from numpy import nan
from nltk.tokenize.treebank import TreebankWordTokenizer

tokenize = TreebankWordTokenizer().tokenize

def add_subject_name(row):
    rows = []
    for mid in [row['subject'], row['object']]:
        sql = """SELECT alias FROM fb_name
                 WHERE mid='{mid}'""".format(mid=mid)
        cursor.execute(sql)
        rows += cursor.fetchall()
    if len(rows) == 0:
        return nan
    # Sort by largest name first
    names = sorted([row[0].strip().lower() for row in rows], key=lambda n: len(n), reverse=True)
    for name in names:
        if name in row['question']:
            return name
    return nan

df_train['subject_name'] = df_train.apply(add_subject_name, axis=1)
df_dev['subject_name'] = df_dev.apply(add_subject_name, axis=1)
df_dev
# Out:
#        subject                                           relation   object  \
# 6219     03k3r  biology/organism_classification/organisms_of_t...  0bs56bp
# 3364   02qlppc                   cvg/computer_videogame/cvg_genre   01sjng
# 9374    02l7c8                               tv/tv_genre/programs  0dlmm88
# 10142  049_zj3                      location/location/containedby    04rrx
# 97     02w9ycr              people/deceased_person/cause_of_death    0qcr0
# 8296    08k_58                                 music/artist/album  02rw0hc
# 3932   0dp76p7                                 music/album/artist   06twql
# 6960    06c6tz           ice_hockey/hockey_player/hockey_position   02qvdc
# 2168    0d0gvn          computer/computer_processor/manufacturers    03s7h
# 1893    05gg9s                   cvg/computer_videogame/cvg_genre   06zm8z
# 7734   03thx7t                            type/content/media_type     08x8
# 2040    013b6_                            people/ethnicity/people    0lccn
# 5967    0bjksk      education/educational_institution/school_type  025tjcb
# 4549   02rdg9w                         common/topic/notable_types  01xryvt
# 5587    02hmvc                film/film_genre/films_in_this_genre  0jwgkc_
# 2056   09v84yn                        film/film/costume_design_by  0s81gs6
# 4870    01243b                                 music/genre/albums  0hgq0p0
# 2366    01hr58                         location/location/contains  0472hfv
# 5320   040780m                   transportation/road/major_cities   0b4ydf
# 3710    0w9n3k                  music/recording/canonical_version  014zb9t
# 7433    05mj7m                               people/person/gender   05zppz
# 611    026wltf                       people/person/place_of_birth    02cft
# 7204   0fyb_78                           music/album/release_type   014k0b
# 5330    057yc8                                   film/film/rating   0kprd3
# 1127    0dshmb                               film/film/written_by  0bby21y
# 2616    0cylqf                               time/event/locations     0p2n
# 7792    04l26r                  internet/top_level_domain/sponsor   01210w
# 2673   0288tkt                           music/album/release_type   02lx2r
# 3410    03wrqt                                    film/film/genre    03npn
# 10158  03gvk09                     broadcast/radio_station/format   02vjzr
# ...        ...                                                ...      ...
# 6077   0g7z202                                music/release/track  0g7z206
# 6648   05k6tn8                      baseball/baseball_player/bats   01r7cb
# 6740   02rr30l                         common/topic/notable_types  01xryvt
# 10843   02kwdc               base/petbreeds/dog_breed/temperament  04kqp3v
# 39     04v7kz6                             book/book_edition/book   02tjsj
# 6484    03qcvl                                    film/film/genre   02l7c8
# 10242  01nycg3                           broadcast/artist/content  03gc55x
# 1847   04dx4lh  user/micahsaul/five_alarm_food/hot_sauce/ingre...   05g0_z
# 7985    01x4cg            book/publishing_company/books_published  04v2zbl
# 1092   0hqv7rn       medicine/drug_formulation/active_ingredients   03kq0q
# 3325   07f77q8                       base/reviews/review/mentions   02qfhb
# 2894    07kx5k                                 film/producer/film   07lf83
# 1363   01jzqrj                                 music/album/artist  01vrnxc
# 3481     01n7q                            book/book_subject/works  04wj37b
# 111    03c3yh6                             people/person/religion    03_gx
# 6368   04wbg56                           book/written_work/author   01q7tn
# 942     02kfwr  base/animal_synopses/synopsized_animal/has_syn...  0xn5dj9
# 5664    09c7w0                         location/location/contains  0484_dj
# 4169   03y5mlg        astronomy/astronomical_discovery/discoverer   01l89j
# 4143     0t_9y                       location/location/time_zones   02hcv8
# 6782   0fwpksp                                music/release/label    0g768
# 6257   07s3vqk                                 music/artist/label    0g768
# 96     0qz9_50                           people/person/profession  02hrh1q
# 5857   09vwf94              people/deceased_person/place_of_death    0sf9_
# 7382    016hlq              people/deceased_person/place_of_death    0rrwt
# 9785     02hnl                  music/instrument/instrumentalists   07mxcz
# 7763    0948ch                      location/location/containedby    086g2
# 5218   051gtt5                                 book/book/editions  051gtvd
# 1346    01n073          cvg/cvg_publisher/game_versions_published  02hm28q
# 3582   0fwyp66                     music/album/album_content_type   06vw6v
#
#                                                 question  \
# 6219            name an american thoroughbread racehorse
# 3364   what kind of game is vision racing driving sim...
# 9374                     what tv program is romance film
# 10142                   what state is polaski located in
# 97          what disease claimed the life of fern emmett
# 8296     what is tristeza 's album that starts with an s
# 3932   who was the artist on the album just you , jus...
# 6960                 what position does max bentley play
# 2168                    what company made intel core 2 ?
# 1893   what kind of game is the legend of zelda : twi...
# 7734                 what type of media is burne hogarth
# 2040                  what person is an ashkenazi jews ?
# 5967          what type of school is central high school
# 4549                                  who is rick mcnair
# 5587      name a short documentary film released in 2011
# 2056   who designed the costume for the movie copenhagen
# 4870               whats the name of an indie rock album
# 2366                what 's a temple found in chiang mai
# 5320   what major city does nebraska highway 70 pass ...
# 3710               what is canonical version of ethics ?
# 7433                       what is marc singer 's gender
# 611                         where was ruth turner born ?
# 7204   whats the release type of the last thing on my...
# 5330        what is the mpaa rating for the movie sahara
# 1127                        who wrote the film jindabyne
# 2616              where is crossing of the andes located
# 7792                        what university sponsored lc
# 2673   what kind of release was feel sorry for the fa...
# 3410                what type of film is deadly blessing
# 10158        what type of music does krgy station play ?
# ...                                                  ...
# 6077          what tracks are on the release speak now ?
# 6648          does ben copeland bat left or right handed
# 6740                             what is eli noam 's job
# 10843  what kind of personality do german wirehaired ...
# 39            what is a book from the ethan frome series
# 6484            what genre of film is playing by heart ?
# 10242  what radio station plays music from alvin youn...
# 1847   what 's an ingredient in tabasco brand green p...
# 7985   what 's a book published by doubleday ( publis...
# 1092               whats the active ingredient in enbrel
# 3325   who was mentioned in the review of funny peopl...
# 2894               which film was produced by zhang yuan
# 1363   which artist recorded the album fun with knives ?
# 3481               what 's a book that covers california
# 111      does david gottesman follow judaism or buddhism
# 6368   who was the author of the piece chronicles of ...
# 942          what is the miniature version of the poodle
# 5664   what 's a city located in alabama in the unite...
# 4169   what female astronomer did discover 2932 kempc...
# 4143       what time zone is westford , massachusetts in
# 6782   what company signed the band that released the...
# 6257                              who signed ray charles
# 96               what profession does liz toonkel have ?
# 5857   what is the location of michael w. leighton 's...
# 7382            where did charles e. silberman pass away
# 9785                               who uses a drum kit ?
# 7763       what city is vidyasagar university located in
# 5218         what is an edition of the book bill gates ?
# 1346   what was the name of a game version publisjhed...
# 3582                   what kind of album is qué hiciste
#
#                                    subject_name
# 6219                                      horse
# 3364            vision racing driving simulator
# 9374                               romance film
# 10142                                   polaski
# 97                                  fern emmett
# 8296                                   tristeza
# 3932                         just you , just me
# 6960                                max bentley
# 2168                               intel core 2
# 1893    the legend of zelda : twilight princess
# 7734                              burne hogarth
# 2040                             ashkenazi jews
# 5967                        central high school
# 4549                                rick mcnair
# 5587                                      short
# 2056                                 copenhagen
# 4870                                 indie rock
# 2366                                 chiang mai
# 5320                        nebraska highway 70
# 3710                                     ethics
# 7433                                marc singer
# 611                                 ruth turner
# 7204                  the last thing on my mind
# 5330                                     sahara
# 1127                                  jindabyne
# 2616                      crossing of the andes
# 7792                                         lc
# 2673                 feel sorry for the fanatic
# 3410                            deadly blessing
# 10158                                      krgy
# ...                                         ...
# 6077                                  speak now
# 6648                               ben copeland
# 6740                                   eli noam
# 10843                 german wirehaired pointer
# 39                                  ethan frome
# 6484                           playing by heart
# 10242                     alvin youngblood hart
# 1847           tabasco brand green pepper sauce
# 7985                                  doubleday
# 1092                                        NaN
# 3325   review of funny people at www.boston.com
# 2894                                 zhang yuan
# 1363                            fun with knives
# 3481                                 california
# 111                             david gottesman
# 6368                  chronicles of wasted time
# 942                                      poodle
# 5664                              united states
# 4169                           2932 kempchinsky
# 4143                   westford , massachusetts
# 6782                                       baby
# 6257                                ray charles
# 96                                  liz toonkel
# 5857                        michael w. leighton
# 7382                       charles e. silberman
# 9785                                        NaN
# 7763                      vidyasagar university
# 5218                                 bill gates
# 1346                            electronic arts
# 3582                                qué hiciste
#
# [10845 rows x 5 columns]

# %%
from tqdm import tqdm_notebook
from random import sample

flatten = lambda l: [item for sublist in l for item in sublist]

def get_candidates(df):
    ret = []
    n_rows = df.shape[0]
    for index, row in tqdm_notebook(df.iterrows(), total=n_rows):
        # CHECK: Should dev have the below filter?
        if not pd.isnull(row['subject_name']):
            cursor.execute("""SELECT fb_name.alias, fb_kg.subject_mid, array_agg(fb_kg.relation)
                              FROM fb_kg
                              LEFT JOIN fb_name
                              ON subject_mid = mid
                              WHERE alias LIKE %s
                              GROUP BY fb_kg.subject_mid, fb_name.alias""", (row['subject_name'],))
            rows = cursor.fetchall()
            all_relations = flatten([relations for _, _, relations in rows])
            total_facts = float(len(all_relations))
            total_relations = float(len(set(all_relations)))
            labels = []
            feature_rows = []
            for alias, subject_mid, relations in rows:
                label = subject_mid == row['subject']
                labels.append(label)
                n_facts = len(relations) / total_facts
                n_relations = len(set(relations)) / total_relations
                feature_rows.append([n_facts, n_relations])
            assert sum(labels) <= 1, 'n true: %d' % sum(labels) # Only one True
            ret.append({
                'rows': len(rows),
                'total_facts': total_facts,
                'total_relations': total_relations,
                'feature_rows': feature_rows,
                'labels': labels,
            })
    return ret

dev_candidates = get_candidates(df_dev.head(n=500))
print('Sample Candidates:', dev_candidates[:5])
train_candidates = get_candidates(df_train.head(n=4000))
# Out:
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Sample Candidates: [{'rows': 9, 'total_facts': 3199.0, 'total_relations': 65.0, 'feature_rows': [[0.003751172241325414, 0.1076923076923077], [0.0012503907471084713, 0.06153846153846154], [0.9681150359487339, 0.4], [0.009377930603313536, 0.2], [0.0025007814942169426, 0.12307692307692308], [0.00031259768677711783, 0.015384615384615385], [0.0015629884338855893, 0.046153846153846156], [0.010940919037199124, 0.24615384615384617], [0.002188183807439825, 0.1076923076923077]], 'labels': [False, False, True, False, False, False, False, False, False]}, {'rows': 1, 'total_facts': 3.0, 'total_relations': 3.0, 'feature_rows': [[1.0, 1.0]], 'labels': [True]}, {'rows': 1, 'total_facts': 20198.0, 'total_relations': 15.0, 'feature_rows': [[1.0, 1.0]], 'labels': [True]}, {'rows': 1, 'total_facts': 3.0, 'total_relations': 1.0, 'feature_rows': [[1.0, 1.0]], 'labels': [True]}, {'rows': 1, 'total_facts': 6.0, 'total_relations': 6.0, 'feature_rows': [[1.0, 1.0]], 'labels': [True]}]
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

train = flatten([row['feature_rows'] for row in train_candidates])
train_labels = flatten([row['labels'] for row in train_candidates])
dev = flatten([row['feature_rows'] for row in dev_candidates])
dev_labels = flatten([row['labels'] for row in dev_candidates])
model = LogisticRegression()
model.fit(train, train_labels)
dev_pred = model.predict(dev)
print(classification_report(dev_labels, dev_pred))
# Out:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     30323
#        True       0.93      0.78      0.85       481
#
# avg / total       1.00      1.00      1.00     30804

# %%
correct = 0.0
for row in dev_candidates:
    if not row['feature_rows']:
        continue
    confidences = model.decision_function(row['feature_rows'])
    max_confidence = float("-inf")
    max_index = 0
    for i, confidence in enumerate(confidences):
        if confidence > max_confidence:
            max_confidence = confidence
            max_index = i
    if row['labels'][i]:
        correct += 1
print('Num Correct:', correct)
print('Accuracy:', correct / len(dev_candidates))
# Out:
# Num Correct: 336.0
# Accuracy: 0.6956521739130435
