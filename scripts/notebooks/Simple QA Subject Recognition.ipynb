# %% [markdown]
# # Simple QA Subject Recognition
#
# The goal of this notebook is to preprocess a file into the format:
#
# **Subject Name:** angels vengeance
#
# **Result:** what\O language\O is\O angels\I vengeance\I in\O ?\O

# %%
import sys
sys.path.insert(0, '../../')

# %load_ext autoreload
# %autoreload 2

# %%
from scripts.utils.simple_qa import load_simple_qa 

# Destination Filename
DEST = './../../data/simple_qa_subject_recognition_dev.txt'

df, = load_simple_qa(dev=True)
df[:5]
# Out:
#    subject                      relation   object  \
# 0   0f3xg_  symbols/namesake/named_after   0cqt90
# 1   07f3jg  people/person/place_of_birth    0565d
# 2  031j8nn          music/release/region    07ssc
# 3  0c1cyhd            film/director/film  0wxsz5y
# 4  0fvhc0g          music/release/region    0345h
#
#                                             question
# 0  Who was the trump ocean club international hot...
# 1                       where was sasha vujačić born
# 2   What is a region that dead combo was released in
# 3  What is a film directed by wiebke von carolsfeld?
# 4  what country was music for stock exchange  rel...

# %%
from scripts.utils.connect import get_connection 

connection = get_connection()
cursor = connection.cursor()

# %%
from scripts.utils.add_subject_name import add_subject_name

add_subject_name(df, cursor, print_=True)
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# Subject MID (0yzv6q0) does not have aliases.
# Subject MID (0k571hg) does not have aliases.
# Subject MID (02z6y3p) does not have aliases.
# Subject MID (08vqg8n) does not have aliases.
# Subject MID (045p9_r) does not have aliases.
# Subject MID (03czw5g) does not have aliases.
# Subject MID (04j2m25) does not have aliases.
# Subject MID (0bvrjh4) does not have aliases.
# Subject MID (08c_49) does not have aliases.
# Subject MID (0h4867) does not have aliases.
# Subject MID (02qplxv) does not have aliases.
# Subject MID (0kz5hyk) does not have aliases.
# Subject MID (07wk3m) does not have aliases.
# Subject MID (01jyqwk) does not have aliases.
# Subject MID (0_s2kgd) does not have aliases.
# Subject MID (02vk_bv) does not have aliases.
# Subject MID (03f86d) does not have aliases.
# Subject MID (0kyvhwk) does not have aliases.
# Subject MID (0l8d74) does not have aliases.
# Subject MID (04jnfd) does not have aliases.
# Subject MID (04zfl8) does not have aliases.
# Subject MID (0z5y43n) does not have aliases.
# Subject MID (040bk2) does not have aliases.
# Subject MID (0gw5nz9) does not have aliases.
# Subject MID (0gdw67b) does not have aliases.
# Subject MID (0gg9r39) does not have aliases.
# Subject MID (0gjqd5) does not have aliases.
# Subject MID (0gxvdpb) does not have aliases.
# Subject MID (0b6crf) does not have aliases.
# Subject MID (04lcqqy) does not have aliases.
# Subject MID (07vvd5k) does not have aliases.
# Subject MID (04mmj61) does not have aliases.
# Subject MID (01591c) does not have aliases.
# Subject MID (0kymz9t) does not have aliases.
# Subject MID (0nynkpm) does not have aliases.
# Subject MID (01fp91g) does not have aliases.
# Subject MID (0fpwzjl) does not have aliases.
# Subject MID (0k3f05l) does not have aliases.
# Subject MID (0z2l7hh) does not have aliases.
# Subject MID (0wsdt4d) does not have aliases.
# Subject MID (07vvd5k) does not have aliases.
# Subject MID (0j154qx) does not have aliases.
# Subject MID (0kyp82h) does not have aliases.
# Subject MID (01r6n5q) does not have aliases.
# Subject MID (0gbjh51) does not have aliases.
# Subject MID (01bz6g5) does not have aliases.
# Subject MID (0cl6z16) does not have aliases.
# Subject MID (0hh8jh6) does not have aliases.
# Subject MID (04662kd) does not have aliases.
# Subject MID (0fx3ws8) does not have aliases.
#                                               Aliases  \
# 0                                  [bill hosket, jr.]
# 1                  [megan leigh romero, megan romero]
# 2                                           [datskat]
# 3                                        [ron warner]
# 4                               [mr m, mr. m., mr.m.]
# 5   [sabrina fredrica washington, sabrina washingt...
# 6   [t-town, tulsa, tulsa, oklahoma, wagoner count...
# 7                                   [nguyễn văn toàn]
# 8                        [aftereight, capital lights]
# 9                             [35 mm film, 35mm film]
# 10                                     [studio album]
# 11              [latin music, music of latin america]
# 12  [the three caballeros, three amigos!, tres ami...
# 13                         [single-player video game]
# 14             [the best of daniel o'donnell on film]
# 15         [philip pullman, philip pullman cbe, frsl]
# 16                        [stockholm arlanda airport]
# 17      [arthur b. hancock, jr., arthur hancock, jr.]
# 18                           [multiplayer video game]
# 19                               [topical medication]
# 20                                 [teesside gazette]
# 21                         [single-player video game]
# 22        [intégrale, volume 2: the guitar don't lie]
# 23        [marc and the mambas, raoul and the ruined]
# 24                                           [memnon]
# 25                         [single-player video game]
# 26  [he kaw teh v r (1985) 157 clr 523, he kaw teh...
# 27  [lake cowichan, lake cowichan, british columbi...
# 28                         [single-player video game]
# 29      [pappy o'daniel house, rogers-o'daniel house]
# 30                            [jack rose, rose, jack]
# 31                         [single-player video game]
# 32                                       [supernews!]
# 33                                    [pop rock 80's]
# 34  [connick jr, harry, connick, harry, jr., harry...
# 35                                        [macedonia]
# 36                                   [pharaoh seti i]
# 37                           [mockingbird don't sing]
# 38   [christoph schlingensief trifft: richard wagner]
# 39               [william hay, baron hay of ballyore]
# 40  [african american, africian-american, afro-ame...
# 41  [u.s. office of war information, united states...
# 42                    [phillipa lord: she's the shit]
# 43          [pillows & prayers: cherry red 1982–1983]
# 44                               [chocolate starfish]
# 45                         [lost (12\" inch version)]
# 46                              [occupation of mecca]
# 47    [philip b. thompson, jr., philip thompson, jr.]
# 48  [you don't dream in cryo. ....\, “you don’t dr...
# 49                                     [alexis reich]
#
#                                              Question  Subject
# 0               What was bill hosket, jr.'s position   02vvz00
# 1     What track is featured on the salisbury release  098j5p7
# 2                              What composer created?  0zhwd1v
# 3                                  Who's a linebacker  03m9zc3
# 4         what label does the artist mr. m. belong to  01x20gj
# 5             Which label is sabrinawmusic signed to?   0bnsl7
# 6     What newspaper circulates in the town of kearny   013kcv
# 7      Where is the place of birth of nguyen van toan  02vnwfd
# 8      what types of music is played by capitallights  02pvx1q
# 9                what is an example of a film on 35mm    0cj16
# 10  What is the name of the award winning album by...   06vw6v
# 11  What is an artist associated with latin americ...    0g293
# 12                 who did the music for three amigos   03nnzk
# 13         what game is played in single-player mode?   02hjn4
# 14  What kind of music is the film the best of dan...  0crtn5g
# 15             What works written by Phillip Pullman?    098sx
# 16       What is a hub for stockholm-arlanda airport?   015tns
# 17   what was arthur b. hancock, jr.'s cause of death  0gysl4r
# 18          what is a multiplayer computer video game   01z747
# 19                    which formulation is in topical   03jy9d
# 20            who is the owner of the evening gazette   09k6bj
# 21            What is a game with single-player mode?   02hjn4
# 22  What's a song released on intégrale, volume 2:...  03_tf2_
# 23    what record label worked with tormentandtoreros  01p81x_
# 24          Where was anna pavlova buried after death  0r8kzz7
# 25                 what is a single-player mode game?   02hjn4
# 26       which court did he kaw teh v r take place in  0r4w7s4
# 27                  which country is cowichan lake in   05t592
# 28  What is a game with the gameplay mode single-p...   02hjn4
# 29       what county is rogers-odaniel house apart of  06_90t2
# 30                 What is jackrosekensington gender?  01q65fc
# 31                   what game requires single-player   02hjn4
# 32                 What genre of program is supernews  025vhjk
# 33        what artists broadcast's pop rock 80s music  03gbxgp
# 34       what songs have harry connick, jr. produced?    03kts
# 35                 what invasions happened in macedon    0bk25
# 36  what was the fictional character seti i's occu...  045rk92
# 37         what kind of film is mockingbird dont sing   04lm64
# 38  what was the release type of  the basic wagner...  0bfbddk
# 39                    What profession is william hay?  027vn0k
# 40                What ethnicity is Jermaine Jackson?     0x67
# 41  which film did the office of war information h...   057ybl
# 42  which country released phillipa lord: shes the...  04svyms
# 43  What is the name of the track list for the rel...  0f3hh9h
# 44   who is the record label for chocolatestarfish26?  01pkfch
# 45  whats the canonical version of lost (12 inch v...  0fbnfn8
# 46  Who was an entity involved in the conquest of ...   08pfkm
# 47              Where did philip b. thompson, jr. die  02rjy0q
# 48    What artist recorded "You Don't Dream in Cryo"?  0frssfq
# 49                   what is john mark karr's gender    0g80_b
# ### Numbers
# 2.351314% [255 of 10845] questions do not reference subject
#
# 0.461042% [50 of 10845] subject mids do not have aliases

# %%
from tqdm import tqdm_notebook
from numpy import nan
from nltk.stem.snowball import SnowballStemmer
from nltk import word_tokenize
from IPython.display import display
import random
import json
import pandas as pd

stem = SnowballStemmer('english', ignore_stopwords=True).stem

tagged = []
exact_match = 0
not_exact_match = []
for index, row in tqdm_notebook(df.iterrows(), total=df.shape[0]):
    if isinstance(row['subject_name'], str):
        # Line up the question with the subject name
        possesives = ["'", "'s", "`s", "`"]
        token_question = word_tokenize(row['question'].lower())
        token_subject_name = word_tokenize(row['subject_name'].lower())
        # Save the original index but get rid of the possesives
        token_question_no_poss = [(i, token) for i, token in enumerate(token_question)
                          if token not in possesives]
        token_subject_name_no_poss = [token for i, token in enumerate(token_subject_name)
                          if token not in possesives]
        start_index, stop_index = None, None
        for i, (original_i, token) in enumerate(token_question_no_poss):
            # Check if spacy alias matches
            for j, other_token in enumerate(token_subject_name_no_poss):
                offset_original_i, offset_token = token_question_no_poss[i + j]
                if stem(offset_token) != stem(other_token):
                    break
                if j == len(token_subject_name_no_poss) - 1:  # Last iteration
                    stop_index = offset_original_i + 1
                    start_index = original_i

            if start_index is not None:
                break
    
        assert start_index is not None and stop_index is not None
    
        ret =  ''
        for i, token in enumerate(token_question):
            ret += token
            if i >= start_index and i < stop_index:
                ret += ' XX XX I-SUB\n'
            else:
                ret += ' XX XX 0\n'
        
        if token_subject_name == token_question[start_index:stop_index]:
            exact_match += 1
        else:
            not_exact_match.append([' '.join(token_subject_name),
                                    ' '.join(token_question[start_index:stop_index])])

        tagged.append(ret)

print('Exact Match: %f [%d of %d]' % (exact_match / df.shape[0], exact_match, df.shape[0]))
display(random.sample(tagged, 50))
display(random.sample(not_exact_match, 50))
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# Exact Match: 0.955371 [10361 of 10845]
# ['where XX XX 0\nis XX XX 0\nmaplewood XX XX I-SUB\nlocated XX XX 0\n? XX XX 0\n',
#  'what XX XX 0\ntype XX XX 0\nof XX XX 0\nalbum XX XX 0\nis XX XX 0\noranges XX XX I-SUB\n& XX XX I-SUB\nlemons XX XX I-SUB\n',
#  'what XX XX 0\nis XX XX 0\nblack XX XX I-SUB\nand XX XX I-SUB\nwhite XX XX I-SUB\nlive XX XX I-SUB\nbundle XX XX I-SUB\n# XX XX I-SUB\n3 XX XX I-SUB\n',
#  'what XX XX 0\ntype XX XX 0\nof XX XX 0\nmusic XX XX 0\nis XX XX 0\nmade XX XX 0\nby XX XX 0\ndavid XX XX I-SUB\nguetta XX XX I-SUB\n',
#  'what XX XX 0\nkind XX XX 0\nof XX XX 0\nmusic XX XX 0\ndoes XX XX 0\nlobo XX XX I-SUB\ncreate XX XX 0\n',
#  'what XX XX 0\nconflict XX XX 0\noccurred XX XX 0\nin XX XX 0\nmorocco XX XX I-SUB\n',
#  'name XX XX 0\na XX XX 0\nsymptom XX XX 0\nof XX XX 0\nthe XX XX 0\ndisease XX XX 0\nventricular XX XX I-SUB\ntachycardia XX XX I-SUB\n',
#  'what XX XX 0\ntype XX XX 0\nof XX XX 0\nmusic XX XX 0\nis XX XX 0\nof XX XX I-SUB\nwars XX XX I-SUB\nin XX XX I-SUB\nosyrhia XX XX I-SUB\n? XX XX 0\n',
#  'which XX XX 0\nschool XX XX 0\nis XX XX 0\na XX XX 0\nblack XX XX I-SUB\npanther XX XX I-SUB\nthe XX XX 0\nmascot XX XX 0\nof XX XX 0\n',
#  'what XX XX 0\nlanguage XX XX 0\nis XX XX 0\nfrom XX XX 0\ndigging XX XX I-SUB\nthe XX XX I-SUB\ngrave XX XX I-SUB\n',
#  'state XX XX 0\na XX XX 0\ntrack XX XX 0\non XX XX 0\nthe XX XX 0\nrelease XX XX 0\ntuloy XX XX I-SUB\nang XX XX I-SUB\nligaya XX XX I-SUB\n',
#  'stefan XX XX I-SUB\ndechant XX XX I-SUB\nwas XX XX 0\nthe XX XX 0\nart XX XX 0\ndirector XX XX 0\nof XX XX 0\nwhat XX XX 0\nfilm XX XX 0\n',
#  "what XX XX 0\nis XX XX 0\nivan XX XX I-SUB\nmaric XX XX I-SUB\n's XX XX 0\ngender XX XX 0\n",
#  "kunio XX XX I-SUB\nmaekawa XX XX I-SUB\n's XX XX 0\narchitectural XX XX 0\nstyle XX XX 0\nis XX XX 0\nthis XX XX 0\n. XX XX 0\n",
#  'what XX XX 0\nis XX XX 0\nthe XX XX 0\nposition XX XX 0\nthat XX XX 0\nsoccer XX XX 0\nplayer XX XX 0\nlance XX XX I-SUB\ndavids XX XX I-SUB\nplays XX XX 0\n? XX XX 0\n',
#  'what XX XX 0\nlanguage XX XX 0\nis XX XX 0\nin XX XX 0\ngerry XX XX I-SUB\n',
#  'what XX XX 0\nkind XX XX 0\nof XX XX 0\nmusic XX XX 0\nis XX XX 0\notterclan XX XX I-SUB\nknown XX XX 0\nfor XX XX 0\nreleasing XX XX 0\n',
#  'where XX XX 0\nwas XX XX 0\nedward XX XX I-SUB\nlyons XX XX I-SUB\nborn XX XX 0\nin XX XX 0\neurope XX XX 0\n',
#  'who XX XX 0\ndid XX XX 0\nmaurice XX XX I-SUB\nmerleau-ponty XX XX I-SUB\nhelp XX XX 0\nto XX XX 0\ninfluence XX XX 0\n',
#  'which XX XX 0\namerican XX XX 0\nand XX XX 0\ncanadian XX XX 0\nfootball XX XX 0\nplayer XX XX 0\nwas XX XX 0\nborn XX XX 0\nin XX XX 0\npensacola XX XX I-SUB\n? XX XX 0\n',
#  'which XX XX 0\nartist XX XX 0\nreleased XX XX 0\nthe XX XX 0\nalbum XX XX 0\nlullaby XX XX I-SUB\n: XX XX I-SUB\nhits XX XX I-SUB\n, XX XX I-SUB\nrarities XX XX I-SUB\n& XX XX I-SUB\ngems XX XX I-SUB\n',
#  'in XX XX 0\nwhat XX XX 0\nsouthern XX XX 0\nstate XX XX 0\nis XX XX 0\nrecheulos XX XX I-SUB\nlocated XX XX 0\n',
#  'name XX XX 0\na XX XX 0\n1936 XX XX 0\nepic XX XX I-SUB\nfilm XX XX I-SUB\n',
#  'where XX XX 0\nwas XX XX 0\nyorgos XX XX I-SUB\nmakris XX XX I-SUB\nborn XX XX 0\nat XX XX 0\n? XX XX 0\n',
#  'who XX XX 0\nis XX XX 0\nthe XX XX 0\nparent XX XX 0\nof XX XX 0\nhayley XX XX I-SUB\nhasselhoff XX XX I-SUB\n? XX XX 0\n',
#  'what XX XX 0\nalbum XX XX 0\nwas XX XX 0\nsirius XX XX I-SUB\nrecorded XX XX 0\n? XX XX 0\n',
#  'which XX XX 0\nlake XX XX 0\ndoes XX XX 0\nlower XX XX I-SUB\nbuckhorn XX XX I-SUB\nlake XX XX I-SUB\nflow XX XX 0\ninto XX XX 0\n? XX XX 0\n',
#  'who XX XX 0\ndirected XX XX 0\ndam XX XX I-SUB\nstreet XX XX I-SUB\n',
#  'where XX XX 0\nis XX XX 0\nswaim XX XX I-SUB\nplace XX XX I-SUB\nlocated XX XX 0\nwithin XX XX 0\nthe XX XX 0\nunited XX XX 0\nstates XX XX 0\n? XX XX 0\n',
#  'which XX XX 0\nwas XX XX 0\nauthor XX XX 0\nwas XX XX 0\nhelen XX XX I-SUB\nkeller XX XX I-SUB\ninfluenced XX XX 0\nby XX XX 0\n? XX XX 0\n',
#  'what XX XX 0\nnation XX XX 0\ndoes XX XX 0\njane XX XX I-SUB\nreece XX XX I-SUB\npledge XX XX 0\nallegiance XX XX 0\nto XX XX 0\n',
#  'what XX XX 0\nis XX XX 0\nthe XX XX 0\nsingle XX XX 0\nlittle XX XX I-SUB\nred XX XX I-SUB\nrooster XX XX I-SUB\n( XX XX I-SUB\nfeat XX XX I-SUB\n. XX XX I-SUB\njohn XX XX I-SUB\nsebastian XX XX I-SUB\n) XX XX I-SUB\na XX XX 0\nversion XX XX 0\nof XX XX 0\n? XX XX 0\n',
#  'name XX XX 0\nthe XX XX 0\nartist XX XX 0\nwho XX XX 0\nrecorded XX XX 0\nbeat XX XX I-SUB\nit XX XX I-SUB\n. XX XX 0\n',
#  'which XX XX 0\nartist XX XX 0\nmade XX XX 0\nthe XX XX 0\nalbum XX XX 0\njump XX XX I-SUB\n',
#  "who XX XX 0\n's XX XX 0\na XX XX 0\nchief XX XX 0\nminister XX XX 0\nborn XX XX 0\nin XX XX 0\nchapar XX XX I-SUB\n, XX XX I-SUB\ndhubri XX XX I-SUB\n",
#  'what XX XX 0\nare XX XX 0\nnetflix XX XX 0\ntitles XX XX 0\nin XX XX 0\nthe XX XX 0\nfrance XX XX I-SUB\ngenre XX XX 0\n',
#  'which XX XX 0\nwar XX XX 0\ndid XX XX 0\nthe XX XX 0\nfirst XX XX I-SUB\nbattle XX XX I-SUB\nof XX XX I-SUB\nindependence XX XX I-SUB\ntake XX XX 0\nplace XX XX 0\n',
#  'name XX XX 0\nan XX XX 0\nalbum XX XX I-SUB\nreleased XX XX 0\n',
#  'what XX XX 0\nfilm XX XX 0\ndid XX XX 0\njeff XX XX I-SUB\npope XX XX I-SUB\nwrite XX XX 0\n',
#  'what XX XX 0\nevent XX XX 0\nwas XX XX 0\nthe XX XX 0\nbattle XX XX I-SUB\nof XX XX I-SUB\nwesterplatte XX XX I-SUB\npart XX XX 0\nof XX XX 0\n',
#  "what XX XX 0\nis XX XX 0\nvital XX XX I-SUB\naza XX XX I-SUB\n's XX XX 0\njob XX XX 0\n? XX XX 0\n",
#  'what XX XX 0\nformat XX XX 0\nwas XX XX 0\nfree XX XX I-SUB\nthe XX XX I-SUB\nmusic XX XX I-SUB\nreleased XX XX 0\nin XX XX 0\n? XX XX 0\n',
#  'what XX XX 0\nis XX XX 0\na XX XX 0\nbook XX XX 0\nfrom XX XX 0\nthe XX XX 0\nethan XX XX I-SUB\nfrome XX XX I-SUB\nseries XX XX 0\n',
#  'what XX XX 0\nis XX XX 0\nthe XX XX 0\ngender XX XX 0\nof XX XX 0\nfrank XX XX I-SUB\nmcintyre XX XX I-SUB\n? XX XX 0\n',
#  "what XX XX 0\n's XX XX 0\ndan XX XX I-SUB\nharris XX XX I-SUB\n's XX XX 0\nprofession XX XX 0\n",
#  'what XX XX 0\nfilms XX XX 0\nhave XX XX 0\nvittorio XX XX I-SUB\nde XX XX I-SUB\nsica XX XX I-SUB\ndirected XX XX 0\n? XX XX 0\n',
#  'who XX XX 0\nis XX XX 0\nthe XX XX 0\nproducer XX XX 0\nof XX XX 0\narmageddon XX XX I-SUB\n',
#  'which XX XX 0\nalbum XX XX 0\nis XX XX 0\ncreated XX XX 0\nby XX XX 0\nbloodgood XX XX I-SUB\n',
#  'what XX XX 0\ncity XX XX 0\nis XX XX 0\nnear XX XX 0\nthe XX XX 0\nercan XX XX I-SUB\ninternational XX XX I-SUB\nairport XX XX I-SUB\n? XX XX 0\n',
#  "what XX XX 0\n's XX XX 0\na XX XX 0\ntown XX XX 0\nthat XX XX 0\n's XX XX 0\non XX XX 0\nprince XX XX I-SUB\nedward XX XX I-SUB\nisland XX XX I-SUB\n"]
# [["clemson tigers men 's basketball", 'clemson tigers mens basketball'],
#  ['skeeter davies', 'skeeter davis'],
#  ['death eaters', 'death eater'],
#  ['regan gascoigne', 'regan gascoignes'],
#  ["acorna 's world", 'acornas world'],
#  ['bretons', 'breton'],
#  ['joules', 'joule'],
#  ["peter 's point plantation", 'peters point plantation'],
#  ['short films', 'short film'],
#  ['drugs', 'drug'],
#  ["parkinson 's disease", 'parkinsons disease'],
#  ['personal computers', 'personal computer'],
#  ["disney 's kim possible 2 : drakken 's demise",
#   'disneys kim possible 2 : drakkens demise'],
#  ["heaton 's crossroads", 'heatons crossroads'],
#  ['horror film', 'horror films'],
#  ['spike milligans', 'spike milligan'],
#  ['drugs', 'drug'],
#  ["fido 's summer fun , volume 2", 'fidos summer fun , volume 2'],
#  ["love 's boomerang", 'loves boomerang'],
#  ['billie ocean', 'billy ocean'],
#  ["chet 's speech , part ii", 'chets speech , part ii'],
#  ['mithun chakraborty', 'mithun chakrabortys'],
#  ["raffi 's christmas album", 'raffis christmas album'],
#  ['franze schubert', 'franz schubert'],
#  ["prince george 's county", 'prince georges county'],
#  ['michael nymans', 'michael nyman'],
#  ["showgirls 2 : penny 's from heaven", 'showgirls 2 : pennys from heaven'],
#  ["the return of 'allo 'allo !", 'the return of allo allo !'],
#  ['french movies', 'french movie'],
#  ["swingin ' with bud", 'swingin with bud'],
#  [".977 the '80s channel", '.977 the 80s channel'],
#  ["20 classics of the '80s", '20 classics of the 80s'],
#  ["the godfather 's revenge", 'the godfathers revenge'],
#  ['album', 'albums'],
#  ['the killing grounds', 'the killing ground'],
#  ['iceland', 'icelandic'],
#  ["harry potter and the philosopher 's stone",
#   'harry potter and the philosophers stone'],
#  ["st. peter 's episcopal church", 'st. peters episcopal church'],
#  ["sid meier 's alpha centauri", 'sid meiers alpha centauri'],
#  ['drugs', 'drug'],
#  ['eidos interaction', 'eidos interactive'],
#  ["uncle jasper 's will", 'uncle jaspers will'],
#  ['graphics designer', 'graphic designer'],
#  ['megan cheng', 'megan chengs'],
#  ["rockin ' with judy jetson", 'rockin with judy jetson'],
#  ['steve jablonski', 'steve jablonsky'],
#  ["beretta 's island", 'berettas island'],
#  ['album', 'albums'],
#  ['short films', 'short film'],
#  ["assassin 's creed : revelations", 'assassins creed : revelations']]

# %%
file_ = open(DEST, 'w')
file_.write('-DOCSTART- -X- O O\n\n' + '\n'.join(tagged))
# Out:
# 1248783
