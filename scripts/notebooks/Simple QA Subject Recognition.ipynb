# %% [markdown]
# # Simple QA Subject Recognition
#
# The goal of this notebook is to preprocess a file for subject recognition. For every token in a question, we tag it with a I for inside subject or O for outside subject.

# %%
import sys
sys.path.insert(0, '../../')

# %% [markdown]
# Here we load the source file and declare the name of the destination file.

# %%
from scripts.utils.simple_qa import load_simple_qa 

# Destination Filename
DEST = './../../../allennlp/experiments/train.txt'

df, = load_simple_qa(train=True)
df[:5]
# Out:
#    subject                        relation   object  \
# 0  04whkz5      book/written_work/subjects   01cj3p
# 1  0tp2p24     music/release_track/release  0sjc7c1
# 2  04j0t75               film/film/country    07ssc
# 3    0ftqr  music/producer/tracks_produced   0p600l
# 4  036p007         music/release/producers   0677ng
#
#                                             question
# 0                           what is the book e about
# 1  to what release does the release track cardiac...
# 2            what country was the film the debt from
# 3            what songs have nobuo uematsu produced?
# 4                          Who produced eve-olution?

# %% [markdown]
# We use the cursor from psycopg2 to connect to PostgreSQL with our knowledge graph.

# %%
from scripts.utils.connect import get_connection 

connection = get_connection()
cursor = connection.cursor()

# %% [markdown]
# For every example, there is not a clear subject name but we can do a fair job a linking questions with subject names only missing 2.7% of examples.
#
# Our dataset will not include the examples for which we cannot link a subject name. Following an analysis in `Explore Simple QA` we find that the missing subject names are typically due to misspellings or do not exist in Freebase anymore.

# %%
from scripts.utils.link_subject_name import add_subject_name

add_subject_name(df, cursor, print_=True)
# Out:
# HBox(children=(IntProgress(value=0, max=75910), HTML(value='')))
# Subject MID (0rpphvw) does not have aliases.
# Subject MID (06zpt0n) does not have aliases.
# Subject MID (0pdsfmz) does not have aliases.
# Subject MID (0dz8wx) does not have aliases.
# Subject MID (0b5d_l) does not have aliases.
# Subject MID (0j3zvz_) does not have aliases.
# Subject MID (0bvqgyw) does not have aliases.
# Subject MID (0l8mm0j) does not have aliases.
# Subject MID (05xwcnm) does not have aliases.
# Subject MID (06zzpc) does not have aliases.
# Subject MID (0dyvxvf) does not have aliases.
# Subject MID (0rygyy8) does not have aliases.
# Subject MID (07jg3g) does not have aliases.
# Subject MID (0lmk5l) does not have aliases.
# Subject MID (0n5_b_c) does not have aliases.
# Subject MID (0w_mkc2) does not have aliases.
# Subject MID (0djb8lg) does not have aliases.
# Subject MID (0c0l3hf) does not have aliases.
# Subject MID (04htqk) does not have aliases.
# Subject MID (0j5gy9s) does not have aliases.
# Subject MID (0zj79nx) does not have aliases.
# Subject MID (09k116f) does not have aliases.
# Subject MID (063fbj9) does not have aliases.
# Subject MID (03whpdf) does not have aliases.
# Subject MID (0k33swc) does not have aliases.
# Subject MID (03whpdf) does not have aliases.
# Subject MID (01rzmzn) does not have aliases.
# Subject MID (01r33px) does not have aliases.
# Subject MID (0bxlbnc) does not have aliases.
# Subject MID (05zpcz_) does not have aliases.
# Subject MID (0jwz9rz) does not have aliases.
# Subject MID (0wpj3tz) does not have aliases.
# Subject MID (0bj9c4k) does not have aliases.
# Subject MID (0gj6wf9) does not have aliases.
# Subject MID (0fzjwf2) does not have aliases.
# Subject MID (0f_gfk) does not have aliases.
# Subject MID (01kc6h4) does not have aliases.
# Subject MID (07s6zj4) does not have aliases.
# Subject MID (0s8szf_) does not have aliases.
# Subject MID (0_l516_) does not have aliases.
# Subject MID (0kv5dr7) does not have aliases.
# Subject MID (02vn2t8) does not have aliases.
# Subject MID (07xd4) does not have aliases.
# Subject MID (0640q7w) does not have aliases.
# Subject MID (01qdv25) does not have aliases.
# Subject MID (0lns8qj) does not have aliases.
# Subject MID (0c03x2r) does not have aliases.
# Subject MID (0jvbztp) does not have aliases.
# Subject MID (0wjc55v) does not have aliases.
# Subject MID (0sxc1hv) does not have aliases.
# Subject MID (0k2x0n) does not have aliases.
# Subject MID (01jldp_) does not have aliases.
# Subject MID (0h02gs) does not have aliases.
# Subject MID (0gkq_lr) does not have aliases.
# Subject MID (0glyvjx) does not have aliases.
# Subject MID (0_t1w0k) does not have aliases.
# Subject MID (0d_vj4t) does not have aliases.
# Subject MID (0fpcvpz) does not have aliases.
# Subject MID (0crv72l) does not have aliases.
# Subject MID (0jwgv1b) does not have aliases.
# Subject MID (04fxlmx) does not have aliases.
# Subject MID (0frw6z5) does not have aliases.
# Subject MID (026y1rh) does not have aliases.
# Subject MID (0z82szt) does not have aliases.
# Subject MID (018wk4z) does not have aliases.
# Subject MID (0b3st8y) does not have aliases.
# Subject MID (05sqzyf) does not have aliases.
# Subject MID (0kywkbt) does not have aliases.
# Subject MID (02h7hyr) does not have aliases.
# Subject MID (0l76y8l) does not have aliases.
# Subject MID (02p7p0_) does not have aliases.
# Subject MID (0gyrjjh) does not have aliases.
# Subject MID (0j_zvxz) does not have aliases.
# Subject MID (0dfhs6) does not have aliases.
# Subject MID (02h669_) does not have aliases.
# Subject MID (0crwd4t) does not have aliases.
# Subject MID (03h53dg) does not have aliases.
# Subject MID (0gkl8hv) does not have aliases.
# Subject MID (0fz8blt) does not have aliases.
# Subject MID (04t50cr) does not have aliases.
# Subject MID (0j4jcr3) does not have aliases.
# Subject MID (0kd9z1j) does not have aliases.
# Subject MID (0f1q7cv) does not have aliases.
# Subject MID (0rdf18_) does not have aliases.
# Subject MID (0kynrjn) does not have aliases.
# Subject MID (065hp1) does not have aliases.
# Subject MID (0gfgv_d) does not have aliases.
# Subject MID (0cs53t1) does not have aliases.
# Subject MID (02hvshq) does not have aliases.
# Subject MID (02kd3j2) does not have aliases.
# Subject MID (0gfgv_d) does not have aliases.
# Subject MID (0djb9ln) does not have aliases.
# Subject MID (0fpvtjg) does not have aliases.
# Subject MID (026wgzn) does not have aliases.
# Subject MID (0fyzy_w) does not have aliases.
# Subject MID (0bggq7w) does not have aliases.
# Subject MID (09vxjfw) does not have aliases.
# Subject MID (0fsvhm7) does not have aliases.
# Subject MID (02kc1nh) does not have aliases.
# Subject MID (04cklrr) does not have aliases.
# Subject MID (01kdn9c) does not have aliases.
# Subject MID (0gc3kx1) does not have aliases.
# Subject MID (04j0pcd) does not have aliases.
# Subject MID (0y6175c) does not have aliases.
# Subject MID (0hglp1p) does not have aliases.
# Subject MID (013lnpw) does not have aliases.
# Subject MID (0jt7g2) does not have aliases.
# Subject MID (0gbmddn) does not have aliases.
# Subject MID (0gbr3b0) does not have aliases.
# Subject MID (05zk087) does not have aliases.
# Subject MID (03gylv2) does not have aliases.
# Subject MID (04m61fh) does not have aliases.
# Subject MID (0bb4339) does not have aliases.
# Subject MID (03xy_kt) does not have aliases.
# Subject MID (0ny64dl) does not have aliases.
# Subject MID (0crw6bh) does not have aliases.
# Subject MID (0w0dnn8) does not have aliases.
# Subject MID (04lcqqy) does not have aliases.
# Subject MID (0n9kv_9) does not have aliases.
# Subject MID (0gkry3f) does not have aliases.
# Subject MID (0fjs7qh) does not have aliases.
# Subject MID (03xw_n5) does not have aliases.
# Subject MID (02kcb4m) does not have aliases.
# Subject MID (0_jrcww) does not have aliases.
# Subject MID (0fpt0gm) does not have aliases.
# Subject MID (06zn6t4) does not have aliases.
# Subject MID (05w_s_m) does not have aliases.
# Subject MID (03fy85v) does not have aliases.
# Subject MID (0kyszvb) does not have aliases.
# Subject MID (0b_q28k) does not have aliases.
# Subject MID (0bc3387) does not have aliases.
# Subject MID (06zlgp9) does not have aliases.
# Subject MID (02wc6z) does not have aliases.
# Subject MID (0c9plyc) does not have aliases.
# Subject MID (06msfy) does not have aliases.
# Subject MID (04f17z) does not have aliases.
# Subject MID (07ygcts) does not have aliases.
# Subject MID (0x2q3t8) does not have aliases.
# Subject MID (01gyftd) does not have aliases.
# Subject MID (0cs04jc) does not have aliases.
# Subject MID (0h1fc59) does not have aliases.
# Subject MID (04nj_16) does not have aliases.
# Subject MID (0cs44kv) does not have aliases.
# Subject MID (0bh3ss2) does not have aliases.
# Subject MID (0crt9zm) does not have aliases.
# Subject MID (09j_h8s) does not have aliases.
# Subject MID (0h290kq) does not have aliases.
# Subject MID (0l3ztzs) does not have aliases.
# Subject MID (0rd_yj1) does not have aliases.
# Subject MID (07cdshc) does not have aliases.
# Subject MID (0fp9c7s) does not have aliases.
# Subject MID (0l4jzdt) does not have aliases.
# Subject MID (084bwx) does not have aliases.
# Subject MID (04p74c9) does not have aliases.
# Subject MID (0byshgp) does not have aliases.
# Subject MID (0lf79y) does not have aliases.
# Subject MID (0449pfb) does not have aliases.
# Subject MID (0sj26dn) does not have aliases.
# Subject MID (0bvglxv) does not have aliases.
# Subject MID (09rz5y5) does not have aliases.
# Subject MID (01gjnz4) does not have aliases.
# Subject MID (06_y86t) does not have aliases.
# Subject MID (01hfwyh) does not have aliases.
# Subject MID (02wy5lc) does not have aliases.
# Subject MID (0dr08bk) does not have aliases.
# Subject MID (0j1fzwz) does not have aliases.
# Subject MID (0crryr_) does not have aliases.
# Subject MID (075py1z) does not have aliases.
# Subject MID (0mwd49q) does not have aliases.
# Subject MID (06znrf) does not have aliases.
# Subject MID (09pgcxd) does not have aliases.
# Subject MID (0y7wy6k) does not have aliases.
# Subject MID (0bf1lpc) does not have aliases.
# Subject MID (0plkhk1) does not have aliases.
# Subject MID (0g6tq91) does not have aliases.
# Subject MID (05pxc0b) does not have aliases.
# Subject MID (0zbvxwj) does not have aliases.
# Subject MID (0djx4dq) does not have aliases.
# Subject MID (02z3x3z) does not have aliases.
# Subject MID (096dp3) does not have aliases.
# Subject MID (0sgjy1m) does not have aliases.
# Subject MID (02qxqxf) does not have aliases.
# Subject MID (0fby4b2) does not have aliases.
# Subject MID (01hksbh) does not have aliases.
# Subject MID (0c68ns9) does not have aliases.
# Subject MID (0crsbks) does not have aliases.
# Subject MID (0g7pcl5) does not have aliases.
# Subject MID (03m82zk) does not have aliases.
# Subject MID (01myj0t) does not have aliases.
# Subject MID (0c1r708) does not have aliases.
# Subject MID (0s8yzqf) does not have aliases.
# Subject MID (0j_zvxz) does not have aliases.
# Subject MID (04sw7fd) does not have aliases.
# Subject MID (0x03kwr) does not have aliases.
# Subject MID (0z8nbpd) does not have aliases.
# Subject MID (0n1s3sr) does not have aliases.
# Subject MID (03whpdf) does not have aliases.
# Subject MID (0yq8f0w) does not have aliases.
# Subject MID (0285c83) does not have aliases.
# Subject MID (0gyk8tl) does not have aliases.
# Subject MID (03g2qrt) does not have aliases.
# Subject MID (0sh4pjl) does not have aliases.
# Subject MID (0xncrxf) does not have aliases.
# Subject MID (0c8d292) does not have aliases.
# Subject MID (0g41plx) does not have aliases.
# Subject MID (0g997s7) does not have aliases.
# Subject MID (0fm7hh3) does not have aliases.
# Subject MID (0crsdsx) does not have aliases.
# Subject MID (064gwfn) does not have aliases.
# Subject MID (0gfws8y) does not have aliases.
# Subject MID (043zbnd) does not have aliases.
# Subject MID (0dm49p7) does not have aliases.
# Subject MID (0jq96lx) does not have aliases.
# Subject MID (0ch8kqd) does not have aliases.
# Subject MID (0hcbb8m) does not have aliases.
# Subject MID (0mzptbd) does not have aliases.
# Subject MID (0w7cbr8) does not have aliases.
# Subject MID (0_mtrfk) does not have aliases.
# Subject MID (0cfy3rv) does not have aliases.
# Subject MID (0dy9zt) does not have aliases.
# Subject MID (019cj5x) does not have aliases.
# Subject MID (04139r7) does not have aliases.
# Subject MID (0dq21dx) does not have aliases.
# Subject MID (0crrv4f) does not have aliases.
# Subject MID (0k82vt) does not have aliases.
# Subject MID (0gtl5sq) does not have aliases.
# Subject MID (0_kfkv3) does not have aliases.
# Subject MID (02w2zg2) does not have aliases.
# Subject MID (0f12rzg) does not have aliases.
# Subject MID (05wrx38) does not have aliases.
# Subject MID (0m4vg1x) does not have aliases.
# Subject MID (0q9jqjb) does not have aliases.
# Subject MID (065nd3) does not have aliases.
# Subject MID (043zbnd) does not have aliases.
# Subject MID (0449pfb) does not have aliases.
# Subject MID (01j18_) does not have aliases.
# Subject MID (0wyfx9s) does not have aliases.
# Subject MID (01w8rcl) does not have aliases.
# Subject MID (07lp3t) does not have aliases.
# Subject MID (01y4dw) does not have aliases.
# Subject MID (0gh7mr8) does not have aliases.
# Subject MID (0b1vhz) does not have aliases.
# Subject MID (0qzfpg9) does not have aliases.
# Subject MID (09dtpgn) does not have aliases.
# Subject MID (03jg781) does not have aliases.
# Subject MID (0bt_hv5) does not have aliases.
# Subject MID (0fpdpgh) does not have aliases.
# Subject MID (0c0mb7h) does not have aliases.
# Subject MID (0h64yp8) does not have aliases.
# Subject MID (0jvrtd9) does not have aliases.
# Subject MID (0f2fv3f) does not have aliases.
# Subject MID (01k6bst) does not have aliases.
# Subject MID (0pfx1x) does not have aliases.
# Subject MID (0_vbksf) does not have aliases.
# Subject MID (0djrpd2) does not have aliases.
# Subject MID (02qgvhg) does not have aliases.
# Subject MID (0_7n4vm) does not have aliases.
# Subject MID (01kt5b6) does not have aliases.
# Subject MID (0h2d0b8) does not have aliases.
# Subject MID (0k1v4jp) does not have aliases.
# Subject MID (0gw5nz9) does not have aliases.
# Subject MID (0_wjz54) does not have aliases.
# Subject MID (0kyx4c8) does not have aliases.
# Subject MID (0b653h6) does not have aliases.
# Subject MID (0crthf2) does not have aliases.
# Subject MID (0wsl5dx) does not have aliases.
# Subject MID (06znwkl) does not have aliases.
# Subject MID (0j7rxps) does not have aliases.
# Subject MID (0yxpn3_) does not have aliases.
# Subject MID (0bhgq3q) does not have aliases.
# Subject MID (0yssvdz) does not have aliases.
# Subject MID (0g90fx) does not have aliases.
# Subject MID (059xkp_) does not have aliases.
# Subject MID (0b9t5pg) does not have aliases.
# Subject MID (0kz2c8n) does not have aliases.
# Subject MID (0ymrldg) does not have aliases.
# Subject MID (0y5tpk1) does not have aliases.
# Subject MID (0n_wwdn) does not have aliases.
# Subject MID (04t05rf) does not have aliases.
# Subject MID (0cl_jkj) does not have aliases.
# Subject MID (0gt4qt) does not have aliases.
# Subject MID (0kyq7nc) does not have aliases.
# Subject MID (07lygr0) does not have aliases.
# Subject MID (0crsd3b) does not have aliases.
# Subject MID (0v30c30) does not have aliases.
# Subject MID (0vbm7zb) does not have aliases.
# Subject MID (0bj6z7h) does not have aliases.
# Subject MID (03y6j71) does not have aliases.
# Subject MID (0bbc29p) does not have aliases.
# Subject MID (0f7f957) does not have aliases.
# Subject MID (0fyp9_9) does not have aliases.
# Subject MID (09rs_y9) does not have aliases.
# Subject MID (0bhgxcw) does not have aliases.
# Subject MID (0q8f1zq) does not have aliases.
# Subject MID (045y22w) does not have aliases.
# Subject MID (027kwms) does not have aliases.
# Subject MID (0hz397x) does not have aliases.
# Subject MID (0w7cbr8) does not have aliases.
# Subject MID (0g8z9vt) does not have aliases.
# Subject MID (01knpzs) does not have aliases.
# Subject MID (0g4pr7_) does not have aliases.
# Subject MID (0wpzpjx) does not have aliases.
# Subject MID (04ln1gq) does not have aliases.
# Subject MID (05btdj) does not have aliases.
# Subject MID (07cy4b) does not have aliases.
# Subject MID (045tbwg) does not have aliases.
# Subject MID (0zbdc7h) does not have aliases.
# Subject MID (042t3v) does not have aliases.
# Subject MID (0hn9lsz) does not have aliases.
# Subject MID (0j111g9) does not have aliases.
# Subject MID (0gxvf0c) does not have aliases.
# Subject MID (0dm6gz8) does not have aliases.
# Subject MID (0x21_jm) does not have aliases.
# Subject MID (01v7hcx) does not have aliases.
# Subject MID (0jzhh7) does not have aliases.
# Subject MID (017dh0) does not have aliases.
# Subject MID (0v2bntr) does not have aliases.
# Subject MID (0gkrc72) does not have aliases.
# Subject MID (0gkt7kk) does not have aliases.
# Subject MID (0r5wj8r) does not have aliases.
# Subject MID (04j1x84) does not have aliases.
# Subject MID (01g7mbf) does not have aliases.
# Subject MID (0wk_pvq) does not have aliases.
# Subject MID (0gjsc) does not have aliases.
# Subject MID (0gj6wf9) does not have aliases.
# Subject MID (0fhnl2r) does not have aliases.
# Subject MID (07wk3m) does not have aliases.
# Subject MID (05btbgv) does not have aliases.
# Subject MID (0h0tynv) does not have aliases.
# Subject MID (0nbyg9c) does not have aliases.
# Subject MID (0q57lty) does not have aliases.
# Subject MID (0dm441t) does not have aliases.
# Subject MID (04d6h0t) does not have aliases.
# Subject MID (01mf6h9) does not have aliases.
#                                               Aliases  \
# 0                             [harry blackstone, jr.]
# 1                         [slinkee minx, slinky minx]
# 2       [is it love? ultra naté best remixes, vol. 1]
# 3                                    [i'm breathless]
# 4                    [human genome, the human genome]
# 5                                    [all the rage!!]
# 6                                    [blood brothers]
# 7   [<bold>constance georgine, countess markiewicz...
# 8                    [the piper at the gates of dawn]
# 9                             [new hampshire chicken]
# 10                [plum island animal disease center]
# 11  [ied, improvised bombing, improvized explosive...
# 12                                 [(4384) henrybuhl]
# 13  [world war ii: in color, world war ii in hd co...
# 14                                   [enemies closer]
# 15                           [bacterial endocarditis]
# 16                                [racing video game]
# 17                                  [don't look down]
# 18                                  [san rafael lake]
# 19                       [the daddy of rock 'n' roll]
# 20  [street scene: act i. no. 3a \"come in, come in\]
# 21                           [multiplayer video game]
# 22              [marion lake, marion lake, minnesota]
# 23                     [defence, defense, defenseman]
# 24                                           [circa:]
# 25                        [robert \"bucket\" hingley]
# 26                        [to the left of the father]
# 27                                  [i can’t explain]
# 28  [a dino de laurentiis film also, agostino de l...
# 29  [you're a big boy now, you're a big boy now so...
# 30                                     [solar system]
# 31                                      [lévon sayan]
# 32                        [tembec inc., tembec, inc.]
# 33                                   [marc-éric gueï]
# 34                         [single-player video game]
# 35                                     [6289 lanusei]
# 36                           [32nd virginia infantry]
# 37                                          [ray luv]
# 38                              [rodolphe d'erlanger]
# 39                               [topical medication]
# 40                     [hongkonger, hong kong people]
# 41              [ángela caccia torres, ángela torres]
# 42                                  [meghan o'rourke]
# 43                               [pole, stefan betke]
# 44                                      [cabra casay]
# 45  [dr. seuss on the loose, green eggs and ham an...
# 46      [afro-jamaican, jamaicans of african descent]
# 47  [united states presidential election debates, ...
# 48                               [topical medication]
# 49  [edward m. kennedy, jr., edward moore kennedy,...
#
#                                              Question  Subject
# 0   which country does harry blackstone, jr. come ...   0428h5
# 1                     what tracks are by slinkeeminx?  01qtxd4
# 2     what types of album is the best remixes, vol. 1  02w851w
# 3        what platform was im breathless released on?  038xf82
# 4     what is the name of a gene in the hunan genome.    0bsdc
# 5                  what is a track from all the rage!  0q9lhqm
# 6               who is the male composer of the song?  0_78wqs
# 7            what is constance markiewicz's religion?   023395
# 8   Who released the piper at the gates of down tr...  0f1ncqg
# 9   what is the primary use of the chicken breed n...  027843j
# 10         where in new york is building 101 located    028d02
# 11  what disaster featured improvised explosive de...   01n8xw
# 12             what does (4384) 1990 aa orbit around?  080b82j
# 13  What type of film genre is "World War II in HD...  0hnf0jr
# 14   what is the language of the film enemies closeri  0ngxybd
# 15  what antibiotic is used to treat bacterial inf...  07y4wg7
# 16                What is an example of a racing game   01sjng
# 17      What tracks is dont look down a recording of?  023jr86
# 18      san rafael lagoon is located in what country?  02pljc_
# 19  what does the film the daddy of rock n roll fo...   080q4t
# 20  Who composed street scene: act i. no. 3a \\"co...  0_6bnq_
# 21  what's a 2004 game that had a multiplayer program   01z747
# 22                          who was the V names after   013g7s
# 23  which hockey players play defenceman (ice hockey)   02qvl7
# 24                          what is a song by circahq  03yy_zk
# 25  which profession does robert \\"bucket\\" hing...   07_gq0
# 26                   what country is lavoura arcaica?   0bsqxh
# 27            who was the composer of  i cant explain  0bb81zq
# 28       What film is produced by Dino de Laurentils?   0272kv
# 29          What type of album is youre a big boy now  03fzmz_
# 30            what is an asteroid discovered in chile    06p5g
# 31                        what gender is levon sayan?  03c4tf9
# 32          where was the organization tembec founded   03858p
# 33  what coast does was nominated for Classical Al...  02vnrz0
# 34      what is a game with single-player arcade game   02hjn4
# 35               what is (6289) 1984 hp1 a member of?  0by1ydr
# 36  What position does ceyhun eriş play on the soc...  09v276c
# 37            Where is the artist therealrayluv from?  01phgm7
# 38                   Where did rodolphe derlanger die  0404z9b
# 39               What is an example of a topical drug   03jy9d
# 40                     who is a person from hong kong  03bx0k4
# 41                What is Angela Torres' nationality?  0s9hmjc
# 42              What is meghan orourke's nationality?  02vr481
# 43               Name a song by the artist poleartist  01vt0bd
# 44                  what sort of music is kabra kasai  05zr4jj
# 45                Who produced dr seuss on the loose?   0cs05x
# 46  Which language do jamaicans of african ancestr...  047ch9x
# 47         where is the obama–mccain debates located?  02r1155
# 48        what is a topical over the counter medicine   03jy9d
# 49  Which religion does edward m. kennedy, jr. pra...   02h40b
# ### Numbers
# 2.501647% [1899 of 75910] questions do not reference subject
#
# 0.439995% [334 of 75910] subject mids do not have aliases

# %%
from tqdm import tqdm_notebook
import random
from scripts.utils.link_subject_name import tokenize

tagged = [] 
for index, row in tqdm_notebook(df.iterrows(), total=df.shape[0]):
    if isinstance(row['subject_name'], str):
        ret =  ''
        for i, token in enumerate(tokenize(row['question'])):
            ret += token.lower()
            if i >= row['subject_name_start_index'] and i < row['subject_name_stop_index']:
                ret += '/I '
            else:
                ret += '/O ' # IO – Inside Outside tagging schema

        tagged.append(ret.strip())

random.sample(tagged, 50)
# Out:
# HBox(children=(IntProgress(value=0, max=75910), HTML(value='')))
# ['what/O is/O the/O hide/I and/I seek/I :/I the/I search/I for/I truth/I in/I iraq/I book/O about/O',
#  'what/O company/O is/O the/O manufacturer/O of/O vivarin/I 200/I tablet/I ?/O',
#  'what/O is/O a/O famous/O fiction/I book/O',
#  'which/O artist/O made/O the/I snow/I files/I',
#  'what/O instrument/O does/O claudia/I gonson/I play/O ?/O',
#  'nitrogen/I 0.99/I liquid/I is/O a/O formulation/O of/O what/O',
#  "what/O is/O christian/I gaul/I 's/O nationality/O ?/O",
#  'what/O cellular/O system/O does/O the/O htc/I touch/I hd/I use/O',
#  'what/O is/O a/O recording/O of/O miles/I called/O ?/O',
#  'who/O produced/O the/O recording/O pinocchio/I',
#  'whats/O an/O example/O of/O a/O comedy-drama/I film/O',
#  'who/O wrote/O lyrics/O to/O another/I heart/I breaks/I ?/O',
#  'what/O kind/O of/O music/O does/O eli/I degibri/I play/O',
#  'where/O did/O the/O battle/I of/I camp/I wildcat/I take/O place/O',
#  "what/O 's/O the/O title/O track/O off/O rachel/I",
#  'where/O did/O george/I w./I p./I hunt/I die/O',
#  'what/O type/O of/O school/O is/O fort/I defiance/I high/I school/I',
#  'what/O position/O does/O the/O football/O player/O arnau/I riera/I play/O ?/O',
#  'where/O can/O antonio/I vivaldi/I be/O heard/O ?/O',
#  'what/O gender/O is/O leslie/I fiedler/I',
#  'which/O gender/O is/O brian/I tee/I',
#  'where/O in/O india/O was/O the/O organization/O indian/I institute/I of/I journalism/I &/I new/I media/I founded/O',
#  "what/O is/O tin/I ujević/I 's/O gender/O",
#  'who/O is/O jack/I handey/I known/O for/O creating/O',
#  'what/O is/O book/O of/O the/O goosebumps/I literary/O series/O ?/O',
#  'what/O was/O the/O album/O welcome/I to/I sarajevo/I released/O as/O',
#  'what/O tracks/O are/O form/O neo/I ?/O',
#  'what/O kind/O of/O music/O does/O raphael/I perform/O',
#  'what/O book/O genre/O is/O the/I dragon/I waiting/I :/I a/I masque/I of/I history/I ?/O',
#  'what/O is/O the/O release/O on/O sailor/I',
#  'what/O city/O is/O found/O in/O st./I louis/I county/I',
#  'where/O was/O aurelijus/I skarbalius/I born/O ?/O',
#  'what/O type/O of/O album/O is/O blue/I jam/I considered/O',
#  'which/O musician/O recorded/O pow/I r./I toc/I h/I ./I',
#  'what/O artist/O recorded/O mallorca/I',
#  'who/O is/O the/O artist/O that/O recorded/O the/I mikado/I :/I act/I i/I ./I “/I your/I revels/I cease/I !/I ”/I ?/O',
#  'who/O authored/O dragonfly/I :/I nasa/I and/I the/I crisis/I aboard/I mir/I ?/O',
#  'where/O was/O wilbur/I ware/I born/O ?/O',
#  "what/O 's/O a/O war/I film/I made/O in/O 1928/O",
#  'who/O directed/O judwaa/I',
#  'what/O is/O the/O the/I breastfeeding/I book/I book/O about/O',
#  'what/O gender/O is/O jean/I turnbull/I ?/O',
#  "how/O would/O the/I besnard/I lakes/I '/O music/O best/O be/O described/O",
#  'what/O netflix/O genre/O is/O peggy/I lee/I :/I singing/I at/I her/I best/I found/O under/O',
#  'who/O led/O the/O art/O direction/O for/O déjà/I vu/I',
#  'what/O film/O did/O ernst/I toch/I contribute/O in/O',
#  'what/O is/O a/O 2004/O comedy/O film/O drama/I ?/O',
#  'what/O south/O african/O city/O is/O mogakolodi/I ngele/I born/O in/O ?/O',
#  'who/O is/O the/O child/O of/O arvydas/I sabonis/I ?/O',
#  'what/O type/O of/O school/O is/O brookville/I high/I school/I']

# %%
file_ = open(DEST, 'w')
file_.write('\n'.join(tagged))
# Out:
# 4366969
