# %% [markdown]
# # Freebase Seq2Seq

# %%
PREFIX = '/Users/petrochuk/sync/pytorch-seq2seq/notebooks/models/'
OBJECT_CHECKPOINT = PREFIX + 'simple_qa_object_recognition/2017_09_19_10_16_38_[3]'
PREDICATE_CLASSIFICATION_CHECKPOINT = (PREFIX + 
                            'simple_qa_predicate_classification_freebase/2017_09_19_16_01_16')

import math
import pprint

from seq2seq.controllers import Predictor
from seq2seq.util.checkpoint import Checkpoint

pretty_printer = pprint.PrettyPrinter(indent=2)

def preprocess(s):
    """
    This preprocessing step is required for `get_object`.
    The same step is computed when creating the data.
    
    Args:
        s (str) string to preprocess
    Returns:
        preprocessed string
    """
    s = s.lower()
    s = s.replace('?', '')
    s = s.replace('.', '')
    s = s.strip()
    return s

def get_predict(checkpoint_name):
    """ Get a predict callable for a model """
    checkpoint = Checkpoint.get_checkpoint(checkpoint_name=checkpoint_name)
    predictor = Predictor(checkpoint.model, checkpoint.input_field, checkpoint.output_field)
    return predictor.predict

predicate_classification_predict = get_predict(PREDICATE_CLASSIFICATION_CHECKPOINT)
object_recognition_predict = get_predict(OBJECT_CHECKPOINT)

def get_object(question):
    """ Given a question return the object in the question using `OBJECT_CHECKPOINT` model. """
    question = preprocess(question)
    marks, confidence = object_recognition_predict(question)
    entity = []
    for marker, word in zip(marks, question.split()):
        if marker == 'e':
            entity.append(word)
    return ' '.join(entity), sum(confidence) / len(confidence)

def get_predicate_id(question, top=3):
    """ 
    Given a question return the predicate in the question using
    `PREDICATE_CLASSIFICATION_CHECKPOINT` model.
    
    Args:
        question (str)
        above (float) return every predicate that is above 0.9 confidence
    Returns:
        list of predicates and their confidence
    """
    question = preprocess(question)
    return [(class_[0], confidence[0]) for class_, confidence in
     list(predicate_classification_predict(question, top=top))]

# To test this cell
print(get_predicate_id('what area code is 845'))
print(get_object('Who is Obama?'))
# Out:
# [('www.freebase.com/location/location/containedby', 0.3764419095940369), ('www.freebase.com/astronomy/star_system_body/star_system', 0.16490115373806102), ('www.freebase.com/astronomy/asteroid/member_of_asteroid_group', 0.16397528790582935)]
# ('obama', 0.9999145006698564)

# %%
import pprint

from elasticsearch_dsl.connections import connections
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search

# Define a default Elasticsearch client
connections.create_connection(hosts=['localhost'])
client = Elasticsearch()

def get_object_link(object_, property_, print_info=False):
    """
    Link the object_ (str) to a QID.
    
    Args:
        object_ (str): object to link
        predicate_mid (str): MID to filter the results
        print_info (bool): print the top matches
    Return:
        mid (str): object QID
        score (float): the score assigned to the top result
        name (str): name of the object QID
    """
    property_ = property_.replace('www.freebase.com/', '')
    print(object_, property_)
    hits = Search.from_dict({
        'query': {
            'bool': {
                'filter': {
                    'nested': {
                        'path': 'facts', 
                        'query': {
                          'match': { 'facts.property': property_ }
                        }
                    }
                },
                'must': [{
                    'match' : {'name' : object_},
                }]
            }
        },
    }).using(client).index('fb5m_entities').execute()
    if print_info:
        print('Hits:')
        pretty_printer.pprint([(hit.mid, hit.name, hit.meta.score,
                                hit.facts) for hit in hits])
    if len(hits) == 0:
        print('WARNING: No Object found.')
        return None, None, None, None
    return hits[0].mid, hits[0].meta.score, hits[0].name, hits[0].facts

# %%
import ujson as json
import pandas as pd

from IPython.display import display

SRC = '/Users/petrochuk/sync/pytorch-seq2seq/data/simple_qa/dev.tsv'

def answer_question(question):
    """
    Answer a question in JSON format for IO.
    
    Args:
        question (str)
    Returns:
        DL Predicate (str): name of the predicate
        DL Preidcate PID (str): PID of the predicate
        DL Preidcate Confidence (float)
        DL Top Predicates (list of predicate, PID, and confidence): Top predicates about > .9 confience
        DL Object (str): name of the object in the question
        DL Object Confidence (float)
        DL Object Name (str): name of the Wikidata object linked too
        DL Object Aliases (list of str): list of aliases for the object
        DL Object ID (str): QID for th WikiData object
        DL Object Score (float): score by ElasticSearch for object linking
        DL Answers (list of Object ID, Score, Answer): list of tuples that have the PID and QID
    """
    print()
    question = preprocess(question)
    print('Question:', question)
    top_predicates = get_predicate_id(question, top=3)
    print('Predicate QIDs:', top_predicates)
    top_mid = None
    top_score = 0
    top_name = None
    top_predicate_id = None
    top_subject = None
    object_, object_confidence = get_object(question)
    print('Object:', object_, '| Confidence:', object_confidence)
    for predicate_id, confidence in top_predicates:
        mid, score, name, facts = get_object_link(object_, predicate_id)
        print('Object:', name)
        print('Object Score:', score)
        print('Predicate:', predicate_id)
        print('')
        if mid and score > top_score:
            top_subject = [fact for fact in facts if fact['property'] in predicate_id]
            top_mid = mid
            top_score = score
            top_name = name
            top_predicate_id = predicate_id
    print('Object MID:', top_mid)
    print('Object Score:', top_score)
    print('Object Name:', top_name)
    print('Top Predicate:', top_predicate_id)
    if top_subject:
        print('Top Subject:', top_subject[0]['subjects'])
    return top_mid, top_predicate_id

def main():
    """
    Run main to save answers to the pandas table SRC
    """
    data = pd.read_table(SRC)
    display(data.head())
    
    def add_answers(row):
        question = row['Question EN']
        mid, predicate_id = answer_question(question)
        object_mid = row['Object MID'].replace('www.freebase.com/m/', '').strip()
        if not mid or mid != object_mid or row['Freebase Property'] != predicate_id:
            print('FAIL!')
            if mid != object_mid:
                print('WRONG MID:', mid)
            if row['Freebase Property'] != predicate_id:
                print('WRONG PROP:', predicate_id)
            print('Correct MID:', object_mid)
            print('Correct Object:', row['Object EN'])
            print('Correct Subject:', row['Subject EN'])
            print('Correct Subject:', row['Subject MID'])
            print('Correct Property:', row['Freebase Property'])
        else:
            print('CORRECT!')
    
    data = data.apply(add_answers, axis=1)
    print('Done!')

main()
# Out:
#                    Object MID                              Freebase Property  \
# 0   www.freebase.com/m/0f3xg_  www.freebase.com/symbols/namesake/named_after
# 1   www.freebase.com/m/07f3jg  www.freebase.com/people/person/place_of_birth
# 2  www.freebase.com/m/031j8nn          www.freebase.com/music/release/region
# 3  www.freebase.com/m/0c1cyhd            www.freebase.com/film/director/film
# 4  www.freebase.com/m/0fvhc0g          www.freebase.com/music/release/region
#
#                   Subject MID  \
# 0   www.freebase.com/m/0cqt90
# 1    www.freebase.com/m/0565d
# 2    www.freebase.com/m/07ssc
# 3  www.freebase.com/m/0wxsz5y
# 4    www.freebase.com/m/0345h
#
#                                             Question WikiData Property  \
# 0  Who was the trump ocean club international hot...              P138
# 1                       where was sasha vujačić born               P19
# 2   What is a region that dead combo was released in               NaN
# 3  What is a film directed by wiebke von carolsfeld?       inverse:P57
# 4  what country was music for stock exchange  rel...               NaN
#
#        Subject EN                                       Object EN  \
# 0    Donald Trump  Trump Ocean Club International Hotel and Tower
# 1         Maribor                                   Sasha Vujačić
# 2  United Kingdom                                      Dead Combo
# 3            Stay                           Wiebke von Carolsfeld
# 4         Germany                        Music for Stock Exchange
#
#                                          Question FR  \
# 0  qui était l'hôtelier et la tour internationale...
# 1                            où est né sasha vuja?i?
# 2  quelle est la région dans laquelle le combo mo...
# 3  Qu'est-ce qu'un film réalisé par wiebke von ca...
# 4  quel pays était la musique de la bourse publié...
#
#                                          Question EN           Object EN Mask
# 0  Who was the trump ocean club international hot...  c c c e e e e e e e c c
# 1                       where was sasha vujačić born                c c e e c
# 2   What is a region that dead combo was released in      c c c c c e e c c c
# 3  What is a film directed by wiebke von carolsfeld?        c c c c c c e e e
# 4  what country was music for stock exchange  rel...        c c c e e e e c c
# Question: who was the trump ocean club international hotel and tower named after
# Predicate QIDs: [('www.freebase.com/symbols/namesake/named_after', 0.9943095652158973), ('www.freebase.com/symbols/name_source/namesakes', 0.0014407299269798557), ('www.freebase.com/medicine/manufactured_drug_form/manufacturer', 0.0007310642166082501)]
# Object: trump ocean club international hotel and tower | Confidence: 0.9900202416305273
# trump ocean club international hotel and tower symbols/namesake/named_after
# Object: Trump Ocean Club International Hotel and Tower
# Object Score: 29.844212
# Predicate: www.freebase.com/symbols/namesake/named_after
#
# trump ocean club international hotel and tower symbols/name_source/namesakes
# Object: Donald Trump
# Object Score: 9.961305
# Predicate: www.freebase.com/symbols/name_source/namesakes
#
# trump ocean club international hotel and tower medicine/manufactured_drug_form/manufacturer
# Object: Hydrocodone Bitartrate And Acetaminophen 750/7.5 tablet
# Object Score: 2.3830202
# Predicate: www.freebase.com/medicine/manufactured_drug_form/manufacturer
#
# Object MID: 0f3xg_
# Object Score: 29.844212
# Object Name: Trump Ocean Club International Hotel and Tower
# Top Predicate: www.freebase.com/symbols/namesake/named_after
# Top Subject: ['0cqt90']
# CORRECT!
#
# Question: where was sasha vujačić born
# Predicate QIDs: [('www.freebase.com/people/person/place_of_birth', 0.988796629193253), ('www.freebase.com/people/deceased_person/place_of_death', 0.006414474827242902), ('www.freebase.com/people/person/nationality', 0.0026354416796852674)]
# Object: sasha vujačić | Confidence: 0.9995961443768945
# sasha vujačić people/person/place_of_birth
# Object: Sasha Vujačić
# Object Score: 22.358248
# Predicate: www.freebase.com/people/person/place_of_birth
#
# sasha vujačić people/deceased_person/place_of_death
# Object: Sasha Siemel
# Object Score: 9.8173895
# Predicate: www.freebase.com/people/deceased_person/place_of_death
#
# sasha vujačić people/person/nationality
# Object: Sasha Vujačić
# Object Score: 22.358248
# Predicate: www.freebase.com/people/person/nationality
#
# Object MID: 07f3jg
# Object Score: 22.358248
# Object Name: Sasha Vujačić
# Top Predicate: www.freebase.com/people/person/place_of_birth
# Top Subject: ['0565d']
# CORRECT!
#
# Question: what is a region that dead combo was released in
# Predicate QIDs: [('www.freebase.com/music/release/region', 0.9968864374338057), ('www.freebase.com/cvg/game_version/regions', 0.0012758585774487383), ('www.freebase.com/film/film/country', 0.0007153390137447762)]
# Object: dead combo | Confidence: 0.9991012911090041
# dead combo music/release/region
# Object: Dead Combo
# Object Score: 18.128777
# Predicate: www.freebase.com/music/release/region
#
# dead combo cvg/game_version/regions
# WARNING: No Object found.
# Object: None
# Object Score: None
# Predicate: www.freebase.com/cvg/game_version/regions
#
# dead combo film/film/country
# Object: The Big Combo
# Object Score: 8.698951
# Predicate: www.freebase.com/film/film/country
#
# Object MID: 031j8nn
# Object Score: 18.128777
# Object Name: Dead Combo
# Top Predicate: www.freebase.com/music/release/region
# Top Subject: ['07ssc']
# CORRECT!
#
# Question: what is a film directed by wiebke von carolsfeld
# Predicate QIDs: [('www.freebase.com/film/director/film', 0.7244048041773576), ('www.freebase.com/film/film_art_director/films_art_directed', 0.26004214899964295), ('www.freebase.com/film/producer/film', 0.006512214334822111)]
# Object: wiebke von carolsfeld | Confidence: 0.9959200178244215
# wiebke von carolsfeld film/director/film
# Object: Wiebke von Carolsfeld
# Object Score: 25.391832
# Predicate: www.freebase.com/film/director/film
#
# wiebke von carolsfeld film/film_art_director/films_art_directed
# Object: Josef von Sternberg
# Object Score: 5.4278665
# Predicate: www.freebase.com/film/film_art_director/films_art_directed
#
# wiebke von carolsfeld film/producer/film
# Object: Florian Koerner von Gustorf
# Object Score: 5.450319
# Predicate: www.freebase.com/film/producer/film
#
# Object MID: 0c1cyhd
# Object Score: 25.391832
# Object Name: Wiebke von Carolsfeld
# Top Predicate: www.freebase.com/film/director/film
# Top Subject: ['0wxsz5y']
# CORRECT!
#
# Question: what country was music for stock exchange  released in
# Predicate QIDs: [('www.freebase.com/music/release/region', 0.9283089792857677), ('www.freebase.com/film/film/country', 0.04950902939588242), ('www.freebase.com/tv/tv_program/country_of_origin', 0.01484492366481871)]
# Object: music for stock exchange | Confidence: 0.9967634854496173
# music for stock exchange music/release/region
# Object: Music for Stock Exchange
# Object Score: 23.67363
# Predicate: www.freebase.com/music/release/region
#
# music for stock exchange film/film/country
# Object: Stock Shock
# Object Score: 9.291516
# Predicate: www.freebase.com/film/film/country
#
# music for stock exchange tv/tv_program/country_of_origin
# Object: Lock, Stock...
# Object Score: 9.726667
# Predicate: www.freebase.com/tv/tv_program/country_of_origin
#
# Object MID: 0fvhc0g
# Object Score: 23.67363
# Object Name: Music for Stock Exchange
# Top Predicate: www.freebase.com/music/release/region
# Top Subject: ['0345h']
# CORRECT!
#
# Question: where is adler school of professional psychology located
# Predicate QIDs: [('www.freebase.com/location/location/containedby', 0.9787014845950119), ('www.freebase.com/location/hud_county_place/county', 0.008351157799615797), ('www.freebase.com/location/neighborhood/neighborhood_of', 0.0030354453211371805)]
# Object: adler school of professional psychology | Confidence: 0.9977361200009026
# adler school of professional psychology location/location/containedby
# Object: Adler School of Professional Psychology
# Object Score: 26.081497
# Predicate: www.freebase.com/location/location/containedby
#
# adler school of professional psychology location/hud_county_place/county
# Object: Starr School
# Object Score: 5.307297
# Predicate: www.freebase.com/location/hud_county_place/county
#
# adler school of professional psychology location/neighborhood/neighborhood_of
# Object: Estates of Fort Lauderdale
# Object Score: 2.5102375
# Predicate: www.freebase.com/location/neighborhood/neighborhood_of
#
# Object MID: 02wcf0f
# Object Score: 26.081497
# Object Name: Adler School of Professional Psychology
# Top Predicate: www.freebase.com/location/location/containedby
# Top Subject: ['01_d4', '03v0t', '09c7w0']
# CORRECT!
#
# Question: where was john miltern born
# Predicate QIDs: [('www.freebase.com/people/person/place_of_birth', 0.9855602820524764), ('www.freebase.com/people/person/nationality', 0.0056202516336945575), ('www.freebase.com/fictional_universe/fictional_character/place_of_birth', 0.005101344374672345)]
# Object: john miltern | Confidence: 0.9997022914638336
# john miltern people/person/place_of_birth
# Object: John Miltern
# Object Score: 17.232578
# Predicate: www.freebase.com/people/person/place_of_birth
#
# john miltern people/person/nationality
# Object: John Miltern
# Object Score: 17.232578
# Predicate: www.freebase.com/people/person/nationality
#
# john miltern fictional_universe/fictional_character/place_of_birth
# Object: John Brown
# Object Score: 4.7211776
# Predicate: www.freebase.com/fictional_universe/fictional_character/place_of_birth
#
# Object MID: 0c1mfxz
# Object Score: 17.232578
# Object Name: John Miltern
# Top Predicate: www.freebase.com/people/person/place_of_birth
# Top Subject: ['01m1_t']
# CORRECT!
#
# Question: what city is vancouver millionaires from
# Predicate QIDs: [('www.freebase.com/people/person/place_of_birth', 0.4823200531376857), ('www.freebase.com/music/artist/origin', 0.42211973384804674), ('www.freebase.com/people/person/nationality', 0.07573156675551383)]
# Object: vancouver millionaires | Confidence: 0.9992300754729893
# vancouver millionaires people/person/place_of_birth
# Object: George Vancouver
# Object Score: 8.972871
# Predicate: www.freebase.com/people/person/place_of_birth
#
# vancouver millionaires music/artist/origin
# Object: Starving Millionaires
# Object Score: 11.234292
# Predicate: www.freebase.com/music/artist/origin
#
# vancouver millionaires people/person/nationality
# Object: George Vancouver
# Object Score: 8.972871
# Predicate: www.freebase.com/people/person/nationality
#
# Object MID: 08w_vq
# Object Score: 11.234292
# Object Name: Starving Millionaires
# Top Predicate: www.freebase.com/music/artist/origin
# Top Subject: ['0f04v']
# FAIL!
# WRONG MID: 08w_vq
# WRONG PROP: www.freebase.com/music/artist/origin
# Correct MID: 02ws83
# Correct Object: Vancouver Millionaires
# Correct Subject: Vancouver
# Correct Subject: www.freebase.com/m/080h2
# Correct Property: www.freebase.com/sports/sports_team/location
#
# Question: what was seymour parker gilbert's profession
# Predicate QIDs: [('www.freebase.com/common/topic/notable_types', 0.5061983935792842), ('www.freebase.com/people/person/profession', 0.48846458784018454), ('www.freebase.com/fictional_universe/fictional_character/occupation', 0.001958170859705966)]
# Object: seymour parker gilbert's | Confidence: 0.997415828712837
# seymour parker gilbert's common/topic/notable_types
# Object: Seymour Parker Gilbert
# Object Score: 14.147825
# Predicate: www.freebase.com/common/topic/notable_types
#
# seymour parker gilbert's people/person/profession
# Object: Seymour Parker Gilbert
# Object Score: 14.147825
# Predicate: www.freebase.com/people/person/profession
#
# seymour parker gilbert's fictional_universe/fictional_character/occupation
# Object: Jennifer Parker
# Object Score: 7.9854445
# Predicate: www.freebase.com/fictional_universe/fictional_character/occupation
#
# Object MID: 02p_vkx
# Object Score: 14.147825
# Object Name: Seymour Parker Gilbert
# Top Predicate: www.freebase.com/common/topic/notable_types
# Top Subject: ['02xlh55']
# FAIL!
# WRONG PROP: www.freebase.com/common/topic/notable_types
# Correct MID: 02p_vkx
# Correct Object: Seymour Parker Gilbert
# Correct Subject: Lawyer
# Correct Subject: www.freebase.com/m/04gc2
# Correct Property: www.freebase.com/people/person/profession
#
# Question: what does (12385) 1994 uo orbit
# Predicate QIDs: [('www.freebase.com/astronomy/orbital_relationship/orbits', 0.9999544476457116), ('www.freebase.com/astronomy/star_system_body/star_system', 1.0772851583347355e-05), ('www.freebase.com/book/book_edition/book', 5.442681430620748e-06)]
# Object: (12385) 1994 uo | Confidence: 0.9929487387217241
# (12385) 1994 uo astronomy/orbital_relationship/orbits
# Object: (12385) 1994 UO
# Object Score: 26.991232
# Predicate: www.freebase.com/astronomy/orbital_relationship/orbits
#
# (12385) 1994 uo astronomy/star_system_body/star_system
# Object: (6822) 1986 UO
# Object Score: 10.204016
# Predicate: www.freebase.com/astronomy/star_system_body/star_system
#
# (12385) 1994 uo book/book_edition/book
# WARNING: No Object found.
# Object: None
# Object Score: None
# Predicate: www.freebase.com/book/book_edition/book
#
# Object MID: 0k0057k
# Object Score: 26.991232
# Object Name: (12385) 1994 UO
# Top Predicate: www.freebase.com/astronomy/orbital_relationship/orbits
# Top Subject: ['06m_p']
# CORRECT!
#
# Question: who is the singer of only women bleed
# Predicate QIDs: [('www.freebase.com/music/recording/artist', 0.6082351970833801), ('www.freebase.com/music/album/artist', 0.3659694595783031), ('www.freebase.com/music/composition/composer', 0.009624369226329818)]
# Object: only women bleed | Confidence: 0.9990797444770148
# only women bleed music/recording/artist
# Object: Only
# Object Score: 9.953684
# Predicate: www.freebase.com/music/recording/artist
#
# only women bleed music/album/artist
# Object: Only Women Bleed
# Object Score: 20.89313
# Predicate: www.freebase.com/music/album/artist
#
# only women bleed music/composition/composer
# Object: Bleed
# Object Score: 14.061517
# Predicate: www.freebase.com/music/composition/composer
#
# Object MID: 0t_5kfn
# Object Score: 20.89313
# Object Name: Only Women Bleed
# Top Predicate: www.freebase.com/music/album/artist
# Top Subject: ['011hdn']
# CORRECT!
#
# Question: in what french city did antoine de févin die
# Predicate QIDs: [('www.freebase.com/people/deceased_person/place_of_death', 0.9990471827577115), ('www.freebase.com/people/person/place_of_birth', 0.0008845788997617461), ('www.freebase.com/people/deceased_person/place_of_burial', 2.496833095358676e-05)]
# Object: antoine de févin | Confidence: 0.9991565994607152
# antoine de févin people/deceased_person/place_of_death
# Object: Antoine de Févin
# Object Score: 21.533413
# Predicate: www.freebase.com/people/deceased_person/place_of_death
#
# antoine de févin people/person/place_of_birth
# Object: Antoine de Févin
# Object Score: 21.533413
# Predicate: www.freebase.com/people/person/place_of_birth
#
# antoine de févin people/deceased_person/place_of_burial
# Object: Antoine Gélis
# Object Score: 8.654623
# Predicate: www.freebase.com/people/deceased_person/place_of_burial
#
# Object MID: 044bvt
# Object Score: 21.533413
# Object Name: Antoine de Févin
# Top Predicate: www.freebase.com/people/deceased_person/place_of_death
# Top Subject: ['0n5n1']
# CORRECT!
#
# Question: who published rama
# Predicate QIDs: [('www.freebase.com/book/book_edition/publisher', 0.8182195578617105), ('www.freebase.com/cvg/game_version/publisher', 0.11123059211539332), ('www.freebase.com/cvg/computer_videogame/publisher', 0.06685464274973739)]
# Object: rama | Confidence: 0.9999431161333749
# rama book/book_edition/publisher
# WARNING: No Object found.
# Object: None
# Object Score: None
# Predicate: www.freebase.com/book/book_edition/publisher
#
# rama cvg/game_version/publisher
# Object: RAMA
# Object Score: 13.039534
# Predicate: www.freebase.com/cvg/game_version/publisher
#
# rama cvg/computer_videogame/publisher
# Object: Rama
# Object Score: 13.368287
# Predicate: www.freebase.com/cvg/computer_videogame/publisher
#
# Object MID: 07wd2k
# Object Score: 13.368287
# Object Name: Rama
# Top Predicate: www.freebase.com/cvg/computer_videogame/publisher
# Top Subject: ['0dwcl']
# FAIL!
# WRONG MID: 07wd2k
# WRONG PROP: www.freebase.com/cvg/computer_videogame/publisher
# Correct MID: 04hr4_v
# Correct Object: RAMA
# Correct Subject: Sierra Entertainment
# Correct Subject: www.freebase.com/m/0dwcl
# Correct Property: www.freebase.com/cvg/game_version/publisher
#
# Question: who was an advisor for irving langmuir
# Predicate QIDs: [('www.freebase.com/education/academic/advisors', 0.8951663023660709), ('www.freebase.com/people/family/members', 0.020827775369791572), ('www.freebase.com/film/film/costume_design_by', 0.012174211880749415)]
# Object: irving langmuir | Confidence: 0.9984757508076728
# irving langmuir education/academic/advisors
# Object: Irving Langmuir
# Object Score: 21.253815
# Predicate: www.freebase.com/education/academic/advisors
#
# irving langmuir people/family/members
# WARNING: No Object found.
# Object: None
# Object Score: None
# Predicate: www.freebase.com/people/family/members
#
# irving langmuir film/film/costume_design_by
# WARNING: No Object found.
# Object: None
# Object Score: None
# Predicate: www.freebase.com/film/film/costume_design_by
#
# Object MID: 03yzb
# Object Score: 21.253815
# Object Name: Irving Langmuir
# Top Predicate: www.freebase.com/education/academic/advisors
# Top Subject: ['01fk34', '0k216']
# CORRECT!
#
# Question: what is the language of the film bon voyage
# Predicate QIDs: [('www.freebase.com/film/film/language', 0.964994789834044), ('www.freebase.com/film/film/primary_language', 0.030058248358047553), ('www.freebase.com/tv/tv_program/languages', 0.003031609207573171)]
# Object: bon voyage | Confidence: 0.9996035877205072
# bon voyage film/film/language
# Object: Bon Voyage!
# Object Score: 18.901894
# Predicate: www.freebase.com/film/film/language
#
# bon voyage film/film/primary_language
# WARNING: No Object found.
# Object: None
# Object Score: None
# Predicate: www.freebase.com/film/film/primary_language
#
# bon voyage tv/tv_program/languages
# Object: Bon Voyage
# Object Score: 18.607311
# Predicate: www.freebase.com/tv/tv_program/languages
#
# Object MID: 02q8vkz
# Object Score: 18.901894
# Object Name: Bon Voyage!
# Top Predicate: www.freebase.com/film/film/language
# Top Subject: ['02h40lc']
# FAIL!
# WRONG MID: 02q8vkz
# Correct MID: 0gkrfmk
# Correct Object: Bon Voyage
# Correct Subject: English Language-US
# Correct Subject: www.freebase.com/m/02h40lc
# Correct Property: www.freebase.com/film/film/language
#
# Question: which country was the hunyadi family from
# Predicate QIDs: [('www.freebase.com/people/person/nationality', 0.4002955223079677), ('www.freebase.com/film/film/country', 0.24276813687532398), ('www.freebase.com/music/artist/origin', 0.14567706490240181)]
# Object: hunyadi family | Confidence: 0.9977093587399488
# hunyadi family people/person/nationality
# Object: Alex Hunyadi
# Object Score: 12.540858
# Predicate: www.freebase.com/people/person/nationality
#
# hunyadi family film/film/country
# Object: Family
# Object Score: 9.752673
# Predicate: www.freebase.com/film/film/country
#
# hunyadi family music/artist/origin
# Object: Family
# Object Score: 9.498383
# Predicate: www.freebase.com/music/artist/origin
#
# Object MID: 0x1tnsn
# Object Score: 12.540858
# Object Name: Alex Hunyadi
# Top Predicate: www.freebase.com/people/person/nationality
# Top Subject: ['03gj2', '0dd7dt']
# FAIL!
# WRONG MID: 0x1tnsn
# WRONG PROP: www.freebase.com/people/person/nationality
# Correct MID: 01px0j
# Correct Object: Hunyadi family
# Correct Subject: Hungary
# Correct Subject: www.freebase.com/m/03gj2
# Correct Property: www.freebase.com/people/family/country
#
# Question: what major cities does us route 2 run through
# Predicate QIDs: [('www.freebase.com/transportation/road/major_cities', 0.8492561702513217), ('www.freebase.com/medicine/drug_formulation/formulation_of', 0.02518903705871885), ('www.freebase.com/medicine/drug_formulation/routes', 0.02220901091367206)]
# Object: us route 2 | Confidence: 0.9980703070937885
# us route 2 transportation/road/major_cities
# Object: US Route 101
# Object Score: 12.089397
# Predicate: www.freebase.com/transportation/road/major_cities
#
# us route 2 medicine/drug_formulation/formulation_of
# Object: Cefotaxime sodium 2 injection
# Object Score: 4.2260833
# Predicate: www.freebase.com/medicine/drug_formulation/formulation_of
#
# us route 2 medicine/drug_formulation/routes
# Object: Benzocaine benzalkonium chloride 2/2 cloth
# Object Score: 4.765423
# Predicate: www.freebase.com/medicine/drug_formulation/routes
#
# Object MID: 0j9xz
# Object Score: 12.089397
# Object Name: US Route 101
# Top Predicate: www.freebase.com/transportation/road/major_cities
# Top Subject: ['0f04v', '0zdx3', '030qb3t', '0fw1y', '0d6lp']
# FAIL!
# WRONG MID: 0j9xz
# Correct MID: 029j_m
# Correct Object: U.S. Route 2
# Correct Subject: Kalispell
# Correct Subject: www.freebase.com/m/0x1vt
# Correct Property: www.freebase.com/transportation/road/major_cities
#
# Question: who was a child of mithibai jinnah
# Predicate QIDs: [('www.freebase.com/people/person/children', 0.9992166773584613), ('www.freebase.com/fictional_universe/fictional_character/children', 0.00039051100431127607), ('www.freebase.com/people/deceased_person/place_of_death', 9.466517408481486e-05)]
# Object: mithibai jinnah | Confidence: 0.999272326273319
# mithibai jinnah people/person/children
# Object: Mithibai Jinnah
# Object Score: 24.217144
# Predicate: www.freebase.com/people/person/children
#
# mithibai jinnah fictional_universe/fictional_character/children
# WARNING: No Object found.
# Object: None
# Object Score: None
# Predicate: www.freebase.com/fictional_universe/fictional_character/children
#
# mithibai jinnah people/deceased_person/place_of_death
# Object: Emibai Jinnah
# Object Score: 11.682715
# Predicate: www.freebase.com/people/deceased_person/place_of_death
#
# Object MID: 0yc77qn
# Object Score: 24.217144
# Object Name: Mithibai Jinnah
# Top Predicate: www.freebase.com/people/person/children
# Top Subject: ['0d4mrj', '08_bpn', '023vtj']
# CORRECT!
#
# Question: whats a version of the single titled  star
# Predicate QIDs: [('www.freebase.com/music/single/versions', 0.9964333176033597), ('www.freebase.com/cvg/computer_videogame/versions', 0.0008583474599550097), ('www.freebase.com/music/release/album', 0.00044679279230647255)]
# Object: star | Confidence: 0.9997071672745447
# star music/single/versions
# Object: Star
# Object Score: 8.316749
# Predicate: www.freebase.com/music/single/versions
#
# star cvg/computer_videogame/versions
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-146-7b2a1560a9c1> in <module>()
#      85     print('Done!')
#      86
# ---> 87 main()
#
# <ipython-input-146-7b2a1560a9c1> in main()
#      82             print('CORRECT!')
#      83
# ---> 84     data = data.apply(add_answers, axis=1)
#      85     print('Done!')
#      86
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4316                     labels = self._get_agg_axis(axis)
#    4317                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4318                                         labels=labels)
#    4319                     return Series(result, index=labels)
#    4320                 except Exception:
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.reduce (pandas/_libs/lib.c:44036)()
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.Reducer.get_result (pandas/_libs/lib.c:33629)()
#
# <ipython-input-146-7b2a1560a9c1> in add_answers(row)
#      66     def add_answers(row):
#      67         question = row['Question EN']
# ---> 68         mid, predicate_id = answer_question(question)
#      69         object_mid = row['Object MID'].replace('www.freebase.com/m/', '').strip()
#      70         if not mid or mid != object_mid or row['Freebase Property'] != predicate_id:
#
# <ipython-input-146-7b2a1560a9c1> in answer_question(question)
#      38     print('Object:', object_, '| Confidence:', object_confidence)
#      39     for predicate_id, confidence in top_predicates:
# ---> 40         mid, score, name, facts = get_object_link(object_, predicate_id)
#      41         print('Object:', name)
#      42         print('Object Score:', score)
#
# <ipython-input-141-cb9c0d6a6327> in get_object_link(object_, property_, print_info)
#      40             }
#      41         },
# ---> 42     }).using(client).index('fb5m_entities').execute()
#      43     if print_info:
#      44         print('Hits:')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/elasticsearch_dsl/search.py in execute(self, ignore_cache)
#     604                     doc_type=self._doc_type,
#     605                     body=self.to_dict(),
# --> 606                     **self._params
#     607                 )
#     608             )
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      71                 if p in kwargs:
#      72                     params[p] = kwargs.pop(p)
# ---> 73             return func(*args, params=params, **kwargs)
#      74         return _wrapped
#      75     return _wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/elasticsearch/client/__init__.py in search(self, index, doc_type, body, params)
#     621             index = '_all'
#     622         return self.transport.perform_request('GET', _make_path(index,
# --> 623             doc_type, '_search'), params=params, body=body)
#     624
#     625     @query_params('_source', '_source_exclude', '_source_include',
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/elasticsearch/transport.py in perform_request(self, method, url, params, body)
#     310
#     311             try:
# --> 312                 status, headers, data = connection.perform_request(method, url, params, body, ignore=ignore, timeout=timeout)
#     313
#     314             except TransportError as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore)
#     112                 method = method.encode('utf-8')
#     113
# --> 114             response = self.pool.urlopen(method, url, body, retries=False, headers=self.headers, **kw)
#     115             duration = time.time() - start
#     116             raw_data = response.data.decode('utf-8')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# KeyboardInterrupt:
