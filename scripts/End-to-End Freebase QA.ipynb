# %% [markdown]
# # End-to-End Freebase QA

# %% [markdown]
# Use the below line to import modules from the root of the repository.
#
# Reference: https://stackoverflow.com/questions/34976803/sys-path-different-in-jupyter-and-python-how-to-import-own-modules-in-jupyter

# %%
import sys
sys.path.insert(0, '../../../allennlp')
sys.path.insert(0, '../../')
import pandas as pd
from tqdm import tqdm_notebook
import random
import numpy as np
random_seed = 123
random.seed(random_seed)
np.random.seed(random_seed)
tqdm_notebook().pandas()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# We use the cursor from psycopg2 to connect to PostgreSQL with our knowledge graph.

# %%
from scripts.utils.connect import get_connection 

connection = get_connection()
cursor = connection.cursor()

# %% [markdown]
# Load the Simple Questions V2 validation dataset.

# %%
from scripts.utils.simple_qa import load_simple_qa 
from sklearn.utils import shuffle


df_dev, = load_simple_qa(dev=True)
df_dev = shuffle(df_dev, random_state=random_seed)
df_dev[:5]
# Out:
#        subject                                           relation   object  \
# 6219     03k3r  biology/organism_classification/organisms_of_t...  0bs56bp
# 3364   02qlppc                   cvg/computer_videogame/cvg_genre   01sjng
# 9374    02l7c8                               tv/tv_genre/programs  0dlmm88
# 10142  049_zj3                      location/location/containedby    04rrx
# 97     02w9ycr              people/deceased_person/cause_of_death    0qcr0
#
#                                                 question
# 6219           Name an American Thoroughbread racehorse
# 3364   what kind of game is vision racing driving sim...
# 9374                     what tv program is romance film
# 10142                  what state is  polaski located in
# 97          what disease claimed the life of fern emmett

# %% [markdown]
# For every example, there is not a clear subject name but we can do a fair job a linking questions with subject names only missing 2.7% of examples.

# %% [markdown]
# ## Predict Subject Name
#
# Using a tagging model, we are going to predict the subject name for every row.

# %%
from allennlp.models.archival import load_archive
from allennlp.service.predictors import Predictor
from scripts.utils.link_subject_name import tokenize
import math

SUBJECT_RECOGNITION = '../../../allennlp/experiments/crf_tagger_lstm_no_reg_3/model.tar.gz'
archive = load_archive(SUBJECT_RECOGNITION, cuda_device=0)
predictor = Predictor.from_archive(archive, 'sentence-tagger')

# TODO: Better handle multiple subject_names picking the one with the highest probability

def predict_subject_name(s):
    question_tokens = tokenize(s)
    predicted = predictor.predict_json({'sentence': ' '.join(question_tokens)}, 0)
    logit_to_probability = lambda x: 1 / (1 + math.exp(-x))
    # Confidence that a token is a entity
    confidence = [logit_to_probability(logit[1]) for logit in predicted['logits']] 
    
    predicted_subject_name = ''
    inside = False
    start_index = 0
    end_index = len(predicted['tags'])
    for i, tag in enumerate(predicted['tags']): 
        if tag == 'I' and not inside:
            predicted_subject_name = predicted['words'][i]
            inside = True
            start_index = i
        elif tag != 'I':
            if inside:
                end_index = i
            inside = False
        elif tag == 'I':
            predicted_subject_name += ' ' + predicted['words'][i]
            
    if inside:
        end_index = len(predicted['tags'])
        
    assert len(confidence) == len(question_tokens)
            
    return (predicted_subject_name,
            question_tokens,
            confidence,
            start_index,
            end_index)

predict_subject_name('what major cities does u.s. route 2 run through?')
predict_subject_name('what was arthur b. hancock, jr.\'s cause of death')
# Out:
# ('arthur b. hancock',
#  ['what',
#   'was',
#   'arthur',
#   'b.',
#   'hancock',
#   ',',
#   'jr.',
#   "'s",
#   'cause',
#   'of',
#   'death'],
#  [0.011748453053504696,
#   0.0030749839218348137,
#   0.9847373594185165,
#   0.7639913663356342,
#   0.9820837711450371,
#   0.043732789036917616,
#   0.15952436461081299,
#   0.08061072016615713,
#   0.14452510878420124,
#   0.288720534216086,
#   0.17725884038983625],
#  2,
#  5)

# %%
import pandas as pd
from numpy import nan

def add_predicted_subject_name(row):
    subject_name, question, tag_confidence, start_index, end_index = predict_subject_name(row['question'])
    if len(subject_name) > 0:
        row['predicted_subject_name'] = subject_name
        row['tokenized_question'] = question
        row['tag_confidence'] = tag_confidence
        row['predicted_subject_name_start_index'] = start_index
        row['predicted_subject_name_stop_index'] = end_index
    else:
        row['predicted_subject_name'] = nan
        row['tokenized_question'] = nan
        row['tag_confidence'] = nan
        row['predicted_subject_name_start_index'] = nan
        row['predicted_subject_name_stop_index'] = nan
        
    return row

df_dev = df_dev.progress_apply(add_predicted_subject_name, axis=1)
df_dev[:5]
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
#        subject                                           relation   object  \
# 6219     03k3r  biology/organism_classification/organisms_of_t...  0bs56bp
# 3364   02qlppc                   cvg/computer_videogame/cvg_genre   01sjng
# 9374    02l7c8                               tv/tv_genre/programs  0dlmm88
# 10142  049_zj3                      location/location/containedby    04rrx
# 97     02w9ycr              people/deceased_person/cause_of_death    0qcr0
#
#                                                 question  \
# 6219           Name an American Thoroughbread racehorse
# 3364   what kind of game is vision racing driving sim...
# 9374                     what tv program is romance film
# 10142                  what state is  polaski located in
# 97          what disease claimed the life of fern emmett
#
#                 predicted_subject_name  \
# 6219            American Thoroughbread
# 3364   vision racing driving simulator
# 9374                      romance film
# 10142                          polaski
# 97                         fern emmett
#
#                                       predicted_question  \
# 6219      [Name, an, American, Thoroughbread, racehorse]
# 3364   [what, kind, of, game, is, vision, racing, dri...
# 9374              [what, tv, program, is, romance, film]
# 10142            [what, state, is, polaski, located, in]
# 97     [what, disease, claimed, the, life, of, fern, ...
#
#                                           tag_confidence  \
# 6219   [0.03852444377976815, 0.011928176725244675, 0....
# 3364   [0.009964622867763331, 0.01985006595168436, 0....
# 9374   [0.006318914004223599, 0.005014553051472905, 0...
# 10142  [0.0079512906240557, 0.03284792185161542, 0.00...
# 97     [0.021128480615324314, 0.38043073700318475, 0....
#
#        predicted_subject_name_start_index  predicted_subject_name_stop_index
# 6219                                  2.0                                4.0
# 3364                                  5.0                                9.0
# 9374                                  4.0                                6.0
# 10142                                 3.0                                4.0
# 97                                    6.0                                8.0

# %% [markdown]
# ### Link Predicted Subject Alias to MID

# %% [markdown]
# #### True Alias

# %%
import unicodedata
import re
from nltk import word_tokenize
import pandas as pd
from scripts.utils.levenshtein import levenshtein_word_distance
from IPython.display import display
from numpy import nan

def strip_accents(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s))

def preproces(s):
    """
    Preprocess before computing the edit distance.
    
    Remove punctuation to allow for consistent tokenization 
        (e.g. who produces npr: wait wait... dont tell me! podcast?
              gunnar \"the ghost pilot\" andersson
              that's == thats)
    Represent as ASCII
        (e.g. ikkyū)
    Lower case
    Tokenize
    """
    # Represent characters in ASCII
    s = strip_accents(s)
    # Remove punctuation
    s = re.sub(r'[^\w\s]','',s)
    # Substitue multiple spaces with one
    s = re.sub('\s+', ' ', s)
    s = s.strip()
    s = s.lower()
    s = tuple(word_tokenize(s))
    return s

def levenshtein_link_alias(row, name_table='fb_two_subject_name'):
    cursor.execute('SELECT alias FROM ' + name_table + ' WHERE mid=%s', (row['subject'],))
    aliases = [a[0] for a in cursor.fetchall()]
    if len(aliases) > 0:
        distances = [levenshtein_word_distance(preproces(a), preproces(row['question']))[0] for a in aliases]
        normalized_distances = [(len(aliases[i]) - d) / len(aliases[i]) for i, d in enumerate(distances)]
        if max(normalized_distances) >= 0.8:
            subject_alias_index = max(range(len(normalized_distances)), key=lambda i: normalized_distances[i])
            subject_alias = aliases[subject_alias_index]
            return subject_alias
    return nan

df_dev['subject_name'] = df_dev.progress_apply(levenshtein_link_alias, axis=1)
print('Linked', sum(df_dev.subject_name.notnull()), 'examples')
df_dev[:5]
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# Linked 10640 examples
#        subject                                           relation   object  \
# 6219     03k3r  biology/organism_classification/organisms_of_t...  0bs56bp
# 3364   02qlppc                   cvg/computer_videogame/cvg_genre   01sjng
# 9374    02l7c8                               tv/tv_genre/programs  0dlmm88
# 10142  049_zj3                      location/location/containedby    04rrx
# 97     02w9ycr              people/deceased_person/cause_of_death    0qcr0
#
#                                                 question  \
# 6219           Name an American Thoroughbread racehorse
# 3364   what kind of game is vision racing driving sim...
# 9374                     what tv program is romance film
# 10142                  what state is  polaski located in
# 97          what disease claimed the life of fern emmett
#
#                 predicted_subject_name  \
# 6219            American Thoroughbread
# 3364   vision racing driving simulator
# 9374                      romance film
# 10142                          polaski
# 97                         fern emmett
#
#                                       predicted_question  \
# 6219      [Name, an, American, Thoroughbread, racehorse]
# 3364   [what, kind, of, game, is, vision, racing, dri...
# 9374              [what, tv, program, is, romance, film]
# 10142            [what, state, is, polaski, located, in]
# 97     [what, disease, claimed, the, life, of, fern, ...
#
#                                           tag_confidence  \
# 6219   [0.03852444377976815, 0.011928176725244675, 0....
# 3364   [0.009964622867763331, 0.01985006595168436, 0....
# 9374   [0.006318914004223599, 0.005014553051472905, 0...
# 10142  [0.0079512906240557, 0.03284792185161542, 0.00...
# 97     [0.021128480615324314, 0.38043073700318475, 0....
#
#        predicted_subject_name_start_index  predicted_subject_name_stop_index  \
# 6219                                  2.0                                4.0
# 3364                                  5.0                                9.0
# 9374                                  4.0                                6.0
# 10142                                 3.0                                4.0
# 97                                    6.0                                8.0
#
#                           subject_name
# 6219                               NaN
# 3364   vision racing driving simulator
# 9374                           romance
# 10142                          polaski
# 97                         fern emmett

# %% [markdown]
# #### Index Aliases for Canditate Generation

# %%
name_table = 'fb_two_subject_name'
cursor.execute('ALTER TABLE ' + name_table + ' ADD normalized_alias varchar')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-6d3080c8b984> in <module>()
#       1 name_table = 'fb_two_subject_name'
# ----> 2 cursor.execute('ALTER TABLE ' + name_table + ' ADD normalized_alias varchar')
#
# ProgrammingError: column "normalized_alias" of relation "fb_two_subject_name" already exists

# %%
from tqdm import tqdm_notebook
import psycopg2

chunk_size = 10000

def update_chunk(rows):
    query = 'UPDATE ' + name_table + ' SET normalized_alias = %s WHERE mid = %s and alias = %s'
    psycopg2.extras.execute_batch(cursor, query, rows)

cursor.execute('SELECT mid, alias FROM ' + name_table)
rows = []
for mid, alias in tqdm_notebook(cursor.fetchall()):
    normalized_alias = ' '.join(preproces(alias))
    rows.append(tuple([normalized_alias, mid, alias]))
    
    # Insert Chunk
    if len(rows) > chunk_size:
        update_chunk(rows)
        rows = []
        
update_chunk(rows)
# Out:
# HBox(children=(IntProgress(value=0, max=2996459), HTML(value='')))

# %%
cursor.execute('CREATE INDEX ' + name_table + '_normalized_alias_trgm ON ' + name_table + ' USING gist(normalized_alias gist_trgm_ops);')
connection.commit()

# %% [markdown]
# #### Cached Similarity Queries

# %%
from functools import lru_cache

# Allows running experiments without redoing SQL calls
@lru_cache(maxsize=65536)
def query_same_alias(alias, name_table='fb_two_subject_name'):
    cursor.execute("""
                  SELECT mid, alias
                  FROM {} 
                  WHERE normalized_alias LIKE %s""".format(name_table),
                 ('%' + alias + '%',))
    return list(cursor.fetchall())

# Allows running experiments without redoing SQL calls
@lru_cache(maxsize=65536)
def query_sub_aliases(aliases, name_table='fb_two_subject_name'):
    cursor.execute("""
                  SELECT mid, alias
                  FROM {} 
                  WHERE alias LIKE %s
                  OR alias LIKE %s
                  OR alias LIKE %s""".format(name_table),
                 ('% ' + alias, '% ' + alias + ' %', alias + ' %'))
    return list(cursor.fetchall())

# Allows running experiments without redoing SQL calls
@lru_cache(maxsize=65536)
def query_similar_aliases(alias, name_table='fb_two_subject_name'):
    cursor.execute("""
                  SELECT set_limit(0.3);
                  SELECT mid, alias, similarity(alias, %s) AS score
                  FROM {} 
                  ORDER BY score DESC
                  LIMIT 1000""".format(name_table, alias),
                 (alias,))
    return list(cursor.fetchall())

# %% [markdown]
# #### Candidate Generation Strategies

# %%
from collections import defaultdict
from nltk.corpus import stopwords
import string
import numpy as np

stopwords = set(stopwords.words('english'))

correct = 0
skipped = 0
print_index = 0
def add_candidates(row):
    global correct
    global skipped
    global print_index
    if isinstance(row['predicted_subject_name'], str):
        candidates = defaultdict(list)
        candidates_mids = []
        predicted_subject_name = ' '.join(preproces(row['predicted_subject_name']))
        
        # NOTE: Try querying the exact same alias
        query_rows = query_same_alias(predicted_subject_name)
        for mid, alias in query_rows:
            candidates_mids.append(mid)
            candidates[alias].append(mid)
            
        if len(query_rows) > 0 and row['subject'] not in candidates_mids and isinstance(row['subject_name'], str):
            print_index += 1
            print('| ' + str(print_index) + ' | ' + 
                  ' | '.join([row['question'], predicted_subject_name, row['subject_name'], str(len(query_rows))])
                 + ' | |')
        
        if row['subject'] in candidates_mids:
            correct += 1
            
        if len(query_rows) == 0:
            skipped += 1

        return candidates
    else:
        skipped += 1
        return []
    
df_dev['candidates'] = df_dev.progress_apply(add_candidates, axis=1)

print('Canditate Accuracy: %f [%d of %d]' % (correct / df_dev.shape[0], correct, df_dev.shape[0]))    
print('Strategy Accuracy: %f [%d of %d]' % (correct / (df_dev.shape[0] - skipped), correct,
                                            (df_dev.shape[0] - skipped)))    
print('Skipped Rows: %f [%d of %d]' % (skipped / df_dev.shape[0], skipped, df_dev.shape[0]))
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# | 1 | Name an album released by aaron carter | aaron carter | album | 6 | |
# | 2 | what is a tablet used to treat hypertension  | hypertension | tablet | 28 | |
# | 3 | What's a soundtrack written by anthony marinelli | anthony marinelli | soundtrack | 2 | |
# | 4 | which karl may characters was a tribal chief? | karl may | tribal chief | 4 | |
# | 5 | name an album by George Canyon | george canyon | album | 2 | |
# | 6 | What is a compilation album by creedence clearwater revival | compilation album | creedence | 16 | |
# | 7 | what is one of the master's powers  | the master | master | 425 | |
# | 8 | What newspaper circulates in the town of kearny | kearny | t-town | 22 | |
# | 9 | what animated cartoon was about ducks? | ducks | animated cartoon | 62 | |
# | 10 | What's the soundtrack for s.cry.ed | scryed | soundtrack | 4 | |
# | 11 | name a location contained in peoria county, illinois. | peoria county illinois | peoria county | 20 | |
# | 12 | which fantasy series were written by mercedes lackey? | fantasy | mercedes lackey | 2676 | |
# | 13 | which album is released by Sham 69 | sham 69 | album | 9 | |
# | 14 | What's an album by soil | soil | album | 108 | |
# | 15 | what's one of the brothers grimm's famous fairy tales | fairy tales | the brothers grimm | 75 | |
# | 16 | What compilation album did olivia newton-john release in 1998? | compilation album | olivia newton-john | 16 | |
# | 17 | what type of film is the need for speed | the need for speed | need for speed | 4 | |
# | 18 | what is an album by Chico DeBarge? | chico debarge | album | 2 | |
# | 19 | what's an arcade game made by atari | arcade game | atari | 18 | |
# | 20 | Name a novel by Vladimir Nabokov | vladimir nabokov | novel | 7 | |
# | 21 | who is of caucasian race in babylon 5 | babylon 5 | caucasian | 87 | |
# | 22 | what is a visual art painting | visual art | painting | 27 | |
# | 23 | brian swimme wrote what book that dealt with  science | brian swimme | science | 1 | |
# | 24 | Which animation did Raoul Servais direct | raoul servais | animation | 1 | |
# | 25 | what is an album by leo sayer? | leo sayer | album | 10 | |
# | 26 | which country was the cosmic egg released in | the cosmic egg | cosmic egg | 1 | |
# | 27 | who is an artist that creates latin pop music | latin pop music | latin pop | 1 | |
# | 28 | What is a compilation album from 2006  | compilation album | album | 16 | |
# | 29 | who is the most influential female k-pop singer? | singer | k-pop | 1418 | |
# | 30 | What is a city in Surrey County, north carolina? | surrey county | north carolina | 1 | |
# | 31 | What is an album written by Johannes Brahms | johannes brahms | album | 15 | |
# | 32 | what are indie films? | indie films | indie film | 1 | |
# | 33 | which albums were released by the century media label? | century media | album | 6 | |
# | 34 | which airline is in the air canada jazz | air canada jazz | jazz | 1 | |
# | 35 | Name a drug that contains serine. | drug | serine | 364 | |
# | 36 | who recorded the tower of london | the tower of london | tower of london | 2 | |
# | 37 | Who is an artist  signed by rca records? | rca records | rca | 4 | |
# | 38 | Which mining companies are located in Brazil  | brazil | mining | 2112 | |
# | 39 | where was the end of the line filmed  | the end of the line | end of the line | 4 | |
# | 40 | What's a game that konami published for the wii | konami | wii | 50 | |
# | 41 | which fear factor episode involved wrecking balls | wrecking balls | fear factor | 1 | |
# | 42 | What is queen's compilation album called | compilation album | queen | 16 | |
# | 43 | Name a rowing team from Oxford | oxford | rowing | 595 | |
# | 44 | what is the genre of the magic | the magic | magic | 550 | |
# | 45 | what horror films came out in 2002? | horror films | horror | 4 | |
# | 46 | who is a fictional human character from the television series Angel | angel | human | 7982 | |
# | 47 | which peninsula campaign battles took place during the american civil war? | american civil war | peninsula campaign | 21 | |
# | 48 | Who is the music by in destruction, inc.? | in destruction | destruction, inc. | 1 | |
# | 49 | which actor was born in sydney? | sydney | actor | 825 | |
# | 50 | what novel is written by James Kelman | james kelman | novel | 1 | |
# | 51 | Which male character is from the film la Folie Du Doute? | la folie du doute | male | 1 | |
# | 52 | What is the name of the comedy film created by todd solondz?  | comedy film | todd solondz | 4 | |
# | 53 | what is the name of an American post-hardcore band formed in 2010 in Dallas | dallas | post-hardcore | 1047 | |
# | 54 | what is a compilation album | compilation album | album | 16 | |
# | 55 | what is the cursive script used in china for | china | cursive script | 2582 | |
# | 56 | if someone is the chancellor of germany, what is their title  | chancellor of germany | chancellor | 1 | |
# | 57 | what is a national park in Wyoming  | wyoming | national park | 591 | |
# | 58 | which albums were released by deep purple? | deep purple | album | 803 | |
# | 59 | what film festival is recurring? | recurring | film festival | 7 | |
# | 60 | What is the name of a solar system that orbits the sun? | the sun | solar system | 1253 | |
# | 61 | what artist sings opera music | opera music | opera | 1 | |
# | 62 | what is the name of the live solo piano jazz album  | piano jazz | jazz | 15 | |
# | 63 | What is an erotic book by Bogza displaying surrealism? | erotic | surrealism | 185 | |
# | 64 | What is a Japanese animation series | japanese animation | animation | 1 | |
# | 65 | What's an album by daz dillinger | daz dillinger | album | 5 | |
# | 66 | which compilation album was released in 2005? | compilation album | album | 16 | |
# | 67 | What type of harp is traditionally found in ireland | ireland | harp | 1079 | |
# | 68 | which airport does the airline air one services? | airline | air one | 456 | |
# | 69 | What's an album by tech n9ne | tech n9ne | album | 1 | |
# | 70 | what is an album from 2005 | 2005 | album | 1920 | |
# | 71 | which lgbt films were directed by jim hubbard? | jim hubbard | lgbt | 1 | |
# | 72 | in which language is the growth movie spoken | the growth | growth | 8 | |
# | 73 | what albums did Willie Nelson release? | willie nelson | album | 89 | |
# | 74 | what is the name of a student in Hollyoaks | hollyoaks | student | 6 | |
# | 75 | what are albums? | albums | album | 218 | |
# | 76 | what's the name of an album by boris the sprinkler | boris the sprinkler | album | 1 | |
# | 77 | Name of album by the alternative metal band drowning pool. | alternative metal | drowning pool | 1 | |
# | 78 | what tract is released by derek sherinian | tract | derek sherinian | 1004 | |
# | 79 | in what format is legend: the best of toto album presented | legend the best of toto | toto | 1 | |
# | 80 | which drug formulation is used as an antacid? | antacid | drug | 272 | |
# | 81 | What's an album featuring music by ella fitzgerald | ella fitzgerald | album | 163 | |
# | 82 | which song was composed by gary numan? | gary numan | song | 21 | |
# | 83 | which season of andrew zimmerman's show did he visit uganda in | andrew zimmerman | uganda | 1 | |
# | 84 | which song is composed by Steve Rothery | steve rothery | song | 1 | |
# | 85 | what is a secondary school in england  | secondary school | england | 131 | |
# | 86 | What is a jazz album by Thad Jones? | jazz | album | 3335 | |
# | 87 | What's a compilation album written by alan jackson | alan jackson | album | 8 | |
# | 88 | what musician was born in south london? | south london | musician | 4 | |
# | 89 | What's a jazz album | jazz | album | 3335 | |
# | 90 | what kind of movie is the mystery road | the mystery road | mystery road | 1 | |
# | 91 | what albums were released in 2000? | albums | album | 218 | |
# | 92 | which world war ii events took place in the atlantic sea? | atlantic sea | world war ii | 5 | |
# | 93 | What animal was Golduck in Pokemon? | pokemon | golduck | 262 | |
# | 94 | What is the name of a bakery in scottsdale, arizona? | scottsdale arizona | bakery | 2 | |
# | 95 | what is james a. micheners ethnicity | james a micheners | james a. michener | 1 | |
# | 96 | what formula is available in a liquid? | a liquid | liquid | 1 | |
# | 97 | what's a prominent theater located in vancouver, british columbia | vancouver british columbia | theater | 3 | |
# | 98 | Name a 2002 Indian Tamil romantic biographical film film written and directed by Vasanthabalan | vasanthabalan | biographical film | 1 | |
# | 99 | that's amore by dean martin, is what kind of album | dean martin | that's amore | 76 | |
# | 100 | Which bollywood film stars Menekka Arora and Arun Bali | arun bali | bollywood | 1 | |
# | 101 | What's a book written about the great wall of china | the great wall of china | great wall of china | 6 | |
# | 102 | what is the miniature version of the poodle | the poodle | poodle | 2 | |
# Canditate Accuracy: 0.936284 [10154 of 10845]
# Strategy Accuracy: 0.983915 [10154 of 10320]
# Skipped Rows: 0.048409 [525 of 10845]

# %% [markdown]
# #### Baseline Candidate Generation via Exact Match
#
# Statistics:
# - Canditate Accuracy: 0.852928 [9250 of 10845]
# - Strategy Accuracy: 0.977285 [9250 of 9465]
# - Skipped Rows: 0.127248 [1380 of 10845]
#
# Discussion:
#
# 27 of 50 errors are due to longer matches; therefore, our next candidate generation model will take into account longer candidates.
#
# Error Bucket:
#
# | Index | Question | Predicted Subject | Subject Name | Number of Candidates | Bucket
# |:--|:--|:--|:--|
# | 1 | Name an album released by aaron carter | aaron carter | album | 2 | Wrong Span |
# | 2 | which country is the commune of luxembourg in | luxembourg | commune of luxembourg | 40 | Wrong Span, Longer |
# | 3 | what song was included in the hits album 6 | 6 | the hits album 6 | 8 | Wrong Span, Longer Alias |
# | 4 | what is about between two women | two women | between two women | 8 | Wrong Span, Longer Alias |
# | 5 | what is a tablet used to treat hypertension  | hypertension | tablet | 1 | Wrong Span|
# | 6 | What's a soundtrack written by anthony marinelli | anthony marinelli | soundtrack | 2 | Wrong Span |
# | 7 | which karl may characters was a tribal chief? | karl may | tribal chief | 2 | Wrong Span |
# | 8 | name an album by George Canyon | george canyon | album | 2 | Wrong Span |
# | 9 | what is the name of the netflix martial arts film? | martial arts | martial arts film | 46 | Wrong Span, Longer Alias |
# | 10 | What is a compilation album by creedence clearwater revival | compilation album | creedence | 1 | Wrong Span |
# | 11 | what is one of the master's powers  | the master | master | 19 | Wrong Span, Longer Alias, Article|
# | 12 | what's one of the subjects talked about it usually begins with ayn rand | ayn rand | it usually begins with ayn rand | 11 | Wrong Span, Longer Alias |
# | 13 | What newspaper circulates in the town of kearny | kearny | t-town | 2 | Wrong Span |
# | 14 | which musician plays the drum kit | drum | drums | 74 | Longer alias |
# | 15 | what animated cartoon was about ducks? | ducks | animated cartoon | 2 | Wrong Span |
# | 16 | where is the bomb's origins | bomb | the bomb | 6 | Wrong span, Longer alias |
# | 17 | what is south by java head about  | java head | south by java head | 2 | Wrong Span, Longer Alias |
# | 18 | what album is released as a compilation albumby CEMA | album | compilation | 18 | Wrong Span |
# | 19 | What is a book that is about arabic name | arabic | arabic name | 1 | Wrong Span, Longer Alias |
# | 20 | what genre is crystal city | crystal city | the crystal city | 3 | Wrong Span, Longer Alias |
# | 21 | which fantasy series were written by mercedes lackey? | fantasy | mercedes lackey | 1614 | Wrong Span |
# | 22 | brian oshea performs what type of martial art | brian oshea | brian o'shea | 1 | Punctuation |
# | 23 | What is the best of johnny & the hurricanes's country of origin? | johnny & the hurricanes | the best of johnny & the hurricanes | 1 | Wrong Span, Longer Alias |
# | 24 | which album is released by Sham 69 | sham 69 | album | 2 | Wrong Span |
# | 25 | what track was released on to hear the angels sing | the angels sing | to hear the angels sing | 1 | Wrong Span, Longer Alias |
# | 26 | What's an album by soil | soil | album | 4 | Wrong Span |
# | 27 | Name one of the breton people | breton | bretons | 22 | Wrong Span, Longer Alias |
# | 28 | what's one of the brothers grimm's famous fairy tales | fairy tales | the brothers grimm | 8 | Wrong Span |
# | 29 | What's the original version of cruisin | cruisin | cruisin' | 7 | Wrong Span, Longer Alias |
# | 30 | What compilation album did olivia newton-john release in 1998? | compilation album | olivia newton-john | 1 | Wrong Span |
# | 31 | what's one event that celebrates the leather subculture | leather | leather subculture | 3 | Wrong Span, Longer Alias |
# | 32 | what type of film is the need for speed | the need for speed | need for speed | 3 | Wrong Span, Longer Alias |
# | 33 | what is an album by Chico DeBarge? | chico debarge | album | 1 | Wrong Span |
# | 34 | which church does robert jaworski, jr. ascribe to | robert jaworski | robert jaworski, jr. | 1 | Wrong Span, Longer Alias |
# | 35 | what's an arcade game made by atari | arcade game | atari | 2 | Wrong Span |
# | 36 | Name a novel by Vladimir Nabokov | vladimir nabokov | novel | 2 | Wrong Span |
# | 37 | roy rogers restaurants in which industry? | roy rogers | roy rogers restaurants | 42 | Wrong Span |
# | 38 | who is of caucasian race in babylon 5 | babylon 5 | caucasian | 4 | Wrong Span |
# | 39 | what is a visual art painting | visual art | painting | 1 | Wrong Span |
# | 40 | brian swimme wrote what book that dealt with  science | brian swimme | science | 1 | Wrong Span |
# | 41 | Which animation did Raoul Servais direct | raoul servais | animation | 1 | Wrong Span |
# | 42 | what is an album by leo sayer? | leo sayer | album | 3 | Wrong Span |
# | 43 | who played the drum  in the Los Angeles rock quintet Rooney | drum | drums | 74 | Wrong Span, Longer Alias |
# | 44 | What is a compilation album from 2006  | compilation album | album | 1 | Wrong Span, Longer Alias |
# | 45 | who is the most influential female k-pop singer? | singer | k-pop | 399 | Wrong Span |
# | 46 | what western state does contain avila place | avila | avila place | 2 | Wrong Span, Longer Alias |
# | 47 | What is an album written by Johannes Brahms | johannes brahms | album | 1 | Wrong Span |
# | 48 | what is the mouth name of the  conejos river  | conejos | conejos river | 1 | Wrong Span, Longer Alias |
# | 49 | which language is two projects by frederick kiesler usually shown in | frederick kiesler | two projects by frederick kiesler | 1 | Wrong Span, Longer Alias |
# | 50 | which film created the barefoot artist  | barefoot | the barefoot artist | 7 | Wrong Span, Longer Alias |
#
# #### Candidate Generation via Exact Match + Longer
#
# Statistics:
# - Canditate Accuracy: 0.871093 [9447 of 10845]
# - Strategy Accuracy: 0.983345 [9447 of 9607]
# - Skipped Rows: 0.114154 [1238 of 10845]
#
# Dicussion:
#
# All the errors are due to the wrong span. 6/50 Articles are incosistenly applied; therefore, during training we should remove them from the CRF tags on the left side. 2/50 Punctuation should be removed during our preprocessing of aliases. This is consistent with our exploratory notebook preprocess step.
#
# The data is quite noisy around the word album. We could consider adding an edge cases specifically to deal with that word.
#
# Error Bucket:
#
# | Index | Question | Predicted Subject | Subject Name | Number of Candidates | Bucket
# |:--|:--|:--|:--|
# | 1 | Name an album released by aaron carter | aaron carter | album | 6 | Wrong Span |
# | 2 | what is a tablet used to treat hypertension  | hypertension | tablet | 28 | Wrong Span |
# | 3 | What's a soundtrack written by anthony marinelli | anthony marinelli | soundtrack | 2 | Wrong Span |
# | 4 | which karl may characters was a tribal chief? | karl may | tribal chief | 4 | Wrong Span |
# | 5 | name an album by George Canyon | george canyon | album | 2 | Wrong Span |
# | 6 | What is a compilation album by creedence clearwater revival | compilation album | creedence | 16 | Wrong Span |
# | 7 | what is one of the master's powers  | the master | master | 425 | Wrong Span, Shorter, Article |
# | 8 | What newspaper circulates in the town of kearny | kearny | t-town | 22 | Wrong Span |
# | 9 | what animated cartoon was about ducks? | ducks | animated cartoon | 57 | Wrong Span |
# | 10 | What's the soundtrack for s.cry.ed | s.cry.ed | soundtrack | 2 | Wrong Span |
# | 11 | which fantasy series were written by mercedes lackey? | fantasy | mercedes lackey | 2676 | Wrong Span |
# | 12 | brian oshea performs what type of martial art | brian oshea | brian o'shea | 1 | Punctuation |
# | 13 | which album is released by Sham 69 | sham 69 | album | 9 | Wrong Span |
# | 14 | What's an album by soil | soil | album | 107 | Wrong Span, Album |
# | 15 | what's one of the brothers grimm's famous fairy tales | fairy tales | the brothers grimm | 75 | Wrong Span  |
# | 16 | What compilation album did olivia newton-john release in 1998? | compilation album | olivia newton-john | 16 | Wrong Span |
# | 17 | who recorded ich wär so gern wie du | ich wär so gern wie du | ich wär' so gern wie du | 1 | Punctuation |
# | 18 | what type of film is the need for speed | the need for speed | need for speed | 4 | Wrong Span, Shorter, Article |
# | 19 | what is an album by Chico DeBarge? | chico debarge | album | 1 | Wrong Span |
# | 20 | what's an arcade game made by atari | arcade game | atari | 18 | Wrong Span |
# | 21 | Name a novel by Vladimir Nabokov | vladimir nabokov | novel | 7 | Wrong Span |
# | 22 | who is of caucasian race in babylon 5 | babylon 5 | caucasian | 87 | Wrong Span |
# | 23 | what is a visual art painting | visual art | painting | 27 | Wrong Span |
# | 24 | brian swimme wrote what book that dealt with  science | brian swimme | science | 1 | Wrong Span |
# | 25 | Which animation did Raoul Servais direct | raoul servais | animation | 1 | Wrong Span |
# | 26 | what is an album by leo sayer? | leo sayer | album | 10 | Wrong Span |
# | 27 | which country was the cosmic egg released in | the cosmic egg | cosmic egg | 1 | Wrong Span, Shorter Article |
# | 28 | who is an artist that creates latin pop music | latin pop music | latin pop | 1 | Wrong Span, "Music" Shorter |
# | 29 | What is a compilation album from 2006  | compilation album | album | 16 | Wrong Span, Shorter "Compilation" |
# | 30 | who is the most influential female k-pop singer? | singer | k-pop | 1416 | Wrong Span |
# | 31 | What is a city in Surrey County, north carolina? | surrey county | north carolina | 1 | Wrong Span |
# | 32 | What is an album written by Johannes Brahms | johannes brahms | album | 14 | Wrong Span |
# | 33 | what are indie films? | indie films | indie film | 1 | Plural |
# | 34 | which albums were released by the century media label? | century media | album | 6 | Wrong Span |
# | 35 | which airline is in the air canada jazz | air canada jazz | jazz | 1 | Wrong Span, Shorter "Air Canada" |
# | 36 | Name a drug that contains serine. | drug | serine | 363 | Wrong Span |
# | 37 | who recorded the tower of london | the tower of london | tower of london | 2 | Wrong Span, Shorter Article |
# | 38 | Who is an artist  signed by rca records? | rca records | rca | 4 | Wrong Span |
# | 39 | Which mining companies are located in Brazil  | brazil | mining | 2112 | Wrong Span |
# | 40 | where was the end of the line filmed  | the end of the line | end of the line | 4 | Wrong Span, Shorter Article |
# | 41 | What's a game that konami published for the wii | konami | wii | 50 | Wrong Span |
# | 42 | which fear factor episode involved wrecking balls | wrecking balls | fear factor | 1 | Wrong Span  |
# | 43 | What is queen's compilation album called | compilation album | queen | 16 | Wrong Span |
# | 44 | Name a rowing team from Oxford | oxford | rowing | 595 | Wrong Span |
# | 45 | what is the genre of the magic | the magic | magic | 550 | Shorter Article, Wrong Span |
# | 46 | what horror films came out in 2002? | horror films | horror | 4 | Wrong Span, Shorter|
# | 47 | who is a fictional human character from the television series Angel | angel | human | 7367 | Wrong Span |
# | 48 | which peninsula campaign battles took place during the american civil war? | american civil war | peninsula campaign | 21 | Wrong Span |
# | 49 | Who is the music by in destruction, inc.? | in destruction | destruction, inc. | 1 | Wrong Span, Shorter, Stop Word |
# | 50 | which actor was born in sydney? | sydney | actor | 825 | Wrong Span |
#
#
# #### Candidate Generation via Exact Match + Longer + Normalized Punctuation
#
# Statistics:
# - Canditate Accuracy: 0.936284 [10154 of 10845]
# - Strategy Accuracy: 0.983915 [10154 of 10320]
# - Skipped Rows: 0.048409 [525 of 10845]
#
# Dicussion:
#
# 6/50 Errors are due to articles. 1/50 is due to a plural word. 1 / 50 is due to stop words. 49/50 of them are due to the wrong span being selected.
#
# Error Bucket:
#
# | Index | Question | Predicted Subject | Subject Name | Number of Candidates | Bucket
# |:--|:--|:--|:--|
# | 1 | Name an album released by aaron carter | aaron carter | album | 6 | Wrong Span |
# | 2 | what is a tablet used to treat hypertension  | hypertension | tablet | 28 | Wrong Span |
# | 3 | What's a soundtrack written by anthony marinelli | anthony marinelli | soundtrack | 2 | Wrong Span |
# | 4 | which karl may characters was a tribal chief? | karl may | tribal chief | 4 | Wrong Span |
# | 5 | name an album by George Canyon | george canyon | album | 2 | Wrong Span |
# | 6 | What is a compilation album by creedence clearwater revival | compilation album | creedence | 16 | Wrong Span |
# | 7 | what is one of the master's powers  | the master | master | 425 | Wrong Span, Shorter, Article |
# | 8 | What newspaper circulates in the town of kearny | kearny | t-town | 22 | Wrong Span |
# | 9 | what animated cartoon was about ducks? | ducks | animated cartoon | 62 | Wrong Span |
# | 10 | What's the soundtrack for s.cry.ed | scryed | soundtrack | 4 | Wrong Span |
# | 11 | name a location contained in peoria county, illinois. | peoria county illinois | peoria county | 20 | Wrong Span |
# | 12 | which fantasy series were written by mercedes lackey? | fantasy | mercedes lackey | 2676 | Wrong Span |
# | 13 | which album is released by Sham 69 | sham 69 | album | 9 | Wrong Span |
# | 14 | What's an album by soil | soil | album | 108 | Wrong Span |
# | 15 | what's one of the brothers grimm's famous fairy tales | fairy tales | the brothers grimm | 75 | Wrong Span |
# | 16 | What compilation album did olivia newton-john release in 1998? | compilation album | olivia newton-john | 16 | Wrong Span |
# | 17 | what type of film is the need for speed | the need for speed | need for speed | 4 | Wrong Span, Shorter, Article |
# | 18 | what is an album by Chico DeBarge? | chico debarge | album | 2 | Wrong Span |
# | 19 | what's an arcade game made by atari | arcade game | atari | 18 | Wrong Span |
# | 20 | Name a novel by Vladimir Nabokov | vladimir nabokov | novel | 7 | Wrong Span |
# | 21 | who is of caucasian race in babylon 5 | babylon 5 | caucasian | 87 | Wrong Span |
# | 22 | what is a visual art painting | visual art | painting | 27 | Wrong Span |
# | 23 | brian swimme wrote what book that dealt with  science | brian swimme | science | 1 |  Wrong Span|
# | 24 | Which animation did Raoul Servais direct | raoul servais | animation | 1 | Wrong Span |
# | 25 | what is an album by leo sayer? | leo sayer | album | 10 | Wrong Span |
# | 26 | which country was the cosmic egg released in | the cosmic egg | cosmic egg | 1 | Wrong Span, Shorter, Article |
# | 27 | who is an artist that creates latin pop music | latin pop music | latin pop | 1 | Wrong Span, Shorter |
# | 28 | What is a compilation album from 2006  | compilation album | album | 16 | Wrong Span, Shorter |
# | 29 | who is the most influential female k-pop singer? | singer | k-pop | 1418 | Wrong Span |
# | 30 | What is a city in Surrey County, north carolina? | surrey county | north carolina | 1 | Wrong Span |
# | 31 | What is an album written by Johannes Brahms | johannes brahms | album | 15 | Wrong Span |
# | 32 | what are indie films? | indie films | indie film | 1 | Plural |
# | 33 | which albums were released by the century media label? | century media | album | 6 | Wrong Span |
# | 34 | which airline is in the air canada jazz | air canada jazz | jazz | 1 | Wrong Span, Shorter |
# | 35 | Name a drug that contains serine. | drug | serine | 364 | Wrong Span |
# | 36 | who recorded the tower of london | the tower of london | tower of london | 2 | Wrong Span, Shorter, Article |
# | 37 | Who is an artist  signed by rca records? | rca records | rca | 4 | Wrong Span, Shorter |
# | 38 | Which mining companies are located in Brazil  | brazil | mining | 2112 | Wrong Span |
# | 39 | where was the end of the line filmed  | the end of the line | end of the line | 4 | Wrong Span, Shorter, Article |
# | 40 | What's a game that konami published for the wii | konami | wii | 50 | Wrong Span |
# | 41 | which fear factor episode involved wrecking balls | wrecking balls | fear factor | 1 | Wrong Span  |
# | 42 | What is queen's compilation album called | compilation album | queen | 16 | Wrong Span |
# | 43 | Name a rowing team from Oxford | oxford | rowing | 595 | Wrong Span |
# | 44 | what is the genre of the magic | the magic | magic | 550 | Wrong Span, Shorter, Article |
# | 45 | what horror films came out in 2002? | horror films | horror | 4 | Wrong Span, Shorter |
# | 46 | who is a fictional human character from the television series Angel | angel | human | 7982 | Wrong Span |
# | 47 | which peninsula campaign battles took place during the american civil war? | american civil war | peninsula campaign | 21 | Wrong Span |
# | 48 | Who is the music by in destruction, inc.? | in destruction | destruction, inc. | 1 | Wrong Span, Stop Word |
# | 49 | which actor was born in sydney? | sydney | actor | 825 | Wrong Span |
# | 50 | what novel is written by James Kelman | james kelman | novel | 1 | Wrong Span |

# %%
from functools import lru_cache

# Allows running experiments without redoing SQL calls
@lru_cache(maxsize=65536)
def cached_lookup(ngram):
    cursor.execute("""SELECT mid, alias, normalized_alias FROM fb_two_subject_name 
                  WHERE normalized_alias = %s OR 
                  normalized_alias LIKE %s""", (ngram, '%' + ngram + '%'))
    return list(cursor.fetchall())

# %%
@lru_cache(maxsize=65536)
def cached_similarity(ngram):
    cursor.execute("""
        SELECT set_limit(0.3);
        SELECT mid, alias, normalized_alias
        FROM fb_two_subject_name
        WHERE normalized_alias %% %s
    """, (predicted,))
    return cursor.fetchall()

# %%
normalize_alias('where did william wilson \\"buffalo bill\\" quinn die')
normalize_alias('where did william wilson \\"buffalo bill\\" quinn die')
# Out:
# "where did william wilson \\ '' buffalo bill\\ '' quinn die"

# %%
cursor.execute("SELECT substring_similarity('Devereaux', 'General Ricardo Wall y Devereux')");
cursor.fetchall();
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-157-d9cf5c2c494d> in <module>()
#       1
# ----> 2 cursor.execute("SELECT substring_similarity('Devereaux', 'General Ricardo Wall y Devereux')");
#       3 cursor.fetchall();
#
# ProgrammingError: function substring_similarity(unknown, unknown) does not exist
# LINE 1: SELECT substring_similarity('Devereaux', 'General Ricardo Wa...
#                ^
# HINT:  No function matches the given name and argument types. You might need to add explicit type casts.

# %%
# TODO: Ask Luke about the TopK sequences for a CRF and how to get them
from collections import defaultdict
from tqdm import tqdm_notebook
import numpy as np
import pandas as pd
import random
from scripts.utils.link_subject_name import get_alias_in_sentence
from scripts.utils.link_subject_name import normalize_alias
from functools import reduce


is_alias_in_sentence = lambda setence, alias: not np.isnan(get_alias_in_sentence(setence, [alias])[0])
stopwords = ['the', 'a', 'an', 'in']
remove_stopwords = lambda normalized_alias: ' '.join([w for w in normalized_alias.split() if w not in stopwords]).strip()

correct = 0
predicted_mids_column = []
total_aliases = 0
features = []

for row_index, row in tqdm_notebook(df_dev.iterrows(), total=df_dev.shape[0]):
    predicted_mids = []
    predicted = normalize_alias(row['predicted_subject_name'].split())
#     if len(predicted) > 0:
#         for i in range(len(predicted)):
#             # CASE: Added a prediction, move on
#             if len(predicted_mids_column) - 1 == row_index:
#                 break;
            
#             gram_size = len(predicted) - i
#             ngrams = list(get_ngrams(list(range(len(predicted))), gram_size))
#             score = lambda ngram: reduce(lambda x, y: x * y, [
#                 row['tag_confidence'][i + row['predicted_subject_name_start_index']] for i in ngram])
#             # Get the ngram with the highest probability
#             ngrams = sorted(ngrams, key=score, reverse=True)
#             for ngram in ngrams:
#                 # Convert ngram from indicies -> words -> phrase
#                 ngram = ' '.join([predicted[i] for i in ngram])
#                 # NOTE: We found that 97% of the time the alias is an exact match with stemming and removing possesives
#                 # and 0.58% there is a one character difference punctuation
#                 candidates = cached_lookup(ngram)
#                 normalized_aliases = set([normalized_alias for (_, _, normalized_alias) in candidates])
#                 normalized_question = ' ' + normalize_alias(row['question']) +  ' '
#                 normalized_aliases = [a for a in normalized_aliases
#                                       if fuzzy_substring(' ' + a + ' ', normalized_question) / (len(a) + 2) < 0.05]
                
#                 if len(normalized_aliases) > 0:
#                     get_length = lambda normalized_alias: len(remove_stopwords(normalized_alias))
#                     max_length_candidate = max(normalized_aliases, key=get_length)
#                     max_length = get_length(max_length_candidate)
#                     top_candidates = set([a for a in normalized_aliases if get_length(a) == max_length])
#                     aliases = set([alias for (_, alias, normalized_alias) in candidates 
#                                    if normalized_alias in top_candidates])
#                     predicted_mids = set([mid for (mid, _, normalized_alias) in candidates 
#                                    if normalized_alias in top_candidates])
#                     predicted_mids_column.append(predicted_mids)
#                     total_aliases += len(aliases)

#                     if row['subject'] not in predicted_mids:
#                         print('WRONG CANDIDATE')
#                         print('Predicted NGram:', ngram)
#                         print('Predicted Aliases:', aliases)
#                         print('Predicted MIDS:', predicted_mids)
#                         print('Max Score:', max_length)
#                     break;
#     else:
#         print('EMPTY SUBJECT PREDICTION')
#         pass


    if len(predicted) > 0:
        # NOTE: Articles are sometimes added by the model as part of the entity
        # We remove them because they are not consistently added or substracted by Freebase
        predicted = predicted.split()
        if predicted[0] in ['a', 'the', 'an']:
            predicted = predicted[1:]
        predicted = ' '.join(predicted)
        
        def filter_candidates(candidates):
            ### Filter candidates based on similarity to question ###
            if len(candidates) == 0:
                return []
            normalized_aliases = list(set([normalized_alias for (_, _, normalized_alias) in candidates]))
            question_tokens = tuple(normalize_alias(row['question']).split())
            question_distance_feature = lambda a: (len(a) - fuzzy_word(tuple(a.split()), question_tokens)) / len(a)
            normalized_aliases = set([a for a in normalized_aliases if question_distance_feature(a) > 0.9])
            return [c for c in candidates if c[2] in normalized_aliases]    
        
        ### Get candidates with high recall. ###
        # Depending on how confident it is, we look it up exactly? That should give us breathing room
        candidates = cached_lookup(predicted)
        candidates = filter_candidates(candidates)
        if len(candidates) == 0:
            candidates = cached_similarity(predicted)
            candidates = filter_candidates(candidates)
            
        predicted_mids = [mid for (mid, _, _) in candidates]
        normalized_aliases = set([normalized_alias for (_, _, normalized_alias) in candidates])
        predicted_mids_column.append(predicted_mids)
        if isinstance(row['subject_name'], str) and row['subject'] not in predicted_mids:
            print('Question Distance:', question_distance_feature(normalize_alias(row['subject_name'])))
        if row['subject'] in predicted_mids and len(normalized_aliases) > 1:
            print('aliases:', normalized_aliases)
            print('question:', row['question'])
            print('predicted:', predicted)
            print('correct:', row['subject_name'])
            print()
            
        total_aliases += len(normalized_aliases)          
    else: 
        predicted_mids_column.append([])
        print('Empty Predicted')
        
        
        
        # Features used for scoring
#         if len(normalized_aliases) > 0:
#             predicted_distance_feature = lambda a: ((max(len(predicted), len(a)) - 
#                                                     fuzzy_word(tuple(a.split()), tuple(predicted.split())))
#                                                     / max(len(predicted), len(a)))
#             get_features = lambda a: (question_distance_feature(a), predicted_distance_feature(a),  len(a))
#             features = [get_features(a) for a in normalized_aliases]

#             scores = [predicted_distance * length for (_, predicted_distance, length) in features]
#             max_score = max(scores)
#             top_aliases = set([normalized_aliases[i] for i, s in enumerate(scores) if s == max_score])
#         else:
#             top_aliases = []
            
#         if normalize_alias(row['subject_name']) in top_aliases:
#             correct += 1
#         elif isinstance(row['subject_name'], str):
#             print('Question:', row['question'])
#             print('Top alises:', top_aliases)
#             print('Top Score:', max_score)
#             print('True Subject Name:', row['subject_name'])
#             print('Predicted Subject Name:', predicted)
#             print('Number of rows:', len(features))
#             print('Correct:', get_features(normalize_alias(row['subject_name'])))
#             print('Wrong:', [get_features(a) for a in top_aliases])
#             print()
        

#     predicted = normalize_alias(row['predicted_subject_name'].split())
#     cursor.execute('SELECT mid, normalized_alias FROM fb_two_name WHERE normalized_alias = %s', (predicted, ))
#     rows = list(cursor.fetchall())
#     predicted_mids = set([row[0] for row in rows])
#     aliases = set([r[1] for r in rows])

#     if len(predicted_mids) == 0:
#         # CASE: Missing words on left or right causing no matches
#         cursor.execute("""
#             SELECT set_limit(0.3);
#             SELECT mid, normalized_alias, similarity(normalized_alias, %s) AS similarity_score 
#             FROM fb_two_name
#             WHERE normalized_alias %% %s
#         """, (predicted, predicted))
#         rows = list(cursor.fetchall())
#         max_similarity_score = max(row[2] for row in rows)
#         predicted_mids = set([r[0] for r in rows if r[2] == max_similarity_score])
#         aliases = set([r[1] for r in rows if r[2] == max_similarity_score])
#     predicted_mids_column.append(predicted_mids)
#     total_aliases += len(aliases)
    
    if row['subject'] in predicted_mids:
        correct += 1
    else:
        print('Question:', row['question'])
        print('Subject MID:', row['subject'])
        cursor.execute('SELECT alias, normalized_alias FROM fb_two_subject_name WHERE mid = %s', (row['subject'],))
        aliases = cursor.fetchall()
        print('Subject Alises:', aliases)
        print('Subject Name:', row['subject_name'])
        print('Predicted Confidence:', row['tag_confidence'])
        print('Predicted:', predicted)
        print('strategy:', strategy)
        print('Num Predicted MIDS:', len(predicted_mids))
        if isinstance(row['subject_name'], str):
            print('1True' if normalize_alias(row['subject_name']) in predicted else '1False')
        print('Nan and None:',predicted, 'True' if len(predicted) == 0 and not isinstance(row['subject_name'], str) else 'False')
        print('WHOOPS')
        print()

# 0.968 ~ base?
# 0.973997 ~ Similarity 0.3
# 0.973721 ~ 1 token
# 0.975657 ~ Similarity 0.2
# 0.976763 ~ Similarity 0.2 + Remove articles

# EXPERIMENT Best linking strategy ~
# normalized_alias: 0.625700 expected linking accuracy / 0.922914 accuracy
# normalized_alias + similarity max filter: 0.653346 | 0.956478 / Average N Aliases: 1.012633
# normalized_alias + similarity: 0.627181 | ~0.967358
# normalized_alias: 0.635924 expected linking accuracy / 0.933241 accuracy
# normalized_alias + ngrams: 0.650822 expected linking accuracy / 0.955187 accuracy / Average N Aliases: 1.189212
# question distance 0.95: 0.628252 expected linking accuracy / 0.961457 accuracy /Average N Aliases: 1.102536
# question distance 0.9: 0.626057 expected linking accuracy / 0.965698 accuracy / Average N Aliases: 1.179991

print('Accuracy: %f [%d of %d]' % (correct / df_dev.shape[0], correct, df_dev.shape[0]))
print('Average N Aliases: %f [%d of %d]' % (total_aliases / df_dev.shape[0], total_aliases, df_dev.shape[0]))
df_dev['predicted_mids'] = pd.Series(predicted_mids_column, index=df_dev.index)
expected_accuracy = 0
for index, row in df_dev.iterrows():
    if row['subject'] in row['predicted_mids']:
        expected_accuracy += 1 / len(row['predicted_mids'])
print('Expected Linking Accuracy: %f' % (expected_accuracy / df_dev.shape[0]))

df_dev[:5]
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# aliases: {'bon voyag', 'bon voyag !'}
# question: What is the language of the film bon voyage?
# predicted: bon voyag
# correct: bon voyage
#
# aliases: {'u.s. rout 24', 'u.s. rout 22', 'u.s. rout 29', 'u.s. rout 27', 'u.s. rout 20', 'u.s. rout 23', 'u.s. rout 26', 'u.s. rout 21', 'u.s. rout 2'}
# question: what major cities does u.s. route 2 run through
# predicted: u.s. rout 2
# correct: u.s. route 2
#
# aliases: {'australia', 'v australia'}
# question: which recordings contains the composition australia?
# predicted: australia
# correct: australia
#
# aliases: {'riot grrrl', 'riot', 'music'}
# question: what artist creates riot grrrl music
# predicted: riot grrrl music
# correct: riot grrrl
#
# aliases: {'the invad', 'invad'}
# question: What is the language of the invaders?
# predicted: invad
# correct: the invaders
#
# aliases: {'the thriller', 'thriller'}
# question: What is the name of a title found under the thriller (genre)
# predicted: thriller
# correct: thriller
#
# aliases: {'frome', 'ethan frome', 'ethan', 'seri'}
# question: what is a book from the ethan frome series
# predicted: ethan frome seri
# correct: ethan frome
#
# Question: What was bill hosket, jr.'s position
# Subject MID: 02vvz00
# Subject Alises: [('bill hosket, jr.', 'bill hosket , jr .')]
# Subject Name: nan
# Predicted Confidence: [0.9855041947873536, 0.9978494898208053, 0.9934257304986485, 0.9925223498273237, 0.9862480142715955, 0.9064149087079691, 0.9843648222151468, 0.9734713535637629]
# Predicted: bill hosket
# strategy: same or bigger
# Num Predicted MIDS: 150
# Nan and None: bill hosket False
# WHOOPS
#
# aliases: {'version', 'mecca', 'canon'}
# question: what is the name for meccas canonical version
# predicted: mecca canon version
# correct: mecca
#
# aliases: {'i miss you', 'i miss you…'}
# question: what is  i miss you
# predicted: i miss you
# correct: i miss you
#
# Question Distance: 0.25
# Question: What type of harp is traditionally found in ireland
# Subject MID: 03m5k
# Subject Alises: [('harp', 'harp')]
# Subject Name: harp
# Predicted Confidence: [0.9719518137754877, 0.8199849787610658, 0.9300321456053152, 0.8137553876765253, 0.9210764889161706, 0.7537318392450131, 0.888180804450196, 0.9735423696360175, 0.9734056518544164]
# Predicted: ireland
# strategy: same or bigger
# Num Predicted MIDS: 219
# 1False
# Nan and None: ireland False
# WHOOPS
#
# Question: What track is featured on the salisbury release
# Subject MID: 098j5p7
# Subject Alises: [('megan leigh romero', 'megan leigh romero'), ('megan romero', 'megan romero')]
# Subject Name: nan
# Predicted Confidence: [0.9837789520073175, 0.9018167147978334, 0.9658195645845792, 0.9785876171390612, 0.9692402133227251, 0.9363313284321486, 0.9996816980466697, 0.9929576507766665]
# Predicted: salisburi
# strategy: same or bigger
# Num Predicted MIDS: 76
# Nan and None: salisburi False
# WHOOPS
#
# aliases: {'madagascar', 'madagascar 2', 'the third', 'third', 'madagascar 3'}
# question: what's the full title of the third madagascar movie
# predicted: third madagascar
# correct: madagascar
#
# aliases: {'water', 'canch', 'the', 'the water'}
# question: where does the water in the canche come from
# predicted: water in the canch
# correct: canche
#
# Question: What composer created?
# Subject MID: 0zhwd1v
# Subject Alises: [('datskat', 'datskat')]
# Subject Name: nan
# Predicted Confidence: [0.9939640550308302, 0.9986372081309658, 0.9920773344721144, 0.9909877643657964]
# Predicted: compos
# strategy: same or bigger
# Num Predicted MIDS: 46
# Nan and None: compos False
# WHOOPS
#
# aliases: {'5 minut to midnight', '2 minut to midnight', 'minut to midnight', 'one minut to midnight'}
# question: what track is on minutes to midnight
# predicted: minut to midnight
# correct: minutes to midnight
#
# aliases: {'robert harril', 'robert harri'}
# question: where was robert harris (painter) born
# predicted: robert harri
# correct: robert harris
#
# aliases: {'the silenc of the lamb 2', 'the silenc of the lamb', 'silenc of the lamb'}
# question: who wrote the book the silence of the lambs
# predicted: silenc of the lamb
# correct: the silence of the lambs
#
# Question: Who's a linebacker
# Subject MID: 03m9zc3
# Subject Alises: [('ron warner', 'ron warner')]
# Subject Name: nan
# Predicted Confidence: [0.9761044421667598, 0.9451180272807651, 0.996682693667723, 0.9993382514750941]
# Predicted: lineback
# strategy: same or bigger
# Num Predicted MIDS: 1
# Nan and None: lineback False
# WHOOPS
#
# aliases: {'cure', 'the cure'}
# question: What is a song by the cure?
# predicted: cure
# correct: the cure
#
# aliases: {'world war ii', 'world war iii'}
# question: who was a military personnel involved in world war ii
# predicted: world war ii
# correct: world war ii
#
# aliases: {'beyond good & evil 2', 'beyond good & evil', 'beyond good & evil hd'}
# question: Name a track off of beyond good & evil
# predicted: beyond good & evil
# correct: beyond good & evil
#
# aliases: {'william wall', 'william walli'}
# question: What is william wall's gender?
# predicted: william wall
# correct: william wall
#
# aliases: {'dead men walk', 'dead man walk', 'dead', 'is dead', 'dead man talk', 'walk', 'dead man'}
# question: what kinds of movie is dead man walking in netlix
# predicted: dead man walk in netlix
# correct: dead man walking
#
# aliases: {'phenomenon', 'a phenomenon'}
# question: what type of music is on the album phenomenon
# predicted: phenomenon
# correct: phenomenon
#
# aliases: {'radio', 'wmjc', 'station'}
# question: what area does wmjc radio station play for
# predicted: wmjc radio station
# correct: wmjc
#
# aliases: {'bigg boss 7', 'bigg boss', 'bigg boss 6'}
# question: what is a season of bigg boss (indian tv series)
# predicted: bigg boss
# correct: bigg boss
#
# aliases: {'auburn 852s', 'auburn 852'}
# question: is the auburn 852 a 4 door or convertible
# predicted: auburn 852
# correct: auburn 852
#
# aliases: {'randi sander', 'brandi sander'}
# question: what gender is randy sanders
# predicted: randi sander
# correct: randy sanders
#
# aliases: {'bluegrass', 't ( disc 1 )', 'bluegrass 1956-68', 'z ( disc 1 )'}
# question: what is a song on bluegrass 1956-68 (disc 1)
# predicted: bluegrass 1956-68 ( disc 1 )
# correct: bluegrass 1956-68
#
# Question: what label does the artist mr. m. belong to
# Subject MID: 01x20gj
# Subject Alises: [('mr m', 'mr m'), ('mr. m.', 'mr. m .'), ('mr.m.', 'mr.m .')]
# Subject Name: nan
# Predicted Confidence: [0.990918486339374, 0.9300780699719777, 0.9941043946126784, 0.9468190687704862, 0.997582451090794, 0.9943965833408502, 0.9985225298283454, 0.9975929781705734, 0.9976272167248956]
# Predicted: mr. m.
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: mr. m. False
# WHOOPS
#
# aliases: {'video', 'intellivis', 'consol', 'video game', 'video game consol'}
# question: What is a game played with the intellivision video game console?
# predicted: intellivis video game consol
# correct: intellivision
#
# aliases: {'come', 'this pud for you', 'for you', 'this'}
# question: what is the series where the episode this puds for you comes from
# predicted: this pud for you come
# correct: this pud's for you
#
# Question: What is Zhang Heping's gender?
# Subject MID: 0yzv6q0
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9862048042500551, 0.9983040482775382, 0.9960516182069812, 0.9962355877705364, 0.9986435982025386, 0.9649820480520944, 0.9970281891056896]
# Predicted: zhang hepe
# strategy: same or bigger
# Num Predicted MIDS: 1
# Nan and None: zhang hepe False
# WHOOPS
#
# Question: Which label is sabrinawmusic signed to?
# Subject MID: 0bnsl7
# Subject Alises: [('sabrina fredrica washington', 'sabrina fredrica washington'), ('sabrina washington', 'sabrina washington'), ('washington, sabrina', 'washington , sabrina')]
# Subject Name: nan
# Predicted Confidence: [0.9909718102999815, 0.9440252036786434, 0.997224179967397, 0.9999084827924377, 0.9988047321474256, 0.9608321256338791, 0.9982615859597822]
# Predicted: sabrinawmus
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: sabrinawmus False
# WHOOPS
#
# aliases: {'film', 'footbal'}
# question: what is a football film on netflix?
# predicted: footbal film
# correct: football
#
# aliases: {'the electr', 'electr', 'murder', 'electr chair', 'chair'}
# question: Who was killed by the electric chair for murder
# predicted: electr chair for murder
# correct: electric chair
#
# aliases: {'car', 'the car'}
# question: what is a track from the car
# predicted: car
# correct: the car
#
# aliases: {'three world trade center', '2 world trade center', 'one world trade center', '1 world trade center', 'world trade center 4', 'two world trade center', 'world trade center 3', '4 world trade center', '7 world trade center', 'world trade center'}
# question: what can be found within the world trade center
# predicted: world trade center
# correct: world trade center
#
# aliases: {'69 eye', 'the 69 eye'}
# question: what kind of music does the 69 eyes make?
# predicted: 69 eye
# correct: the 69 eyes
#
# Question Distance: 0.3333333333333333
# Question: which peninsula campaign battles took place during the american civil war?
# Subject MID: 01n7bq
# Subject Alises: [('peninsula campaign', 'peninsula campaign'), ('peninsular campaign', 'peninsular campaign')]
# Subject Name: peninsula campaign
# Predicted Confidence: [0.9669588332876561, 0.5115258416347906, 0.6135179174435403, 0.6921095048098437, 0.7982076311603408, 0.9050479401435996, 0.859160531496634, 0.9745379343377158, 0.9640464145356981, 0.6845687787934522, 0.9415022735998089, 0.9987811050662649]
# Predicted: american civil war
# strategy: same or bigger
# Num Predicted MIDS: 2
# 1False
# Nan and None: american civil war False
# WHOOPS
# aliases: {'ak soundtrack', 'π soundtrack', 'soundtrack', '3 soundtrack', 'x soundtrack'}
# question: what's a name of a soundtrack
# predicted: soundtrack
# correct: soundtrack
#
# aliases: {'stanford univers .', 'stanford univers'}
# question: What is a  fraternity or sorority at stanford university?
# predicted: stanford univers
# correct: stanford university
#
# Question: What newspaper circulates in the town of kearny
# Subject MID: 013kcv
# Subject Alises: [('wagoner county / tulsa city', 'wagon counti / tulsa citi'), ('tulsa', 'tulsa'), ('tulsa, oklahoma', 'tulsa , oklahoma'), ('t-town', 't-town')]
# Subject Name: nan
# Predicted Confidence: [0.9749530105604103, 0.8485470333991963, 0.9496939538555046, 0.8066772969914706, 0.8602264923964622, 0.6650237234745787, 0.917764141218179, 0.9986309223015929]
# Predicted: kearni
# strategy: same or bigger
# Num Predicted MIDS: 2
# Nan and None: kearni False
# WHOOPS
#
# Empty Predicted
# Question: Name a country who has constitutional republic as a form of government.
# Subject MID: 0c9rw5
# Subject Alises: [('constitutional republic', 'constitut republ')]
# Subject Name: constitutional republic
# Predicted Confidence: [0.9174840963158608, 0.9514837607702779, 0.5434090249706229, 0.7448666315254353, 0.9772817717911397, 0.8445417735058475, 0.8052126629978575, 0.9786674041350987, 0.9515050639020897, 0.8898615397764068, 0.9694524885732392, 0.9587688982444942, 0.9968472557528708]
# Predicted:
# strategy: same or bigger
# Num Predicted MIDS: 0
# 1False
# Nan and None:  False
# WHOOPS
#
# aliases: {'piano', 'the piano'}
# question: Who is an instrumentalist known for playing the piano?
# predicted: piano
# correct: piano
#
# aliases: {'earthquak !', 'earthquak', 'earthquak v'}
# question: What is a version of the single earthquake?
# predicted: earthquak
# correct: earthquake
#
# aliases: {'rugbi leagu 3', 'rugbi leagu', 'rugbi', 'leagu', 'rugbi leagu 2', 'coach'}
# question: What is the name of the Bulldog's Rugby league coach?
# predicted: rugbi leagu coach
# correct: rugby league
#
# aliases: {'who want to live forev', 'who want to live forev ?'}
# question: who is the producer of who wants to live forever
# predicted: who want to live forev
# correct: who wants to live forever
#
# Question: Where is the place of birth of nguyen van toan
# Subject MID: 02vnwfd
# Subject Alises: [('nguyễn văn toàn', 'nguyễn văn toàn')]
# Subject Name: nan
# Predicted Confidence: [0.9488005854866124, 0.978989240266644, 0.933816818832562, 0.892373986354025, 0.9617796362016372, 0.8495699752168046, 0.9932407989486347, 0.9933285950683959, 0.912211276539528, 0.8857456490573875]
# Predicted: nguyen van toan
# strategy: same or bigger
# Num Predicted MIDS: 21
# Nan and None: nguyen van toan False
# WHOOPS
#
# Question: what types of music is played by capitallights
# Subject MID: 02pvx1q
# Subject Alises: [('capital lights', 'capit light'), ('aftereight', 'aftereight')]
# Subject Name: nan
# Predicted Confidence: [0.979092526493844, 0.8695385534486385, 0.926629036698098, 0.8130920137489044, 0.9582458032531567, 0.7571747626787092, 0.9922617015926027, 0.9948021272525879]
# Predicted: capitallight
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: capitallight False
# WHOOPS
#
# aliases: {'air', 'jazz', 'canada', 'air canada'}
# question: which airline is in the air canada jazz
# predicted: air canada jazz
# correct: jazz
#
# aliases: {'south', 'the south'}
# question: what kind of book is the south
# predicted: south
# correct: the south
#
# aliases: {'the war report 2', 'the war report'}
# question: Which genre of music is on the album the war report
# predicted: war report
# correct: the war report
#
# aliases: {'the korean war', 'korean war'}
# question: Who was a notable person in the korean war?
# predicted: korean war
# correct: korean war
#
# Question: what is an example of a film on 35mm
# Subject MID: 0cj16
# Subject Alises: [('35 mm film', '35 mm film'), ('35mm film', '35mm film')]
# Subject Name: nan
# Predicted Confidence: [0.9828297779286213, 0.9752811905917971, 0.9407205175429372, 0.9099169537752281, 0.9509160261691735, 0.9573798040454603, 0.5027524366940144, 0.992778468212583, 0.9905455346653412]
# Predicted: 35mm
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: 35mm False
# WHOOPS
#
# aliases: {'capsul', 'the capsul'}
# question: What is a drug in the capsule form?
# predicted: capsul
# correct: capsule
#
# aliases: {'the mr. t experi', 'mr. t experi'}
# question: What genre is the mr. t experience
# predicted: mr. t experi
# correct: the mr. t experiance
#
# aliases: {'multipl endocrin neoplasia i', 'multipl endocrin neoplasia'}
# question: which genome is the gene multiple endocrine neoplasia i in
# predicted: endocrin neoplasia
# correct: multiple endocrine neoplasia i
#
# Question: What is the name of the award winning album by Linda Ronstant?
# Subject MID: 06vw6v
# Subject Alises: [('studio album', 'studio album')]
# Subject Name: nan
# Predicted Confidence: [0.975551737465496, 0.9791926685244375, 0.8808810862082497, 0.9122641306825647, 0.9471767823301418, 0.884909882962561, 0.7986429189939734, 0.7036353229673928, 0.8525545728664214, 0.9960151531809817, 0.8880362828201502, 0.8933572288002546, 0.9980565319124658]
# Predicted: linda ronstant
# strategy: same or bigger
# Num Predicted MIDS: 19
# Nan and None: linda ronstant False
# WHOOPS
#
# aliases: {'oath', 'the oath'}
# question: Which netflix genre is the oath?
# predicted: oath
# correct: the oath
#
# aliases: {'bryan ferri', 'bryan ferrit'}
# question: What is a track produced by bryan ferry?
# predicted: bryan ferri
# correct: bryan ferry
#
# aliases: {'o holi night', 'o holi night !'}
# question: Which release was o holy night recorded on?
# predicted: o holi night
# correct: o holy night
#
# aliases: {'eye of fire', 'a funer for the eye of fire'}
# question: Name the modern science fiction author of a funeral for the eyes of fire.
# predicted: eye of fire
# correct: a funeral for the eyes of fire
#
# Question: What is an artist associated with latin american music?
# Subject MID: 0g293
# Subject Alises: [('music of latin america', 'music of latin america'), ('latin music', 'latin music')]
# Subject Name: nan
# Predicted Confidence: [0.9846187720530875, 0.9796308326879565, 0.9581915290045492, 0.8661151232691678, 0.9428056410474345, 0.9948582160436321, 0.9487311190002667, 0.7392406283203853, 0.84890351045197, 0.9976476020667584]
# Predicted: latin american music
# strategy: same or bigger
# Num Predicted MIDS: 171
# Nan and None: latin american music False
# WHOOPS
#
# aliases: {'georg barna', 'georg barn'}
# question: which movie did george barnes work on as the cinematographer
# predicted: georg barn
# correct: george barnes
#
# aliases: {'love', 'love actual'}
# question: what is a language that love actually was produced in
# predicted: love
# correct: love actually
#
# aliases: {'eastern daylight time', 'time zone', 'daylight', 'eastern'}
# question: Name a county that is within the eastern daylight time zone
# predicted: eastern daylight time zone
# correct: eastern daylight time
#
# aliases: {'the saint', 'saint'}
# question: what is the album of the artist the saints?
# predicted: saint
# correct: the saints
#
# aliases: {'the collect 1', 'collect', 'the collect', 'the * collect', 'the collect 2', 'the collect 4', 'the collect 3'}
# question: is the collection a compact disc or dvd
# predicted: collect
# correct: the collection
#
# Question Distance: 0.5
# Question: which song is composed by Steve Rothery
# Subject MID: 074ft
# Subject Alises: [('song', 'song')]
# Subject Name: song
# Predicted Confidence: [0.9855864971895966, 0.5949892136623306, 0.9464313475655075, 0.9290151211098748, 0.9948819531974826, 0.9539441996662746, 0.7146494855410568]
# Predicted: steve rotheri
# strategy: same or bigger
# Num Predicted MIDS: 1
# 1False
# Nan and None: steve rotheri False
# WHOOPS
#
# aliases: {'the appl', 'appl'}
# question: where is the apples from?
# predicted: appl
# correct: the apples
#
# aliases: {'el dorado', 'the loss of el dorado'}
# question: Where was the loss of el dorado located?
# predicted: el dorado
# correct: the loss of el dorado
#
# aliases: {'beast', 'the beast'}
# question: what kind of movie is the beast
# predicted: beast
# correct: the beast
#
# Question: what game is played in single-player mode?
# Subject MID: 02hjn4
# Subject Alises: [('single-player video game', 'single-play video game')]
# Subject Name: nan
# Predicted Confidence: [0.97201766448272, 0.7156089585351443, 0.9650142278394267, 0.9298832933077704, 0.997238874215575, 0.990288524850504, 0.9774547696814069, 0.9990005840390171]
# Predicted: single-play mode
# strategy: same or bigger
# Num Predicted MIDS: 36
# Nan and None: single-play mode False
# WHOOPS
# aliases: {'magic', 'the magic 7'}
# question: what is the genre of the magic
# predicted: magic
# correct: magic
#
# Question Distance: 1.0
# Question: What's an album featuring music by ella fitzgerald
# Subject MID: 02lx2r
# Subject Alises: [('album', 'album')]
# Subject Name: album
# Predicted Confidence: [0.9749941107730988, 0.977765011018162, 0.9864322996471675, 0.967608339603163, 0.9376750532532405, 0.8830168507014754, 0.9920100478248248, 0.8751860914493533, 0.6255055041901164]
# Predicted: ella fitzgerald
# strategy: same or bigger
# Num Predicted MIDS: 22
# 1False
# Nan and None: ella fitzgerald False
# WHOOPS
#
# aliases: {'in london', 'london'}
# question: which cooking show has an episode in london
# predicted: london
# correct: london
#
# aliases: {"the best of daniel o'donnel on film", 'the best of x', 'best of', 'the best of…', 'the best off', "daniel o'donnel", 'the best of', 'daniel'}
# question: What kind of music is the film the best of daniel odonnell on film about?
# predicted: best of daniel odonnel on film
# correct: nan
#
# aliases: {'alic b. tokla', 'the autobiographi of alic b. tokla'}
# question: what book type is the autobiography of alice b. toklas
# predicted: alic b. tokla
# correct: the autobiography of alice b. toklas
#
# aliases: {'the saw doctor', 'saw doctor'}
# question: what kind of music does  the saw doctors make
# predicted: saw doctor
# correct: the saw doctors
#
# aliases: {'glenn frey', 'glenni frey', 'album', 'live album', 'glenn frey live', 'frey', 'glenn', 'live'}
# question: what format does the glenn frey live album is played
# predicted: glenn frey live album
# correct: glenn frey live
#
# aliases: {'birmingham', 'birmingham 6'}
# question: Which retired English professional footballer was born in birmingham?
# predicted: birmingham
# correct: birmingham
#
# aliases: {'two women', 'between two women'}
# question: what is about between two women
# predicted: two women
# correct: between two women
#
# aliases: {'crystal castl', 'crystal castl i'}
# question: what type of music is crystal castles classified under
# predicted: crystal castl
# correct: crystal castles
#
# aliases: {'comedi', 'heart', 'coronet', 'kind heart and coronet'}
# question: Name an English film producer of the kind hearts and coronets comedy
# predicted: kind heart and coronet comedi
# correct: kind hearts and coronets
#
# aliases: {'cinderfella', 'in the begin', 'begin', 'the begin', 'cinderella', 'in tha begin', 'cinderella man'}
# question: who was one of the production companies listed in the beginning of cinderella man
# predicted: begin of cinderella man
# correct: cinderella man
#
# aliases: {'pennsylvania', 'pennsylvanian'}
# question: what house is in pennsylvania
# predicted: pennsylvania
# correct: pennsylvania
#
# aliases: {'phillip', 'philip pullman', 'pullman'}
# question: What works written by Phillip Pullman?
# predicted: phillip pullman
# correct: nan
#
# Question: What is a hub for stockholm-arlanda airport?
# Subject MID: 015tns
# Subject Alises: [('stockholm arlanda airport', 'stockholm arlanda airport')]
# Subject Name: nan
# Predicted Confidence: [0.9778700676978828, 0.9575648708115099, 0.853560557219267, 0.6311896952884513, 0.9957127081080768, 0.9799304763706349, 0.9684908354025162, 0.998818000519436]
# Predicted: stockholm-arlanda airport
# strategy: same or bigger
# Num Predicted MIDS: 9
# Nan and None: stockholm-arlanda airport False
# WHOOPS
#
# aliases: {'harri potter and the philosoph stone', 'harri potter and the philosoph stone .'}
# question: what genre is harry potter and the philosophers stone
# predicted: harri potter and the philosoph stone
# correct: harry potter and the philosopher's stone
#
# aliases: {'section', 'hbo'}
# question: What's a title available under the hbo section of netflix
# predicted: hbo section
# correct: hbo
#
# Question: what is doreen denning's gender?
# Subject MID: 0k571hg
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9865561393791884, 0.9984473725247301, 0.9989308028495051, 0.9981465498504706, 0.9988950698299596, 0.9683935822404828, 0.9972923547992575]
# Predicted: doreen den
# strategy: same or bigger
# Num Predicted MIDS: 7
# Nan and None: doreen den False
# WHOOPS
#
# aliases: {'loir', 'the loir'}
# question: what was the loire painted on
# predicted: loir
# correct: the loire
#
# aliases: {'kiwi', 'the kiwi'}
# question: people of the kiwi ethnicity speak what language?
# predicted: kiwi
# correct: kiwi
#
# aliases: {'specul', 'fiction', 'specul fiction'}
# question: what is a book in the speculative fiction gendre
# predicted: specul fiction gendr
# correct: speculative fiction
#
# Question: What type of release did ohio have?
# Subject MID: 02z6y3p
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9818824611700717, 0.954536736983257, 0.9492220570099937, 0.8107863037197813, 0.995444416098261, 0.9997444949154949, 0.9903256134469869, 0.9923919994851739]
# Predicted: ohio
# strategy: same or bigger
# Num Predicted MIDS: 350
# Nan and None: ohio False
# WHOOPS
#
# aliases: {'sound of music', 'the sound of music'}
# question: who composed the music for the sound of music (film)
# predicted: sound of music
# correct: the sound of music
#
# aliases: {'remembr', 'film'}
# question: what is the spoken language of the remembrance film
# predicted: remembr film
# correct: remembrance
#
# aliases: {'arthur b. hancock', 'arthur b. hancock , jr .'}
# question: what was arthur b. hancock, jr.'s cause of death
# predicted: arthur b. hancock
# correct: nan
#
# Question: what is a multiplayer computer video game
# Subject MID: 01z747
# Subject Alises: [('multiplayer video game', 'multiplay video game')]
# Subject Name: nan
# Predicted Confidence: [0.9872490504748348, 0.9742933995609285, 0.9957850245102777, 0.9784022874003817, 0.8094234603515134, 0.7978140444637342, 0.534672216950993]
# Predicted: multiplay comput video game
# strategy: same or bigger
# Num Predicted MIDS: 18
# Nan and None: multiplay comput video game False
# WHOOPS
#
# aliases: {'love stori', 'a love stori'}
# question: Which genre of film is love story?
# predicted: love stori
# correct: love story
#
# aliases: {'the magic citi', 'magic citi'}
# question: what kind of book is the magic city
# predicted: magic citi
# correct: the magic city
#
# aliases: {'the midnight man', 'midnight man'}
# question: who was in charge of music for the midnight man?
# predicted: midnight man
# correct: the midnight man
#
# aliases: {'autobiographi', 'autobiographix'}
# question: what is the title of a book in the  autobiography genre
# predicted: autobiographi
# correct: autobiography
#
# aliases: {'bryan ferri', 'bryan ferrit'}
# question: what track did bryan ferry produce?
# predicted: bryan ferri
# correct: bryan ferry
#
# Question: which formulation is in topical
# Subject MID: 03jy9d
# Subject Alises: [('topical medication', 'topic medic')]
# Subject Name: nan
# Predicted Confidence: [0.9806632211867732, 0.51885864474921, 0.9869144010810214, 0.9778991327074884, 0.9366323266466847]
# Predicted: topic
# strategy: same or bigger
# Num Predicted MIDS: 118
# Nan and None: topic False
# WHOOPS
#
# aliases: {'the thriller', 'thriller'}
# question: What film falls into the thriller (genre)?
# predicted: thriller
# correct: thriller
#
# Question: who is the owner of the evening gazette
# Subject MID: 09k6bj
# Subject Alises: [('teesside gazette', 'teessid gazett')]
# Subject Name: nan
# Predicted Confidence: [0.9674844317909157, 0.95095155719677, 0.8452835019057798, 0.5915682186624014, 0.9629078194409064, 0.9114755445522972, 0.9893782508608264, 0.7255340326190043]
# Predicted: even gazett
# strategy: same or bigger
# Num Predicted MIDS: 11
# Nan and None: even gazett False
# WHOOPS
#
# aliases: {'the express', 'express'}
# question: who produced the film the express
# predicted: express
# correct: the express
#
# aliases: {'roll stone', 'the roll stone', 'the roll stone .', 'a roll stone', 'roll stone .'}
# question: what is an album recorded by the rolling stones
# predicted: roll stone
# correct: the rolling stones
#
# aliases: {'show', 'varieti', 'varieti show', 'german'}
# question: What's a german variety show
# predicted: german varieti show
# correct: variety show
#
# Question Distance: 0.3333333333333333
# Question: what is a tablet used to treat hypertension
# Subject MID: 0kdn9
# Subject Alises: [('buccal tablet', 'buccal tablet'), ('tablet', 'tablet')]
# Subject Name: tablet
# Predicted Confidence: [0.976723567075791, 0.9455872264946983, 0.9305907339866835, 0.8880667169961686, 0.981786571701796, 0.8307462012298011, 0.9569742252742964, 0.9263354453017703]
# Predicted: hypertens
# strategy: same or bigger
# Num Predicted MIDS: 2
# 1False
# Nan and None: hypertens False
# WHOOPS
#
# Question Distance: 0.3
# Question: Name of album by the alternative metal band drowning pool.
# Subject MID: 026f8f
# Subject Alises: [('drowning pool', 'drown pool')]
# Subject Name: drowning pool
# Predicted Confidence: [0.9813667749229383, 0.9722777181987156, 0.8321003619778545, 0.9891602773995837, 0.8164475772131575, 0.8798361318594922, 0.840161203978592, 0.8190147547455126, 0.529605862261612, 0.6645375488114041, 0.9790804438111186]
# Predicted: altern metal
# strategy: same or bigger
# Num Predicted MIDS: 1
# 1False
# Nan and None: altern metal False
# WHOOPS
# aliases: {'counti of the unit state', 'unit state'}
# question: what is the name of a city found in pasco county in the united states
# predicted: unit state
# correct: united states
#
# aliases: {'the perfect crime # 2', 'a perfect crime', 'the perfect crime', 'perfect crime'}
# question: what type of film is the perfect crime
# predicted: perfect crime
# correct: the perfect crime
#
# aliases: {'film product', 'film produc'}
# question: Name a film producer.
# predicted: film produc
# correct: film producer
#
# Question Distance: 0.26666666666666666
# Question: what tract is released by derek sherinian
# Subject MID: 03yxb3
# Subject Alises: [('derek sherinian', 'derek sherinian'), ('derek sherinan', 'derek sherinan')]
# Subject Name: derek sherinian
# Predicted Confidence: [0.9882285547064672, 0.9954248459597338, 0.9865656226034942, 0.7914722163308474, 0.9862921030196323, 0.5756480383180821, 0.8842639270562713]
# Predicted: tract
# strategy: same or bigger
# Num Predicted MIDS: 1
# 1False
# Nan and None: tract False
# WHOOPS
#
# Question Distance: 0.3333333333333333
# Question: what animated cartoon was about ducks?
# Subject MID: 095bb
# Subject Alises: [('animated cartoon', 'anim cartoon')]
# Subject Name: animated cartoon
# Predicted Confidence: [0.9825814680156716, 0.493306501193934, 0.7354274217070739, 0.9447796962293412, 0.9502023356891668, 0.989044102446366, 0.997869305255494]
# Predicted: duck
# strategy: same or bigger
# Num Predicted MIDS: 10
# 1False
# Nan and None: duck False
# WHOOPS
#
# aliases: {'fantasi', 'the fantasi'}
# question: what is a film in the fantasy genre?
# predicted: fantasi
# correct: fantasy
#
# Question: What is a game with single-player mode?
# Subject MID: 02hjn4
# Subject Alises: [('single-player video game', 'single-play video game')]
# Subject Name: nan
# Predicted Confidence: [0.9798712825608358, 0.9659529417543073, 0.9589581865054708, 0.48187565279985517, 0.9967064524704126, 0.9857527168212372, 0.9655024604094142, 0.9988712303813994]
# Predicted: single-play mode
# strategy: same or bigger
# Num Predicted MIDS: 2
# Nan and None: single-play mode False
# WHOOPS
#
# aliases: {'long trail', 'the long trail'}
# question: what's one of the topics in the long trail
# predicted: long trail
# correct: the long trail
#
# aliases: {'kansa citi 6', 'kansa citi 7', 'kansa citi', 'kansa citi 5'}
# question: what is the notable type of kansas city
# predicted: kansa citi
# correct: kansas city
#
# aliases: {'program', 'famili'}
# question: what is a family program
# predicted: famili program
# correct: family
#
# aliases: {'help', 'gulzar'}
# question: what film did gulzar help write
# predicted: gulzar help
# correct: gulzar
#
# Question: What's a song released on intégrale, volume 2: the guitar dont lie
# Subject MID: 03_tf2_
# Subject Alises: [("intégrale, volume 2: the guitar don't lie", "intégral , volum 2 : the guitar do n't lie")]
# Subject Name: nan
# Predicted Confidence: [0.9723365029769572, 0.964549254852195, 0.9583855684602524, 0.5812020666070101, 0.9438267001523688, 0.9762307893734713, 0.9264110614638513, 0.5024070404785007, 0.5640319907079085, 0.5685231666244469, 0.4923373379063538, 0.5556547721227605, 0.5731854877488122, 0.541860521628857, 0.5712351310136302]
# Predicted: intégral , volum 2 : the guitar dont lie
# strategy: same or bigger
# Num Predicted MIDS: 15
# Nan and None: intégral , volum 2 : the guitar dont lie False
# WHOOPS
#
# aliases: {'symphoni no . 47', 'symphoni no . 41', 'symphoni no . 42', 'symphoni no . 44', 'symphoni no . 4', 'symphoni no . 40', 'symphoni no . 48'}
# question: who plays symphony no. 4
# predicted: symphoni no . 4
# correct: symphony no. 4
#
# Question: what record label worked with tormentandtoreros
# Subject MID: 01p81x_
# Subject Alises: [('marc and the mambas', 'marc and the mamba'), ('raoul and the ruined', 'raoul and the ruin')]
# Subject Name: nan
# Predicted Confidence: [0.9832968394455996, 0.8376941772785113, 0.6298956867005289, 0.9270992915038492, 0.98772104096519, 0.996397730476389]
# Predicted: tormentandtorero
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: tormentandtorero False
# WHOOPS
#
# Question: Where was anna pavlova buried after death
# Subject MID: 0r8kzz7
# Subject Alises: [('memnon', 'memnon')]
# Subject Name: nan
# Predicted Confidence: [0.9773168563953712, 0.9981665352671473, 0.9989707801512684, 0.9984014545138329, 0.9994397940429919, 0.9107809515227051, 0.9992041555542825]
# Predicted: anna pavlova
# strategy: same or bigger
# Num Predicted MIDS: 2
# Nan and None: anna pavlova False
# WHOOPS
#
# aliases: {'the doubl', 'doubl'}
# question: What genre of movie is the double?
# predicted: doubl
# correct: the double
#
# aliases: {'venoforc ii', 'venoforc i'}
# question: how is venoforce i dosed
# predicted: venoforc i
# correct: venoforce i
#
# aliases: {'suprem', 'suprem court of canada', 'the court', 'court', 'canada', 'suprem court'}
# question: what is a legal case in the court of supreme court of canada?
# predicted: court of suprem court of canada
# correct: supreme court of canada
#
# Question: what is a single-player mode game?
# Subject MID: 02hjn4
# Subject Alises: [('single-player video game', 'single-play video game')]
# Subject Name: nan
# Predicted Confidence: [0.9835266956630564, 0.9641540522297243, 0.9923194023868073, 0.9755046781028461, 0.8648975585214341, 0.788337265866889, 0.9974118964027404]
# Predicted: single-play mode game
# strategy: same or bigger
# Num Predicted MIDS: 26
# Nan and None: single-play mode game False
# WHOOPS
#
# aliases: {'the method actor', 'method actor'}
# question: which city does the group the method actors come from
# predicted: method actor
# correct: the method actors
#
# aliases: {'the red scream', 'red scream'}
# question: which language was the red scream written in
# predicted: red scream
# correct: the red scream
#
# aliases: {'the knife', 'knife'}
# question: who produced the knife?
# predicted: knife
# correct: the knife
#
# Question: what type of novel is elemental: the power of illuminated love?
# Subject MID: 08vqg8n
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9867889757330403, 0.9754820390935415, 0.9726151745712983, 0.9080971341000995, 0.9975563970054714, 0.9865423516514743, 0.5384732036392771, 0.6707055579553329, 0.7267199965755288, 0.6607234647394544, 0.7755699919019711, 0.9832839593302748, 0.9973618750312216]
# Predicted: element : the power of illumin love
# strategy: same or bigger
# Num Predicted MIDS: 1
# Nan and None: element : the power of illumin love False
# WHOOPS
#
# Empty Predicted
# Question: What is the name of a gay themed film
# Subject MID: 04tkhfk
# Subject Alises: [('gay themed', 'gay theme')]
# Subject Name: gay themed
# Predicted Confidence: [0.97255343972734, 0.9831686397025977, 0.8446684896260137, 0.9516206236510825, 0.9604792253502179, 0.9608077488177668, 0.8768454440200762, 0.7832006139028735, 0.6532998610969618]
# Predicted:
# strategy: same or bigger
# Num Predicted MIDS: 0
# 1False
# Nan and None:  False
# WHOOPS
#
# Question: which court did he kaw teh v r take place in
# Subject MID: 0r4w7s4
# Subject Alises: [('he kaw teh v r (1985) 157 clr 523', 'he kaw teh v r ( 1985 ) 157 clr 523'), ('he kaw teh v the queen', 'he kaw teh v the queen')]
# Subject Name: nan
# Predicted Confidence: [0.9662005525581884, 0.47931897690655323, 0.9332726073632924, 0.9490878045576967, 0.9450940555742978, 0.7853761646429248, 0.6929089496358375, 0.9546487097413351, 0.9972517310928591, 0.9507059248093832, 0.9939518873589824]
# Predicted: kaw teh v r
# strategy: same or bigger
# Num Predicted MIDS: 5
# Nan and None: kaw teh v r False
# WHOOPS
#
# aliases: {'pope clement xi', 'pope clement xii'}
# question: where did pope clement xi die
# predicted: pope clement xi
# correct: pope clement xi
#
# aliases: {'rugbi leagu', 'rugbi leagu 3', 'rugbi leagu 2'}
# question: Who is a player that is in the rugby league
# predicted: rugbi leagu
# correct: rugby league
#
# aliases: {'north carolina', 'north', 'carolina', 'southeast'}
# question: What town on the southeast of north carolina?
# predicted: southeast of north carolina
# correct: north carolina
#
# aliases: {'poodl', 'the poodl'}
# question: what is the miniature version of the poodle
# predicted: poodl
# correct: poodle
#
# aliases: {'the wild child', 'wild child'}
# question: who wrote the screenplay for the wild child
# predicted: wild child
# correct: the wild child
#
# aliases: {'bulletproof', 'bulletproof !'}
# question: what is a track off the bulletproof album
# predicted: bulletproof
# correct: bulletproof
# aliases: {'ak soundtrack', 'soundtrack album', 'π soundtrack', 'soundtrack', '3 soundtrack', 'x soundtrack'}
# question: whats an example of a soundtrack album
# predicted: soundtrack
# correct: soundtrack
#
# Question Distance: 0.2
# Question: What's a soundtrack written by anthony marinelli
# Subject MID: 0l14gg
# Subject Alises: [('soundtrack', 'soundtrack')]
# Subject Name: soundtrack
# Predicted Confidence: [0.9788438190603553, 0.9718340869309384, 0.9614877589425324, 0.5605627945112349, 0.9677317537600492, 0.9920197287715544, 0.9611139107000497, 0.7176164506148925]
# Predicted: anthoni marinelli
# strategy: same or bigger
# Num Predicted MIDS: 2
# 1False
# Nan and None: anthoni marinelli False
# WHOOPS
#
# aliases: {'women badminton , singl', 'men badminton , singl'}
# question: what olympic games was mens badminton, singles apart of
# predicted: men badminton , singl
# correct: men's badminton, singles
#
# aliases: {'an artist against the third reich', 'against the third reich'}
# question: what's one of the topics discussed in an artist against the third reich
# predicted: against the third reich
# correct: an artist against the third reich
#
# aliases: {'zero hour', 'zero hour !'}
# question: what series is zero hour from?
# predicted: zero hour
# correct: zero hour
#
# aliases: {'kraftwerk 2', 'kraftwerk 1', 'kraftwerk'}
# question: What genre does kraftwerk perform?
# predicted: kraftwerk
# correct: kraftwerk
#
# Empty Predicted
# Question: what experimental musical group is known for its indie rock music
# Subject MID: 01243b
# Subject Alises: [('kimberly dawn', 'kimber dawn'), ('indie rock', 'indi rock'), ('kimberly fardad', 'kimber fardad')]
# Subject Name: indie rock
# Predicted Confidence: [0.9903604361363155, 0.7807416018716932, 0.5932886169204993, 0.9307634288686443, 0.9570902669581405, 0.9628816937393896, 0.9648524046978972, 0.9519742177523872, 0.8064848489538528, 0.9372164172588534, 0.9464574870169609]
# Predicted:
# strategy: same or bigger
# Num Predicted MIDS: 0
# 1False
# Nan and None:  False
# WHOOPS
#
# aliases: {'hitcher', 'the hitcher'}
# question: Which country was the film the hitcher from
# predicted: hitcher
# correct: the hitcher
#
# Question Distance: 0.23076923076923078
# Question: which fantasy series were written by mercedes lackey?
# Subject MID: 0d5v_
# Subject Alises: [('lackey, mercedes', 'lackey , merced'), ('mercedes ritchie lackey', 'merced ritchi lackey'), ('misty lackey', 'misti lackey'), ('mercedes r. lackey', 'merced r. lackey'), ('mercedes lackey', 'merced lackey')]
# Subject Name: mercedes lackey
# Predicted Confidence: [0.9950851188276173, 0.994868438311101, 0.9673817696550251, 0.8908518075049565, 0.9175480428211786, 0.9822441513805983, 0.5616726622566687, 0.6429120600448475, 0.9969551598240549]
# Predicted: fantasi
# strategy: same or bigger
# Num Predicted MIDS: 1619
# 1False
# Nan and None: fantasi False
# WHOOPS
#
# aliases: {'poison', 'the poison'}
# question: Who wrote the poisoners
# predicted: poison
# correct: the poisoners
#
# aliases: {'the articl of confeder', 'articl of confeder'}
# question: What is the subject of the articles of confederation?
# predicted: articl of confeder
# correct: the articles of confederation
#
# Question: which country is cowichan lake in
# Subject MID: 05t592
# Subject Alises: [('lake cowichan', 'lake cowichan'), ('lake cowichan, canada', 'lake cowichan , canada'), ('lake cowichan, british columbia', 'lake cowichan , british columbia')]
# Subject Name: nan
# Predicted Confidence: [0.9913000183558507, 0.9538322199733603, 0.9976413392708126, 0.9969374422339828, 0.9887986281829936, 0.9994970099849726]
# Predicted: cowichan lake
# strategy: same or bigger
# Num Predicted MIDS: 25
# Nan and None: cowichan lake False
# WHOOPS
#
# Question: What is a game with the gameplay mode single-player?
# Subject MID: 02hjn4
# Subject Alises: [('single-player video game', 'single-play video game')]
# Subject Name: nan
# Predicted Confidence: [0.9829113987372513, 0.9724666841021317, 0.9601881558722218, 0.6374913849963006, 0.9836839202783779, 0.9406395892210306, 0.5922512145972445, 0.9742099553339312, 0.9990829600486906, 0.9977520544020916]
# Predicted: single-play
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: single-play False
# WHOOPS
#
# Question Distance: 0.2727272727272727
# Question: what is a national park in Wyoming
# Subject MID: 05gz5
# Subject Alises: [('ii: national park', 'ii : nation park'), ('national park', 'nation park')]
# Subject Name: national park
# Predicted Confidence: [0.9807606176025866, 0.923406461587931, 0.9401971145872964, 0.7688650265097448, 0.7467909592569834, 0.99190219187369, 0.8322258506398268]
# Predicted: wyom
# strategy: same or bigger
# Num Predicted MIDS: 98
# 1False
# Nan and None: wyom False
# WHOOPS
#
# aliases: {'look', 'the look'}
# question: Who made the album the looks?
# predicted: look
# correct: the looks
#
# aliases: {'bay citi roller', 'the bay citi roller'}
# question: which albums were released by the bay city rollers?
# predicted: bay citi roller
# correct: the bay city rollers
#
# aliases: {'santa claus is come to town', 'santa claus is come to town ...'}
# question: which artist recorded a version of santa claus is coming to town
# predicted: santa claus is come to town
# correct: santa claus is coming to town
#
# aliases: {'jeev', 'by jeev'}
# question: who is a character in the play by jeeves
# predicted: jeev
# correct: by jeeves
#
# Question: which region contains asti docg
# Subject MID: 045p9_r
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9885242813427358, 0.9001002520305751, 0.9975356148047614, 0.9932686630778478, 0.8932300763766616]
# Predicted: asti docg
# strategy: same or bigger
# Num Predicted MIDS: 3
# Nan and None: asti docg False
# WHOOPS
#
# Question: what is can you tell me how to get to sesame street? the theme song for
# Subject MID: 03czw5g
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.7692915413597551, 0.9951574245103753, 0.9190567102894903, 0.49731568684004945, 0.468450585640334, 0.49594760712003366, 0.606972314778981, 0.6623259642086489, 0.5270129838239997, 0.7269171863486898, 0.6349278514455933, 0.923210473840347, 0.7003430504506114, 0.7106931369878661, 0.5344855271500988, 0.6047680131831761, 0.9405063641100736]
# Predicted: sesam street
# strategy: same or bigger
# Num Predicted MIDS: 6
# Nan and None: sesam street False
# WHOOPS
#
# aliases: {'california', 'california x'}
# question: Name a location in california
# predicted: california
# correct: california
#
# aliases: {"rogers-o'daniel hous", 'hous'}
# question: what county is rogers-odaniel house apart of
# predicted: rogers-odaniel hous
# correct: nan
#
# aliases: {'d train', 'the d train'}
# question: what sort of movie is the d train
# predicted: d train
# correct: the d train
#
# Question: What is jackrosekensington gender?
# Subject MID: 01q65fc
# Subject Alises: [('jack rose', 'jack rose'), ('rose, jack', 'rose , jack')]
# Subject Name: nan
# Predicted Confidence: [0.9815307905782671, 0.9971856466786287, 0.9998879263183336, 0.9450250541020498, 0.9920025269597498]
# Predicted: jackrosekensington
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: jackrosekensington False
# WHOOPS
#
# Empty Predicted
# Question: What's a sports game made by midway games
# Subject MID: 022dc6
# Subject Alises: [('sports game', 'sport game')]
# Subject Name: sports game
# Predicted Confidence: [0.9777803330568837, 0.9429542451661075, 0.9804286895100668, 0.8514414440827967, 0.7225771921215308, 0.9665300165838031, 0.9826041577461588, 0.8592949455093222, 0.6619279044032028]
# Predicted:
# strategy: same or bigger
# Num Predicted MIDS: 0
# 1False
# Nan and None:  False
# WHOOPS
#
# aliases: {'o.k . ken', 'o.k . ken ?'}
# question: what kind of music is on the album o.k. ken?
# predicted: o.k . ken
# correct: o.k. ken?
#
# aliases: {'ned randolph', 'ed randolph'}
# question: Which city in Illinois was ed randolph born in?
# predicted: ed randolph
# correct: ed randolph
#
# aliases: {'sometim i wish we were an eagl', 'sometim i'}
# question: which two genres does sometimes i wish we were an eagle blend together
# predicted: sometim i wish we were an eagl blend togeth
# correct: sometimes i wish we were an eagle
#
# aliases: {'pink panther 2', 'pink panther', 'the pink panther 2', 'the pink panther'}
# question: Who wrote the film the pink panther?
# predicted: pink panther
# correct: the pink panther
#
# Question: which language was red satin recorded in?
# Subject MID: 04j2m25
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9891377684237527, 0.937338862874257, 0.9982823080456, 0.9888121563311739, 0.9961881179307533, 0.998424877151287, 0.9673309578689006, 0.9987321350427177]
# Predicted: red satin
# strategy: same or bigger
# Num Predicted MIDS: 1465
# Nan and None: red satin False
# WHOOPS
#
# aliases: {'ulster counti , new york', 'ulster counti'}
# question: what is a city in ulster county, new york
# predicted: ulster counti
# correct: ulster county, new york
#
# aliases: {'the great train robberi', 'great train robberi'}
# question: the great train robbery is by who
# predicted: great train robberi
# correct: the great train robbery
#
# aliases: {'manag', 'window manag', 'pwm', 'window'}
# question: what is the software for pwm (window manager)
# predicted: pwm ( window manag )
# correct: pwm
#
# aliases: {'futur sound of london', 'the futur sound of london'}
# question: what tracks did the future sound of london produce
# predicted: futur sound of london
# correct: the future sounds of london
#
# Question: what state is featured in seven days in may?
# Subject MID: 0bvrjh4
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9736946767187187, 0.8113613971506675, 0.9655220854661938, 0.8993999337456946, 0.9961306218569945, 0.9787262095673309, 0.7198710660485454, 0.506660087048445, 0.9483522801938989, 0.9960427982435653]
# Predicted: seven day in may
# strategy: same or bigger
# Num Predicted MIDS: 88
# Nan and None: seven day in may False
# WHOOPS
#
# aliases: {'he purpl heart', 'the purpl heart', 'purpl heart'}
# question: Who directed the film  the purple heart
# predicted: purpl heart
# correct: the purple heart
# aliases: {'cross', 'the cross'}
# question: what is the language of the crossing?
# predicted: cross
# correct: the crossing
#
# aliases: {'the jungl book 2', 'jungl book', 'the jungl book'}
# question: what's a song on the album the jungle book
# predicted: jungl book
# correct: the jungle book
#
# aliases: {'bollywood', 'bollywood movi'}
# question: whats the title of a bollywood movie
# predicted: bollywood
# correct: bollywood
#
# Question Distance: 1.0
# Question: What is a compilation album from 2006
# Subject MID: 02lx2r
# Subject Alises: [('album', 'album')]
# Subject Name: album
# Predicted Confidence: [0.9883143061123084, 0.9769069337493334, 0.9952884176124034, 0.927202256111374, 0.974571267809309, 0.9985052701545284, 0.9171188075818063]
# Predicted: compil album
# strategy: same or bigger
# Num Predicted MIDS: 1
# 1True
# Nan and None: compil album False
# WHOOPS
#
# aliases: {'of mice and men .', 'of mice and men'}
# question: what is the soundtrack for of mice and men called
# predicted: of mice and men
# correct: of mice and men
#
# aliases: {'gold collect', 'gold collect v', 'the gold collect'}
# question: what is the track list from the release the gold collection?
# predicted: gold collect
# correct: the gold collection
#
# aliases: {'the outsid', 'outsid'}
# question: What type of album is the outsider?
# predicted: outsid
# correct: the outsider
#
# aliases: {'locat of itauguá', 'galleri', 'the galleri', 'locat', 'in the galleri', 'the galleria'}
# question: What place appears in the gallery of location of itauguá
# predicted: galleri of locat of itauguá
# correct: location of itauguá
#
# aliases: {'mountain of the cannib god', 'the mountain of the cannib god'}
# question: What kind of film is the mountain of the cannibal god?
# predicted: mountain of the cannib god
# correct: the mountain of the cannibal god
#
# Question: what game requires single-player
# Subject MID: 02hjn4
# Subject Alises: [('single-player video game', 'single-play video game')]
# Subject Name: nan
# Predicted Confidence: [0.9842317945457001, 0.885585220285827, 0.9956832035971148, 0.9983644780625609]
# Predicted: single-play
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: single-play False
# WHOOPS
#
# aliases: {'legal it', 'legal'}
# question: What composer wrote legalize it?
# predicted: legal
# correct: legalize it
#
# aliases: {'club', 'the book club'}
# question: what film genre is the book club?
# predicted: club
# correct: the book club
#
# aliases: {'itali', 'in itali'}
# question: what is a place located in italy
# predicted: itali
# correct: italy
#
# aliases: {'person recollect of joan of arc', 'person recollect of joan of arc , v2'}
# question: who authored personal recollections of joan of arc?
# predicted: person recollect of joan of arc
# correct: personal recollections of joan of arc
#
# Empty Predicted
# Question: What's an album by the band portal
# Subject MID: 02lx2r
# Subject Alises: [('album', 'album')]
# Subject Name: album
# Predicted Confidence: [0.9788706317883704, 0.9736744315410645, 0.962791186323413, 0.8861275933993951, 0.9938482207993198, 0.5804584130258985, 0.5894818160732451, 0.7142214156626219]
# Predicted:
# strategy: same or bigger
# Num Predicted MIDS: 0
# 1False
# Nan and None:  False
# WHOOPS
#
# aliases: {'dixi chick', 'the dixi chick'}
# ...
# Predicted:
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None:  True
# WHOOPS
#
# aliases: {'mordialloc', 'mordialloc secondari colleg', 'institut', 'educ institut'}
# question: what color is the educational institution mordialloc secondary college
# predicted: educ institut mordialloc secondari colleg
# correct: mordialloc secondary college
#
# aliases: {'bone walker', 't bone walker'}
# question: What type of literary genre is bone walker?
# predicted: bone walker
# correct: bone walker
#
# aliases: {'pound', 'egyptian', 'egyptian pound', 'currenc'}
# question: what country uses egyptian pound as currency
# predicted: egyptian pound as currenc
# correct: egyptian pound
#
# Question: who published the computer game lego star wars ii
# Subject MID: 0bdzrd
# Subject Alises: [('lego star wars ii: die klassische trilogie', 'lego star war ii : die klassisch trilogi'), ('lego star wars ii: the original trilogy', 'lego star war ii : the origin trilog'), ('lego star wars ii: la trilogie originale', 'lego star war ii : la trilogi original')]
# Subject Name: nan
# Predicted Confidence: [0.9787116746017176, 0.9815173181726947, 0.6407043261229967, 0.709557833237431, 0.9800549577928999, 0.9291892103907119, 0.7517177805474748, 0.7428431605916108, 0.8237433960342672]
# Predicted: lego star war ii
# strategy: same or bigger
# Num Predicted MIDS: 1803
# Nan and None: lego star war ii False
# WHOOPS
#
# Empty Predicted
# Question: where is the movie originally from
# Subject MID: 0gksxg8
# Subject Alises: [('watch this woman', 'watch this woman')]
# Subject Name: nan
# Predicted Confidence: [0.5270547708248191, 0.9983145094972646, 0.8763518648406572, 0.6015282992876289, 0.9046618043971879, 0.9988292380134557]
# Predicted:
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None:  True
# WHOOPS
#
# aliases: {'st vincent colleg inc', 'st vincent colleg'}
# question: st vincent college is a notable what?
# predicted: st vincent colleg
# correct: st vincent college
#
# aliases: {'the campaign', 'cheer', 'campaign', 'the cheer truck', 'truck'}
# question: who is the advertiser for the campaign the cheering truck?
# predicted: campaign the cheer truck
# correct: the cheering truck
#
# aliases: {'the world', 'against', 'play : us against the world', 'us against the world', 'against the world'}
# question: which country was play: us against the world made and distributed in
# predicted: play : us against the world made and
# correct: play: us against the world
#
# aliases: {'sport', 'sport car'}
# question: What's an example of a sports car
# predicted: sport
# correct: sports car
#
# aliases: {'a resurrect', 'resurrect'}
# question: Who did the music for the film resurrection?
# predicted: resurrect
# correct: resurrection
#
# aliases: {'ani difranco +', 'ani difranco'}
# question: Which piece did ani difranco compose?
# predicted: ani difranco
# correct: ani difranco
#
# aliases: {'languag', 'his brother', 'arem languag', 'are languag', 'brother in arm', 'ari languag', 'brother'}
# question: What is brothers in arms' language filmed in?
# predicted: brother in arm languag
# correct: brothers in arms
#
# aliases: {'the boy friend', 'boy friend'}
# question: What kind of motion picture is the boy friend
# predicted: boy friend
# correct: the boy friend
#
# aliases: {'santa claus is come to town', 'santa claus is come to town ...'}
# question: which song is part of santa claus is coming to town
# predicted: santa claus is come to town
# correct: santa claus is coming to town
#
# aliases: {'rememb me', 'i rememb me', 'rememb me 3', 'rememb me ?'}
# question: what album is remember me from
# predicted: rememb me
# correct: remember me
#
# Question: what kind of institution is the dhi water.environment.health
# Subject MID: 04cvbv2
# Subject Alises: [('dhi water & environment', 'dhi water & environ')]
# Subject Name: nan
# Predicted Confidence: [0.9691543593660019, 0.8857977793692018, 0.9129249146969144, 0.7330262129856937, 0.8886809361311442, 0.9392102247511755, 0.9834944408250331, 0.8169961405785542]
# Predicted: dhi water.environment.health
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: dhi water.environment.health False
# WHOOPS
#
# aliases: {'question of time', 'a question of time'}
# question: What language is used in the composition a question of time
# predicted: question of time
# correct: a question of time
#
# aliases: {'total recal', 'total recal 2'}
# question: which country released total recall
# predicted: total recal
# correct: total recall
#
# Question Distance: 0.25
# Question: which lgbt films were directed by jim hubbard?
# Subject MID: 0hn10
# Subject Alises: [('lgbt', 'lgbt')]
# Subject Name: lgbt
# Predicted Confidence: [0.9873555929691167, 0.926706788234717, 0.9014636917978549, 0.935516392494928, 0.9105106303273305, 0.9934615188437174, 0.9129354138711163, 0.9140084637433443, 0.9987157671068415]
# Predicted: jim hubbard
# strategy: same or bigger
# Num Predicted MIDS: 1
# 1False
# Nan and None: jim hubbard False
# WHOOPS
#
# Question: What's a novel that wilhelmina grubbly-plank appears in
# Subject MID: 0hh8jh6
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.97990704184552, 0.9565015100836917, 0.9109555282701414, 0.7152185288658531, 0.9964207672646342, 0.9498554192911189, 0.9407473156208979, 0.9919535973827315, 0.9920788634652214]
# Predicted: wilhelmina grubbly-plank
# strategy: same or bigger
# Num Predicted MIDS: 2
# Nan and None: wilhelmina grubbly-plank False
# WHOOPS
#
# aliases: {'shade', 'in shade'}
# question: whose music is in shade?
# predicted: shade
# correct: shade
#
# aliases: {'onlin', 'associ', 'onlin news associ', 'news'}
# question: what is online news associations sector
# predicted: onlin news associ sector
# correct: online news association
#
# aliases: {'bartend charact in atlas shrug', 'atlas shrug'}
# question: who created the bartender character in atlas shrugged
# predicted: atlas shrug
# correct: bartender character in atlas shrugged
#
# aliases: {'surco saramago', 'philosoph', 'surco', 'saramago'}
# question: What is an interest of philosopher surco saramago?
# predicted: philosoph surco saramago
# correct: surco saramago
#
# aliases: {'the mysteri island', 'mysteri island'}
# question: What genre of book is the mysterious island?
# predicted: mysteri island
# correct: the mysterious island
#
# aliases: {'plain', 'in plain sight', 'lie in plain sight', 'sight'}
# question: Who designed the costumes for the fil lies in plain sight
# predicted: fil lie in plain sight
# correct: lies in plain sight
#
# aliases: {'cinematograph', 'cinematographi'}
# question: Name a cinematographer
# predicted: cinematograph
# correct: cinematographer
#
# aliases: {'boogeyman', 'boogeyman 3', 'boogeyman 2', 'the boogeyman'}
# question: What nation made the boogeyman
# predicted: boogeyman
# correct: the boogeyman
#
# aliases: {'superstar 4', 'superstar'}
# question: Name a track off the musical release superstar.
# predicted: superstar
# correct: superstar
#
# Question: what type of music does arsen shomakhov play?
# Subject MID: 04662kd
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9868770245708774, 0.9776306884137801, 0.978358478181689, 0.926621336802898, 0.9972774861172146, 0.9925236343599247, 0.992632779675806, 0.9947309365900939, 0.9932758007628083]
# Predicted: arsen shomakhov
# strategy: same or bigger
# Num Predicted MIDS: 0
# Nan and None: arsen shomakhov False
# WHOOPS
#
# aliases: {'the bibl', 'bibl'}
# question: What is a book about the bible?
# predicted: bibl
# correct: the bible
#
# aliases: {'militari offic', 'militari offici'}
# question: What is military officer a notable archetype of
# predicted: militari offic
# correct: military officer
#
# aliases: {'theft', 'a theft'}
# question: what type of book is a theft?
# predicted: theft
# correct: a theft
#
# aliases: {'the ace of heart', 'ace of heart'}
# question: what type of movie is the ace of hearts
# predicted: ace of heart
# correct: the ace of hearts
#
# aliases: {'placenta previa', 'diseas', 'placenta', 'placenta praevia'}
# question: what are the risk factors of disease placenta praevia?
# predicted: diseas placenta praevia
# correct: placenta praevia
#
# aliases: {'reviv in belfast 2', 'reviv in belfast'}
# question: what kind of music is revival in belfast classified under
# predicted: reviv in belfast
# correct: revival in belfast
#
# aliases: {'the vine', 'vine'}
# question: what label is the vines with?
# predicted: vine
# correct: the vines
#
# aliases: {'star', 'star song'}
# question: what is star song of
# predicted: star
# correct: star
#
# aliases: {'mine', 'the mine'}
# question: what is a company within the mining industry?
# predicted: mine
# correct: mining
#
# aliases: {'バブルガムクライシス 6 : red eye', 'π soundtrack', 'red eye', 'soundtrack', '3 soundtrack', 'x soundtrack'}
# question: What tv program utilized the バブルガムクライシス 6: red eyes soundtrack
# predicted: バブルガムクライシス 6 : red eye soundtrack
# correct: バブルガムクライシス 6: red eyes
#
# aliases: {'piranha 3dd', 'dd', 'piranha'}
# question: what company produced piranha dd
# predicted: piranha dd
# correct: nan
#
# Question: what type of film is to kill a cop?
# Subject MID: 0fx3ws8
# Subject Alises: []
# Subject Name: nan
# Predicted Confidence: [0.9888182685148386, 0.980726261915005, 0.9805587340913393, 0.9597292476255455, 0.9967553984107649, 0.9393813378683676, 0.8485876733505542, 0.5625566490520135, 0.9904498739090922, 0.9921178920060776]
# Predicted: to kill a cop
# strategy: same or bigger
# Num Predicted MIDS: 23
# Nan and None: to kill a cop False
# WHOOPS
#
# aliases: {'the flower girl', 'flower girl'}
# question: what genre is the film the flower girl
# predicted: flower girl
# correct: the flower girl
#
# Question: What type of release was police officer by Smiley Culture?
# Subject MID: 0gt5zf
# Subject Alises: [('the wearing of the grin', 'the wear of the grin')]
# Subject Name: nan
# Predicted Confidence: [0.9875245130176897, 0.9752394448878228, 0.973527215331354, 0.9076322071404774, 0.9972588508841098, 0.9596978323849854, 0.7007595649176382, 0.8078219522918051, 0.6852881932326662, 0.9054599456194599, 0.9978914512799939]
# Predicted: polic offic by smiley cultur
# strategy: same or bigger
# Num Predicted MIDS: 601
# Nan and None: polic offic by smiley cultur False
# WHOOPS
#
# aliases: {'the art of love', 'art of love'}
# question: In what format was the art of love released?
# predicted: art of love
# correct: the art of love
#
# aliases: {'the hacienda', 'classic', 'hacienda', 'the haçienda classic'}
# question: Where was the hacienda classics released?
# predicted: hacienda classic
# correct: nan
#
# aliases: {'the matrix revolut', 'matrix revolut'}
# question: Who was the film art director for the film the matrix revolutions?
# predicted: matrix revolut
# correct: the matrix revolutions
#
# Question Distance: 0.30434782608695654
# Question: What is a compilation album by creedence clearwater revival
# Subject MID: 012lfr
# Subject Alises: [('credence clearwater revival', 'credenc clearwat reviv'), ('creedence', 'creedenc'), ('クリーデンス・クリアウォーター・リヴァイヴァル', 'クリーデンス・クリアウォーター・リヴァイヴァル'), ('creedence clearwater revial', 'creedenc clearwat revial'), ('c.c.r.', 'c.c.r .'), ('creedance clearwater revival', 'creedanc clearwat reviv'), ('creedence clearwater revival', 'creedenc clearwat reviv'), ('creedence clearwater rivival', 'creedenc clearwat riviv'), ('creedence clearwater revisited', 'creedenc clearwat revisit'), ('ccr', 'ccr'), ('creedence clear water revival', 'creedenc clear water reviv')]
# Subject Name: creedence clearwater revival
# Predicted Confidence: [0.9891813013056164, 0.9763324598375801, 0.9921690653974192, 0.8795551217212254, 0.9115150119334254, 0.9964419163737491, 0.7435483064303872, 0.48921938732220854, 0.7675865140845559]
# Predicted: compil album
# strategy: same or bigger
# Num Predicted MIDS: 1
# 1False
# Nan and None: compil album False
# WHOOPS
#
# aliases: {'very best of', 'the very best of…', 'the very best of'}
# question: who released the music album called the very best of
# predicted: very best of
# correct: the very best of
#
# aliases: {'concert', 'the art in heaven concert', 'in heaven', 'the art'}
# question: what country is associated withe the art in heaven concert
# predicted: associ with the art in heaven concert
# correct: the art in heaven concert
#
# aliases: {'general hospit', 'general hospit 2'}
# question: Name a general hospital.
# predicted: general hospit
# correct: general hospital
#
# aliases: {'pianist', 'the pianist'}
# question: what kind of film is the pianist (2002 film)
# predicted: pianist
# correct: the pianist
#
# aliases: {'commune of luxembourg', 'luxembourg'}
# question: which country is the commune of luxembourg in
# predicted: luxembourg
# correct: commune of luxembourg
#
# Question Distance: 0.42857142857142855
# Question: which airport does the airline air one services?
# Subject MID: 058b8z
# Subject Alises: [('air one', 'air one'), ('aliadriatica', 'aliadriatica')]
# Subject Name: air one
# Predicted Confidence: [0.9542242479168778, 0.8847077058093475, 0.9793082562301811, 0.8742522165093961, 0.9816820057198359, 0.6793583164742075, 0.5347352010202212, 0.5198639354539454, 0.9933198236421789]
# Predicted: airlin
# strategy: same or bigger
# Num Predicted MIDS: 8
# 1False
# Nan and None: airlin False
# WHOOPS
#
#
# Accuracy: 0.965698 [10473 of 10845]
# Average N Aliases: 1.179991 [12797 of 10845]
# Expected Linking Accuracy: 0.626086
#    subject                      relation   object  \
# 0   0f3xg_  symbols/namesake/named_after   0cqt90
# 1   07f3jg  people/person/place_of_birth    0565d
# 2  031j8nn          music/release/region    07ssc
# 3  0c1cyhd            film/director/film  0wxsz5y
# 4  0fvhc0g          music/release/region    0345h
#
#                                             question  \
# 0  Who was the trump ocean club international hot...
# 1                       where was sasha vujačić born
# 2   What is a region that dead combo was released in
# 3  What is a film directed by wiebke von carolsfeld?
# 4  what country was music for stock exchange  rel...
#
#                                      subject_name  subject_name_start_index  \
# 0  trump ocean club international hotel and tower                       3.0
# 1                                   sasha vujačić                       2.0
# 2                                      dead combo                       5.0
# 3                           wiebke von carolsfeld                       6.0
# 4                        music for stock exchange                       3.0
#
#    subject_name_stop_index                          predicted_subject_name  \
# 0                     10.0  trump ocean club international hotel and tower
# 1                      4.0                                   sasha vujačić
# 2                      7.0                                      dead combo
# 3                      9.0                           wiebke von carolsfeld
# 4                      7.0                        music for stock exchange
#
#                                   predicted_question  \
# 0              Who was the #head_entity# named after
# 1                       where was #head_entity# born
# 2  What is a region that #head_entity# was releas...
# 3         What is a film directed by #head_entity# ?
# 4         what country was #head_entity# released in
#
#                                       tag_confidence  \
# 0  [0.9293023252209918, 0.8612211722891993, 0.967...
# 1  [0.9826483932316815, 0.9986743224610085, 0.999...
# 2  [0.9650627174054079, 0.9847821153288865, 0.603...
# 3  [0.9833911283844019, 0.9653590589910868, 0.958...
# 4  [0.963210482176025, 0.8503666558303614, 0.9947...
#
#    predicted_subject_name_start_index  predicted_subject_name_stop_index  \
# 0                                   3                                 10
# 1                                   2                                  4
# 2                                   5                                  7
# 3                                   6                                  9
# 4                                   3                                  7
#
#       predicted_mids
# 0           [0f3xg_]
# 1           [07f3jg]
# 2  [0gql46, 031j8nn]
# 3          [0c1cyhd]
# 4          [0fvhc0g]

# %%
from tqdm import tqdm_notebook
from numpy import nan
import pandas as pd
from collections import defaultdict

correct_object = 0
correct_relation = 0
correct_subject = 0
predicted_facts_column = []
for index, row in tqdm_notebook(df_dev.iterrows(), total=df_dev.shape[0]):
    cursor.execute('SELECT object_mid, relation, subject_mid FROM fb_two_kg WHERE subject_mid = ANY(%s)', (list(row['predicted_mids']), ))
    rows = cursor.fetchall()
    predicted_facts = defaultdict(lambda: defaultdict(set))
    
    for object_mid, relation, subject_mid in rows:
        predicted_facts[relation][subject_mid].add(object_mid)        
        
    predicted_facts_column.append(predicted_facts)
    
    predicted_object_mids = set([fact[0] for fact in rows])
    if row['object'] in predicted_object_mids:
        correct_object += 1    
        
    predicted_relations = set([fact[1] for fact in rows])
    if row['relation'] in predicted_relations:
        correct_relation += 1
        
    predicted_subject_mids = set([fact[2] for fact in rows])
    if row['subject'] in predicted_subject_mids:
        correct_subject += 1

df_dev['predicted_facts'] = pd.Series(predicted_facts_column, index=df_dev.index)
print('End-to-end Object Canditate Accuracy So Far:', correct_object / df_dev.shape[0])
print('End-to-end Relation Canditate Accuracy So Far:', correct_relation / df_dev.shape[0])
print('End-to-end Subject Canditate Accuracy So Far:', correct_subject / df_dev.shape[0])
df_dev[:5]
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# End-to-end Object Canditate Accuracy So Far: 0.9746426924850161
# End-to-end Relation Canditate Accuracy So Far: 0.9763024435223605
# End-to-end Subject Canditate Accuracy So Far: 0.9656984785615491
#    subject                      relation   object  \
# 0   0f3xg_  symbols/namesake/named_after   0cqt90
# 1   07f3jg  people/person/place_of_birth    0565d
# 2  031j8nn          music/release/region    07ssc
# 3  0c1cyhd            film/director/film  0wxsz5y
# 4  0fvhc0g          music/release/region    0345h
#
#                                             question  \
# 0  Who was the trump ocean club international hot...
# 1                       where was sasha vujačić born
# 2   What is a region that dead combo was released in
# 3  What is a film directed by wiebke von carolsfeld?
# 4  what country was music for stock exchange  rel...
#
#                                      subject_name  subject_name_start_index  \
# 0  trump ocean club international hotel and tower                       3.0
# 1                                   sasha vujačić                       2.0
# 2                                      dead combo                       5.0
# 3                           wiebke von carolsfeld                       6.0
# 4                        music for stock exchange                       3.0
#
#    subject_name_stop_index                          predicted_subject_name  \
# 0                     10.0  trump ocean club international hotel and tower
# 1                      4.0                                   sasha vujačić
# 2                      7.0                                      dead combo
# 3                      9.0                           wiebke von carolsfeld
# 4                      7.0                        music for stock exchange
#
#                                   predicted_question  \
# 0              Who was the #head_entity# named after
# 1                       where was #head_entity# born
# 2  What is a region that #head_entity# was releas...
# 3         What is a film directed by #head_entity# ?
# 4         what country was #head_entity# released in
#
#                                       tag_confidence  \
# 0  [0.9293023252209918, 0.8612211722891993, 0.967...
# 1  [0.9826483932316815, 0.9986743224610085, 0.999...
# 2  [0.9650627174054079, 0.9847821153288865, 0.603...
# 3  [0.9833911283844019, 0.9653590589910868, 0.958...
# 4  [0.963210482176025, 0.8503666558303614, 0.9947...
#
#    predicted_subject_name_start_index  predicted_subject_name_stop_index  \
# 0                                   3                                 10
# 1                                   2                                  4
# 2                                   5                                  7
# 3                                   6                                  9
# 4                                   3                                  7
#
#       predicted_mids                                    predicted_facts
# 0           [0f3xg_]  {'location/location/containedby': {'0f3xg_': {...
# 1           [07f3jg]  {'sports/professional_sports_team/draft_picks'...
# 2  [0gql46, 031j8nn]  {'music/release/region': {'031j8nn': {'07ssc'}...
# 3          [0c1cyhd]  {'people/person/gender': {'0c1cyhd': {'02zsn'}...
# 4          [0fvhc0g]  {'music/release/track_list': {'0fvhc0g': {'0mr...

# %% [markdown]
# # Relation Model Yu et Al.

# %%
import re
import torch
from torch.autograd import Variable

RELATION_CLASSIFIER = '../../logs/2785.01-01_17:32:06.yu_relation_model/01m_01d_17h_54m_53s.pt'

import pprint

from nltk.tokenize.treebank import TreebankWordTokenizer

from lib.checkpoint import Checkpoint

pretty_printer = pprint.PrettyPrinter(indent=2)
tokenizer = TreebankWordTokenizer() # Same tokenizer used during training

relation_classifier = Checkpoint(checkpoint_path=RELATION_CLASSIFIER, device=0)
relation_classifier.model.relation_word_rnn.flatten_parameters()
relation_classifier.model.relation_rnn.flatten_parameters()
relation_classifier.model.text_rnn.flatten_parameters()
relation_classifier.model.train(mode=False)

cuda = lambda v: v.cuda() if torch.cuda.is_available() else t
to_variable = lambda e: cuda(Variable(torch.LongTensor(e).unsqueeze(1).contiguous()))
    
def get_relation_score(question, relation):
    question = question.lower()
    question_encoded = relation_classifier.text_encoder.encode(question)
    relation_encoded = relation_classifier.relation_encoder.encode(relation)
    relation_word_encoded = relation_classifier.relation_word_encoder.encode(relation)

    question_encoded = to_variable(question_encoded)
    relation_encoded = to_variable(relation_encoded)
    relation_word_encoded = to_variable(relation_word_encoded)

    return relation_classifier.model(question_encoded, relation_encoded, relation_word_encoded).data[0]

# To test this cell
print(get_relation_score('where was #head_entity# born ?', '/people/person/place_of_birth'))
print(get_relation_score('where was #head_entity# born ?', '/location/location/people_born_here'))
# Out:
# 0.7156175971031189
# 0.6886991858482361

# %% [markdown]
# # Baseline Relation Model

# %%
from functools import lru_cache
from lib.checkpoint import Checkpoint


import math

BASELINE_RELATION_CLASSIFIER = '../../results/0756.12-22_15:25:19.relation_classifier/12m_22d_15h_37m_20s.pt'

baseline_relation_classifer = Checkpoint(checkpoint_path=BASELINE_RELATION_CLASSIFIER, device=0)
baseline_relation_classifer.model.train(mode=False)

@lru_cache(maxsize=4000)
def model(text, text_length):
    return baseline_relation_classifer.model(text, text_length)[0]

def get_baseline_relation_score(question, relation):
    relation = 'www.freebase.com' + relation
    question = question.lower()
    encoded = baseline_relation_classifer.input_text_encoder.encode(question)
    encoded = to_variable(encoded)
    encoded_length = torch.LongTensor([encoded.size()[0]])
    output_batch = model(encoded, encoded_length)
    output_batch = output_batch.squeeze(0)
    relation_index = baseline_relation_classifer.output_text_encoder.encode(relation)[0]
    return math.exp(output_batch[relation_index].data[0])
    
print(get_baseline_relation_score('Where was Obama born?', '/people/person/place_of_birth'))
print(get_baseline_relation_score('Where was Obama born?', '/location/location/people_born_here'))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'lib.nn.seq_to_label.SeqToLabel' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.sparse.Embedding' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.rnn.GRU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.dropout.Dropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.container.Sequential' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.batchnorm.BatchNorm1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:316: SourceChangeWarning: source code of class 'torch.nn.modules.activation.ReLU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# 0.8835899947877679
# 0.11019587285726916
# ../../lib/nn/seq_to_label.py:52: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   scores = F.log_softmax(output)

# %% [markdown]
# # Final End-To-End Metric

# %%
from tqdm import tqdm_notebook
from numpy import nan
import pandas as pd
from collections import defaultdict
import random

sr_correct = 0
o_correct = 0
relation_correct = 0
subject_mid_correct = 0
total = 0
for index, row in tqdm_notebook(df_dev.iterrows(), total=df_dev.shape[0]):
    max_relation_score = float('-inf')
    max_relation = None

    for relation in row['predicted_facts']:
        # NOTE: row['question'] for baseline
        # row['predicted_question'] for yu et al.
        relation_score = get_baseline_relation_score(row['question'], '/' + relation)

        if relation_score > max_relation_score:
            max_relation_score = relation_score
            max_relation = relation

    if max_relation is not None:
        # The dataset was assembled favoring grouped facts with more facts
        # 2 - 3% point increase in accuracy
        # subject_mid, object_mids = random.sample(row['predicted_facts'][max_relation].items(), 1)[0]
        subject_mid, object_mids = sorted(row['predicted_facts'][max_relation].items(),
                                          key=lambda i: len(i[1]), reverse=True)[0]

        if max_relation == row['relation'] and subject_mid == row['subject']:
            sr_correct += 1
        if row['object'] in object_mids:
            o_correct += 1
        if max_relation == row['relation']:
            relation_correct += 1
        if subject_mid == row['subject']:
            subject_mid_correct += 1

    total += 1

# Yu Et Al. Relation Model
# Subject & Relation Accuracy: 0.745781 [8088 of 10845]
# Object Accuracy: 0.800277 [8679 of 10845]
# Relation Accuracy: 0.812356 [8810 of 10845]
# Subject MID Accuracy: 0.808114 [8764 of 10845]

# Baseline Relation Model
# Subject & Relation Accuracy: 0.776763 [8424 of 10845]
# Object Accuracy: 0.833195 [9036 of 10845]
# Relation Accuracy: 0.873490 [9473 of 10845]
# Subject MID Accuracy: 0.834025 [9045 of 10845]

print('Subject & Relation Accuracy: %f [%d of %d]' % (sr_correct / total, sr_correct, total))
print('Object Accuracy: %f [%d of %d]' % (o_correct / total, o_correct, total))
print('Relation Accuracy: %f [%d of %d]' % (relation_correct / total, relation_correct, total))
print('Subject MID Accuracy: %f [%d of %d]' % (subject_mid_correct / total, subject_mid_correct, total))
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# ../../lib/nn/seq_to_label.py:52: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   scores = F.log_softmax(output)
# Subject & Relation Accuracy: 0.773075 [8384 of 10845]
# Object Accuracy: 0.831259 [9015 of 10845]
# Relation Accuracy: 0.877086 [9512 of 10845]
# Subject MID Accuracy: 0.828861 [8989 of 10845]
