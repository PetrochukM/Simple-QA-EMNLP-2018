# %% [markdown]
# # Step 1 - Predict Subject Name

# %%
import sys
sys.path.insert(0, '../../../allennlp')
sys.path.insert(0, '../../')
from tqdm import tqdm_notebook
from scripts.utils.connect import get_connection 
import random
import numpy as np

tqdm_notebook().pandas()
connection = get_connection()
cursor = connection.cursor()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
# Run the end-to-end pipeline on the development set

from scripts.utils.simple_qa import load_simple_qa 
from sklearn.utils import shuffle

df_dev, = load_simple_qa(dev=True)
df_dev = shuffle(df_dev, random_state=123)
df_dev[:5]
# Out:
#        subject                                           relation   object  \
# 6219     03k3r  biology/organism_classification/organisms_of_t...  0bs56bp
# 3364   02qlppc                   cvg/computer_videogame/cvg_genre   01sjng
# 9374    02l7c8                               tv/tv_genre/programs  0dlmm88
# 10142  049_zj3                      location/location/containedby    04rrx
# 97     02w9ycr              people/deceased_person/cause_of_death    0qcr0
#
#                                                 question
# 6219           Name an American Thoroughbread racehorse
# 3364   what kind of game is vision racing driving sim...
# 9374                     what tv program is romance film
# 10142                  what state is  polaski located in
# 97          what disease claimed the life of fern emmett

# %% [markdown]
# ## Load Subject Name Model

# %%
import importlib
import scripts.utils.import_notebook
from allennlp.models.archival import load_archive
from allennlp.service.predictors import Predictor
        
ARCHIVE = load_archive('../../results/subject_recognition.02_01_19:36:36/model.tar.gz',
                       cuda_device=0)
PREDICTOR = Predictor.from_archive(ARCHIVE, 'sentence-tagger')

## TEST ##
question = 'what major cities does u.s. route 2 run through ?'
print('Question:', question)
print('Predicted Tags:', PREDICTOR.predict_json({'sentence': question}, 0)['tags'])
# Out:
# Question: what major cities does u.s. route 2 run through ?
# Predicted Tags: ['O', 'O', 'O', 'O', 'I', 'I', 'I', 'O', 'O', 'O']

# %% [markdown]
# ## Top K Model Decoder
#
# The best subject name span is not always found in our KG; therefore, here we define a top k viterbi decoder. This allows us to get the top k subject names.

# %%
import torch

# FROM: https://gist.github.com/Deepblue129/afaa3613a99a8e7213d2efdd02ae4762 
def viterbi_decode(tag_sequence: torch.Tensor, transition_matrix: torch.Tensor, top_k: int=5):
    """
    Perform Viterbi decoding in log space over a sequence given a transition matrix
    specifying pairwise (transition) potentials between tags and a matrix of shape
    (sequence_length, num_tags) specifying unary potentials for possible tags per
    timestep.
    Parameters
    ----------
    tag_sequence : torch.Tensor, required.
        A tensor of shape (sequence_length, num_tags) representing scores for
        a set of tags over a given sequence.
    transition_matrix : torch.Tensor, required.
        A tensor of shape (num_tags, num_tags) representing the binary potentials
        for transitioning between a given pair of tags.
    top_k : int, required.
        Integer defining the top number of paths to decode.
    Returns
    -------
    viterbi_path : List[int]
        The tag indices of the maximum likelihood tag sequence.
    viterbi_score : float
        The score of the viterbi path.
    """
    sequence_length, num_tags = list(tag_sequence.size())

    path_scores = []
    path_indices = []
    # At the beginning, the maximum number of permutations is 1; therefore, we unsqueeze(0)
    # to allow for 1 permutation.
    path_scores.append(tag_sequence[0, :].unsqueeze(0))
    # assert path_scores[0].size() == (n_permutations, num_tags)

    # Evaluate the scores for all possible paths.
    for timestep in range(1, sequence_length):
        # Add pairwise potentials to current scores.
        # assert path_scores[timestep - 1].size() == (n_permutations, num_tags)
        summed_potentials = path_scores[timestep - 1].unsqueeze(2) + transition_matrix
        summed_potentials = summed_potentials.view(-1, num_tags)

        # Best pairwise potential path score from the previous timestep. 
        max_k = min(summed_potentials.size()[0], top_k)
        scores, paths = torch.topk(summed_potentials, k=max_k, dim=0)
        # assert scores.size() == (n_permutations, num_tags)
        # assert paths.size() == (n_permutations, num_tags)

        scores = tag_sequence[timestep, :] + scores
        # assert scores.size() == (n_permutations, num_tags)
        path_scores.append(scores)
        path_indices.append(paths.squeeze())

    # Construct the most likely sequence backwards.
    path_scores = path_scores[-1].view(-1)
    max_k = min(path_scores.size()[0], top_k)
    viterbi_scores, best_paths = torch.topk(path_scores, k=max_k, dim=0)
    viterbi_paths = []
    for i in range(max_k):
        viterbi_path = [best_paths[i]]
        for backward_timestep in reversed(path_indices):
            viterbi_path.append(int(backward_timestep.view(-1)[viterbi_path[-1]]))
        # Reverse the backward path.
        viterbi_path.reverse()
        # Viterbi paths uses (num_tags * n_permutations) nodes; therefore, we need to modulo.
        viterbi_path = [j % num_tags for j in viterbi_path]
        viterbi_paths.append(viterbi_path)
    return viterbi_paths, viterbi_scores

## TEST ##
sequence_logits = torch.FloatTensor([[1, 0, 0, 4], [1, 0, 6, 2], [0, 3, 0, 4]])
transition_matrix = torch.zeros([4, 4])
transition_matrix[0, 0] = 1
transition_matrix[2, 1] = 5
indices, value = viterbi_decode(sequence_logits, transition_matrix)
assert indices[0] == [3, 2, 1]
assert value[0] == 18

# %%
from typing import List

import torch
from torch.autograd import Variable

# Originally From:
# https://github.com/allenai/allennlp/blob/master/allennlp/modules/conditional_random_field.py#L162
def viterbi_tags(logits: List[List[int]], mask: List[int], top_k: int) -> List[List[int]]:
    """
    Uses viterbi algorithm to find most likely tags for the given inputs.
    """
    logits = torch.FloatTensor(logits)
    mask = torch.LongTensor(mask)
    
    max_seq_length, num_tags = logits.size()

    # Augment transitions matrix with start and end transitions
    start_tag = num_tags
    end_tag = num_tags + 1
    transitions = torch.Tensor(num_tags + 2, num_tags + 2).fill_(-10000.)

    transitions[:num_tags, :num_tags] = ARCHIVE.model.crf.transitions.data
    transitions[start_tag, :num_tags] = ARCHIVE.model.crf.start_transitions.data
    transitions[:num_tags, end_tag] = ARCHIVE.model.crf.end_transitions.data

    # Pad the max sequence length by 2 to account for start_tag + end_tag.
    tag_sequence = torch.Tensor(max_seq_length + 2, num_tags + 2)

    sequence_length = torch.sum(mask)

    # Start with everything totally unlikely
    tag_sequence.fill_(-10000.)
    # At timestep 0 we must have the START_TAG
    tag_sequence[0, start_tag] = 0.
    # At steps 1, ..., sequence_length we just use the incoming logits
    logits[:sequence_length]
    tag_sequence[1:(sequence_length + 1), :num_tags] = logits[:sequence_length]
    # And at the last timestep we must have the END_TAG
    tag_sequence[sequence_length + 1, end_tag] = 0.

    # We pass the tags and the transitions to ``viterbi_decode``.
    viterbi_paths, viterbi_scores = viterbi_decode(tag_sequence[:(sequence_length + 2)], transitions, top_k)
    # Get rid of START and END sentinels and append.
    viterbi_paths = [path[1:-1] for path in viterbi_paths]
    # Translate indexes to labels
    viterbi_paths = [
        [ARCHIVE.model.vocab.get_token_from_index(i, namespace="labels")
         for i in paths] for paths in viterbi_paths
    ]
    return viterbi_paths, viterbi_scores

## TEST ##
top_k = 5
predicted = PREDICTOR.predict_json({'sentence': 'what major cities does u.s. route 2 run through ?'}, 0)
viterbi_paths, viterbi_scores = viterbi_tags(predicted['logits'], predicted['mask'], top_k)

# Best viterbi_paths should equal to predicted tags
assert predicted['tags'] == viterbi_paths[0]

for i in range(top_k):
    print('[Score: %f] Path:' % viterbi_scores[i], viterbi_paths[i])
# Out:
# [Score: 89.824478] Path: ['O', 'O', 'O', 'O', 'I', 'I', 'I', 'O', 'O', 'O']
# [Score: 70.228516] Path: ['O', 'O', 'O', 'O', 'I', 'I', 'I', 'O', 'I', 'O']
# [Score: 69.189430] Path: ['O', 'O', 'O', 'O', 'O', 'I', 'I', 'O', 'O', 'O']
# [Score: 68.404587] Path: ['O', 'O', 'O', 'O', 'I', 'O', 'I', 'O', 'O', 'O']
# [Score: 67.396950] Path: ['O', 'O', 'O', 'O', 'I', 'I', 'I', 'I', 'O', 'O']

# %% [markdown]
# ## Wrap Up
#
# Put the model and top k decoder together. Predict the subject name accross all the examples in the dataframe.

# %%
import math
import re

def predict_subject_name(tokens):
    # Predict Tags
    predicted = PREDICTOR.predict_json({'sentence': ' '.join(tokens)}, 0)
    viterbi_paths, viterbi_scores = viterbi_tags(predicted['logits'], predicted['mask'], 25)
    
    predicted_subject_names = []
    for tags, score in zip(viterbi_paths, viterbi_scores):
        assert len(tags) == len(tokens)
        # Ignore if multiple subject names are selected
        n_subjects = sum(tags[i] == 'I' and (i - 1 == -1 or tags[i - 1] == 'O') for i in range(len(tags)))
        if n_subjects == 1:
            predicted_subject_name = ' '.join([tokens[i] for i, tag in
                                               enumerate(tags) if tag == 'I'])
            start_index = [i for i, tag in enumerate(tags) 
                           if tag == 'I' and (i == 0 or tags[i - 1] == 'O')][0]
            end_index = [i for i, tag in enumerate(tags) 
                         if tag == 'I' and (i == len(tags) - 1 or tags[i + 1] == 'O')][0] + 1
            predicted_subject_names.append({
                'name': predicted_subject_name,
                'score': score,
                'start_index': start_index,
                'end_index': end_index,
            })
    return predicted_subject_names

## TEST ##
print('Sample Output:')
predict_subject_name(['what', 'major', 'cities', 'does', 'u.s.', 'route', '2', 'run', 'through', '?'])
# Out:
# Sample Output:
# [{'end_index': 7,
#   'name': 'u.s. route 2',
#   'score': 89.82447814941406,
#   'start_index': 4},
#  {'end_index': 7,
#   'name': 'route 2',
#   'score': 69.1894302368164,
#   'start_index': 5},
#  {'end_index': 8,
#   'name': 'u.s. route 2 run',
#   'score': 67.3969497680664,
#   'start_index': 4},
#  {'end_index': 6,
#   'name': 'u.s. route',
#   'score': 67.22178649902344,
#   'start_index': 4},
#  {'end_index': 7,
#   'name': 'does u.s. route 2',
#   'score': 66.82366943359375,
#   'start_index': 3},
#  {'end_index': 9,
#   'name': 'u.s. route 2 run through',
#   'score': 56.90545654296875,
#   'start_index': 4},
#  {'end_index': 7, 'name': '2', 'score': 56.87400436401367, 'start_index': 6},
#  {'end_index': 5,
#   'name': 'u.s.',
#   'score': 54.90635299682617,
#   'start_index': 4},
#  {'end_index': 7,
#   'name': 'cities does u.s. route 2',
#   'score': 52.69660568237305,
#   'start_index': 2},
#  {'end_index': 8,
#   'name': 'route 2 run',
#   'score': 46.761905670166016,
#   'start_index': 5},
#  {'end_index': 6,
#   'name': 'route',
#   'score': 46.58673858642578,
#   'start_index': 5}]

# %%
import pandas as pd
from numpy import nan

PREPROCESS = importlib.import_module(
                "scripts.Simple QA Models.Subject Recognition Data").preprocess
TOKENIZE = importlib.import_module(
                "scripts.Simple QA Models.Subject Recognition Data").spacy_tokenize

def add_predicted_subject_name(row):
    question_tokens = TOKENIZE(PREPROCESS(row['question']))
    predicted_subject_names = predict_subject_name(question_tokens)
    row['predicted_subject_names'] = predicted_subject_names
    row['predicted_question_tokens'] = question_tokens
    return row

df_dev = df_dev.progress_apply(add_predicted_subject_name, axis=1)
df_dev[:5]
# Out:
# importing Jupyter notebook from ../../scripts/Simple QA Models/Subject Recognition Data.ipynb
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# importing Jupyter notebook from ../../scripts/Simple QA Numbers/HYPOTHESIS - Subject Name not in Question.ipynb
#        subject                                           relation   object  \
# 6219     03k3r  biology/organism_classification/organisms_of_t...  0bs56bp
# 3364   02qlppc                   cvg/computer_videogame/cvg_genre   01sjng
# 9374    02l7c8                               tv/tv_genre/programs  0dlmm88
# 10142  049_zj3                      location/location/containedby    04rrx
# 97     02w9ycr              people/deceased_person/cause_of_death    0qcr0
#
#                                                 question  \
# 6219           Name an American Thoroughbread racehorse
# 3364   what kind of game is vision racing driving sim...
# 9374                     what tv program is romance film
# 10142                  what state is  polaski located in
# 97          what disease claimed the life of fern emmett
#
#                                  predicted_subject_names  \
# 6219   [{'name': 'american thoroughbread', 'score': 4...
# 3364   [{'name': 'vision racing driving simulator', '...
# 9374   [{'name': 'romance film', 'score': 55.87209701...
# 10142  [{'name': 'polaski', 'score': 57.6216735839843...
# 97     [{'name': 'fern emmett', 'score': 69.716217041...
#
#                                predicted_question_tokens
# 6219      [name, an, american, thoroughbread, racehorse]
# 3364   [what, kind, of, game, is, vision, racing, dri...
# 9374              [what, tv, program, is, romance, film]
# 10142            [what, state, is, polaski, located, in]
# 97     [what, disease, claimed, the, life, of, fern, ...

# %% [markdown]
# ## Analysis Setup
#
# Add the True `subject_name` and `start_index` / `end_index` to check the accuracy of our predicted values.

# %%
import importlib
from functools import partial

edit_distance_link_alias = importlib.import_module(
                "scripts.Simple QA Numbers.HYPOTHESIS - Question Refers to Multiple Subjects").edit_distance_link_alias
normalize = importlib.import_module(
                "scripts.Simple QA Numbers.HYPOTHESIS - Subject Name not in Question").normalize

# Create a column with the subject_name linked per example
df_dev['subject_name'] = df_dev.progress_apply(partial(edit_distance_link_alias, cursor, normalize), axis=1)
# Out:
# importing Jupyter notebook from ../../scripts/Simple QA Numbers/HYPOTHESIS - Question Refers to Multiple Subjects.ipynb
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))

# %%
import importlib
# Adds:
# - question_tokens
# - subject_name
# - start_index
# - end_index
find_subject_name_span = importlib.import_module(
                "scripts.Simple QA Models.Subject Recognition Data").find_subject_name_span

# Create a column with the subject_name linked per example
df_dev = df_dev.progress_apply(find_subject_name_span, axis=1)
df_dev[:5]
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
#        end_index   object                          predicted_question_tokens  \
# 6219         NaN  0bs56bp     [name, an, american, thoroughbread, racehorse]
# 3364         9.0   01sjng  [what, kind, of, game, is, vision, racing, dri...
# 9374         6.0  0dlmm88             [what, tv, program, is, romance, film]
# 10142        4.0    04rrx            [what, state, is, polaski, located, in]
# 97           8.0    0qcr0  [what, disease, claimed, the, life, of, fern, ...
#
#                                  predicted_subject_names  \
# 6219   [{'name': 'american thoroughbread', 'score': 4...
# 3364   [{'name': 'vision racing driving simulator', '...
# 9374   [{'name': 'romance film', 'score': 55.87209701...
# 10142  [{'name': 'polaski', 'score': 57.6216735839843...
# 97     [{'name': 'fern emmett', 'score': 69.716217041...
#
#                                                 question  \
# 6219           Name an American Thoroughbread racehorse
# 3364   what kind of game is vision racing driving sim...
# 9374                     what tv program is romance film
# 10142                  what state is  polaski located in
# 97          what disease claimed the life of fern emmett
#
#                                          question_tokens  \
# 6219                                                 NaN
# 3364   [what, kind, of, game, is, vision, racing, dri...
# 9374              [what, tv, program, is, romance, film]
# 10142            [what, state, is, polaski, located, in]
# 97     [what, disease, claimed, the, life, of, fern, ...
#
#                                                 relation  start_index  \
# 6219   biology/organism_classification/organisms_of_t...          NaN
# 3364                    cvg/computer_videogame/cvg_genre          5.0
# 9374                                tv/tv_genre/programs          4.0
# 10142                      location/location/containedby          3.0
# 97                 people/deceased_person/cause_of_death          6.0
#
#        subject                     subject_name  \
# 6219     03k3r                              NaN
# 3364   02qlppc  vision racing driving simulator
# 9374    02l7c8                     romance film
# 10142  049_zj3                          polaski
# 97     02w9ycr                      fern emmett
#
#                         subject_name_tokens
# 6219                                    NaN
# 3364   (vision, racing, driving, simulator)
# 9374                        (romance, film)
# 10142                            (polaski,)
# 97                           (fern, emmett)

# %%
df_dev.to_pickle('step_1_predict_subject_name.pkl')

# %% [markdown]
# ## Analysis - Correct Span
#
# We determine the correct subject name span and compare it to the predicted subject name.

# %%
from tqdm import tqdm_notebook

accuracies = [0] * 10
total = 0

def is_correct(row, top_k):
    for i in range(min(top_k, len(row['predicted_subject_names']))):
        if (row['start_index'] == row['predicted_subject_names'][i]['start_index'] and
            row['end_index'] == row['predicted_subject_names'][i]['end_index']):
            return True
    return False
    

for index, row in tqdm_notebook(df_dev.iterrows(), total=df_dev.shape[0]):
    if not isinstance(row['subject_name'], str):
        continue
        
    total += 1
    accuracies = [count + is_correct(row, i + 1) for i, count in enumerate(accuracies)]

for i, count in enumerate(accuracies):
    print('Accuracy Top %d: %f [%d of %d]' % (i + 1, count / total, count, total))
    
# Accuracy Top 1: 0.942618 [10037 of 10648]
# Accuracy Top 2: 0.973892 [10370 of 10648]
# Accuracy Top 3: 0.982438 [10461 of 10648]
# Accuracy Top 4: 0.988449 [10525 of 10648]
# Accuracy Top 5: 0.991736 [10560 of 10648]
# Accuracy Top 6: 0.994083 [10585 of 10648]
# Accuracy Top 7: 0.995586 [10601 of 10648]
# Accuracy Top 8: 0.996056 [10606 of 10648]
# Accuracy Top 9: 0.996901 [10615 of 10648]
# Accuracy Top 10: 0.997558 [10622 of 10648]
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# Accuracy Top 1: 0.953888 [10157 of 10648]
# Accuracy Top 2: 0.972671 [10357 of 10648]
# Accuracy Top 3: 0.979339 [10428 of 10648]
# Accuracy Top 4: 0.984035 [10478 of 10648]
# Accuracy Top 5: 0.986382 [10503 of 10648]
# Accuracy Top 6: 0.988355 [10524 of 10648]
# Accuracy Top 7: 0.990609 [10548 of 10648]
# Accuracy Top 8: 0.992017 [10563 of 10648]
# Accuracy Top 9: 0.992581 [10569 of 10648]
# Accuracy Top 10: 0.992675 [10570 of 10648]

# %% [markdown]
# ## Analysis - Normalized Link
#
# We normalize the correct subject name and compare it to the predicted name normalized.
#
# We expect this to be lower than the span analysis because in "HYPOTHESIS - Subject Name not in Question", we found that 97.85% of the time the subject name normalized is not in the question; therefore, some spans that are correct will not be equal to the subject name normalized.

# %%
import importlib

normalize = importlib.import_module(
                "scripts.Simple QA Numbers.HYPOTHESIS - Subject Name not in Question").normalize
tokenize = importlib.import_module(
                "scripts.Simple QA Models.Subject Recognition Data").spacy_tokenize

# %%
from tqdm import tqdm_notebook
from scripts.utils.table import format_pipe_table

negative_sample = []
accuracies = [0] * 10
total = 0

def is_correct(row, top_k):
    subject_name = normalize(' '.join(tokenize(row['subject_name'])))
    for i in range(min(top_k, len(row['predicted_subject_names']))):
        predicted_subject_name = normalize(row['predicted_subject_names'][i]['name'])
        if predicted_subject_name == subject_name:
            return True
    return False

for index, row in tqdm_notebook(df_dev.iterrows(), total=df_dev.shape[0]):
    if not isinstance(row['subject_name'], str):
        continue
        
    total += 1
    accuracies = [count + is_correct(row, i + 1) for i, count in enumerate(accuracies)]
    if not is_correct(row, 1):
        negative_sample.append({
            'Subject Name': row['subject_name'],
            'Predicted Subject Name': [row['predicted_subject_names'][i]['name']
                                       for i in range(min(5, len(row['predicted_subject_names'])))],
        })

for i, count in enumerate(accuracies):
    print('Accuracy Top %d: %f [%d of %d]' % (i + 1, count / total, count, total))
print('Negative Sample:\n')
print(format_pipe_table(negative_sample[:50]))

# Accuracy Top 1: 0.935105 [9957 of 10648]
# Accuracy Top 2: 0.963749 [10262 of 10648]
# Accuracy Top 3: 0.971638 [10346 of 10648]
# Accuracy Top 4: 0.977273 [10406 of 10648]
# Accuracy Top 5: 0.980372 [10439 of 10648]
# Accuracy Top 6: 0.982532 [10462 of 10648]
# Accuracy Top 7: 0.983847 [10476 of 10648]
# Accuracy Top 8: 0.984316 [10481 of 10648]
# Accuracy Top 9: 0.984974 [10488 of 10648]
# Accuracy Top 10: 0.985631 [10495 of 10648]
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
# Accuracy Top 1: 0.945530 [10068 of 10648]
# Accuracy Top 2: 0.962998 [10254 of 10648]
# Accuracy Top 3: 0.968539 [10313 of 10648]
# Accuracy Top 4: 0.973610 [10367 of 10648]
# Accuracy Top 5: 0.975770 [10390 of 10648]
# Accuracy Top 6: 0.977648 [10410 of 10648]
# Accuracy Top 7: 0.979245 [10427 of 10648]
# Accuracy Top 8: 0.980560 [10441 of 10648]
# Accuracy Top 9: 0.981123 [10447 of 10648]
# Accuracy Top 10: 0.981217 [10448 of 10648]
# Negative Sample:
#
# | Index | Predicted Subject Name | Subject Name |
# | --- | --- | --- |
# | 0 | ['documentary film', 'short documentary film', 'documentary', 'film', 'documentary film released'] | short |
# | 1 | ['krgy station', 'krgy station play', 'krgy', 'station', 'does krgy station'] | krgy |
# | 2 | ['austrailian screenwriter', 'screenwriter', 'austrailian screenwriter ?', 'austrailian', 'famous austrailian screenwriter'] | screenwriter |
# | 3 | ['the water in the canche', 'water in the canche', 'in the canche', 'the water in the canche come', 'does the water in the canche'] | canche |
# | 4 | ['red clouds war', 'clouds war', 'the red clouds war', 'red clouds', 'red clouds war ?'] | red cloud's war |
# | 5 | ['the sandman ( vertigo )', 'the sandman ( vertigo', 'sandman ( vertigo )', 'the sandman (', 'the sandman'] | the sandman |
# | 6 | ['sketch )', 'music ( sketch )', 'the music ( sketch )', '( sketch )', 'sketch'] | music (sketch) |
# | 7 | ['peters point plantation', "peters point plantation 's", 'point plantation', 'peters point', 'is peters point plantation'] | peter's point plantation |
# | 8 | ['it must have been years be heard', 'it must have been years be heard in', 'must have been years be heard', 'it must have been years be', 'composition it must have been years be heard'] | it must have been years |
# | 9 | ['the track : so long to broadway', 'track : so long to broadway', 'the track : so long to broadway ?', ': so long to broadway', 'the track : so long to'] | so long to broadway |
# | 10 | ['aaron carter', 'aaron', 'carter', 'by aaron carter', 'released by aaron carter'] | album |
# | 11 | ['s - series', 'vehicle saturn s - series', 'saturn s - series', 'the vehicle saturn s - series', '- series'] | saturn s-series |
# | 12 | ['pillows & prayers : cherry red 1982 - 1983', 'pillows & prayers : cherry red 1982 -', 'pillows & prayers : cherry red 1982 - 1983 ?', 'pillows & prayers : cherry red 1982', '& prayers : cherry red 1982 - 1983'] | pillows & prayers: cherry red 1982–1983 |
# | 13 | ['luxembourg', 'of luxembourg', 'luxembourg in', 'commune of luxembourg', 'of luxembourg in'] | commune of luxembourg |
# | 14 | ['gulzar help', 'gulzar', 'gulzar help write', 'help', 'did gulzar help'] | gulzar |
# | 15 | ['the eye of the eagle', 'eye of the eagle', 'the eye of the eagle ?', 'is the eye of the eagle', 'the eye of the'] | eye of the eagle |
# | 16 | ['the blues collection 5 : jungle music', 'blues collection 5 : jungle music', 'collection 5 : jungle music', 'the blues collection 5 : jungle', 'the blues collection 5 : jungle music was'] | jungle music |
# | 17 | ['two women', 'women', 'two', 'between two women', 'about between two women'] | between two women |
# | 18 | ['battle of hudsons bay', 'of hudsons bay', 'battle of hudsons bay take', 'the battle of hudsons bay', 'battle of hudsons'] | battle of hudson's bay |
# | 19 | ['anthony marinelli', 'marinelli', 'anthony', 'by anthony marinelli', 'soundtrack'] | soundtrack |
# | 20 | ['karl may', 'karl may characters', 'tribal chief', 'may', 'karl'] | tribal chief |
# | 21 | ['george canyon', 'canyon', 'george', 'by george canyon', 'album by george canyon'] | album |
# | 22 | ['waddy wachtel', "waddy wachtel 's", 'waddy', 'wachtel', 'was waddy wachtel'] | waddy |
# | 23 | ['portal', 'band portal', 'the band portal', 'album', 'band'] | album |
# | 24 | ['megan chengs', 'megan chengs ethnicity', 'megan', 'chengs', 's megan chengs'] | megan cheng |
# | 25 | ['martial arts', 'martial arts film', 'martial', 'netflix martial arts', 'arts'] | martial arts film |
# | 26 | ['anglo files : a field guide to the british', 'the anglo files : a field guide to the british', 'anglo files : a field guide to the', 'files : a field guide to the british', 'of the anglo files : a field guide to the british'] | the anglo files: a field guide to the british |
# | 27 | ['mcgill daily', 'the mcgill daily', 'mcgill', 'is the mcgill daily', 'daily'] | the mcgill daily |
# | 28 | ['compilation album', 'album', 'compilation', 'compilation album by', 'a compilation album'] | creedence clearwater revival |
# | 29 | ['showed e.n.g', 'e.n.g', 'showed e.n.g .', 'showed', 'originally showed e.n.g'] | e.n.g. |
# | 30 | ['medicine', 'topical medicine', 'a topical medicine', 'topical', 'a'] | topical medication |
# | 31 | ['the master', 'master', 'of the master', "the master 's", 'one of the master'] | master |
# | 32 | ['ayn rand', 'with ayn rand', 'begins with ayn rand', 'rand', 'ayn'] | it usually begins with ayn rand |
# | 33 | ['tha shiznit', 'tha', 'tha shiznit episode', 'tha shiznit episode ii', 'shiznit'] | tha shiznit episode ii |
# | 34 | ['manufacturing longbridge', 'longbridge', 'a manufacturing longbridge', 'manufacturing longbridge plant', 'longbridge plant'] | longbridge plant |
# | 35 | ['horse street cry', 'breeded the horse street cry', 'street cry', 'the horse street cry', 'cry'] | street cry |
# | 36 | ['kearny', 'of kearny', 'town of kearny', 'town', 'circulates'] | t-town |
# | 37 | ['cheetah girls : pop star sensations', 'the cheetah girls : pop star sensations', 'cheetah girls : pop star', 'the cheetah girls : pop star', 'produce the cheetah girls : pop star sensations'] | the cheetah girls: pop star sensations |
# | 38 | ['drum', 'drum kit', 'the drum', 'plays the drum', 'the drum kit'] | drums |
# | 39 | ['the night - time butterflies series', 'the night - time butterflies', 'night - time butterflies series', 'night - time butterflies', 'the night - time butterflies series originates'] | night-time butterflies |
# | 40 | ['charge of pecos national historical park', 'pecos national historical park', 'of pecos national historical park', 'in charge of pecos national historical park', 'national historical park'] | pecos national historical park |
# | 41 | ['cadillac comes', 'cadillac', 'comes', 'track cadillac comes', 'track cadillac'] | cadillac |
# | 42 | ['dimillos floating restaurant', 'dimillos floating restaurant in', 'floating restaurant', 'dimillos floating', 'is dimillos floating restaurant'] | dimillo's floating restaurant |
# | 43 | ['the fil lies in plain sight', 'fil lies in plain sight', 'for the fil lies in plain sight', 'lies in plain sight', 'the fil lies in plain'] | lies in plain sight |
# | 44 | ['charlotte fich', "charlotte fich 's", 'charlotte', 'fich', 'is charlotte fich'] | charlotte |
# | 45 | ['npr : wait wait ... do nt tell me ! podcast', 'wait wait ... do nt tell me ! podcast', ': wait wait ... do nt tell me ! podcast', 'npr : wait wait ... do nt tell me !', 'wait ... do nt tell me ! podcast'] | npr: wait wait... don't tell me! |
# | 46 | ['regatta mystery', 'mystery', 'piece regatta mystery', 'regatta', 'the piece regatta mystery'] | the regatta mystery |
# | 47 | ['jack dejohnrette', 'of jack dejohnrette', "jack dejohnrette 's", 'jack', 'name of jack dejohnrette'] | album |
# | 48 | ['tamil', 'bollywood tamil', 'tamil film', 'what bollywood tamil', 'bollywood tamil film'] | bollywood |
# | 49 | ['the hot relationships', 'hot relationships', 'the hot relationships book', 'is the hot relationships', 'relationships'] | hot relationships |
