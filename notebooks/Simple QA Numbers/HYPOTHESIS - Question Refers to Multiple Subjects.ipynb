# %% [markdown]
# # HYPOTHESIS - Question Refers to Multiple Subjects
#
#
# SimpleQuestions dataset example question is equivilant to (subject, relation, ?); therefore, for it to be answerable there must not be a duplicate (subject, relation, ?) tuple in the KG.
#
# Within `HYPOTHESIS - Subject Name not in Question.ipynb` we suggest an algorithm for linking the subject alias to the question.
#
# Following we linked the subject alias referenced in the question, we can check if there exists other (subject, relation, ?).

# %%
import sys
sys.path.insert(0, '../../')
import pandas as pd
import random
from tqdm import tqdm_notebook
tqdm_notebook().pandas()
from lib.utils import FB2M_NAME_TABLE
from lib.utils import FB2M_KG_TABLE
from lib.utils import get_connection 
import lib.import_notebook

connection = get_connection()
cursor = connection.cursor()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/nbformat/current.py:19: UserWarning: nbformat.current is deprecated.
#
# - use nbformat for read/write/validate public API
# - use nbformat.vX directly to composing notebooks of a particular version
#
#   """)

# %%
from lib.simple_qa import load_simple_qa 

# Load development set because its a magnitude smaller than the training set.
df, = load_simple_qa(dev=True)
df[:5]
# Out:
#    subject                      relation   object  \
# 0   0f3xg_  symbols/namesake/named_after   0cqt90
# 1   07f3jg  people/person/place_of_birth    0565d
# 2  031j8nn          music/release/region    07ssc
# 3  0c1cyhd            film/director/film  0wxsz5y
# 4  0fvhc0g          music/release/region    0345h
#
#                                             question
# 0  Who was the trump ocean club international hot...
# 1                       where was sasha vujačić born
# 2   What is a region that dead combo was released in
# 3  What is a film directed by wiebke von carolsfeld?
# 4  what country was music for stock exchange  rel...

# %% [markdown]
# ## Step 1 - Link Question to Subject Alias

# %%
import importlib
module = importlib.import_module("notebooksSimple QA Numbers.HYPOTHESIS - Subject Name not in Question")
normalize = module.normalize
# Out:
# importing Jupyter notebook from ../../notebooks/Simple QA Numbers/HYPOTHESIS - Subject Name not in Question.ipynb

# %%
import pandas as pd
from lib.edit_distance import edit_token_distance
from IPython.display import display
from numpy import nan
from functools import partial

def edit_distance_link_alias(cursor, normalize, row, name_table=FB2M_NAME_TABLE):
    cursor.execute('SELECT alias FROM ' + name_table + ' WHERE mid=%s', (row['subject'],))
    aliases = [a[0] for a in cursor.fetchall()]
    normalized_aliases = [normalize(a) for a in aliases]
    for i, n_a in enumerate(normalized_aliases):
        if len(n_a.strip()) == 0:
            aliases.pop(i)
            normalized_aliases.pop(i)
    
    normalized_aliases = [tuple(a.split()) for a in normalized_aliases]
    if len(normalized_aliases) > 0:
        # NOTE: Given that there is no punctuation in the phrase then splitting based on white spaces works
        normalized_question = tuple(normalize(row['question']).split())
        distances = [edit_token_distance(n_a, normalized_question) for n_a in normalized_aliases]
        normalized_aliases_lengths = [sum(len(t) for t in n_a) for n_a in normalized_aliases]
        normalized_distances = [(normalized_aliases_lengths[i] - d[0]) / normalized_aliases_lengths[i]
                                for i, d in enumerate(distances)]
        
        if max(normalized_distances) >= 0.75:
            # NOTE: Pick the longest and least edit distance
            # TODO: Look at criteria for sorting
            subject_alias_index = max(range(len(normalized_distances)),
                                      key=lambda i: (normalized_distances[i], len(aliases[i])))
            subject_alias = aliases[subject_alias_index]
            return subject_alias
    return nan

# Create a column with the subject_name linked per example
df['subject_name'] = df.progress_apply(partial(edit_distance_link_alias, cursor, normalize), axis=1)
display(df[:5])
# Out:
# HBox(children=(IntProgress(value=0, max=10845), HTML(value='')))
#    subject                      relation   object  \
# 0   0f3xg_  symbols/namesake/named_after   0cqt90
# 1   07f3jg  people/person/place_of_birth    0565d
# 2  031j8nn          music/release/region    07ssc
# 3  0c1cyhd            film/director/film  0wxsz5y
# 4  0fvhc0g          music/release/region    0345h
#
#                                             question  \
# 0  Who was the trump ocean club international hot...
# 1                       where was sasha vujačić born
# 2   What is a region that dead combo was released in
# 3  What is a film directed by wiebke von carolsfeld?
# 4  what country was music for stock exchange  rel...
#
#                                      subject_name
# 0  trump ocean club international hotel and tower
# 1                                   sasha vujacic
# 2                                      dead combo
# 3                           wiebke von carolsfeld
# 4                        music for stock exchange

# %% [markdown]
# ## Step 2 - Count Duplicates (subject, relation, ?)

# %%
from functools import lru_cache

@lru_cache(maxsize=10885)
def get_duplicate_mids(name_table, kg_table, subject_name, relation):
    cursor.execute("""
      SELECT subject_mid
      FROM {name_table}
      INNER JOIN {kg_table}
      ON subject_mid = mid
      WHERE alias = %s
      AND fb_two_kg.relation = %s""".format(name_table=name_table, kg_table=kg_table),
               (subject_name, relation))
    mids = set([mid for (mid,) in cursor.fetchall()])
    return mids

# %%
import statistics

import random

dups_data = []
n_dups = []

def count_duplicates(row, name_table=FB2M_NAME_TABLE, kg_table=FB2M_KG_TABLE):
    mids = get_duplicate_mids(name_table, kg_table, row['subject_name'], row['relation'])
    
    if len(mids) > 1:
        assert row['subject'] in mids
        dups_data.append({
            'Subject Name': row['subject_name'],
            'Relation': row['relation'],
            'Question': row['question'], 
            'Number of Duplicate MIDs': str(len(mids)),
            'True MID': row['subject'],
            'Duplicate MIDs': mids,
        })
    elif len(mids) == 0:
        # Unable to find any MIDs related to alias
        print('No MIDs for alias')
        print(row)

    n_dups.append(len(mids))

df[df.subject_name.notnull()].progress_apply(count_duplicates, axis=1)
display(pd.DataFrame(dups_data)[:50])
# Out:
# HBox(children=(IntProgress(value=0, max=10640), HTML(value='')))
#                                        Duplicate MIDs  \
# 0                  {0b4pm3, 0gkrfmk, 0gmhlt, 0k3qrvh}
# 1   {0ft53m8, 0dzb769, 0nl9mxz, 0rtntk, 0nlql9t, 0...
# 2   {02prsd4, 0zvwcn5, 0_hqxrc, 0_j2lh4, 0465qnd, ...
# 3                   {09gbzy0, 0d5jxc, 0b1xf4, 08jcb1}
# 4   {0c03hf7, 01lftjn, 01hqqnq, 01m5vhv, 0gg5fdj, ...
# 5                                    {025wdlw, 02y49}
# 6   {04v7k_9, 04v7ky6, 04v7k_0, 04v7kzr, 04v7h85, ...
# 7                         {03gt0jb, 0pc47fb, 0h566cd}
# 8                                  {0hqsrcv, 0hqrlp6}
# 9   {0177d57, 0247xcj, 014c2ft, 0dypv5t, 0fhg_23, ...
# 10                 {02py9bj, 090s_0, 06znpjr, 0dy60p}
# 11  {0yp4hw, 0dt98t1, 0nm_v6k, 0f80t9k, 01bc3kk, 0...
# 12  {0m10gwq, 0mrzlrp, 0qf1jmg, 0kj003k, 0_jffy3, ...
# 13               {0qjz6j9, 0x1csxp, 034ydkw, 030kxb6}
# 14  {0f83dpg, 0ftx4vb, 0f7ffd9, 0dz584k, 03j7fs3, ...
# 15  {0f_b6b7, 0fs_76c, 0g0x__m, 0np_20y, 0g735fz, ...
# 16  {0lxcjyd, 0m8fptm, 0mtfyt2, 0mfb5jh, 0nrws36, ...
# 17  {0ygz5, 0qymh, 04b0ky2, 0z1gh, 01138j, 02wbwd,...
# 18  {0gc63b2, 0d48n9, 0hf2gqv, 0v9djbr, 0gc3lhh, 0...
# 19  {0114q4, 0480bx_, 0q_84, 04b2tsy, 0fwksf, 09j5...
# 20                        {0dp73l0, 033r2wp, 0d_bz8k}
# 21                {0gdjrjk, 0gx2sh8, 0b_xrk3, 072192}
# 22                                 {03g22tr, 01n61t7}
# 23  {01642z2, 0z18tn, 0qcfjjm, 0qh41hs, 0nmnksv, 0...
# 24  {0vk1cw, 013c4fb, 0q64gd, 0166ggr, 023p5r8, 0_...
# 25                        {0zx5yph, 02r8389, 0_7v2w6}
# 26                                 {03wdjs1, 0ds7_cg}
# 27                                   {07s9rl0, 02822}
# 28  {0ndxq, 0mllm, 0npk3, 0nv8k, 0nn0w, 0ng5y, 0kw...
# 29  {012dtnk, 0dvc5b_, 019jgmn, 0wcmbk, 0snwrzp, 0...
# 30                                  {02rlckk, 04fmg5}
# 31  {0j511vb, 05q96q6, 03hhq_3, 03wh1s, 0g0dy6, 04...
# 32  {07rh8f, 0nmgglz, 0f24qbm, 04bks1b, 0w2xjyk, 0...
# 33                         {09r8zj, 01j28b3, 01l6kk8}
# 34                                 {0dy04sq, 03flhgg}
# 35  {0f2wzpr, 01c6wr7, 0dvb1y5, 0t4d9t, 0dt7857, 0...
# 36                                 {0fjr5vp, 0xcm_s6}
# 37  {018c1x2, 0f2x3xs, 0q6rqd, 0xd3kth, 0dw_vc2, 0...
# 38                         {09gg50x, 09sc4q, 0gddt6v}
# 39                                 {0bwmhlc, 0c00djh}
# 40                                 {0fg5pnt, 033xctz}
# 41                                 {0g7yfj_, 037nqf4}
# 42                        {05nrqz9, 05nrqzm, 05nrqzg}
# 43                                 {0pmhj24, 027qm91}
# 44                                    {0fdp85, 02w4v}
# 45            {0bjq4, 048_tdz, 0s96w, 04y6gd, 0fvdw5}
# 46                                   {07b_l, 0qskgqg}
# 47  {0nm4kcw, 0st_j5, 0nty09, 01d7gkg, 01nr1tx, 0f...
# 48  {06cgy, 01vw20_, 03kd4m, 01kk3lb, 015cbq, 016z...
# 49               {04vqsbx, 0c5ss7y, 04vqsb3, 04vqsbl}
#
#    Number of Duplicate MIDs  \
# 0                         4
# 1                        49
# 2                         9
# 3                         4
# 4                        20
# 5                         2
# 6                         9
# 7                         3
# 8                         2
# 9                        26
# 10                        4
# 11                      399
# 12                       12
# 13                        4
# 14                        6
# 15                       12
# 16                       26
# 17                       12
# 18                        8
# 19                        7
# 20                        3
# 21                        4
# 22                        2
# 23                      158
# 24                      178
# 25                        3
# 26                        2
# 27                        2
# 28                       17
# 29                       27
# 30                        2
# 31                        6
# 32                       40
# 33                        3
# 34                        2
# 35                      270
# 36                        2
# 37                      161
# 38                        3
# 39                        2
# 40                        2
# 41                        2
# 42                        3
# 43                        2
# 44                        2
# 45                        5
# 46                        2
# 47                      700
# 48                       11
# 49                        4
#
#                                              Question  \
# 0        What is the language of the film bon voyage?
# 1          whats a version of the single titled  star
# 2   which recordings contains the composition aust...
# 3                    what country is ghost house from
# 4         what is the release type of the album wake?
# 5                    who is the chid of fritz leiber?
# 6         what is a book from the ethan frome series
# 7                                 where is look from?
# 8   what is the active ingredient moiety in fast f...
# 9       what is the name for meccas canonical version
# 10                       who wrote gulliver's travels
# 11                                what is  i miss you
# 12     what album was the song greenland featured on
# 13                    what is a track from dirty love
# 14               what track is on minutes to midnight
# 15         what country was the fame monster  done in
# 16                       which release was reading on
# 17                       What US state contains clyde
# 18             where was robert harris (painter) born
# 19                        which country is lamont in
# 20  what is a track from the release cobra: studio...
# 21  What kind of motion picture is a place in the sun
# 22  How was the album ellen allien remix collectio...
# 23  The recording star is an adaptation of which s...
# 24  what is the name of a track from roll over bee...
# 25                     who wrote the composition soon
# 26         which language is spoken in gautam govinda
# 27                  what is a film in the genre drama
# 28                      what city is in marion county
# 29                        what is a track from tamara
# 30                     What is william wall's gender?
# 31                            who directed robin hood
# 32  what would be a music spin with the topic of h...
# 33      what type of music is on the album phenomenon
# 34     Name a format in which luminitza was released.
# 35      Which album is hollywood on, by Blues Company
# 36               is punk rock rarities a album or dvd
# 37              What is a version of the single free?
# 38            who is the performer of this is my life
# 39                which city was helen grant born in
# 40      where was nude dimensions, volume 2 released?
# 41  what country was the london chuck berry sessio...
# 42                  which company published nascar 09
# 43          what city and state did joe bowman die in
# 44             Who's a musician that plays folk music
# 45  in which county in Illinois is grant park located
# 46                         what counties are in texas
# 47                                   What was eclipse
# 48   What is the title of one of bob marley's albums?
# 49            What kind of binding does iowa come in?
#
#                                              Relation  \
# 0                                  film/film/language
# 1                               music/single/versions
# 2                        music/composition/recordings
# 3                                   film/film/country
# 4                            music/album/release_type
# 5                              people/person/children
# 6                              book/book_edition/book
# 7                                   film/film/country
# 8   medicine/drug_formulation/active_ingredient_mo...
# 9                   music/recording/canonical_version
# 10                                 film/film/story_by
# 11                         common/topic/notable_types
# 12                        music/release_track/release
# 13                                music/release/album
# 14                                music/release/track
# 15                               music/release/region
# 16                      music/release_track/recording
# 17                      location/location/containedby
# 18                       people/person/place_of_birth
# 19                      location/location/containedby
# 20                                music/release/track
# 21                                    film/film/genre
# 22                           music/album/release_type
# 23                  music/recording/canonical_version
# 24                             music/recording/tracks
# 25                         music/composition/lyricist
# 26                                 film/film/language
# 27                film/film_genre/films_in_this_genre
# 28                         location/location/contains
# 29                             music/recording/tracks
# 30                               people/person/gender
# 31                              film/film/directed_by
# 32                         common/topic/notable_types
# 33                                  music/album/genre
# 34                               music/release/format
# 35                           music/recording/releases
# 36                           music/album/release_type
# 37                              music/single/versions
# 38                                 music/album/artist
# 39                       people/person/place_of_birth
# 40                               music/release/region
# 41                               music/release/region
# 42                         cvg/game_version/publisher
# 43              people/deceased_person/place_of_death
# 44                                music/genre/artists
# 45                      location/location/containedby
# 46                         location/location/contains
# 47                         common/topic/notable_types
# 48                                 music/artist/album
# 49                          book/book_edition/binding
#
#                        Subject Name True MID
# 0                        bon voyage  0gkrfmk
# 1                              star  0nndnv_
# 2                         australia  0zvwcn5
# 3                       ghost house   0b1xf4
# 4                              wake  0fsn5x_
# 5                      fritz leiber    02y49
# 6                       ethan frome  04v7kz6
# 7                              look  0pc47fb
# 8                       fast freeze  0hqrlp6
# 9                             mecca  0fhg_23
# 10               gulliver's travels   090s_0
# 11                       i miss you  01bc3kk
# 12                        greenland  0m7317g
# 13                       dirty love  0x1csxp
# 14              minutes to midnight  03j7fs3
# 15                 the fame monster  0g8br_z
# 16                          reading  0ns5ryx
# 17                            clyde    0wykn
# 18                    robert harris   0d48n9
# 19                           lamont  0480bx_
# 20            cobra: studio version  0dp73l0
# 21               a place in the sun   072192
# 22    ellen allien remix collection  03g22tr
# 23                             star  0f0bg9l
# 24              roll over beethoven  019gzbd
# 25                             soon  0zx5yph
# 26                   gautam govinda  03wdjs1
# 27                            drama  07s9rl0
# 28                    marion county    0ng5y
# 29                           tamara  024vlq2
# 30                     william wall   04fmg5
# 31                       robin hood   0g0dy6
# 32                          hawkeye  0f6v53b
# 33                       phenomenon   09r8zj
# 34                        luminitza  03flhgg
# 35                        hollywood  0dnl20b
# 36               punk rock rarities  0fjr5vp
# 37                             free   0_0m6k
# 38                  this is my life  09gg50x
# 39                      helen grant  0c00djh
# 40        nude dimensions, volume 2  0fg5pnt
# 41  the london chuck berry sessions  0g7yfj_
# 42                        nascar 09  05nrqz9
# 43                       joe bowman  027qm91
# 44                       folk music    02w4v
# 45                       grant park  048_tdz
# 46                            texas    07b_l
# 47                          eclipse  03j7d4w
# 48                              bob    0bkf4
# 49                             iowa  0c5ss7y

# %% [markdown]
# ## Analysis - Numbers

# %%
from IPython.display import display, Markdown

total_rows = df.shape[0]
n_rows = sum(df.subject_name.notnull())
expected_percision = sum(1.0 / n for n in n_dups if n != 0) / n_rows
one_duplicate = sum(1 for n in n_dups if n == 1)
zero_duplicate = sum(1 for n in n_dups if n == 0)


display(Markdown(
    '##### Filter by the `relation` and true `subject_mid`, then the duplicate distribution is:\n' + 
    '- Number of examples: %d\n' % n_rows + 
    '- Median number of duplicates: %f\n' % statistics.median(n_dups) + 
    '- Max number of duplicates: %f\n' % max(n_dups) + 
    '- Mean number of duplicates: %f\n' % statistics.mean(n_dups) + 
    '- Stdev number of duplicates: %f\n' % statistics.stdev(n_dups) + 
    '- `subject_name`s with 0 duplicate: %f [%d of %d]\n' % (zero_duplicate / n_rows, zero_duplicate, n_rows) +  
    '- `subject_name`s with 1 duplicate: %f [%d of %d]\n' % (one_duplicate / n_rows, one_duplicate, n_rows) +  
    '- Expected percision with 100%% recall and random guessing: %f\n' % expected_percision
))
# Out:
# ##### Filter by the `relation` and true `subject_mid`, then the duplicate distribution is:
# - Number of examples: 10640
# - Median number of duplicates: 1.000000
# - Max number of duplicates: 2077.000000
# - Mean number of duplicates: 11.373778
# - Stdev number of duplicates: 73.552866
# - `subject_name`s with 0 duplicate: 0.000000 [0 of 10640]
# - `subject_name`s with 1 duplicate: 0.826692 [8796 of 10640]
# - Expected percision with 100% recall and random guessing: 0.872740

# %% [markdown]
# ## Step 3 - Better than random guessing
#
# Given {s_0, s_1, ...}, r, and {o_0, o_1, ...} the subject with the most atomic facts (s, r, o) in KG is most likely to get picked. The white paper states that their sampling strategy is a function f(r); therefore, if a particular subject has more atomic facts with relation r then is has a higher chance of getting picked during sampling.

# %%
import random 

correct = 0

def expected_accuracy(row, name_table=FB2M_NAME_TABLE, kg_table=FB2M_KG_TABLE):
    global correct
    mids = get_duplicate_mids(name_table, kg_table, row['subject_name'], row['relation'])
    mids = list(mids)
    if len(mids) > 1:
        scores = []
        for mid in mids:
            cursor.execute("""
                SELECT count(*)
                FROM {kg_table}
                WHERE subject_mid = %s
                AND relation = %s
            """.format(kg_table=kg_table), (mid, row['relation']))
            # Score is the number of facts associated with (s, r, ?)
            scores.append(cursor.fetchall()[0][0])
        max_score = max(scores)
        max_mids = [mids[i] for i, s in enumerate(scores) if s == max_score]
        if row['subject'] in max_mids:
            correct += 1 / len(max_mids)
    elif len(mids) == 1 and mids[0] == row['subject']:
        correct += 1
      
df[df.subject_name.notnull()].progress_apply(expected_accuracy, axis=1)
n_rows = sum(df.subject_name.notnull())
print('Better than Random Guessing Accuracy: %f [%d of %d]' % ((correct/ n_rows), correct, n_rows))
# Out:
# HBox(children=(IntProgress(value=0, max=10640), HTML(value='')))
# Better than Random Guessing Accuracy: 0.892452 [9495 of 10640]

# %% [markdown]
# ## Analysis - Empirical Examples of Duplicates
#
# Here we randomly sample the duplicates our algorithm found to assist in empirical analysis and verification of the algorithms correctness.
#
# The goal is to print out a random sample of duplicates and the facts associated with each duplicate. Empirically we verify that it's impossible for a human to tell apart the duplicate from the True answer.

# %%
from collections import defaultdict
import pprint

pp = pprint.PrettyPrinter(indent=2)
MAX_SAMPLE_DUPLICATE_MIDS = 5

def get_replaced_by(mid):
    # Check if the subject has been replaced; Otherwise, return the latter MID.
    cursor.execute("""
        SELECT object
        FROM fb
        WHERE subject = %s
        AND relation = '<http://rdf.freebase.com/ns/dataworld.gardening_hint.replaced_by>'
        """, (mid,))
    rows = [r[0] for r in cursor.fetchall()]
    assert len(rows) < 2
    if len(rows) == 1:
        return rows[0]
    else:
        return mid

def get_aliases(subject):
    # Get aliases for a subject. If there are no aliases, it returns the subject.
    if 'http://rdf.freebase.com/ns/m.' in subject:
        mid = subject
        cursor.execute("""
            SELECT object
            FROM fb
            WHERE subject = %s
            AND object LIKE '%%@en'
            AND relation IN ('<http://rdf.freebase.com/ns/type.object.name>',
                             '<http://rdf.freebase.com/ns/common.topic.alias>',
                             '<http://www.w3.org/2000/01/rdf-schema#label>',
                             '<http://rdf.freebase.com/ns/medicine.drug_formulation.brand_names>')
            """, (mid,))
        aliases = tuple(set([r[0] for r in cursor.fetchall()]))
        if len(aliases) == 0:
            return subject
        return aliases
    else:
        return subject

for i, row in tqdm_notebook(enumerate(random.sample(dups_data, 25))):
    print('\n\n[%s] Question: %s' % (i, row['Question']))
    print('Subject Name:', row['Subject Name'])
    print('Relation:', row['Relation'])
    print('Number of Duplicates:', len(row['Duplicate MIDs']))

    # Sample + Format duplicate MIDS
    duplicate_mids = list(row['Duplicate MIDs'])
    duplicate_mids = ['<http://rdf.freebase.com/ns/m.' + mid + '>' for mid in duplicate_mids]
    # NOTE: Some MIDs have been replaced; therefore, its important for us to follow that link
    duplicate_mids = set([get_replaced_by(m) for m in duplicate_mids])
    print('Replaced Duplicates (Same MID via dataworld.gardening_hint.replaced_by):', 
          len(row['Duplicate MIDs']) - len(duplicate_mids))
    sample_size = min(len(duplicate_mids), MAX_SAMPLE_DUPLICATE_MIDS)
    duplicate_mids = random.sample(duplicate_mids, sample_size)
    
    # Get aliases for the duplicate MIDS to ensure that the duplicate MIDs are referenced in the question
    print_aliases = [(mid, get_aliases(mid)) for mid in duplicate_mids]
    print('ALIASES:')
    pp.pprint(print_aliases)
    
    # GOAL: Facts should be pruned to only be facts useful for comparing the subjects
    # GOAL: Print facts in a human readable way to allow for quick empirical analysis
    # Get all facts for all duplicates mids
    cursor.execute("""
        SELECT subject, relation, object
        FROM fb
        WHERE subject = ANY(%s)
    """, (duplicate_mids,))
    facts = cursor.fetchall()
    
    # Get english names for Freebase nodes to make it human readable
    facts = [(s, r, get_aliases(o)) for (s, r, o) in facts]
    
    # Filter facts every subject has in common
    common_facts = defaultdict(set)
    for s, r, o in facts:
        common_facts[(r, o)].add(s)
    facts = [(s, r, o) for (s, r, o) in facts if len(common_facts[(r, o)]) < sample_size]

    # Filter relations that every duplicate subject does not address
    # Those relations are less helpful at finding differences amoung subjects
    relation_to_subjects = defaultdict(set)
    for subject, relation, object_ in facts:
        relation_to_subjects[relation].add(subject)
    facts = [(s, r, o) for (s, r, o) in facts if len(relation_to_subjects[r]) >= sample_size]
    
    # Group together facts and pretty print
    print_facts = defaultdict(lambda: defaultdict(lambda: set()))
    for s, r, o in facts:
        # NOTE: Freebase nodes are not helpful
        if 'http://rdf.freebase.com/ns/m.' in o or 'http://rdf.freebase.com/ns/g.' in o:
            continue
        
        # NOTE: Descriptions are long and not helpful
        # TODO: Not sure how to use to type.object.key but lots of facts are around that relation
        if 'common.topic.description' in r or 'key' in r:
            continue

        r = r.replace('<http://rdf.freebase.com/', '')
        r = r.replace('>', '')
        s = s.replace('<http://rdf.freebase.com/ns/m.', '')
        s = s.replace('>', '')
        if isinstance(o, (set, list)):
            print_facts[r][s].update(o)
        else:
            print_facts[r][s].add(o)

    # Print
    # Remove defaultdict to print prettier
    print_facts = dict(print_facts)
    for r, values in print_facts.items():
        print_facts[r] = dict(values)
    
    print('COMPARABLE FACTS:')
    pp.pprint(print_facts)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# [0] Question: What is the language of the film bon voyage?
# Subject Name: bon voyage
# Relation: film/film/language
# Number of Duplicates: 4
# Replaced Duplicates (Same MID via dataworld.gardening_hint.replaced_by): 0
# ALIASES:
# [ ('<http://rdf.freebase.com/ns/m.0k3qrvh>', ('"Bon Voyage"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0gmhlt>', ('"Bon Voyage"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0gkrfmk>', ('"Bon Voyage"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0b4pm3>', ('"Bon Voyage"@en',))]
# COMPARABLE FACTS:
# { '<http://www.w3.org/2000/01/rdf-schema#label': { '0b4pm3': { '"Bon '
#                                                                'Voyage"@ca',
#                                                                '"Bon '
#                                                                'Voyage"@fi',
#                                                                '"Bon '
#                                                                'Voyage"@fr',
#                                                                '"Bon '
#                                                                'Voyage"@it',
#                                                                '"Bon '
#                                                                'Voyage"@nl',
#                                                                '"Bon '
#                                                                'Voyage"@pl',
#                                                                '"Bon '
#                                                                'Voyage"@ro',
#                                                                '"Gute '
#                                                                'Reise"@de',
#                                                                '"Jó utat"@hu',
#                                                                '"Καλό '
#                                                                'ταξίδι"@el',
#                                                                '"На добър '
#                                                                'път"@bg',
#                                                                '"سفر امن"@fa'},
#                                                    '0gkrfmk': {'"봉 보야쥬"@ko'},
#                                                    '0gmhlt': { '"Bon '
#                                                                'Voyage"@de',
#                                                                '"Bon '
#                                                                'Voyage"@fr',
#                                                                '"Bon '
#                                                                'Voyage"@pl',
#                                                                '"Bon '
#                                                                'Voyage"@sv',
#                                                                '"Bon '
#                                                                'voyage"@da',
#                                                                '"Bon '
#                                                                'voyage"@es',
#                                                                '"Bon '
#                                                                'voyage"@it',
#                                                                '"Drum bun"@ro',
#                                                                '"Viagem do '
#                                                                'Coração"@pt',
#                                                                '"Щасливої '
#                                                                'дороги!"@uk',
#                                                                '"บองโวยาจ...ถนนสายชีวิต"@th',
#                                                                '"즐거운 여행"@ko'},
#                                                    '0k3qrvh': { '"Bon '
#                                                                 'voyage"@ro'}},
#   'ns/common.topic.notable_types': { '0b4pm3': { ( '"Motion Picture"@en',
#                                                    '"Film"@en',
#                                                    '"Movie"@en')},
#                                      '0gkrfmk': { ( '"Motion Picture"@en',
#                                                     '"Film"@en',
#                                                     '"Movie"@en')},
#                                      '0gmhlt': {('"Award-Winning Work"@en',)},
#                                      '0k3qrvh': { ( '"Motion Picture"@en',
#                                                     '"Film"@en',
#                                                     '"Movie"@en')}},
#   'ns/common.topic.topic_equivalent_webpage': { '0b4pm3': { '<http://bg.wikipedia.org/wiki/%1D%30_%34%3E%31%4A%40_%3F%4A%42>',
#                                                             '<http://bg.wikipedia.org/wiki/index.html?curid=476576>',
#                                                             '<http://ca.wikipedia.org/wiki/Bon_Voyage>',
#                                                             '<http://ca.wikipedia.org/wiki/index.html?curid=927653>',
#                                                             '<http://de.wikipedia.org/wiki/Gute_Reise>',
#                                                             '<http://de.wikipedia.org/wiki/index.html?curid=751884>',
#                                                             '<http://el.wikipedia.org/wiki/%9A%B1%BB%CC_%C4%B1%BE%AF%B4%B9>',
#                                                             '<http://el.wikipedia.org/wiki/index.html?curid=288031>',
#                                                             '<http://en.wikipedia.org/wiki/Bon_Voyage_(1944_film)>',
#                                                             '<http://en.wikipedia.org/wiki/index.html?curid=3878392>',
#                                                             '<http://fa.wikipedia.org/wiki/%33%41%31_%27%45%46_(%41%CC%44%45_%F1%F9%F4%F4)>',
#                                                             '<http://fa.wikipedia.org/wiki/index.html?curid=3225368>',
#                                                             '<http://fi.wikipedia.org/wiki/Bon_Voyage>',
#                                                             '<http://fi.wikipedia.org/wiki/index.html?curid=1175739>',
#                                                             '<http://fr.wikipedia.org/wiki/Bon_Voyage_(film,_1944)>',
#                                                             '<http://fr.wikipedia.org/wiki/index.html?curid=804335>',
#                                                             '<http://it.wikipedia.org/wiki/Bon_Voyage>',
#                                                             '<http://it.wikipedia.org/wiki/index.html?curid=701829>',
#                                                             '<http://nl.wikipedia.org/wiki/Bon_Voyage_(1944)>',
#                                                             '<http://nl.wikipedia.org/wiki/index.html?curid=2088614>',
#                                                             '<http://www.allocine.fr/film/fichefilm_gen_cfilm=6809.html>',
#                                                             '<http://www.imdb.com/title/tt0036659/>'},
#                                                 '0gkrfmk': { '<http://movie.daum.net/moviedetail/moviedetailMain.do?movieId=43371>',
#                                                              '<http://movie.nate.com/movie/movieinfo?cinema_id=40482>',
#                                                              '<http://www.cine21.com/do/movie/detail/main?movie_id=22557>',
#                                                              '<http://www.imdb.com/title/tt0475524/>'},
#                                                 '0gmhlt': { '<http://da.wikipedia.org/wiki/Bon_voyage_(2003)>',
#                                                             '<http://da.wikipedia.org/wiki/index.html?curid=262554>',
#                                                             '<http://en.wikipedia.org/wiki/Bon_Voyage_(2003_film)>',
#                                                             '<http://en.wikipedia.org/wiki/index.html?curid=6758985>',
#                                                             '<http://es.wikipedia.org/wiki/Bon_voyage_(pel%EDcula)>',
#                                                             '<http://es.wikipedia.org/wiki/index.html?curid=2065822>',
#                                                             '<http://fr.wikipedia.org/wiki/Bon_Voyage_(film,_2003)>',
#                                                             '<http://fr.wikipedia.org/wiki/index.html?curid=291603>',
#                                                             '<http://it.wikipedia.org/wiki/Bon_voyage>',
#                                                             '<http://it.wikipedia.org/wiki/index.html?curid=1719317>',
#                                                             '<http://movi.es/ApUqD>',
#                                                             '<http://movie.nate.com/movie/movieinfo?cinema_id=18190>',
#                                                             '<http://th.wikipedia.org/wiki/%1A%2D%07%42%27%22%32%08...%16%19%19%2A%32%22%0A%35%27%34%15>',
#                                                             '<http://th.wikipedia.org/wiki/index.html?curid=197392>',
#                                                             '<http://uk.wikipedia.org/wiki/%29%30%41%3B%38%32%3E%57_%34%3E%40%3E%33%38!_(%44%56%3B%4C%3C)>',
#                                                             '<http://uk.wikipedia.org/wiki/index.html?curid=1934271>',
#                                                             '<http://www.allocine.ca/film/fichefilm_gen_cfilm=43958.html>',
#                                                             '<http://www.allocine.fr/film/fichefilm_gen_cfilm=43958.html>',
#                                                             '<http://www.beyazperde.com/filmler/film-43958>',
#                                                             '<http://www.cineseoul.com/movies/cinedata.html?cinemaID=18190>',
#                                                             '<http://www.filmstarts.de/kritiken/37286-Bon-Voyage.html>',
#                                                             '<http://www.imdb.com/title/tt0310778/>',
#                                                             '<http://www.metacritic.com/film/titles/bonvoyage>',
#                                                             '<http://www.movist.com/movies/movie.asp?mid=16717>',
#                                                             '<http://www.movli.com/movie/bon-voyage-6209>',
#                                                             '<http://www.ranker.com/review/bon-voyage/610608>',
#                                                             '<http://www.rottentomatoes.com/m/1130780-bon_voyage/>',
#                                                             '<http://www.screenrush.co.uk/films/film-43958>'},
#                                                 '0k3qrvh': { '<http://www.imdb.com/title/tt2373248/>',
#                                                              '<http://www.movli.com/movie/bon-voyage-449654>'}},
#   'ns/film.film.country': { '0b4pm3': { ( '"GBR"@en',
#                                           '"The United Kingdom of Great '
#                                           'Britain and Northern Ireland"@en',
#                                           '"United Kingdom of Great Britain '
#                                           'and Northern Ireland"@en',
#                                           '"Great Britain"@en',
#                                           '"United Kingdom"@en',
#                                           '"United Kingdom of Great '
#                                           'Britain"@en',
#                                           '"Britain"@en',
#                                           '"GB"@en',
#                                           '"United Kingdom of Great Britain '
#                                           'and Ireland"@en',
#                                           '"UK"@en',
#                                           '"U.K."@en')},
#                             '0gkrfmk': { ( '"GBR"@en',
#                                            '"The United Kingdom of Great '
#                                            'Britain and Northern Ireland"@en',
#                                            '"United Kingdom of Great Britain '
#                                            'and Northern Ireland"@en',
#                                            '"Great Britain"@en',
#                                            '"United Kingdom"@en',
#                                            '"United Kingdom of Great '
#                                            'Britain"@en',
#                                            '"Britain"@en',
#                                            '"GB"@en',
#                                            '"United Kingdom of Great Britain '
#                                            'and Ireland"@en',
#                                            '"UK"@en',
#                                            '"U.K."@en'),
#                                          ( '"République française"@en',
#                                            '"l\'Hexagone"@en',
#                                            '"French Republic"@en',
#                                            '"France"@en')},
#                             '0gmhlt': { ( '"République française"@en',
#                                           '"l\'Hexagone"@en',
#                                           '"French Republic"@en',
#                                           '"France"@en')},
#                             '0k3qrvh': { ( '"Helvetia"@en',
#                                            '"Schweiz"@en',
#                                            '"Svizra"@en',
#                                            '"Svizzera"@en',
#                                            '"La Suisse"@en',
#                                            '"Switzerland"@en',
#                                            '"Swiss Confederation"@en')}},
#   'ns/film.film.genre': { '0b4pm3': { ( '"Short Film"@en',
#                                         '"Short subject"@en',
#                                         '"Short films"@en',
#                                         '"Short"@en'),
#                                       ('"War"@en', '"War film"@en')},
#                           '0gkrfmk': { ( '"Short Film"@en',
#                                          '"Short subject"@en',
#                                          '"Short films"@en',
#                                          '"Short"@en')},
#                           '0gmhlt': { ('"Comedy film"@en', '"Comedy"@en'),
#                                       ( '"Drama"@en',
#                                         '"Television drama"@en',
#                                         '"Drama film"@en',
#                                         '"/m/02822"@en',
#                                         '"Dramatic programming"@en'),
#                                       ( '"Mystery fiction"@en',
#                                         '"Mystery film"@en',
#                                         '"Mystery novel"@en',
#                                         '"Mystery"@en'),
#                                       ( '"Romance Film"@en',
#                                         '"Romantic drama"@en',
#                                         '"Romance"@en'),
#                                       ('"Thriller"@en',),
#                                       ('"War"@en', '"War film"@en')},
#                           '0k3qrvh': { ('"Animation"@en', '"Animated"@en'),
#                                        ( '"Short Film"@en',
#                                          '"Short subject"@en',
#                                          '"Short films"@en',
#                                          '"Short"@en')}},
#   'ns/film.film.language': { '0b4pm3': { ( '"Français"@en',
#                                            '"French language"@en',
#                                            '"Francais"@en',
#                                            '"French"@en')},
#                              '0gkrfmk': { ( '"Sekgoa"@en',
#                                             '"English Language"@en',
#                                             '"English"@en',
#                                             '"Anglit"@en',
#                                             '"English language"@en')},
#                              '0gmhlt': { ( '"Français"@en',
#                                            '"French language"@en',
#                                            '"Francais"@en',
#                                            '"French"@en'),
#                                          ( '"High German"@en',
#                                            '"Tedesco"@en',
#                                            '"German Language"@en',
#                                            '"Hochdeutsch"@en',
#                                            '"German, Standard Language"@en',
#                                            '"German, Standard"@en',
#                                            '"Deutsch"@en',
#                                            '"German"@en'),
#                                          ( '"Italian Language"@en',
#                                            '"Italiano"@en',
#                                            '"Italian"@en'),
#                                          ( '"Sekgoa"@en',
#                                            '"English Language"@en',
#                                            '"English"@en',
#                                            '"Anglit"@en',
#                                            '"English language"@en')},
#                              '0k3qrvh': { ( '"Sekgoa"@en',
#                                             '"English Language"@en',
#                                             '"English"@en',
#                                             '"Anglit"@en',
#                                             '"English language"@en')}},
#   'ns/imdb.topic.title_id': { '0b4pm3': {'"tt0036659"'},
#                               '0gkrfmk': {'"tt0475524"'},
#                               '0gmhlt': {'"tt0310778"'},
#                               '0k3qrvh': {'"tt2373248"'}},
#   'ns/kg.object_profile.prominent_type': { '0b4pm3': { '<http://rdf.freebase.com/ns/film.film>'},
#                                            '0gkrfmk': { '<http://rdf.freebase.com/ns/film.film>'},
#                                            '0gmhlt': { '<http://rdf.freebase.com/ns/award.award_winning_work>'},
#                                            '0k3qrvh': { '<http://rdf.freebase.com/ns/film.film>'}},
#   'ns/type.object.name': { '0b4pm3': { '"Bon Voyage"@ca',
#                                        '"Bon Voyage"@fi',
#                                        '"Bon Voyage"@fr',
#                                        '"Bon Voyage"@it',
#                                        '"Bon Voyage"@nl',
#                                        '"Bon Voyage"@pl',
#                                        '"Bon Voyage"@ro',
#                                        '"Gute Reise"@de',
#                                        '"Jó utat"@hu',
#                                        '"Καλό ταξίδι"@el',
#                                        '"На добър път"@bg',
#                                        '"سفر امن"@fa'},
#                            '0gkrfmk': {'"봉 보야쥬"@ko'},
#                            '0gmhlt': { '"Bon Voyage"@de',
#                                        '"Bon Voyage"@fr',
#                                        '"Bon Voyage"@pl',
#                                        '"Bon Voyage"@sv',
#                                        '"Bon voyage"@da',
#                                        '"Bon voyage"@es',
#                                        '"Bon voyage"@it',
#                                        '"Drum bun"@ro',
#                                        '"Viagem do Coração"@pt',
#                                        '"Щасливої дороги!"@uk',
#                                        '"บองโวยาจ...ถนนสายชีวิต"@th',
#                                        '"즐거운 여행"@ko'},
#                            '0k3qrvh': {'"Bon voyage"@ro'}}}
#
#
# [1] Question: whats a version of the single titled  star
# Subject Name: star
# Relation: music/single/versions
# Number of Duplicates: 49
# Replaced Duplicates (Same MID via dataworld.gardening_hint.replaced_by): 0
# ALIASES:
# [ ('<http://rdf.freebase.com/ns/m.0vp0pf>', ('"Star"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0lgngy>', ('"Star"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0mlj_h>', ('"Star"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0dzb769>', ('"Star"@en',)),
#   ('<http://rdf.freebase.com/ns/m.01cy1z3>', ('"Star"@en',))]
# COMPARABLE FACTS:
# { 'ns/common.topic.topic_equivalent_webpage': { '01cy1z3': { '<http://musicbrainz.org/recording/5bcaee08-f2ed-4929-8d9d-6d43055f2291>'},
#                                                 '0dzb769': { '<http://musicbrainz.org/recording/5abade30-bc7e-4367-a82a-96350db6fdc8>'},
#                                                 '0lgngy': { '<http://musicbrainz.org/recording/54f7f77f-47fa-4d1a-868b-9e9c9aa3db2b>',
#                                                             '<http://musicbrainz.org/recording/ffc18c9a-abdb-4803-8d16-3dced1e1bd72>'},
#                                                 '0mlj_h': { '<http://musicbrainz.org/recording/0b08040d-fd3d-4880-85dc-2dc1e6e13ce1>',
#                                                             '<http://musicbrainz.org/recording/43950ae1-3657-48c9-aaca-c487b35e4871>',
#                                                             '<http://musicbrainz.org/recording/67875606-2b80-4081-a9f6-5d8f2c04c854>',
#                                                             '<http://musicbrainz.org/recording/7341a22c-cd3b-4947-8743-ed8563d771d9>'},
#                                                 '0vp0pf': { '<http://musicbrainz.org/recording/88db4141-cd0f-4f64-a722-8790ed854810>'}},
#   'ns/music.recording.artist': { '01cy1z3': { ( '"The Hollies"@en',
#                                                 '"Hollies"@en',
#                                                 '"Hollies, The"@en')},
#                                  '0dzb769': {('"The Roots"@en',)},
#                                  '0lgngy': { ( '"The Cult - Labbatt Tracks"@en',
#                                                '"Death Cult"@en',
#                                                '"Cult, The"@en',
#                                                '"The Cult"@en')},
#                                  '0mlj_h': { ( '"Gigi D\'Agostini"@en',
#                                                '"Dottor Dag"@en',
#                                                '"Giggi Dagostino"@en',
#                                                '"Lento Violento Man"@en',
#                                                '"Gigi D\'Agostino"@en',
#                                                '"La Tana Del Suono"@en',
#                                                '"Gigi DAgostino"@en',
#                                                '"D\'Agostino Planet"@en',
#                                                '"GiGi D\'Agnostino"@en',
#                                                '"Gigi D’Agostino"@en',
#                                                '"Gigi D Agostino"@en',
#                                                '"Luigi Di Agostino"@en',
#                                                '"Gigi D\'Agostiono"@en',
#                                                '"Il Folklorista"@en',
#                                                '"D\'Agostino, Gigi"@en',
#                                                '"Dotter Dag"@en',
#                                                '"Gigi D\' Agostino"@en',
#                                                '"GG D\'Ag"@en',
#                                                '"Gigi D´agostino"@en',
#                                                '"Gigi D\'Agostino)"@en',
#                                                '"Lento violento Man"@en',
#                                                '"Love Transistor"@en',
#                                                '"Noise Maker"@en')},
#                                  '0vp0pf': {('"Hanadensha"@en',)}},
#   'ns/music.recording.length': { '01cy1z3': {'"197.0"'},
#                                  '0dzb769': {'"373.0"'},
#                                  '0lgngy': {'"302.373"'},
#                                  '0mlj_h': {'"324.2"'},
#                                  '0vp0pf': {'"261.133"'}},
#   'ns/music.recording.releases': { '01cy1z3': {('"Live Hits"@en',)},
#                                    '0dzb769': {('"The Tipping Point"@en',)},
#                                    '0lgngy': {('"The Cult"@en',)},
#                                    '0mlj_h': { ('"L\'Amour Toujours"@en',),
#                                                ( '"L\'amour Toujours (disc 1: '
#                                                  'Chansons for the '
#                                                  'Heart)"@en',),
#                                                ('"L’Amour Toujours"@en',)},
#                                    '0vp0pf': {('"Narcotic Guitar"@en',)}}}
#
#
# [2] Question: which recordings contains the composition australia?
# Subject Name: australia
# Relation: music/composition/recordings
# Number of Duplicates: 9
# Replaced Duplicates (Same MID via dataworld.gardening_hint.replaced_by): 1
# ALIASES:
# [ ('<http://rdf.freebase.com/ns/m.0_62f1p>', ('"Australia"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0465qnd>', ('"Australia"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0kpg4sd>', ('"Australia"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0_hqxrc>', ('"Australia"@en',)),
#   ('<http://rdf.freebase.com/ns/m.02prsd4>', ('"Australia"@en',))]
# COMPARABLE FACTS:
# { 'ns/common.topic.notable_types': { '02prsd4': { ( '"Composition"@en',
#                                                     '"Song"@en')},
#                                      '0465qnd': { ( '"Composition"@en',
#                                                     '"Song"@en')},
#                                      '0_62f1p': { ( '"Composition"@en',
#                                                     '"Song"@en')},
#                                      '0_hqxrc': { ( '"Composition"@en',
#                                                     '"Song"@en')},
#                                      '0kpg4sd': {('"TV theme song"@en',)}},
#   'ns/common.topic.topic_equivalent_webpage': { '02prsd4': { '<http://en.wikipedia.org/wiki/Australia_(The_Shins_song)>',
#                                                              '<http://en.wikipedia.org/wiki/index.html?curid=9773455>'},
#                                                 '0465qnd': { '<http://en.wikipedia.org/wiki/Australia_(Gyroscope_song)>',
#                                                              '<http://en.wikipedia.org/wiki/index.html?curid=17605271>'},
#                                                 '0_62f1p': { '<http://musicbrainz.org/work/d354c3f0-c06a-409d-87d8-d598a18b1791>'},
#                                                 '0_hqxrc': { '<http://musicbrainz.org/work/119192b7-782e-4ace-9f35-c0d3d3850108>'},
#                                                 '0kpg4sd': { '<http://en.wikipedia.org/wiki/Australia_(Manic_Street_Preachers_song)>',
#                                                              '<http://en.wikipedia.org/wiki/index.html?curid=601334>',
#                                                              '<http://es.wikipedia.org/wiki/Australia_(canci%F3n)>',
#                                                              '<http://es.wikipedia.org/wiki/index.html?curid=3481056>',
#                                                              '<http://musicbrainz.org/work/12524330-5983-4225-ad22-7a73e254baeb>'}},
#   'ns/kg.object_profile.prominent_type': { '02prsd4': { '<http://rdf.freebase.com/ns/music.composition>'},
#                                            '0465qnd': { '<http://rdf.freebase.com/ns/music.composition>'},
#                                            '0_62f1p': { '<http://rdf.freebase.com/ns/music.composition>'},
#                                            '0_hqxrc': { '<http://rdf.freebase.com/ns/music.composition>'},
#                                            '0kpg4sd': { '<http://rdf.freebase.com/ns/tv.tv_theme_song>'}}}
#
#
# [3] Question: what country is ghost house from
# Subject Name: ghost house
# Relation: film/film/country
# Number of Duplicates: 4
# Replaced Duplicates (Same MID via dataworld.gardening_hint.replaced_by): 0
# ALIASES:
# [ ( '<http://rdf.freebase.com/ns/m.08jcb1>',
#     ('"Ghost House"@en', '"Bhoot"@en', '"Ghost"@en')),
#   ( '<http://rdf.freebase.com/ns/m.09gbzy0>',
#     ('"Ghost House"@en', '"Deadline - Focus Your Fear"@en', '"Deadline"@en')),
#   ( '<http://rdf.freebase.com/ns/m.0d5jxc>',
#     ( '"Messengers"@en',
#       '"The Messengers"@en',
#       '"The Untitled Pang Brothers Horror Project"@en',
#       '"ghost house"@en',
#       '"Scarecrow"@en')),
#   ( '<http://rdf.freebase.com/ns/m.0b1xf4>',
#     ( '"Ghost Lives"@en',
#       '"Ghost House"@en',
#       '"Kwisini sanda"@en',
#       '"Gwishini sanda"@en'))]
# COMPARABLE FACTS:
# { '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type': { '08jcb1': { '<http://rdf.freebase.com/ns/award.award_nominated_work>',
#                                                                     '<http://rdf.freebase.com/ns/award.award_winning_work>',
#                                                                     '<http://rdf.freebase.com/ns/base.ovguide.bollywood_films>',
#                                                                     '<http://rdf.freebase.com/ns/base.ovguide.topic>'},
#                                                         '09gbzy0': { '<http://rdf.freebase.com/ns/media_common.netflix_title>'},
#                                                         '0b1xf4': { '<http://rdf.freebase.com/ns/user.alust.default_domain.processed_with_review_queue>'},
#                                                         '0d5jxc': { '<http://rdf.freebase.com/ns/media_common.netflix_title>'}},
#   '<http://www.w3.org/2000/01/rdf-schema#label': { '08jcb1': { '"Bhoot"@en',
#                                                                '"Bhoot"@fr',
#                                                                '"Bhoot"@it',
#                                                                '"Bhoot"@pl',
#                                                                '"بووت"@ar',
#                                                                '"भूत"@hi'},
#                                                    '09gbzy0': { '"Deadline – '
#                                                                 'Focus Your '
#                                                                 'Fear"@de',
#                                                                 '"Deadline"@da',
#                                                                 '"Deadline"@en',
#                                                                 '"Deadline"@es',
#                                                                 '"Deadline"@fi',
#                                                                 '"Deadline"@fr',
#                                                                 '"Deadline"@it',
#                                                                 '"Deadline"@sv',
#                                                                 '"Deadline"@tr',
#                                                                 '"Flashes de '
#                                                                 'uma '
#                                                                 'Psicose"@pt',
#                                                                 '"Flashes de '
#                                                                 'uma '
#                                                                 'Psicose"@pt-BR',
#                                                                 '"Termen-limită"@ro',
#                                                                 '"Termin"@pl',
#                                                                 '"Дедлайн"@ru',
#                                                                 '"Дедлайн"@uk',
#                                                                 '"데드라인"@ko'},
#                                                    '0b1xf4': { '"Ghost '
#                                                                'House"@en',
#                                                                '"Gwishini '
#                                                                'sanda"@pl',
#                                                                '"浪漫鬼屋"@zh',
#                                                                '"浪漫鬼屋"@zh-Hant',
#                                                                '"귀신이 산다"@ko'},
#                                                    '0d5jxc': { '"A hírnök"@hu',
#                                                                '"Glasnici '
#                                                                'zla"@hr',
#                                                                '"Glasniki '
#                                                                'zla"@sl',
#                                                                '"Les '
#                                                                'Messagers"@fr',
#                                                                '"Mesagerii"@ro',
#                                                                '"Os '
#                                                                'Mensageiros"@pt',
#                                                                '"Pahan '
#                                                                'sanansaattajat"@fi',
#                                                                '"Posłańcy"@pl',
#                                                                '"Prokletí domu '
#                                                                'slunečnic"@cs',
#                                                                '"The '
#                                                                'Messengers"@ca',
#                                                                '"The '
#                                                                'Messengers"@da',
#                                                                '"The '
#                                                                'Messengers"@de',
#                                                                '"The '
#                                                                'Messengers"@en',
#                                                                '"The '
#                                                                'Messengers"@es',
#                                                                '"The '
#                                                                'Messengers"@id',
#                                                                '"The '
#                                                                'Messengers"@it',
#                                                                '"The '
#                                                                'Messengers"@nl',
#                                                                '"The '
#                                                                'Messengers"@no',
#                                                                '"The '
#                                                                'Messengers"@sv',
#                                                                '"The '
#                                                                'Messengers"@tr',
#                                                                '"Посланники"@ru',
#                                                                '"השליחים"@iw',
#                                                                '"الرسل"@ar',
#                                                                '"پیام\u200cرسان"@fa',
#                                                                '"คนเห็นโคตรผี"@th',
#                                                                '"ゴースト・ハウス"@ja',
#                                                                '"鬼使神差"@zh',
#                                                                '"鬼使神差"@zh-Hant',
#                                                                '"메신져 - 죽은자들의 '
#                                                                '경고"@ko'}},
#   'ns/common.topic.alias': { '08jcb1': {'"Ghost House"@en', '"Ghost"@en'},
#                              '09gbzy0': { '"Deadline - Focus Your Fear"@en',
#                                           '"Deadline"@ro',
#                                           '"Ghost House"@en',
#                                           '"Prazo Mortal"@pt'},
#                              '0b1xf4': { '"Ghost Lives"@en',
#                                          '"Gwishini sanda"@en',
#                                          '"Kwisini sanda"@en'},
#                              '0d5jxc': { '"Messengers"@en',
#                                          '"Scarecrow"@en',
#                                          '"The Messengers"@ro',
#                                          '"The Untitled Pang Brothers Horror '
#                                          'Project"@en',
#                                          '"ghost house"@en',
#                                          '"信使"@zh-Hant',
#                                          '"鬼差"@zh-Hant'}},
#   'ns/common.topic.notable_types': { '08jcb1': {('"Award-Winning Work"@en',)},
#                                      '09gbzy0': { ( '"Motion Picture"@en',
#                                                     '"Film"@en',
#                                                     '"Movie"@en')},
#                                      '0b1xf4': { ( '"Motion Picture"@en',
#                                                    '"Film"@en',
#                                                    '"Movie"@en')},
#                                      '0d5jxc': { ( '"Motion Picture"@en',
#                                                    '"Film"@en',
#                                                    '"Movie"@en')}},
#   'ns/common.topic.topic_equivalent_webpage': { '08jcb1': { '<http://en.wikipedia.org/wiki/Bhoot_(film)>',
#                                                             '<http://en.wikipedia.org/wiki/index.html?curid=2994151>',
#                                                             '<http://fr.wikipedia.org/wiki/Bhoot_(film)>',
#                                                             '<http://fr.wikipedia.org/wiki/index.html?curid=3847057>',
#                                                             '<http://hi.wikipedia.org/wiki/%2D%42%24_(2003_%2B%3C%3F%32%4D%2E)>',
#                                                             '<http://hi.wikipedia.org/wiki/index.html?curid=25121>',
#                                                             '<http://it.wikipedia.org/wiki/Bhoot>',
#                                                             '<http://it.wikipedia.org/wiki/index.html?curid=4022052>',
#                                                             '<http://pl.wikipedia.org/wiki/Bhoot>',
#                                                             '<http://pl.wikipedia.org/wiki/index.html?curid=1171413>',
#                                                             '<http://www.allocine.ca/film/fichefilm_gen_cfilm=90676.html>',
#                                                             '<http://www.allocine.fr/film/fichefilm_gen_cfilm=90676.html>',
#                                                             '<http://www.imdb.com/title/tt0341266/>',
#                                                             '<http://www.movli.com/movie/bhoot-72047>',
#                                                             '<http://www.ranker.com/review/bhoot/578561>',
#                                                             '<http://www.rottentomatoes.com/m/bhoot/>',
#                                                             '<http://www.screenrush.co.uk/films/film-90676>'},
#                                                 '09gbzy0': { '<http://de.wikipedia.org/wiki/Deadline_%13_Focus_Your_Fear>',
#                                                              '<http://de.wikipedia.org/wiki/index.html?curid=5077619>',
#                                                              '<http://en.wikipedia.org/wiki/Deadline_(2009_film)>',
#                                                              '<http://en.wikipedia.org/wiki/index.html?curid=25226299>',
#                                                              '<http://es.wikipedia.org/wiki/Deadline_(pel%EDcula_de_2009)>',
#                                                              '<http://es.wikipedia.org/wiki/index.html?curid=4471513>',
#                                                              '<http://fr.wikipedia.org/wiki/Deadline_(film,_2009)>',
#                                                              '<http://fr.wikipedia.org/wiki/index.html?curid=8011520>',
#                                                              '<http://movi.es/BVmuh>',
#                                                              '<http://movie.daum.net/moviedetail/moviedetailMain.do?movieId=55244>',
#                                                              '<http://movie.nate.com/movie/movieinfo?cinema_id=48654>',
#                                                              '<http://pl.wikipedia.org/wiki/Termin_(film_2009)>',
#                                                              '<http://pl.wikipedia.org/wiki/index.html?curid=2518374>',
#                                                              '<http://pt.wikipedia.org/wiki/Deadline_(filme)>',
#                                                              '<http://pt.wikipedia.org/wiki/index.html?curid=4609170>',
#                                                              '<http://sv.wikipedia.org/wiki/Deadline_(2009)>',
#                                                              '<http://sv.wikipedia.org/wiki/index.html?curid=1106700>',
#                                                              '<http://www.allocine.ca/film/fichefilm_gen_cfilm=137146.html>',
#                                                              '<http://www.allocine.fr/film/fichefilm_gen_cfilm=137146.html>',
#                                                              '<http://www.cine21.com/do/movie/detail/main?movie_id=28396>',
#                                                              '<http://www.cineseoul.com/movies/cinedata.html?cinemaID=41806>',
#                                                              '<http://www.filmstarts.de/kritiken/104840-Deadline.html>',
#                                                              '<http://www.imdb.com/title/tt1242618/>',
#                                                              '<http://www.kinopoisk.ru/level/1/film/418799>',
#                                                              '<http://www.maxmovie.com/movie_info/detail.asp?m_id=M000066978>',
#                                                              '<http://www.movist.com/movies/movie.asp?mid=42694>',
#                                                              '<http://www.movli.com/movie/deadline-55901>',
#                                                              '<http://www.netflix.com/Movie/70115891>',
#                                                              '<http://www.screenrush.co.uk/films/film-137146>'},
#                                                 '0b1xf4': { '<http://en.wikipedia.org/wiki/Ghost_House>',
#                                                             '<http://en.wikipedia.org/wiki/index.html?curid=3824857>',
#                                                             '<http://ko.wikipedia.org/wiki/%C0%E0%74_%B0%E4>',
#                                                             '<http://ko.wikipedia.org/wiki/index.html?curid=330332>',
#                                                             '<http://movie.daum.net/moviedetail/moviedetailMain.do?movieId=39411>',
#                                                             '<http://movie.nate.com/movie/movieinfo?cinema_id=20172>',
#                                                             '<http://pl.wikipedia.org/wiki/Gwishini_sanda>',
#                                                             '<http://pl.wikipedia.org/wiki/index.html?curid=494170>',
#                                                             '<http://www.cine21.com/do/movie/detail/main?movie_id=8586>',
#                                                             '<http://www.imdb.com/title/tt0420660/>',
#                                                             '<http://www.maxmovie.com/movie_info/detail.asp?m_id=M000018516>',
#                                                             '<http://www.movist.com/movies/movie.asp?mid=8829>',
#                                                             '<http://zh.wikipedia.org/wiki/index.html?curid=3516146>',
#                                                             '<http://zh.wikipedia.org/zh-cn/%6A%2B%3C%4B>',
#                                                             '<http://zh.wikipedia.org/zh-tw/%6A%2B%3C%4B>'},
#                                                 '0d5jxc': { '<http://ar.wikipedia.org/wiki/%27%44%31%33%44_(%41%4A%44%45)>',
#                                                             '<http://ar.wikipedia.org/wiki/index.html?curid=1903627>',
#                                                             '<http://da.wikipedia.org/wiki/The_Messengers>',
#                                                             '<http://da.wikipedia.org/wiki/index.html?curid=468202>',
#                                                             '<http://de.wikipedia.org/wiki/The_Messengers>',
#                                                             '<http://de.wikipedia.org/wiki/index.html?curid=4072776>',
#                                                             '<http://en.wikipedia.org/wiki/The_Messengers_(film)>',
#                                                             '<http://en.wikipedia.org/wiki/index.html?curid=5159254>',
#                                                             '<http://es.wikipedia.org/wiki/The_Messengers>',
#                                                             '<http://es.wikipedia.org/wiki/index.html?curid=4667431>',
#                                                             '<http://fa.wikipedia.org/wiki/%7E%CC%27%45%0C%31%33%27%46_(%41%CC%44%45)>',
#                                                             '<http://fa.wikipedia.org/wiki/index.html?curid=3367775>',
#                                                             '<http://fi.wikipedia.org/wiki/Pahan_sanansaattajat>',
#                                                             '<http://fi.wikipedia.org/wiki/index.html?curid=374917>',
#                                                             '<http://fr.wikipedia.org/wiki/Les_Messagers>',
#                                                             '<http://fr.wikipedia.org/wiki/index.html?curid=3582377>',
#                                                             '<http://hr.wikipedia.org/wiki/Glasnici_zla>',
#                                                             '<http://hr.wikipedia.org/wiki/index.html?curid=204297>',
#                                                             '<http://it.wikipedia.org/wiki/The_Messengers>',
#                                                             '<http://it.wikipedia.org/wiki/index.html?curid=1209286>',
#                                                             '<http://ja.wikipedia.org/wiki/%B4%FC%B9%C8%FB%CF%A6%B9>',
#                                                             '<http://ja.wikipedia.org/wiki/index.html?curid=1742858>',
#                                                             '<http://movi.es/BVUMn>',
# ...
#                                                   '"2005 Berlin International '
#                                                   'Film Festival"@en')}},
#   'ns/film.film.genre': { '072192': { ( '"Drama"@en',
#                                         '"Television drama"@en',
#                                         '"Drama film"@en',
#                                         '"/m/02822"@en',
#                                         '"Dramatic programming"@en'),
#                                       ( '"Romance Film"@en',
#                                         '"Romantic drama"@en',
#                                         '"Romance"@en')},
#                           '0b_xrk3': { ('"Animation"@en', '"Animated"@en'),
#                                        ( '"Short Film"@en',
#                                          '"Short subject"@en',
#                                          '"Short films"@en',
#                                          '"Short"@en')},
#                           '0gdjrjk': { ( '"Drama"@en',
#                                          '"Television drama"@en',
#                                          '"Drama film"@en',
#                                          '"/m/02822"@en',
#                                          '"Dramatic programming"@en'),
#                                        ('"LGBT"@en',)},
#                           '0gx2sh8': { ( '"Short Film"@en',
#                                          '"Short subject"@en',
#                                          '"Short films"@en',
#                                          '"Short"@en')}},
#   'ns/film.film.initial_release_date': { '072192': { '"1951-08-14"^^<http://www.w3.org/2001/XMLSchema#date>'},
#                                          '0b_xrk3': { '"1960"^^<http://www.w3.org/2001/XMLSchema#gYear>'},
#                                          '0gdjrjk': { '"1995"^^<http://www.w3.org/2001/XMLSchema#gYear>'},
#                                          '0gx2sh8': { '"2004"^^<http://www.w3.org/2001/XMLSchema#gYear>'}},
#   'ns/film.film.language': { '072192': { ( '"Sekgoa"@en',
#                                            '"English Language"@en',
#                                            '"English"@en',
#                                            '"Anglit"@en',
#                                            '"English language"@en')},
#                              '0b_xrk3': { ( '"Czech language"@en',
#                                             '"Bohemian"@en',
#                                             '"Czech Language"@en',
#                                             '"Czech"@en',
#                                             '"Cestina"@en'),
#                                           ( '"Sekgoa"@en',
#                                             '"English Language"@en',
#                                             '"English"@en',
#                                             '"Anglit"@en',
#                                             '"English language"@en')},
#                              '0gdjrjk': { ( '"Graecae"@en',
#                                             '"Grec"@en',
#                                             '"Greek Language"@en',
#                                             '"Neo-hellenic"@en',
#                                             '"Ellinika"@en',
#                                             '"Romaic"@en',
#                                             '"Modern Greek (1453-)"@en',
#                                             '"Greek"@en',
#                                             '"Greco"@en')},
#                              '0gx2sh8': { ( '"Français"@en',
#                                             '"French language"@en',
#                                             '"Francais"@en',
#                                             '"French"@en')}},
#   'ns/imdb.topic.title_id': { '072192': {'"tt0043924"'},
#                               '0b_xrk3': {'"tt0054186"'},
#                               '0gdjrjk': {'"tt1669558"'},
#                               '0gx2sh8': {'"tt0474444"'}},
#   'ns/type.object.name': { '072192': { '"A Place in the Sun"@ca',
#                                        '"A Place in the Sun"@en',
#                                        '"A Place in the Sun"@es',
#                                        '"A Place in the Sun"@ms',
#                                        '"A Place in the Sun"@nl',
#                                        '"Egy hely a nap alatt"@hu',
#                                        '"Ein Platz an der Sonne"@de',
#                                        '"En plats i solen"@sv',
#                                        '"Mesto pod soncem"@sl',
#                                        '"Miejsce pod słońcem"@pl',
#                                        '"Paikka auringossa"@fi',
#                                        '"Um Lugar ao Sol"@pt',
#                                        '"Um Lugar ao Sol"@pt-BR',
#                                        '"Um Lugar ao Sol"@pt-PT',
#                                        '"Un posto al sole"@it',
#                                        '"Une place au soleil"@fr',
#                                        '"Μια θέση στον ήλιο"@el',
#                                        '"Место под солнцем"@ru',
#                                        '"Място под слънцето"@bg',
#                                        '"מקום תחת השמש"@iw',
#                                        '"مكان في الشمس"@ar',
#                                        '"موقعیت مطلوب برای ترقی"@fa',
#                                        '"陽のあたる場所"@ja',
#                                        '"젊은이의 양지"@ko'},
#                            '0b_xrk3': { '"A Place in the Sun"@en',
#                                         '"O místo na slunci"@de'},
#                            '0gdjrjk': { '"A Place in the Sun"@en',
#                                         '"A Place in the Sun"@tr',
#                                         '"Μια Θέση στον Ήλιο"@el'},
#                            '0gx2sh8': {'"A Place In The Sun"@en'}}}
#
#
# [22] Question: How was the album ellen allien remix collection released?
# Subject Name: ellen allien remix collection
# Relation: music/album/release_type
# Number of Duplicates: 2
# Replaced Duplicates (Same MID via dataworld.gardening_hint.replaced_by): 1
# ALIASES:
# [ ( '<http://rdf.freebase.com/ns/m.01n61t7>',
#     ('"Ellen Allien Remix Collection"@en', '"Remix Collection"@en'))]
# COMPARABLE FACTS:
# {}
#
#
# [23] Question: The recording star is an adaptation of which song?
# Subject Name: star
# Relation: music/recording/canonical_version
# Number of Duplicates: 158
# Replaced Duplicates (Same MID via dataworld.gardening_hint.replaced_by): 1
# ALIASES:
# [ ('<http://rdf.freebase.com/ns/m.0tdbc5>', ('"Star"@en',)),
#   ('<http://rdf.freebase.com/ns/m.018_w84>', ('"Star"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0smgv62>', ('"Star"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0dpx3b9>', ('"Star"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0tb8_q>', ('"Star"@en',))]
# COMPARABLE FACTS:
# { 'ns/common.topic.topic_equivalent_webpage': { '018_w84': { '<http://musicbrainz.org/recording/7bba0a8b-e06a-403c-9b03-62f2e00df4b2>'},
#                                                 '0dpx3b9': { '<http://musicbrainz.org/recording/77a2f4e8-7b78-4238-9250-df6cb2f840f5>'},
#                                                 '0smgv62': { '<http://musicbrainz.org/recording/a0c36857-e4a5-489b-acdc-9f896ceb511d>'},
#                                                 '0tb8_q': { '<http://musicbrainz.org/recording/608c0609-3dd5-455b-910d-719be6b1edff>'},
#                                                 '0tdbc5': { '<http://musicbrainz.org/recording/1857ec21-e161-4dc0-abce-e32e53062e82>',
#                                                             '<http://musicbrainz.org/recording/1ed7e721-d492-42bc-afb6-293ec5495867>'}},
#   'ns/music.recording.artist': { '018_w84': { ( '"Nasareth"@en',
#                                                 '"Nazaret"@en',
#                                                 '"Nazareth"@en')},
#                                  '0dpx3b9': {('"Elysian Fields"@en',)},
#                                  '0smgv62': { ( '"Nasareth"@en',
#                                                 '"Nazaret"@en',
#                                                 '"Nazareth"@en')},
#                                  '0tb8_q': { ( '"Reamon"@en',
#                                                '"Reamonn"@en',
#                                                '"Reamonn-"@en')},
#                                  '0tdbc5': {('"08001"@en',)}}}
#
#
# [24] Question: what is the name of a track from roll over beethoven
# Subject Name: roll over beethoven
# Relation: music/recording/tracks
# Number of Duplicates: 178
# Replaced Duplicates (Same MID via dataworld.gardening_hint.replaced_by): 2
# ALIASES:
# [ ('<http://rdf.freebase.com/ns/m.0q64gd>', ('"Roll Over Beethoven"@en',)),
#   ('<http://rdf.freebase.com/ns/m.010lyt0>', ('"Roll Over Beethoven"@en',)),
#   ('<http://rdf.freebase.com/ns/m.015_449>', ('"Roll Over Beethoven"@en',)),
#   ('<http://rdf.freebase.com/ns/m.0f5vc2k>', ('"Roll Over Beethoven"@en',)),
#   ('<http://rdf.freebase.com/ns/m.01b6x14>', ('"Roll Over Beethoven"@en',))]
# COMPARABLE FACTS:
# { 'ns/common.topic.topic_equivalent_webpage': { '010lyt0': { '<http://musicbrainz.org/recording/47fbc8b9-b381-4f70-ab10-66b7d4ed7389>'},
#                                                 '015_449': { '<http://musicbrainz.org/recording/9d27d75d-e2bf-4564-a01a-d77d0af4abbc>'},
#                                                 '01b6x14': { '<http://musicbrainz.org/recording/cf539f53-4010-4758-9b53-59add40279f0>'},
#                                                 '0f5vc2k': { '<http://musicbrainz.org/recording/1f6070cd-8285-452e-98c2-d599e04853ad>',
#                                                              '<http://musicbrainz.org/recording/93f8966d-38f0-425e-b1ab-74a3e03cdb77>',
#                                                              '<http://musicbrainz.org/recording/d6f8de78-b0c3-4b37-a484-62066374b7cb>'},
#                                                 '0q64gd': { '<http://musicbrainz.org/recording/2049dd4f-2a52-4f73-bc1a-24ee2db04ca1>'}},
#   'ns/music.recording.artist': { '010lyt0': { ( '"John Henry Ramistella"@en',
#                                                 '"Ramistella, Johnny"@en',
#                                                 '"John Ramistella"@en',
#                                                 '"Johnny Ramistella"@en',
#                                                 '"Johnny Rivers"@en')},
#                                  '015_449': { ( '"Sgt. Pepper\'s Lonely Hearts '
#                                                 'Club Band"@en',
#                                                 '"The Fab Four"@en',
#                                                 '"披頭四"@en',
#                                                 '"Beatles"@en',
#                                                 '"Beetles"@en',
#                                                 '"The Silver Beetles"@en',
#                                                 '"the beatles"@en',
#                                                 '"金龜樂團"@en',
#                                                 '"The Beatles"@en')},
#                                  '01b6x14': { ( '"Killer"@en',
#                                                 '"The Killer Himself"@en',
#                                                 '"Lewis, Jerry Lee"@en',
#                                                 '"Jerry Lee Lewis"@en',
#                                                 '"The Killer"@en',
#                                                 '"The Ferriday Fireball"@en',
#                                                 '"Jerry Lee Lewis with His '
#                                                 'Pumping Piano"@en',
#                                                 '"Jerry Lewis"@en',
#                                                 '"rock & roll\'s first great '
#                                                 'wild man"@en',
#                                                 '"Gerald Lee Lewis"@en',
#                                                 '"Jerry Lee Lewis & His '
#                                                 'Pumping Piano"@en')},
#                                  '0f5vc2k': { ( '"Killer"@en',
#                                                 '"The Killer Himself"@en',
#                                                 '"Lewis, Jerry Lee"@en',
#                                                 '"Jerry Lee Lewis"@en',
#                                                 '"The Killer"@en',
#                                                 '"The Ferriday Fireball"@en',
#                                                 '"Jerry Lee Lewis with His '
#                                                 'Pumping Piano"@en',
#                                                 '"Jerry Lewis"@en',
#                                                 '"rock & roll\'s first great '
#                                                 'wild man"@en',
#                                                 '"Gerald Lee Lewis"@en',
#                                                 '"Jerry Lee Lewis & His '
#                                                 'Pumping Piano"@en'),
#                                               ( '"Lewis, Linda Gail"@en',
#                                                 '"Linda Gail Lewis"@en')},
#                                  '0q64gd': { ( '"E.L.O."@en',
#                                                '"E.L.O"@en',
#                                                '"E. L. O."@en',
#                                                '"エレクトリック・ライト・オーケストラ"@en',
#                                                '"The Electric Light '
#                                                'Orchestra"@en',
#                                                '"ELO"@en',
#                                                '"Electric Light '
#                                                'Orchestra"@en')}},
#   'ns/music.recording.length': { '010lyt0': {'"170.0"'},
#                                  '015_449': {'"135.893"'},
#                                  '01b6x14': {'"144.0"'},
#                                  '0f5vc2k': {'"118.0"'},
#                                  '0q64gd': {'"468.6"'}},
#   'ns/music.recording.releases': { '010lyt0': { ( '"At The Whisky Á Go Go / '
#                                                   'Here We Á Go Go '
#                                                   'Again!"@en',)},
#                                    '015_449': {('"1962 Live Recordings"@en',)},
#                                    '01b6x14': { ( '"Best of Jerry Lee '
#                                                   'Lewis"@en',)},
#                                    '0f5vc2k': { ( '"The Locust Years (disc '
#                                                   '7)"@en',
#                                                   '"The Locust Years (disc '
#                                                   '5)"@en',
#                                                   '"The Locust Years (disc '
#                                                   '4)"@en',
#                                                   '"The Locust Years (disc '
#                                                   '3)"@en',
#                                                   '"The Locust Years (disc '
#                                                   '2)"@en',
#                                                   '"The Locust Years (disc '
#                                                   '6)"@en',
#                                                   '"The Locust Years... (And '
#                                                   'the Return to the Promised '
#                                                   'Land) (disc 1)"@en',
#                                                   '"The Locust Years (disc '
#                                                   '8)"@en')},
#                                    '0q64gd': { ( '"Flashback (disc 2)"@en',
#                                                  '"Flashback"@en',
#                                                  '"Flashback (disc 3)"@en')}}}
